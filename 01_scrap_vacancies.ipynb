# %% [markdown]
# # Data scraping from hh.ru and preparation

# %% [markdown]
# Main goals of this file are:
# - to get hands-on experience on scraping raw data from the web
# - to get hands-on experience on basic processing / organizing datasets

# %% [markdown]
# Secondary goals:
# - to understand how one can get data about vacancies from the biggest Russian job site - hh.ru
# - to make a snapshot of DS vacancies, process it and save in .csv for further analysis

# %%
#import requests
#import urllib.request
from datetime import datetime as dt
#import re
from bs4 import BeautifulSoup
import json
import numpy as np
import pandas as pd

from time import sleep

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium import webdriver

import sys

# %%
import logging

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

handler = logging.StreamHandler(stream=sys.stdout)
handler.setFormatter(logging.Formatter(fmt='[%(asctime)s: %(funcName)s: %(levelname)s] %(message)s'))
logger.addHandler(handler)

# %% [markdown]
# ## Preparations

# %%
output_filename_base = 'vacancies-data-scientist-'

# %% [markdown]
# URLs to search vacancies by words "аналитик данных" / "data scien*" in hh.ru looks like:
# https://hh.ru/search/vacancy?
#     text=data+scien*&                   # will be format parameter
#     search_field=name&search_field=description&
#     area=1&                             # will be format parameter, if is missing => search in all areas, can contain several values (area=1&area=2&...)
#     salary=150000&currency_code=RUR&    # will be format parameter, if set to '' (salary=&...) => search for all salary amounts
#     only_with_salary=true&              # leave only vacancies with salary
#     label=not_from_agency&              # leave direct eployers only
#     experience=doesNotMatter&
#     professional_role=96&               # if filter by specialization needed (96 = programmer, developer)
#     order_by=relevance&
#     search_period=0&
#     items_on_page=100&
#     no_magic=true&
#     L_save_area=true
#     page=1&                         # these 2 parameters are used when navigating to different pages
#     hhtmFrom=vacancy_search_list

# %%
"""
Artefacts from v1

search_url_template = "https://hh.ru/search/vacancy?text={search_text}{search_fields}{areas}&salary={salary}&currency_code=RUR&experience=doesNotMatter{other}&order_by=relevance&search_period=0&items_on_page=100"
salary_level = '' #'150000'
search_texts = [
    "data+scien*",
    "%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85",
    "data analy*",
    "{}",
    "разработчик"
]
search_fields = {
    'vac_name': '&search_field=name',
    'vac_descr': '&search_field=description'
}
areas = {
    '#later': '{areas}', # left to configure later
    'All': '',
    'Moscow': '&area=1',
    'SPb': '&area=2',
    'Ekaterinburg': '&area=3',
    'Novosib': '&area=4',
    'Austria': '&area=7',
    'Erevan': '&area=13',
    'NNovgorod': '&area=66',
    'RostovND': '&area=76',
    'Samara': '&area=78',
    'Saratov': '&area=79',
    'Kazan': '&area=88',
    'Chelyabinsk': '&area=104',
    '???': '&area=159',
    'Almaty': '&area=160',
    'Minsk': '&area=1002',
    'Nur-Sultan': '&area=159',
    'Tbilisi': '&area=2758',
    'Tashkent': '&area=2759',
}
url_tail = '&page={}&hhtmFrom=vacancy_search_list'
"""

# %%
"""
Artefacts from v1
def combine_base_url(template=None, search_text='', search_field_keys=['vac_name'], area_keys=[], salary='', only_with_salary=False, other=''): #, items_per_page=100
    if template is None:
        return None
    search_fields_str = ''
    for key in search_field_keys:
        search_fields_str += search_fields[key]
    areas_str = ''
    for key in area_keys:
        areas_str += areas[key]
    if salary == '' or salary is None:
        salary_str = ''
    else:
        salary_str = str(salary)
    if only_with_salary:
        salary_str +=  '&only_with_salary=true'
    return template.format(search_text=search_text, search_fields=search_fields_str, areas=areas_str, salary=salary_str, other=other) #, items_per_page
"""

# %%
"""
base_url = combine_base_url(
    template = search_url_template,
    search_text=search_texts[4],
    area_keys=['Moscow'],
    salary=salary_level, only_with_salary=True,
    other='&label=not_from_agency&professional_role=96' # only for programmers vacancies
)
base_url
"""
# Out:
# 'https://hh.ru/search/vacancy?text=разработчик&search_field=name&area=1&salary=&only_with_salary=true&currency_code=RUR&experience=doesNotMatter&label=not_from_agency&professional_role=96&order_by=relevance&search_period=0&items_on_page=100'

# %% [markdown]
# Simple class to contruct url

# %%
class HhRuUrlConstructor():
    map_search_fields = {
        'vac_name': '&search_field=name',
        'vac_descr': '&search_field=description'
    }

    map_areas = {
        None: '{areas}', # left to configure later
        'All': '',
        'Moscow': '&area=1',
        'SPb': '&area=2',
        'Ekaterinburg': '&area=3',
        'Novosib': '&area=4',
        'Austria': '&area=7',
        'Erevan': '&area=13',
        'NNovgorod': '&area=66',
        'RostovND': '&area=76',
        'Samara': '&area=78',
        'Saratov': '&area=79',
        'Kazan': '&area=88',
        'Chelyabinsk': '&area=104',
        '???': '&area=159',
        'Almaty': '&area=160',
        'Minsk': '&area=1002',
        'Nur-Sultan': '&area=159',
        'Tbilisi': '&area=2758',
        'Tashkent': '&area=2759',
    }

    base_part = 'https://hh.ru/search/vacancy?'
    url_tail = '&experience=doesNotMatter{other}&order_by=relevance&search_period=0&items_on_page=100'
    search_paging = '&page={}&hhtmFrom=vacancy_search_list'

    
    def __init__(self,
                    vacancy_name=None,
                    search_fields=['vac_name', 'vac_descr'],
                    areas=['Moscow'],
                    salary_level=None, # -1 or None = all available, but -1 is easier to check and overwrite later
                    currency='RUR',
                    only_with_salary=False,
                    other=''
                ) -> None:
        self.vacancy_name = vacancy_name
        self.search_fields = search_fields
        self.areas = areas
        self.salary_level = salary_level
        self.currency = currency
        self.only_with_salary = only_with_salary
        self.other = other
        
    def _get_url_vacancy(self, vacancy_name):
        result = ''
        if vacancy_name is None:
            vacancy_name = self.vacancy_name
        if vacancy_name is not None:
            result += 'text=' + self.vacancy_name
        return result
    

    def _get_url_search_fields(self, sfields):
        if sfields is None:
            sfields = self.search_fields
        if sfields is None:
            return ''
        result = ''
        if type(sfields) == type(list()):
            for i in sfields:
                result += self.map_search_fields.get(i, '')
        else:
            result += self.map_search_fields.get(sfields, '')
        return result
    

    def _get_url_areas(self, areas):
        result=''
        if areas is None:
            areas = self.areas
        if areas is None:
            return result
        if type(areas) == type(list()):
            for i in areas:
                result += self.map_areas.get(i, '')
        else:
            result += self.map_areas.get(areas, '')
        return result

        
    def _get_url_salary(self, salary, currency, only_with_salary): # salary == -1 -> get class default value (received when instantiated)
        result=''
        is_salary_given = False
        if salary == -1: # use default from class when instantiated
            salary = self.salary_level
        if (salary is not None) and (salary != -1): # now both values -> all available
            result += '&salary={}'.format(salary)
            is_salary_given = True
        if currency == -1: # use default from class when instantiated
            currency = self.currency
        if (currency is not None) and (currency != -1): # now both values -> all values
            result += '&currency_code=' + currency
        
        if is_salary_given: # if salary was given we can't ignore it even if [self.]only_with_salary set to False
            result += '&only_with_salary=true'
        else:
            if only_with_salary is None: # use default from class when instantiated
                only_with_salary = self.only_with_salary
            if only_with_salary is not None:
                result += '&only_with_salary=' + str(only_with_salary).lower()
        
        return result

            
    def get_url(self, sfields=None, areas=None, salary=-1, currency=-1, only_with_salary=None, other='', page=None):
        result = self.base_part + \
                self._get_url_vacancy(vacancy_name=None) + \
                self._get_url_search_fields(sfields=sfields) + \
                self._get_url_areas(areas=areas) + \
                self._get_url_salary(salary=salary, currency=currency, only_with_salary=only_with_salary) + \
                self.url_tail.format(other=other)
        if (page is None) or (page == 0):
            return result
        elif page == 'param':
            return result + self.search_paging
        else:
            return result + self.search_paging.format(page)

# %% [markdown]
# Testing created class on different search queries:

# %%
search_query = HhRuUrlConstructor(
    vacancy_name="data+scien*",
    search_fields='vac_name',
)
print(search_query.get_url())
print(search_query.get_url(areas='SPb')) # area=2 instead of 1
print(search_query.get_url(salary=200000))
print(search_query.get_url(salary=4000, currency='USD'))
# Out:
# https://hh.ru/search/vacancy?text=data+scien*&search_field=name&area=1&currency_code=RUR&only_with_salary=false&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100
# https://hh.ru/search/vacancy?text=data+scien*&search_field=name&area=2&currency_code=RUR&only_with_salary=false&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100
# https://hh.ru/search/vacancy?text=data+scien*&search_field=name&area=1&salary=200000&currency_code=RUR&only_with_salary=true&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100
# https://hh.ru/search/vacancy?text=data+scien*&search_field=name&area=1&salary=4000&currency_code=USD&only_with_salary=true&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100

# %% [markdown]
# Making query url too receive full pull of data (with or without salary mentioned):
# - vacancy name: data analyst in Russian (there is no equivalent for 'data scientist')
# - search by: vacancy name only (do not search in vacancy description)
# - search area: Moscow only (the most vacancies are there)

# %% [markdown]
# Preparing browser under selenium control to collect data

# %%
chrome_mode = 'headed' #'headless' # for debug purposes we can change this value to any but 'headless' to run Chrome in standard mode
chrome_options = Options()
if chrome_mode == 'headless':
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--disable-gpu')
    chrome_options.add_argument('--headless')
service = Service(executable_path="d:\\Applications\\WebDriver\\chromedriver-107-x32.exe")
browser = webdriver.Chrome(service=service, options=chrome_options)

# %%
browser.get(search_query.get_url())

# %% [markdown]
# The page source code analysis shows that all info about vacancies is located under 'template' key. This 1-row data looks like json-parseable multilevel structure. So let's feed it to json module and analyse more deeply.

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')
# Page source code showed us there is only 1 'template' tag on page.
# It contains a huge amount of data including vacancies list in dictionary-like format (possibly for JS parsing).
json_parsed = json.loads(soup.find_all('template')[0].text)
print('"Template" tag contains {} keys'.format(len(json_parsed)))
# Out:
# "Template" tag contains 525 keys

# %%
json_parsed
# Out:
# {'authPhone': None,
#  'authNewEmployerAreaIdsToRedirect': [],
#  'authNewEmployerCategories': [],
#  'authNewEmployerFields': [],
#  'authNewEmployerInitialValues': {},
#  'authNewEmployerPhoneMask': None,
#  'activeResumeAccessType': None,
#  'accountTemporarilyLocked': {},
#  'accountPhoneVerification': None,
#  'applicantSignup': {'fields': [{'name': 'login',
#     'conditions': {'minCount': 1,
#      'maxCount': 1,
#      'parts': [{'minLength': 0, 'maxLength': 127}]},
#     'simpleValues': None,
#     'customValues': None,
#     'error': None,
#     'warning': None,
#     'empty': True},
#    {'name': 'password',
#     'conditions': {'minCount': 1,
#      'maxCount': 1,
#      'parts': [{'minLength': 6, 'maxLength': 32}]},
#     'simpleValues': None,
#     'customValues': None,
#     'error': None,
#     'warning': None,
#     'empty': True},
#    {'name': 'firstName',
#     'conditions': {'minCount': 1,
#      'maxCount': 1,
#      'parts': [{'minLength': 1, 'maxLength': 255}]},
#     'simpleValues': None,
#     'customValues': None,
#     'error': None,
#     'warning': None,
#     'empty': True},
#    {'name': 'lastName',
#     'conditions': {'minCount': 1,
#      'maxCount': 1,
#      'parts': [{'minLength': 1, 'maxLength': 255}]},
#     'simpleValues': None,
#     'customValues': None,
#     'error': None,
#     'warning': None,
#     'empty': True}],
#   'hideLogin': False},
#  'applicantVacancyResponseStatuses': {},
#  'applicantResumes': [],
#  'applicantResponseStreaks': {},
#  'applicantPackageType': 'basic',
#  'applicantServiceType': '',
#  'applicantPaymentBackUrl': '',
#  'applicantAnalyticsAction': '',
#  'applicantPaymentTypes': [],
#  'applicantAvailableResumeServices': [],
#  'applicantPackageContent': [],
#  'applicantAvailableQuantities': [],
#  'applicantServicesPrices': {},
#  'applicantPaymentSource': 'desktop',
#  'applicantFindJobRecommendedQuantity': None,
#  'applicantSuitableVacancyByResume': {},
#  'account': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountConnect': {},
#  'accountConnectOAuth': {},
#  'accountConnectResponse': {},
#  'actualAccount': None,
#  'accountHistoryServices': {'employerActiveTemporalServices': [],
#   'employerTemporalServices': [],
#   'employerActiveSingleServices': [],
#   'employerFreeServices': []},
#  'accountHistoryReplenishments': {'bills': [],
#   'documentLinksVisibility': False,
#   'currency': 'RUR'},
#  'accountHistoryExpenditures': {'services': [], 'currency': ''},
#  'artifactRules': None,
#  'hhidAccount': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountDelete': {'applicantName': '',
#   'resumesList': {'resumes': {'published': [], 'unpublished': []},
#    'count': 0}},
#  'adsSearchParams': {'puid11': 'searchVacancy',
#   'puid23': 'Москва',
#   'puid14': 'data scien*',
#   'puid29': '',
#   'puid30': '',
#   'puid12': '',
#   'puid13': ''},
#  'adsVacancyParams': {},
#  'alreadyRegisteredEmployer': None,
#  'anonymousUserType': 'applicant',
#  'advancedSearch': {'showSearchConditions': False,
#   'hideSuggest': False,
#   'vacancy': None,
#   'resume': None,
#   'experience': [],
#   'keySkills': [],
#   'university': [],
#   'citizenship': [],
#   'work_ticket': [],
#   'employment': [],
#   'schedule': [],
#   'driver_license_types': [],
#   'job_search_status': [],
#   'language': [],
#   'exclusion': []},
#  'advancedVacancySearch': {'text': '',
#   'randomExampleNumber': 1,
#   'searchFields': [],
#   'selectedValues': {}},
#  'anonymousEmployer': {'suggestedProfessions': [],
#   'applicantCount': None,
#   'publicationPrice': None,
#   'dbAccessPrice': None,
#   'averageEmployersOnline': None,
#   'statisticsDate': None},
#  'allowedSMSCountries': None,
#  'appleBusinessChat': {'isEnabled': False, 'href': ''},
#  'abortPageContent': False,
#  'applicantEmployersNegotiationStats': {'employer-negotiation-stats': []},
#  'applicantEmployerManagersActivity': [],
#  'applicantNews': [],
#  'applicantArticles': [],
#  'applicantLatestResume': None,
#  'applicantFaq': [],
#  'addressesSuggestRemoteMode': False,
#  'analyticsParams': {'hhtmSource': 'vacancy_search_list',
#   'hhtmFrom': '',
#   'hhtmSourceLabel': '',
#   'hhtmFromLabel': '',
#   'screenType': 'SIMPLE'},
#  'applicantInfo': {'total': 0, 'finished': 0, 'visible': 0, 'searchable': 0},
#  'applicantNegotiations': {'topicList': [], 'filterInUse': 'all'},
#  'applicantNegotiationsActionsData': {'deleteAction': {},
#   'filters': [],
#   'filterByStatus': [],
#   'backUrl': '',
#   'order': {}},
#  'applicantPaymentServices': [],
#  'applicantResumesStatistics': {},
#  'applicantSettingsMenu': [],
#  'applicantSubscriptions': {'formItems': {},
#   'initialValues': {},
#   'email': None,
#   'emailVerified': None},
#  'applicantUseful': [],
#  'applicantUserStatuses': None,
#  'applicantNeedJobSearchStatusChangeModal': False,
#  'applicantPossibleJobOffers': [],
#  'authUrl': {'login-url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-form': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-field-value': '',
#   'backurl-field-name': 'backUrl',
#   'remember-field-name': 'remember',
#   'remember-field-value': 'yes',
#   'backurl': 'https://hh.ru/search/vacancy?text=data+scien%2A&search_field=name&area=1&currency_code=RUR&only_with_salary=false&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#   'failurl': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'signup-form': '/account/signup?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'auth-employer-url': '/auth/employer/?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'remember-password': '/account/remember_password?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'agreement-form': '/account/agreement?backurl=%2Faccount%2Fsignup%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526area%253D1%2526currency_code%253DRUR%2526only_with_salary%253Dfalse%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100',
#   'employer-agreement': '/auth/employer/agreement?backurl=%2Fauth%2Femployer%2F%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526area%253D1%2526currency_code%253DRUR%2526only_with_salary%253Dfalse%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100'},
#  'availableVacancyActions': {},
#  'analyticsConversionPromo': None,
#  'brandedVacancyTemplates': [],
#  'employerSubscriptions': {'initialValues': {}, 'employerId': ''},
#  'emailVerification': {'email': '', 'needVerification': False, 'mailURL': ''},
#  'employerTests': [],
#  'employerResumesNegotiationLinks': {},
#  'employerRegistrationPresentsByCountryId': {},
#  'applicantResumesIdentifiers': [],
#  'areaTree': [],
#  'assessments': {'assessments': []},
#  'loginForm': {'passwordRecovery': {'trl': 'Получить пароль'},
#   'registration': [{'trl': 'Соискателя',
#     'code': 'REG_APPLICANT',
#     'translationKey': 'account.login.registration.applicant.capitalized'},
#    {'trl': 'Работодателя',
#     'code': 'REG_EMPLOYER',
#     'translationKey': 'account.login.registration.employer.capitalized'}],
#   'socialNetworks': [{'trl': 'Google',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'GPLUS',
#     'translationKey': 'socialNetworkTitle.gplus'},
#    {'trl': 'Мой Мир@mail.ru',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'MAIL',
#     'translationKey': 'socialNetworkTitle.mail'},
#    {'trl': 'ВКонтакте',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'VK',
#     'translationKey': 'socialNetworkTitle.vk'},
#    {'trl': 'Одноклассники',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'OK',
#     'translationKey': 'socialNetworkTitle.ok'},
#    {'trl': 'Доктор на работе',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'DNR',
#     'translationKey': 'socialNetworkTitle.dnr'},
#    {'trl': 'Госуслуги',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=ESIA&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'ESIA',
#     'translationKey': 'socialNetworkTitle.esia'}],
#   'registrationSocialNetworks': [{'trl': 'Google',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'GPLUS',
#     'translationKey': 'socialNetworkTitle.gplus'},
#    {'trl': 'Мой Мир@mail.ru',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'MAIL',
#     'translationKey': 'socialNetworkTitle.mail'},
#    {'trl': 'ВКонтакте',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'VK',
#     'translationKey': 'socialNetworkTitle.vk'},
#    {'trl': 'Одноклассники',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'OK',
#     'translationKey': 'socialNetworkTitle.ok'},
#    {'trl': 'Доктор на работе',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'DNR',
#     'translationKey': 'socialNetworkTitle.dnr'},
#    {'trl': 'Госуслуги',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=ESIA&_xsrf=1d9235fc6ed2a6b6e6ee94f59314e355&hhtmSource=vacancy_search_list&userType=applicant',
#     'code': 'ESIA',
#     'translationKey': 'socialNetworkTitle.esia'}]},
#  'backofficeCanEditTemplate': True,
#  'backUrl': None,
#  'banners': {'under-pagination-search-results-l': [{'id': '293',
#     'cId': 'db135865-3127-4720-993c-82495f3b0db7',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'under-pagination-search-results-m': [{'id': '294',
#     'cId': '8effab6c-004c-46d4-99bb-96028813cfe1',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'under-pagination-search-results-s': [{'id': '292',
#     'cId': 'ff58add4-560f-451a-b16a-b57528faf913',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'under-pagination-search-results-xs': [{'id': '521',
#     'cId': 'eaff18ec-1d4c-480b-9b49-69af5679326e',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-rotate': [{'id': '654',
#     'cId': '44ebe122-7be5-4e1c-bb20-4bc06df75d46'},
#    {'id': '655', 'cId': '5f34d737-f2ac-4087-aad9-8c15b2e7ffb1'}],
#   'serp-first-l': [{'id': '221',
#     'cId': '97c125de-e238-47d4-b913-706533fffb41',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-first-m': [{'id': '637',
#     'cId': '18cff1a4-9e2d-4590-8a3e-c3d3f7da3044',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-first-s': [{'id': '613',
#     'cId': 'a8fb6a28-bceb-4048-87fa-1c228357d2fc',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-first-xs': [{'id': '630',
#     'cId': 'ed8a17f3-2d61-4c6e-bfa0-eafe8d8878fa',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-second-l': [{'id': '175',
#     'cId': '5b7a152c-edc6-4aee-8498-4cf33b0322cf',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-second-m': [{'id': '347',
#     'cId': 'd0e77f1d-2786-4409-906c-5f1b2146a509',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-second-s': [{'id': '638',
#     'cId': 'f14ffcac-fd29-46fe-9c22-5fa3162a9e5a',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-second-xs': [{'id': '505',
#     'cId': '2afcec0a-1f07-47b5-b917-7ff4332dc870',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-xs': [{'id': '661',
#     'cId': 'cb18588e-5c18-4422-a37e-b7c9d2a02f5f'},
#    {'id': '662', 'cId': 'dbc2e27d-a0ef-4e67-8936-a8324c1baa76'},
#    {'id': '663', 'cId': '0e820a4f-ce10-41e9-8795-ac34d256a739'}],
#   'serp-third-l': [{'id': '72',
#     'cId': 'be12f6ed-b3d5-4ae8-ad3c-9c36e8970054',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-third-m': [{'id': '261',
#     'cId': '2619a2fb-b602-48dc-89d2-6d6a25430252',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-third-s': [{'id': '261',
#     'cId': '32f1a448-7e1e-4867-af6f-ba00dc13a0ae',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-third-xs': [{'id': '60',
#     'cId': '87c73ab9-0582-4469-b629-f6f2d6085854',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fourth-l': [{'id': '69',
#     'cId': '299881f8-be45-473f-bf69-69cee0297869',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fourth-m': [{'id': '91',
#     'cId': '4214fa83-5000-4a01-ab40-b39366f210ce',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fourth-s': [{'id': '91',
#     'cId': '9cbe5a71-00a8-41e1-bca5-71f516ce7c1a',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fourth-xs': [{'id': '59',
#     'cId': '7dbd7b29-4c48-401a-869a-7d32ff3dc3a8',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fifth-l': [{'id': '158',
#     'cId': 'c6a91d2a-fc1f-42d3-bd22-7771f5ccd3d9',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fifth-m': [{'id': '87',
#     'cId': '0b0555cd-f25e-4294-8940-163f52c5c493',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fifth-s': [{'id': '87',
#     'cId': '51a8ef33-506c-4ebd-bb88-2026a08b2f6c',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fifth-xs': [{'id': '19',
#     'cId': 'ea081b59-2864-44c5-91fa-fdbf02143c57',
#     'pp': 'g',
#     'p2': 'hoyc'}]},
#  'bannersImage': {},
#  'blogPage': {'rubrics': [],
#   'rubric': None,
#   'topic': None,
#   'isBlogEnable': False,
#   'slider': [],
#   'articles': {'items': [], 'paging': None}},
#  'cancelFetchBanners': False,
#  'candidates': {'collection': {'actions': [], 'filters': []},
#   'onlyAssessments': False},
#  'candidatesList': None,
#  'captchaAccountState': {'state': '', 'backurl': '', 'failurl': ''},
#  'careerMarathon': {'email': '', 'emailVerified': False},
#  'catalogLinks': [],
#  'chatBot': {'messengers': [{'type': 'vk',
#     'icon': 'Vk',
#     'href': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//hh.ru/search/vacancy%3Farea%3D1%26enable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26text%3Ddata%2Bscien%252A'},
#    {'type': 'telegram',
#     'icon': 'Telegram',
#     'href': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//hh.ru/search/vacancy%3Farea%3D1%26enable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26text%3Ddata%2Bscien%252A'},
#    {'type': 'viber',
#     'icon': 'Viber',
#     'href': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//hh.ru/search/vacancy%3Farea%3D1%26enable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26text%3Ddata%2Bscien%252A'}],
#   'page': 'vacancysearch',
#   'genericUserType': 'anonymous',
#   'source': 'hhru',
#   'href': 'https://chatbot.hh.ru/hh-bot?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//hh.ru/search/vacancy%3Farea%3D1%26enable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26text%3Ddata%2Bscien%252A'},
#  'chatik': None,
#  'chatikIntegration': False,
#  'chatikUnreadCount': 0,
#  'checkedTopics': [],
#  'checkedEmployerFAQLink': 'https://feedback.hh.ru/article/details/id/5951',
#  'clickmeInfo': None,
#  'commentsByUserId': {},
#  'companiesOfTheDay': [],
#  'config': {'staticHost': 'https://i.hh.ru',
#   'hhcdnHost': 'https://hhcdn.ru',
#   'imageResizingCdnHost': 'https://img.hhcdn.ru'},
#  'counters': {'liveInternet': [{'id': ';HeadHunter?t14.6;'}],
#   'yandex': [{'id': '156828'}],
#   'googleUniversalAnalytics': [{'id': 'UA-11659974-2', 'type': 'main'},
#    {'id': 'G-44H5WGZ123', 'type': 'ga4'}],
#   'mytracker': [{'id': '3209834', 'type': 'main'}],
#   'vkTargeting': [{'id': 'VK-RTRG-318408-3u7id'},
#    {'id': 'VK-RTRG-737575-4yDN2', 'type': 'rw'}]},
#  'countryPhoneCode': '',
#  'untrustedEmployer': False,
#  'contactPhones': [{'country': '+7',
#    'city': '495',
#    'number': '974-64-27',
#    'postfix': 'msk'},
#   {'country': '+7', 'city': '812', 'number': '458-45-45', 'postfix': 'spb'},
#   {'country': '8',
#    'city': '800',
#    'number': '100-64-27',
#    'postfix': 'regions'}],
#  'companiesOfTheDayTrls': {'area': ''},
#  'currencies': {'default': 'RUR',
#   'list': [{'code': 'RUR',
#     'name': 'руб.',
#     'gender': 'MASCULINE',
#     'rate': 1,
#     'defaultCurrency': True,
#     'site': True},
#    {'code': 'USD',
#     'name': 'USD',
#     'gender': 'MASCULINE',
#     'rate': 0.016534,
#     'defaultCurrency': False,
#     'site': True},
#    {'code': 'EUR',
#     'name': 'EUR',
#     'gender': 'MASCULINE',
#     'rate': 0.015904,
#     'defaultCurrency': False,
#     'site': True}]},
#  'complaintReasonTypes': [],
#  'competitorAnalysisBanner': {},
#  'chatWritePossibilities': [],
#  'criteriaCurrencyCode': 'RUR',
#  'crosslinks': None,
#  'currentManagerId': '',
#  'countryId': '1',
#  'defaultCountryCompanySearchId': '113',
#  'detectedVacancySearchAreaIds': ['180'],
#  'discriminationWarning': False,
#  'chatResponseId': None,
#  'displayType': 'DESKTOP',
#  'distances': None,
#  'domainRegionTrl': '',
#  'domainAreaId': '1',
#  'draftsPurchaseInfo': {},
#  'employerAddresses': [],
#  'employerAddressesCount': None,
#  'employerAddressesPage': {'addresses': [],
#   'addressesCount': 0,
#   'isFetching': False,
#   'loadingComponent': ''},
#  'employerArticles': [],
#  'employerBillingInfo': None,
#  'employerCarts': None,
#  'employerChecks': {},
#  'employerAdvice': None,
#  'employerAdvices': [],
#  'employerButtons': {},
#  'employerNegotiationsChangeTopic': None,
#  'employerCompanyMenu': [],
#  'employerConstructorWebViewMode': False,
#  'employerConstructorAutoAddWidget': None,
#  'employerConstructorSettings': {'pictureSettings': {}},
#  'employerConstructor': {'editMode': False,
#   'previewModeWithBranding': True,
#   'version': None,
#   'canEdit': False,
#   'modalError': None,
#   'widgets': [],
#   'widgetsOrder': [],
#   'saveStatus': 'DIRTY',
#   'hasUnsavedChanges': False,
#   'pictureId': None,
#   'resizeStatus': 'DIRTY',
#   'images': [],
#   'tabPrices': [],
#   'hasConstructor': False,
#   'hasService': False,
#   'readyToActivateCartId': None,
#   'sidebarColors': {}},
#  'employerDocuments': [],
#  'employerPageIsViewMode': False,
#  'employerCurrentDivision': None,
#  'employerDocumentsSettings': {},
#  'employerEdoList': [],
#  'employerDocumentsMenu': [],
#  'employerDepartments': [],
#  'employerDivisions': {},
#  'employerFaq': [],
#  'employerHasDivisions': False,
#  'employerId': '',
#  'employerImplants': None,
#  'employerName': '',
#  'employerIndexPage': {},
#  'employerLogo': {'logoUrl': None, 'logoStatus': 'Dirty'},
#  'edoDictionary': None,
#  'employerInfo': {'accreditedITEmployer': False,
#   'id': None,
#   'name': None,
#   'category': None,
#   'address': None,
#   'site': None,
#   'industries': None,
#   'hrBrand': None,
#   'description': None,
#   'saveDescriptionStatus': 'DIRTY',
#   'organizationFormId': None,
#   'isTrusted': False,
#   'canEditDescription': False,
#   'hasUnsavedChanges': False,
#   'employerCountryCode': '',
#   'previousEmployerTargets': []},
#  'employerInsiders': [],
#  'employerInvoicePurchase': {'cart': {'cartId': None, 'services': []},
#   'activations': {'services': {}, 'currentActivationType': None}},
#  'employerInvoicePayment': {'hasPayers': False,
#   'hasPersonAgreement': False,
#   'payers': [],
#   'payersLoading': False,
#   'employer': {'currency': 'RUR', 'country': 'RU', 'employerId': None},
#   'paymentTypesOrder': [],
#   'paymentTypes': {},
#   'organisationTypes': [],
#   'payerMetadata': None,
#   'payer': None,
#   'countries': [],
#   'vats': None,
#   'billTypes': [],
#   'sellers': []},
#  'employerReviewsModal': {'visible': False, 'reviewsEnabled': False},
#  'employerLastSearches': [],
#  'employersListQuery': None,
#  'employerSeoCities': [],
#  'employerSettingsVacancyPublication': {},
#  'employerInsiderInterview': None,
#  'employerManager': None,
#  'employerNoAdviceArticles': [],
#  'employerManagersPage': {'managersViewMeta': {'ableToCreateManager': False,
#    'canEditEmployerManagerQuotas': False,
#    'managersCreationLimitReached': True,
#    'onlyOneManagerEnabled': False,
#    'MCPSGroup': False,
#    'resumeViewsAccessDenied': True,
#    'ResumeViewHistory': False,
#    'showResumeViewsNumbers': False,
#    'giveMCPAllowed': False,
#    'userEmail': ''},
#   'managersShown': [],
#   'negotiationStats': {'politeness-index': {},
#    'responses-read-percent': {},
#    'responses-read-percent-change': {},
#    'responses-received': {},
#    'responses-replied-percent': {},
#    'responses-replied-percent-change': {},
#    'responses-reply-time-days': {}},
#   'resumeViews': {},
#   'filter': '',
#   'loading': False},
#  'employerManagersList': [],
#  'employerManagers': [],
#  'employerMarketSegmentType': None,
#  'employerConsumptionSegmentType': None,
#  'employersList': {'totalEmployersFound': 0, 'employers': [], 'paging': None},
#  'employerNews': [],
#  'employerArchiveVacancyParams': '',
#  'employerExperiences': {'experience': []},
#  'employerReviewsApplicantProfileBadge': False,
#  'employerReviewsApplicantShowIndexWidget': False,
#  'employerReviewsVisibilityStatus': None,
#  'employerSearchSettings': {},
#  'employerSettingsMenu': {'employerManagersLink': '/employer/managers',
#   'menuItems': [],
#   'employerManagerName': ''},
#  'employerNegotiations': {'total': None,
#   'maximumTopicsPerUser': None,
#   'topicList': [],
#   'responseLetters': {},
#   'count': None},
#  'employerSettingsPage': {'email': '',
#   'newEmail': '',
#   'changeEmailHoverTip': None,
#   'MCPName': '',
#   'targetEmployerManagerId': '',
#   'changeEmailForMyself': True},
#  'employerStatus': {'category': '',
#   'state': '',
#   'countryId': '',
#   'suspiciousState': 'NOT_SUSPICIOUS'},
#  'employerViewSelectedAreas': [],
#  'enableBottomSheetVacancyResponse': False,
#  'enableSimilarSavedSearch': False,
#  'enableJobSearchStatus': False,
#  'enableItAccreditation': False,
#  'experiments': {'enabled': {'ux_feedback_cooldown_7_days': 'control',
#    'contact_button_18937': 'experiment',
#    'move_down_vacancy_search_chips': 'experiment',
#    'uxfeedback_employer_page_enabled': 'experiment',
#    'new_applicant_xs_mobile_suggest': 'experiment',
#    'tempexp_hh_158885': 'experiment',
#    'zp_test_api': 'experiment',
#    'captcha_remember_password': 'experiment'},
#   'checked': []},
#  'extraFilters': ['podrabotka',
#   'za_sutki',
#   'za_poslednie_tri_dnya',
#   'bez_opyta_raboty',
#   'polnaya_zanyatost',
#   'chastichnaya_zanyatost',
#   'proektnaya_rabota',
#   'polniy_den',
#   'smenniy_grafik',
#   'vakhtoviy_metod',
#   'udalennaya_rabota',
#   'gibkiy_grafik',
#   'ot_pryamih_rabotodateley',
#   'rabota_dlya_invalidov'],
#  'educationLevels': [],
#  'errorCode': None,
#  'excludedVacancyPublicationAreas': [],
#  'favoriteVacancies': {},
#  'fastVacanciesSubscriptionSettings': {},
#  'favoriteVacanciesCount': None,
#  'features': {'cookies_policy_banner': True,
#   'critical_cookies_list': 'cookie_policy_agreement,hhuid,crypted_hhuid,hhtoken,hhrole,_xsrf,supernova_user_type,_hi,regions,device_breakpoint,GMT,region_clarified,already_registered,lrr,lrp,__ddg1,display,cpa,cpa_employer_id,cpa_deduplication_source',
#   'belarus_resume_stats_hide': True,
#   'new_vacancy_suggest': True,
#   'delayed_cart_activation_article_id': '30085',
#   'belarus_restrictions_hhids': '146897816,146898090,146898104,146898105,146898134,146898135,146898155,146898164,146898247,146898248,146898249,146898347,146898348,146898349,146898354,146898355,146898356',
#   'dedicated_admin_webim_location_in_help': False,
#   'tempexp_18200_employer_ids': '2203486,5483321,1380,1098606,602513,4145,129273,5229045,4180234,5515442,2662485,3795966,3844725,4863497,1291951,5280732,5301711,150011,56711,152063,1017866,848257,113656,708720,682766,1147771,2211838,3052365,1344498,1612956,3350391,1611870,3477677,4290508,968766,1476871,4728159,143439,3588376,752653,4837917,2883966,4087607,2193,5733981,2172573,215699,4861098,145019,1733807,4109583,7044800,237572,2284658,1749095,48970,3506285,2564930,4752892,5088530,4091490,8284948,5353584,4257891,8015,3789495,1017413,2914898,4920821,30666,546756,3338353,218627,2740164,3122483,4898549,3348455,947927,1726677,2226563,105382,4527537,666204,1066018,48711,3417016,2618089,5951038,1175930,1986131,1774445,4741257,1786224,1064915,1184269,8966,738253,1776381,18475,5085558,1729662,1150295,923507,3800984,46863,1655723,1464510,2650498,3382376,1119,4937131,3516325,1949635,3200718,2787885,100642,3027918,2622936,4107043,1990166,3390148,5760547,3176470,6514103,627122,3385480,630474,1411830,43249,5704483,2076308,3172476,647694,2999049,3259675,6977950,1637609,2164984,6242117,4755863,2233856,88973,4702587,4569535,4289717,3049884,4653155,3208510,3496207,4036573,102537,2197905,1093661,5581760,211031,2059392,1962711,1349115,4697662,264606,5193972,65284,77301,1671874,3136745,3847358,3243976,2353376,1450966,1604297,1328507,4844394,1104554,1214094,5596920,3189011,597423,4126397,4575748,8399997,2608066,1127372,4106045,1949495,4611157,3487,1365807,3258845,849631,3758678,1214101,5644111,67843,988073,5840436,14498,217737,1714810,3529249,1551762,3461732,215746,5598829,901269,648490,3126173,1463361,5264959,620469,1825430,3214391,4676335,2762513,200883,563203,915774,66989,4317670,3016552,3447758,2582150,3974726,2148223,1503487,3279751,1374307,42780,2807185,5174637,150960,41861,202171,4774762,935373,1836293,23377,55590,3513073,3870708,3278837,7040107,51137,2400145,3259965,5889987,60444,1158073,4845749,5313103,946607,4767228,658766,1140870,132173,4217607,3899595,955832,5730280,3002007,3190300,859714,1226232,5079408,4304264,1351756,5969183,3095721,663291,65816,2662834,4262319,2874887,901238,926351,605397,2967533,5153615,1155015,3663763,1617356,102115,19479,3618347,1922131,2811884,3198530,236065,4058059,4260187,875489,4851868,3563940,4126,7237084,730158,1136861,4714894,1176646,2471053,4068692,5016020,3330427,2138592,2833321,1277564,1936089,4802305,95903,3686420,2937866,2697273,1368511,1148296,3127424,5416337,5156073,583041,5912186,1969401,6909,1690003,3036223,1955153,4804475,929796,2013104,3159063,5829213,1778551,5234070,1483267,2386915,3207885,622008,3078972,2154151,1185692,2536624,1563,3229761,197120,748921,2638551,2854140,1034928,908828,5301881,5221671,5829219,1647962,933586,5382804,59645,1478179,1694073,3732737,4797570,863107,1216544,5110347,642891,3132692,1302235,1833419,101431,3305314,5653172,642099,1222,1829211,2639799,2595778,673453,2747243,108647,35241,952436,5530262,2492434,67580,2148572,1165172,1838638,5139910,73970,5872845,133609,3207013,632239,2765201,8458285,3098774,579635,5010531,182496,1965843,5347623,7671,7900199,930178,2215983,2825206,5203815,1708289,50301,1201,734505,4571557,1565668,5531235,3917514,2255173,615327,1442753,2893993,2220203,3296463,1133886,87904,3547727,158839,2033782,32219,2502426,2560807,3678558,3853828,33397,4606119,7019736,3825312,3747253,2705066,1665833,1980032,805441,3944556,4612740,5914713,2252941,2902140,57244,3680460,3181495,6191164,2309244,4347418,4682890,1185856,4790616,154,1714977,810587,4005491,2643808,61203,745097,7338811,1424576,2622578,4593686,5276995,4566005,5451427,6016502,1907271,863510,3271305,4891071,980946,847283,4526662,5502003,37832,4964094,1719136,1745651,5153359,4937536,2383429,1817707,2425183,1886349,2914324,2479606,81647,651289,4156805,1508108,2129443,1836747,1839542,8341878,3298512,3312,213362,5445554,4571489,1204287,2447037,8967,2247417,3322731,626014,4570222,768676,5351040,1194435,4617144,2655023,983140,1792752,50545,1113960,3782679,1501972,4210470,4067218,2850254,3013521,39536,5327380, ...
#   'max_vacancies_rendered_on_server': 20,
#   'enable_advertisement_agreement_notification': True},
#  'filteredVacancyResponsesCount': None,
#  'floodlightGtagEnabled': False,
#  'floodlightUtm': {},
#  'financialDocumentDeeds': [],
#  'financialDocumentDeedsFilters': None,
#  'financialDocumentDeedsPaging': None,
#  'financialDocumentDeedsTotalRows': None,
#  'fetchingData': False,
#  'folderContent': None,
#  'footer': [{'name': 'footerNav',
#    'translations': {'name': '[RU:1:supernova.navi.footerNav]'},
#    'subItems': [{'name': 'site',
#      'translations': {'name': 'HeadHunter'},
#      'subItems': [{'name': 'copyright',
#        'translations': {'name': 'О компании'},
#        'url': '/article/28?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'hhCompanyInfo',
#        'translations': {'name': 'Наши вакансии'},
#        'url': '/employer/1455?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advertisingDescription',
#        'translations': {'name': 'Реклама на сайте'},
#        'url': 'https://ads.hh.ru/?from=footer_new&hhtmFromLabel=footer_new',
#        'external': True},
#       {'name': 'hardwareRequirements',
#        'translations': {'name': 'Требования к ПО'},
#        'url': '/article/176?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'dataProtection',
#        'translations': {'name': 'Защита персональных данных'},
#        'url': '/article/personal_data?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'safety',
#        'translations': {'name': 'Безопасный HeadHunter'},
#        'url': '/safety?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'compliance',
#        'translations': {'name': 'Этика и\xa0комплаенс'},
#        'url': '/article/compliance?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'api',
#        'translations': {'name': 'HeadHunter API'},
#        'url': 'https://dev.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'partners',
#        'translations': {'name': 'Партнерам'},
#        'url': '/partners?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'investor',
#        'translations': {'name': 'Инвесторам'},
#        'url': 'https://investor.hh.ru',
#        'external': True},
#       {'name': 'conditions',
#        'translations': {'name': 'Условия оказания услуг'},
#        'url': '/conditions?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'terms',
#        'translations': {'name': 'Условия использования сайтов'},
#        'url': '/terms?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'articles',
#      'translations': {'name': 'Новости и статьи'},
#      'url': '/articles',
#      'subItems': [{'name': 'hrNews',
#        'translations': {'name': 'Новости рынка HR'},
#        'url': '/articles/market-news/hr-news?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'articlesInsider',
#        'translations': {'name': 'Жизнь в компании'},
#        'url': '/articles/insider?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'itproject',
#        'translations': {'name': 'ИТ-проекты'},
#        'url': '/articles/applicants/it-projects?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'employersRating',
#        'translations': {'name': 'Рейтинг работодателей России'},
#        'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'applicantServices',
#      'translations': {'name': 'Сервисы для соискателей'},
#      'subItems': [{'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advancementServices',
#        'translations': {'name': 'Все сервисы'},
#        'url': '/applicant-services/services/all?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'proforientation',
#        'translations': {'name': 'Профориентация'},
#        'url': '/article/proforientation_promo?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'findjob',
#        'translations': {'name': 'Продвижение резюме'},
#        'url': '/applicant/services/findjob?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'wantwork',
#        'translations': {'name': 'Хочу у вас работать'},
#        'url': '/article/98?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'calendar',
#        'translations': {'name': 'Производственный календарь'},
#        'url': '/calendar?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'resumeAudit',
#        'translations': {'name': 'Экспертная рекомендация'},
#        'url': '/article/resume_audit?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'forTeens',
#      'translations': {'name': 'Молодым специалистам'},
#      'subItems': [{'name': 'career',
#        'translations': {'name': 'Карьера для молодых специалистов'},
#        'url': '/students?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'school',
#        'translations': {'name': 'Школа программистов'},
#        'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'schoolProduct',
#        'translations': {'name': 'Школа продактов'},
#        'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'additional',
#      'translations': {'name': '[RU:1:supernova.navi.additional]'},
#      'subItems': [{'name': 'additionalSection',
#        'translations': {'name': '[RU:1:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'anonymousCreateVacancy',
#          'translations': {'name': 'Поиск сотрудников'},
#          'url': '/employer?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'copiny',
#          'translations': {'name': 'Помощь'},
#          'url': 'https://feedback.hh.ru/ticket/add?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#          'external': True},
#         {'name': 'agreement',
#          'translations': {'name': 'Пользовательское соглашение'},
#          'url': '/account/agreement?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:1:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'employersSearch',
#          'translations': {'name': 'Каталог компаний'},
#          'url': '/employers_company?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'catalog',
#          'translations': {'name': 'Работа по профессиям'},
#          'url': '/catalog?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'metroCatalog',
#          'translations': {'name': 'Работа рядом с метро'},
#          'url': '/metro?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:1:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'chatBot',
#          'translations': {'name': 'Уведомления в\xa0мессенджер'},
#          'subItems': [{'name': 'chatBotTelegram',
#            'translations': {'name': '[RU:1:supernova.navi.chatBotTelegram]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotViber',
#            'translations': {'name': '[RU:1:supernova.navi.chatBotViber]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotVk',
#            'translations': {'name': '[RU:1:supernova.navi.chatBotVk]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True}]}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:1:supernova.navi.additionalSection]'},
#        'subItems': [{'name': 'lang',
#          'translations': {'name': '[RU:1:supernova.navi.lang]'}}]}]}]}],
#  'forbidden': False,
#  'globalInvitations': 2911502,
#  'getPageHtmlEnabled': False,
#  'globalStatistics': {'vacancies': 958814,
#   'employers': 1817433,
#   'resumes': 60970507},
#  'hasBrandedTemplates': False,
#  'hasEditSidebarButton': False,
#  'hasForceReloadDreamJob': False,
#  'hasListOfVacanciesByRoles': False,
#  'hasVacancyResponsesSummaryService': False,
#  'hasVideoInterview': False,
#  'invoiceFinishMobilePromoShown': False,
#  'invoiceFinishBillId': None,
#  'invoiceFinishDraftId': None,
#  'isInvoiceWithCart': False,
#  'hasChameleon': False,
#  'headerMenu': [{'name': 'menuLvl1',
#    'translations': {'name': '[RU:1:supernova.navi.menuLvl1]'},
#    'subItems': [{'name': 'mainContent',
#      'translations': {'name': '[RU:1:supernova.navi.mainContent]'},
#      'subItems': [{'name': 'switchers',
#        'translations': {'name': '[RU:1:supernova.navi.switchers]'},
#        'subItems': [{'name': 'areaSwitcher',
#          'translations': {'name': 'Россия'}},
#         {'name': 'applicant',
#          'translations': {'name': 'Соискателям'},
#          'url': '/set_user_type?user_type=applicant&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'active': True},
#         {'name': 'employer',
#          'translations': {'name': 'Работодателям'},
#          'url': '/set_user_type?user_type=employer&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'trackClicks': True}]},
#       {'name': 'fill', 'translations': {'name': '[RU:1:supernova.navi.fill]'}},
#       {'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#       {'name': 'interviewpractice',
#        'translations': {'name': 'Репетиция собеседования'},
#        'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#     {'name': 'applicantServices', 'translations': {'name': 'Все сервисы'}}]},
#   {'name': 'menuLvl2',
#    'translations': {'name': '[RU:1:supernova.navi.menuLvl2]'},
#    'subItems': [{'name': 'logo',
#      'translations': {'name': '[RU:1:supernova.navi.logo]'}},
#     {'name': 'help',
#      'translations': {'name': 'Помощь'},
#      'dropdown': True,
#      'subItems': [{'name': 'mainContent',
#        'translations': {'name': '[RU:1:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'vishnu',
#          'translations': {'name': 'Виртуальный консультант'}},
#         {'name': 'applicantHelp',
#          'translations': {'name': 'Вопросы и ответы'},
#          'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#          'external': True},
#         {'name': 'writeToUs',
#          'translations': {'name': 'Пишите нам'},
#          'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#          'external': True}]},
#       {'name': 'supportChat',
#        'translations': {'name': 'Техподдержка онлайн'}}]},
#     {'name': 'userTypeSwitcher',
#      'translations': {'name': '[RU:1:supernova.navi.userTypeSwitcher]'},
#      'trackClicks': True,
#      'dropdown': True,
#      'subItems': [{'name': 'userTypeSwitcherApplicant',
#        'translations': {'name': 'Ищу работу'},
#        'url': '/set_user_type?user_type=applicant&backurl=%2F',
#        'trackClicks': True,
#        'active': True},
#       {'name': 'userTypeSwitcherEmployer',
#        'translations': {'name': 'Ищу сотрудника'},
#        'url': '/employer',
#        'trackClicks': True}]},
#     {'name': 'fill', 'translations': {'name': '[RU:1:supernova.navi.fill]'}},
#     {'name': 'searchVacancy',
#      'translations': {'name': '[RU:1:supernova.navi.searchVacancy]'},
#      'url': '/search/vacancy/advanced'},
#     {'name': 'signup',
#      'translations': {'name': 'Создать резюме'},
#      'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#     {'name': 'login',
#      'translations': {'name': 'Войти'},
#      'url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26area%3D1%26currency_code%3DRUR%26only_with_salary%3Dfalse%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100'},
#     {'name': 'mobile',
#      'translations': {'name': '[RU:1:supernova.navi.mobile]'},
#      'url': '/mobile',
#      'dropdown': True,
#      'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Россия'}},
#       {'name': 'mainContent',
#        'translations': {'name': '[RU:1:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'help',
#          'translations': {'name': 'Помощь'},
#          'dropdown': True,
#          'subItems': [{'name': 'mainContent',
#            'translations': {'name': '[RU:1:supernova.navi.mainContent]'},
#            'subItems': [{'name': 'applicantHelp',
#              'translations': {'name': 'Вопросы и ответы'},
#              'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#              'external': True},
#             {'name': 'writeToUs',
#              'translations': {'name': 'Пишите нам'},
#              'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#              'external': True}]},
#           {'name': 'supportChat',
#            'translations': {'name': 'Техподдержка онлайн'}}]},
#         {'name': 'signup',
#          'translations': {'name': 'Создать резюме'},
#          'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#       {'name': 'applicantServices',
#        'translations': {'name': 'Все сервисы'},
#        'subItems': [{'name': 'advancementServices',
#          'translations': {'name': 'Продвижение резюме'},
#          'url': '/applicant-services/services/all',
#          'subItems': [{'name': 'expertresume',
#            'translations': {'name': 'Готовое резюме',
#             'description': 'Доверьте составление резюме профессионалам!'},
#            'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'careerconsult',
#            'translations': {'name': 'Карьерная консультация',
#             'description': 'Обсудите с\xa0экспертом, как эффективно искать работу'},
#            'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'interviewpractice',
#            'translations': {'name': 'Репетиция собеседования',
#             'description': 'Подготовьтесь к\xa0интервью вместе с\xa0карьерным экспертом'},
#            'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'applicantVacancyResponsesSummary',
#            'translations': {'name': 'Статистика по\xa0вакансии',
#             'description': 'Сравните себя с\xa0другими кандидатами, откликнувшимися на\xa0вакансию'},
#            'url': '/article/vacancy_summary?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'proforientation',
#            'translations': {'name': 'Профориентация',
#             'description': 'Узнайте, какой вы специалист и добейтесь большего'},
#            'url': '/article/proforientation_promo?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'findjob',
#            'translations': {'name': 'Продвижение резюме',
#             'description': 'Автоматическое поднятие резюме в\xa0результатах поиска'},
#            'url': '/applicant/services/findjob?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'wantwork',
#            'translations': {'name': 'Хочу у вас работать',
#             'description': 'Отправьте свое резюме в компанию мечты'},
#            'url': '/article/98?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'resumeAudit',
#            'translations': {'name': 'Экспертная рекомендация',
#             'description': 'Получите рекомендации карьерного консультанта по\xa0улучшению вашего резюме'},
#            'url': '/article/resume_audit?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#         {'name': 'educationServices',
#          'translations': {'name': 'Образование и консультации'},
#          'subItems': [{'name': 'careerMarathon',
#            'translations': {'name': 'Карьерный марафон'},
#            'url': '/article/career_marathon?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu',
# ...
#         'description': 'Топ-50 Рейтинга работодателей hh.ru (крупнейшие\xa0компании)',
#         'url': 'https://rating.hh.ru/history/rating2021',
#         'position': '50',
#         'year': 2021},
#        {'type': 'hrbrand',
#         'description': 'Победитель Премии HR-бренд',
#         'url': 'http://hrbrand.ru/',
#         'position': 'winner'}]},
#      'companySiteUrl': 'http://www.rosbank.ru',
#      'accreditedITEmployer': False},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1668674341,
#      '$': '2022-11-17T11:39:01.641+03:00'},
#     'type': 'open',
#     'area': {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'},
#     'hr-brand': {'@url': 'http://hrbrand.ru/', 'type': 'winner'},
#     'acceptTemporary': False,
#     'metallic': 'standard',
#     'template': 'makeup:14777',
#     'creationSite': 'hh.ru',
#     'creationSiteId': 1,
#     'displayHost': 'hh.ru',
#     'lastChangeTime': {'@timestamp': 1669020030,
#      '$': '2022-11-21T11:40:30.576+03:00'},
#     'creationTime': '2022-11-17T11:39:01.641+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 97030980,
#      '@managerId': 6290991,
#      '@userId': 74882119},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': False,
#     'links': {'desktop': 'https://hh.ru/vacancy/72460074',
#      'mobile': 'https://m.hh.ru/vacancy/72460074'},
#     'workSchedule': 'REMOTE',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 12753490,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_12753490'},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'professionalRoleIds': [{'professionalRoleId': [165]}],
#     'userLabels': [],
#     'snippet': {'req': 'Опыт работы с большими массивами данных. Знание SQL (в том числе оконные функции, cte, индексы, view, оптимизация запросов). ',
#      'resp': 'Data Engineering: формирование data pipelines, архитектуры базы данных, ETL. System analysis: написание документации, формализация требований к проектам; изучение документации сторонних...',
#      'cond': 'Полностью дистанционный формат работы – это возможность работать из любой точки. Стабильный и прозрачный доход: зарплата и премии по результатам работы. ',
#      'skill': 'Анализ данных, SQL, Python, ETL',
#      'desc': None},
#     'responsesCount': 426,
#     'totalResponsesCount': 426,
#     'online_users_count': 1},
#    {'@responseLetterRequired': False,
#     '@showContact': False,
#     'vacancyId': 71133669,
#     'name': 'Senior Data Scientist',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'COMPANY',
#      '@countryId': 1,
#      '@structureName': '370',
#      '@state': 'APPROVED',
#      'id': 370,
#      'name': 'АльфаСтрахование',
#      'visibleName': 'АльфаСтрахование',
#      'structureName': '370',
#      'logos': {'logo': [{'@type': 'vacancyPage',
#         '@url': '/employer-logo/3553164.png'},
#        {'@type': 'medium', '@url': '/employer-logo/3553164.png'},
#        {'@type': 'searchResultsPage', '@url': '/employer-logo/3553163.png'},
#        {'@type': 'small', '@url': '/employer-logo/3553163.png'},
#        {'@type': 'employerPage', '@url': '/employer-logo/3553162.png'},
#        {'@type': 'ORIGINAL', '@url': '/employer-logo-original/778068.png'}]},
#      'mainEmployerId': 370,
#      'badges': {'badge': [{'type': 'hrbrand',
#         'description': 'Победитель Премии HR-бренд',
#         'url': 'http://hrbrand.ru/',
#         'position': 'winner'}]},
#      'companySiteUrl': 'https://career.alfastrah.ru/',
#      'accreditedITEmployer': False},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1668692744,
#      '$': '2022-11-17T16:45:44.595+03:00'},
#     'type': 'open',
#     'area': {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'},
#     'hr-brand': {'@url': 'http://hrbrand.ru/', 'type': 'winner'},
#     'acceptTemporary': False,
#     'metallic': 'standard',
#     'creationSite': 'hh.ru',
#     'creationSiteId': 1,
#     'displayHost': 'hh.ru',
#     'lastChangeTime': {'@timestamp': 1668692744,
#      '$': '2022-11-17T16:45:44.641+03:00'},
#     'creationTime': '2022-10-14T09:59:11.906+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 113544770,
#      '@managerId': 7936605,
#      '@userId': 91348147},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': False,
#     'links': {'desktop': 'https://hh.ru/vacancy/71133669',
#      'mobile': 'https://m.hh.ru/vacancy/71133669'},
#     'workSchedule': 'FULL_DAY',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 11456965,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_11456965'},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'professionalRoleIds': [{'professionalRoleId': [96]}],
#     'userLabels': [],
#     'snippet': {'req': 'Уверенные знания в области мат. статистики, теории вероятностей, линейной алгебры; Опыт классического DS от 2 лет. Осознанный подход к выбору...',
#      'resp': 'Apache Hadoop (Cloudera) – data lake. Mlflow – Версионирование моделей. Airflow – Пайплайны обработки данных и применения моделей. Python – Разработка моделей. ',
#      'cond': 'Работу в профессиональной команде разработчиков, которая готова делиться знаниями и опытом. Прозрачную систему грейдов , возможность внешнего обучения и прокачки твоих...',
#      'skill': 'Python, SQL',
#      'desc': None},
#     'responsesCount': 4,
#     'totalResponsesCount': 47,
#     'online_users_count': 0},
#    {'@responseLetterRequired': False,
#     '@showContact': False,
#     'vacancyId': 70731531,
#     'name': 'Senior data scientist',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'COMPANY',
#      '@countryId': 1,
#      '@structureName': '1149',
#      '@state': 'APPROVED',
#      'id': 1149,
#      'name': 'ЛОКО-БАНК',
#      'visibleName': 'ЛОКО-БАНК',
#      'structureName': '1149',
#      'logos': {'logo': [{'@type': 'ORIGINAL',
#         '@url': '/employer-logo-original/511744.png'},
#        {'@type': 'employerPage', '@url': '/employer-logo/2488728.png'},
#        {'@type': 'searchResultsPage', '@url': '/employer-logo/2488729.png'},
#        {'@type': 'small', '@url': '/employer-logo/2488729.png'},
#        {'@type': 'vacancyPage', '@url': '/employer-logo/2488730.png'},
#        {'@type': 'medium', '@url': '/employer-logo/2488730.png'}],
#       '@showInSearch': True},
#      'mainEmployerId': 1149,
#      'companySiteUrl': 'http://www.lockobank.ru/',
#      'accreditedITEmployer': False},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1668690186,
#      '$': '2022-11-17T16:03:06.588+03:00'},
#     'type': 'open',
#     'area': {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'},
#     'acceptTemporary': False,
#     'address': {'@id': 778884,
#      '@disabled': False,
#      'metroStations': {'@lat': 55.800441,
#       '@lng': 37.530477,
#       'metro': [{'@isAlias': False,
#         '@cityId': 1,
#         '@id': 12,
#         '@name': 'metro.12',
#         '@order': 6,
#         '@translit': 'aeroport',
#         'id': 12,
#         'lat': 55.800441,
#         'line': {'@id': 2,
#          '@name': 'metroline.2',
#          '@translit': 'zamoskvoretskaya',
#          '@cityId': 1,
#          'id': 2,
#          'name': 'Замоскворецкая',
#          'color': '#4FB04F'},
#         'lng': 37.530477,
#         'name': 'Аэропорт'}]},
#      'city': 'Москва',
#      'street': 'Ленинградский проспект',
#      'building': '39с80',
#      'displayName': 'Москва, Ленинградский проспект, 39с80',
#      'mapData': '{"points":{"center":{"lat":55.79656199997468,"lng":37.536922,"zoom":19},"marker":{"lat":55.796562,"lng":37.536922}}}',
#      'marker': {'@lat': 55.796562, '@lng': 37.536922},
#      'manager': {'@id': 11124693}},
#     'metallic': 'standard',
#     'template': 'makeup:24844',
#     'creationSite': 'hh.ru',
#     'creationSiteId': 1,
#     'displayHost': 'hh.ru',
#     'lastChangeTime': {'@timestamp': 1669214517,
#      '$': '2022-11-23T17:41:57.925+03:00'},
#     'creationTime': '2022-10-04T09:40:26.066+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 143735405,
#      '@managerId': 11177836,
#      '@userId': 121504824},
#     'inboxPossibility': False,
#     'chatWritePossibility': 'DISABLED',
#     'notify': False,
#     'links': {'desktop': 'https://hh.ru/vacancy/70731531',
#      'mobile': 'https://m.hh.ru/vacancy/70731531'},
#     'workSchedule': 'FULL_DAY',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 10837971,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_10837971'},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'professionalRoleIds': [{'professionalRoleId': [40]}],
#     'userLabels': [],
#     'snippet': {'req': 'Профильный опыт работы в банке в области оценки кредитных рисков. Знание SQL на уровне написания сложных запросов, разработки и автоматизации...',
#      'resp': 'Формирование и сопровождение витрин данных для целей моделирования, прогнозирования и data-аналитики. Статистический анализ факторов риска. Расширение, автоматизация и систематизация...',
#      'cond': 'Оформление в соответствии с ТК РФ. Офисный форматы работы. Режим работы: с 9.30 до 18.30, в пятницу с...',
#      'skill': 'Python, SQL, Анализ данных',
#      'desc': None},
#     'responsesCount': 16,
#     'totalResponsesCount': 99,
#     'online_users_count': 0}],
#   'vacanciesCounts': 100,
#   'hasVacanciesWithAddress': True,
#   'isClustersEnabled': True,
#   'clustersCount': 0,
#   'paging': {'previous': {'page': -1, 'disabled': True},
#    'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#     {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True}],
#    'next': {'page': 1, 'disabled': False},
#    'os': 'Win'},
#   'queries': {'effective': 'area=1&clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&control_flag=ratesBoostEnabled%3ATrue&control_flag=ratesBoostFactor%3A1e-05&control_flag=ratesBoostRealCoef%3A1.0&control_flag=ratesBoostPredCoef%3A1.0&control_flag=ratesThreshold%3A0.01&control_flag=responsesThreshold%3A9&control_flag=defaultModelVer%3ANone&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'currentAndInternalParams': 'area=1&clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&control_flag=ratesBoostEnabled%3ATrue&control_flag=ratesBoostFactor%3A1e-05&control_flag=ratesBoostRealCoef%3A1.0&control_flag=ratesBoostPredCoef%3A1.0&control_flag=ratesThreshold%3A0.01&control_flag=responsesThreshold%3A9&control_flag=defaultModelVer%3ANone&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'enableSnippets': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'disableSnippets': 'area=1&clusters=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'legacy': 'areaId=1&clusters=true&itemsOnPage=100&searchfield=vacancyname&text=data+scien%2A',
#    'currentParams': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'rss': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'map': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'dynamicMap': 'clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'legacyRss': 'areaId=1&clusters=true&itemsOnPage=100&searchfield=vacancyname&text=data+scien%2A',
#    'autosearch': 'area=1&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'legacyAutosearch': 'areaId=1&itemsOnPage=100&searchfield=vacancyname&text=data+scien%2A',
#    'pagingBase': 'L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'orderByBase': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'searchPeriodBase': 'area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'itemsOnPageBase': 'area=1&clusters=true&enable_snippets=true&ored_clusters=true&search_field=name&text=data+scien%2A',
#    'searchWizardBase': 'L_is_autosearch=false&area=1&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true'},
#   'queryRanks': [],
#   'totalResults': 191,
#   'enableNovaFilters': True,
#   'enableSimilarSavedSearch': False,
#   'fixes': {},
#   'suggests': {},
#   'catalogLinks': []},
#  'vacancyStat': None,
#  'vacancyTests': {},
#  'vacancyView': {'company': {'visibleName': ''},
#   'status': {},
#   'features': [],
#   'insider': None,
#   'keySkills': None,
#   'contactInfo': None,
#   'description': '',
#   'publicationType': None,
#   'publicationDate': None,
#   'professionalRoleIds': [],
#   'validThroughTime': None,
#   'area': None,
#   'name': '',
#   'compensation': {},
#   'translations': None},
#  'vacancyWizard': {'totalEmployersFound': 0,
#   'employerHits': [],
#   'rootAreaId': 0},
#  'vacancyTemplates': [],
#  'vacancyTemplateForEdit': None,
#  'vacancyClickmeLanding': None,
#  'vacancyViewsCount': None,
#  'vacancyConstructor': {'vacancyBrandedTemplates': [], 'expirationTime': None},
#  'vacancyConstructorBackOfficeView': None,
#  'vacancyConstructorTemplateMode': None,
#  'vacancyConstructorMobilePreview': {'templateId': None},
#  'vacancyConstructorSettings': None,
#  'vacation': None,
#  'vacancyResponsePopup': {},
#  'vacancyResponseSummary': None,
#  'vacancyResponseQuestions': {},
#  'vacancySummaryTopicId': None,
#  'vacancyMessages': [],
#  'vacancyFeedback': None,
#  'vrSignupLogin': {},
#  'vrVacancies': None,
#  'wantWorkEmployer': {'employerInfo': {'id': None, 'name': ''},
#   'employerLogo': {'logoUrl': None}},
#  'workInOtherCity': None,
#  'xsrfToken': '1d9235fc6ed2a6b6e6ee94f59314e355',
#  'employerDivisionChangelog': {'changes': []},
#  'serviceAdditional': {'serviceNames': {}},
#  'supernovaAnonymousDashboard': {'backgroundScope': '',
#   'backgroundIndex': '',
#   'bigPromoEmployerId': '',
#   'bigPromoSlogan': '',
#   'bigPromoLinkText': '',
#   'bigPromoLinkUrl': '',
#   'bigPromoFootnote': None},
#  'pinnedChatMessages': {'hasMore': False, 'items': []},
#  'politenessIndex': None,
#  'preparedVacancyTemplates': [],
#  'snippetAccessResume': {'productList': [],
#   'area': '',
#   'isShowSnippetResume': False},
#  'zpEmployerOnboarding': {'showOnboardingModal': False},
#  'accountHistoryActionsData': None,
#  'accountHistoryMoney': {'hasPersonalManager': False,
#   'state': '',
#   'email': '',
#   'agreements': {},
#   'currency': '',
#   'hrs': {'orders': []},
#   'balances': {},
#   'employerCountry': '',
#   'availableWithoutBlockedMoney': 0},
#  'scheduleInterviewRemindInfo': None,
#  'tempexp15859': False,
#  'talantixResponsesRedirectUrls': {},
#  'isVacancySimplifyForm': False,
#  'router': {'location': {'pathname': '/search/vacancy',
#    'search': '?text=data+scien*&search_field=name&area=1&currency_code=RUR&only_with_salary=false&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#    'hash': '',
#    'key': '0xuv9i',
#    'query': {'text': 'data+scien*',
#     'search_field': 'name',
#     'area': '1',
#     'currency_code': 'RUR',
#     'only_with_salary': 'false',
#     'experience': 'doesNotMatter',
#     'order_by': 'relevance',
#     'search_period': '0',
#     'items_on_page': '100'}},
#   'action': 'POP'}}

# %% [markdown]
# #### Analyzing data structure

# %% [markdown]
# We've got a huge amount of 'empty' data structures after translating page to json format. There are empty dictionaries and dictionaries containing 'empty' data structures. So we have to clean out these artifacts to make the visual analysis of data more efficient.

# %%
# Function to check if dictionary is 'empty'
def is_dict_empty(input_dict):
    result = True
    for key in input_dict.keys():
        if (type(input_dict[key]) == type(dict())) and (len(input_dict[key]) > 0):
            # recurrent check for dictionaries
            result = result and is_dict_empty(input_dict[key])
        else:
            # the structure is empty if its len == 0 or they are None or they are empty list or dictionary
            checks_empty = (input_dict[key] is None) or (str(input_dict[key]) in ['{}', '[]']) or (len(str(input_dict[key])) == 0)
            result = result and checks_empty
        if not result:
            break
    return result

# %%
clean_dict = {}
for key in json_parsed.keys():
    if (type(json_parsed[key]) is type(dict())):
        if not is_dict_empty(json_parsed[key]):
            clean_dict[key] = json_parsed[key]
    else:
        checks_empty = (json_parsed[key] is None) or (str(json_parsed[key]) in ['{}', '[]']) or (len(str(json_parsed[key])) == 0)
        if not checks_empty:
            clean_dict[key] = json_parsed[key]
print('{} non-empty keys in result'.format(len(clean_dict)))
print('======================= Example of data =============================')
for i, key in enumerate(clean_dict.keys()):
    print('{} ====> {}'.format(key, clean_dict[key]))
    if i > 5:
        break
# Out:
# 203 non-empty keys in result
# ======================= Example of data =============================
# applicantSignup ====> {'fields': [{'name': 'login', 'conditions': {'minCount': 1, 'maxCount': 1, 'parts': [{'minLength': 0, 'maxLength': 127}]}, 'simpleValues': None, 'customValues': None, 'error': None, 'warning': None, 'empty': True}, {'name': 'password', 'conditions': {'minCount': 1, 'maxCount': 1, 'parts': [{'minLength': 6, 'maxLength': 32}]}, 'simpleValues': None, 'customValues': None, 'error': None, 'warning': None, 'empty': True}, {'name': 'firstName', 'conditions': {'minCount': 1, 'maxCount': 1, 'parts': [{'minLength': 1, 'maxLength': 255}]}, 'simpleValues': None, 'customValues': None, 'error': None, 'warning': None, 'empty': True}, {'name': 'lastName', 'conditions': {'minCount': 1, 'maxCount': 1, 'parts': [{'minLength': 1, 'maxLength': 255}]}, 'simpleValues': None, 'customValues': None, 'error': None, 'warning': None, 'empty': True}], 'hideLogin': False}
# applicantPackageType ====> basic
# applicantPaymentSource ====> desktop
# accountHistoryReplenishments ====> {'bills': [], 'documentLinksVisibility': False, 'currency': 'RUR'}
# accountDelete ====> {'applicantName': '', 'resumesList': {'resumes': {'published': [], 'unpublished': []}, 'count': 0}}
# adsSearchParams ====> {'puid11': 'searchVacancy', 'puid23': 'Москва', 'puid14': 'data scien*', 'puid29': '', 'puid30': '', 'puid12': '', 'puid13': ''}
# anonymousUserType ====> applicant

# %% [markdown]
# Now the *clean_dict* variable contains key with not-empty data bound to them.
# Keys analysis shows **main search results** are under _'vacancySearchResult'->'vacancies'_ keys.
# Another useful keys are:
# _'searchClusters'_ contains grouping characteristics ('industry', 'groups')
# _'searchClustersDicts'_ contains options to split data further ('area', 'compensation', etc.)

# %%
# Total number of search results (cross check)
print(clean_dict['searchCounts'])
# or
print(clean_dict['vacancySearchResult']['totalResults'])
# Out:
# {'isLoad': False, 'value': 250}
# 250

# %%
# additional info about 'searchClustersDicts' key
clean_dict['searchClustersDicts'].keys()
# Out:
# dict_keys(['area', 'clusters'])

# %% [markdown]
# In case total search results number exceeds 2000 (seems to be hardcoded limit) it is possible to use 'searchClusters'->'area' to implement partial searches

# %%
clean_dict['searchClusters']['area']
# Out:
# {'groups': {'1': {'count': 250,
#    'seoDomain': 'hh.ru',
#    'order': 2,
#    'title': 'Москва',
#    'id': '1'},
#   '232': {'count': 256,
#    'seoDomain': 'hh.ru',
#    'order': 1,
#    'title': 'Центральный округ',
#    'id': '232'},
#   '2019': {'count': 6,
#    'seoDomain': 'hh.ru',
#    'order': 3,
#    'title': 'Московская область',
#    'id': '2019'}},
#  'selectedValues': [1],
#  'disableQueries': [],
#  'order': 3}

# %% [markdown]
# The key _'count'_ contains number of vacancies found in area, _'id'_ - area id. We can parse _'area'->'groups'_ keys to search in regions separately. It gives a way to bypass the max vacancies limitation mentioned above.
# But now we have number of vacancies in Moscow exceeding page capacity (255 vs 100)

# %%
areas_to_crawl = []
area_ids_excluded = ['113'] # grouping ids: 113 = Russia
print('Search result num of vacancies: ', json_parsed['vacancySearchResult']['totalResults'])
if json_parsed['vacancySearchResult']['totalResults'] > 2000:
    search_json_obj = json_parsed['searchClusters']['area']['groups']
    for key in search_json_obj.keys():
        if (key not in area_ids_excluded) and (search_json_obj[key]['count'] > 0):
            areas_to_crawl.append(key)
    print('Total areas with vacancies num: {}'.format(len(areas_to_crawl)))
    print("First 10 values of areas' ids: ", areas_to_crawl[:10])
print('Areas to crawl:', areas_to_crawl)
# Out:
# Search result num of vacancies:  191
# Areas to crawl: []

# %% [markdown]
# Let's check vacancies number per page to ensure _'items_on_page'_ parameter works fine

# %%
vacancies_info = clean_dict['vacancySearchResult']['vacancies']
print('Vacancies data type: {}'.format(type(vacancies_info)))
print('Num of vacancies: {}'.format(len(vacancies_info)))
# Out:
# Vacancies data type: <class 'list'>
# Num of vacancies: 100

# %% [markdown]
# There is 100 records containing vacancies info from the 1st search page. So this parameter is OK. And now I want to find total number of pages to get all of them.
# The _'paging'_ key seems a right place for this info

# %%
clean_dict['vacancySearchResult']['paging']
# Out:
# {'previous': {'page': -1, 'disabled': True},
#  'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#   {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True}],
#  'next': {'page': 1, 'disabled': False},
#  'os': 'Win'}

# %% [markdown]
# Here is pagination data indeed. Last page number is contained in _'lastPage'->'page'_ key (NOTE: in case there are 2 or 3 pages the key _'lastPage'_ is absent). And total search results is splitted on N+1 pages as they are 0-indexed.
# So if _'lastPage'_ is absent we should determine last page number from _'pages'_ list
# Now we have all the necessary info to get all vacancies into 1 place.
# > [!!!] In case of only 1 page the key _'paging'_ will contain _null_ value

# %% [markdown]
# ### Harvesting vacancies info from hh.ru

# %% [markdown]
# It's time to combine all pieces of informations about harvesting procedure to make it correct:
# (1) if total number of results exceeds 2000 I have to get info partially from different areas (which are in *areas_to_crawl* variable). In this case there will possibly be duplicates as I don't know display algorithm in details. If *areas_to_crawl* has length == 0 then there are less than 2000 vacancies found (if it's not enough we can split further by underground lines or stations in Moscow and St.Petersburg (parameter _metro=9&_ or _metro=9.37&_ in address line) -> need to implement parser additionally);
# (2) if _'lastPage'_ key is absent we can determine max number of pages by parsing _'pages'_ key
# (3) we have to loop through all the pages
# (4) we don't need to clean json results as we know all the necessary keys

# %%
# returns num of pages to parse
def get_num_pages(json_dump, logger=logger):
    result = None
    div_paging = json_dump['vacancySearchResult'].get('paging', None)
    if div_paging is not None:
        if div_paging.get('lastPage', None) is None:
            result = max([x['page'] for x in div_paging['pages']])
        else:
            result = div_paging['lastPage']['page']
    return result

# %%
# parse all pages from first
def parse_pages(browser, search_url_obj, parse_by_underground=False, logger=logger):
    logger.debug('Flow control received')
    result = []
    browser.get(search_url_obj.get_url())
    max_available_records = 2000
    if (json_parsed['vacancySearchResult']['totalResults'] > max_available_records) and parse_by_underground:
        logger.debug('More than {} records detected => passing flow control to "parse_pages_by_undeground"'.format(max_available_records))
        result += parse_pages_by_underground(browser, first_page_url, tail_url)
    else:
        if parse_by_underground:
            logger.debug('Less than {} records detected => beginning parsing pages'.format(max_available_records))
        else:
            logger.debug('Skipping parse_pages_by_underground => beginning parsing pages')
        json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
        result += json_dump['vacancySearchResult']['vacancies']
        num_pages = get_num_pages(json_dump)
        logger.debug('Page 1 / {} parsed'.format(num_pages+1))
        if num_pages is not None:
            for page in range(1, num_pages+1):
                browser.get(search_url_obj.get_url(page=page))
                div_list = BeautifulSoup(browser.page_source, 'html.parser').find_all('template')
                json_dump = json.loads(div_list[0].text)
                result += json_dump['vacancySearchResult']['vacancies']
                logger.debug('Page {} / {} parsed'.format(page+1, num_pages+1))
    return result

# %%
# page address to filter search results by underground lines/stations
"""
https://hh.ru/search/vacancy?
                            area=1&
                            metro=9.37&
                            search_field=name&search_field=description&
                            text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&
                            from=suggest_post&
                            clusters=true&
                            no_magic=true&
                            ored_clusters=true&
                            items_on_page=100&
                            enable_snippets=true
"""
# Out:
# '\nhttps://hh.ru/search/vacancy?\n                            area=1&\n                            metro=9.37&\n                            search_field=name&search_field=description&\n                            text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&\n                            from=suggest_post&\n                            clusters=true&\n                            no_magic=true&\n                            ored_clusters=true&\n                            items_on_page=100&\n                            enable_snippets=true\n'

# %%
def parse_pages_by_underground(browser, start_page_url, tail_url, logger=logger):
    # at the moment function is called browser has already opened start_page_url
    # start_page_url doesn't contain 'page=' parameter
    #browser.get(start_page_url)
    logger.debug('Flow control received')
    json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
    # get all underground lines with search result > 0
    underground_dump = json_dump['searchClustersBasic']['metro']['groups']
    underground_lines = {key: underground_dump[key]['title'] for key in underground_dump.keys() if underground_dump[key]['type'] == 'line'}
    new_url_template = start_page_url + '&metro={}'
    logger.debug('Got {} underground lines. Begin parsing'.format(len(underground_lines)))
    
    result = []
    for line in underground_lines:
        logger.debug('Underground line: {}'.format(underground_lines[line]))
        url = new_url_template.format(line)
        browser.get(url)
        json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
        result += json_dump['vacancySearchResult']['vacancies']
        num_pages = get_num_pages(json_dump)
        logger.debug('Page 1 / {} parsed'.format(num_pages+1))
        if num_pages is not None:
            for page in range(1, num_pages+1):
                browser.get(url+tail_url.format(page))
                json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
                result += json_dump['vacancySearchResult']['vacancies']
                logger.debug('Page {} / {} parsed'.format(page+1, num_pages+1))
    return result

# %%
vacancies_info = []
if len(areas_to_crawl) == 0:
    areas_to_crawl.append('1')
if len(areas_to_crawl) > 0:
    for area in areas_to_crawl:
        vacancies_info += parse_pages(browser, search_query, parse_by_underground=False)

print('Final vacancies info contains {} record(s)'.format(len(vacancies_info)))
# Out:
# [2022-11-27 15:21:44,968: parse_pages: DEBUG] Flow control received
# [2022-11-27 15:21:47,828: parse_pages: DEBUG] Skipping parse_pages_by_underground => beginning parsing pages
# [2022-11-27 15:21:48,650: parse_pages: DEBUG] Page 1 / 2 parsed
# [2022-11-27 15:21:51,901: parse_pages: DEBUG] Page 2 / 2 parsed
# Final vacancies info contains 191 record(s)

# %%
len(vacancies_info)
# Out:
# 191

# %% [markdown]
# We've got info from all pages and now can close browser

# %%
browser.quit()

# %% [markdown]
# Dumping data to have an opportunity to restore raw data later...

# %%
filename = output_filename_base + dt.now().date().strftime('%Y-%m-%d')
#filename = output_filename_base + dt.now().date().strftime('%Y-%m-%d')
with open('datasets/'+filename+'.json', 'w') as f:
    json.dump(vacancies_info, f)

# %% [markdown]
# And now it's time to select fields to fill in DataFrame

# %%
for key in vacancies_info[0].keys():
    print('{} =======> {}'.format(key, vacancies_info[0][key]))
# Out:
# @responseLetterRequired =======> True
# @showContact =======> False
# vacancyId =======> 71426958
# name =======> Data Scientist (команда Поиска)
# company =======> {'@showSimilarVacancies': True, '@trusted': True, '@category': 'COMPANY', '@countryId': 1, '@structureName': 'hh', '@state': 'APPROVED', 'id': 1455, 'name': 'HeadHunter', 'visibleName': 'HeadHunter::Analytics/Data Science', 'structureName': 'hh', 'logos': {'logo': [{'@type': 'employerPage', '@url': '/employer-logo/4069246.png'}, {'@type': 'ORIGINAL', '@url': '/employer-logo-original/907140.png'}, {'@type': 'vacancyPage', '@url': '/employer-logo/4069248.png'}, {'@type': 'medium', '@url': '/employer-logo/4069248.png'}, {'@type': 'searchResultsPage', '@url': '/employer-logo/4069247.png'}, {'@type': 'small', '@url': '/employer-logo/4069247.png'}], '@showInSearch': True}, 'department': {'@name': 'HeadHunter::Analytics/Data Science', '@code': 'hh-1455-ds'}, 'employerOrganizationFormId': 0, 'mainEmployerId': 1455, 'companySiteUrl': 'https://hh.ru/', 'accreditedITEmployer': True}
# compensation =======> {'from': 350000, 'currencyCode': 'RUR', 'gross': True}
# publicationTime =======> {'@timestamp': 1669111319, '$': '2022-11-22T13:01:59.972+03:00'}
# type =======> open
# area =======> {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'}
# acceptTemporary =======> False
# address =======> {'@id': 525394, '@disabled': False, 'metroStations': {'@lat': 55.807794, '@lng': 37.638699, 'metro': [{'@isAlias': False, '@cityId': 1, '@id': 8, '@name': 'metro.8', '@order': 5, '@translit': 'alexeevskaya', 'id': 8, 'lat': 55.807794, 'line': {'@id': 6, '@name': 'metroline.6', '@translit': 'kaluzhsko_rizhskaya', '@cityId': 1, 'id': 6, 'name': 'Калужско-Рижская', 'color': '#F07E24'}, 'lng': 37.638699, 'name': 'Алексеевская'}]}, 'city': 'Москва', 'street': 'улица Годовикова', 'building': '9с10', 'displayName': 'Москва, улица Годовикова, 9с10', 'mapData': '{"points":{"center":{"lat":55.80856850771242,"lng":37.63360200000002,"zoom":16},"marker":{"lat":55.809343,"lng":37.628505}}}', 'marker': {'@lat': 55.809343, '@lng': 37.628505}, 'manager': {'@id': 3383792}}
# metallic =======> premium
# template =======> makeup:3699
# creationSite =======> novosibirsk.hh.ru
# creationSiteId =======> 14
# displayHost =======> hh.ru
# lastChangeTime =======> {'@timestamp': 1669125581, '$': '2022-11-22T16:59:41.920+03:00'}
# creationTime =======> 2022-10-21T13:54:51.139+03:00
# canBeShared =======> True
# employerManager =======> {'@hhid': 78295253, '@managerId': 4968976, '@userId': 56163055, 'latestActivity': None}
# inboxPossibility =======> True
# chatWritePossibility =======> ENABLED_AFTER_INVITATION
# notify =======> False
# links =======> {'desktop': 'https://hh.ru/vacancy/71426958', 'mobile': 'https://m.hh.ru/vacancy/71426958'}
# workSchedule =======> FULL_DAY
# acceptIncompleteResumes =======> False
# driverLicenseTypes =======> [{}]
# languages =======> [{}]
# workingDays =======> [{}]
# workingTimeIntervals =======> [{}]
# workingTimeModes =======> [{}]
# hrBotScenario =======> {'hrBotScenarioId': 11877737, 'enabled': False, 'scenarioCode': 'vacancy_scenario_11877737'}
# publicationType =======> PREMIUM
# vacancyPlatforms =======> ['HH']
# professionalRoleIds =======> [{'professionalRoleId': [10]}]
# userLabels =======> []
# snippet =======> {'req': 'Опыт реализации и применения моделей машинного обучения в продакшн. Понимание основных методов и алгоритмов Machine Learning. Знание принципов работы нейросетевых...', 'resp': 'Развитие моделей поискового ранжирования и рекомендательных систем. Тюнинг существующих моделей, feature engineering, а также построение новых решений с нуля. ', 'cond': 'Возможность выбора места работы: удаленно или из офиса. Гибкий график рабочего дня. Оформление в соответствии с ТК РФ, «Белая» заработная...', 'skill': 'Python, SQL, Анализ данных', 'desc': None}
# responsesCount =======> 36
# totalResponsesCount =======> 128
# online_users_count =======> 4

# %% [markdown]
# Useful info keys:
# - 'vacancyId' - unique vacancy id which can be used to see description on https://hh.ru/vacancy/[vacancyId]
# - 'name' - no comments )
# - 'company'->'visibleName' + 'company'->'department'->'@name' - department info (if exists)
# - 'area'->'@id', 'area'->'name' - код и название условной географической области поиска
# - 'address'->'displayName', 'address'->'marker'->('@lat', '@lng') - показываемый адрес и координаты для карты
# - 'compensation'->{'from', 'to', 'currencyCode', 'gross'=(True="before taxes", False="clean amount")} (или 'compensation'->'noCompensation', if no data) - salary info
# - 'workSchedule' - full / shift / remote...
# - 'snippet' - vacancy's description pieces: dict('req' - requirements, 'resp' - responsibilities, 'cond' - conditions, 'skill' - ?not used?, 'desc' - ?)
# - 'publicationTime'
# - 'lastChangeTime'

# %% [markdown]
# Lets define function to get necessary data from json:

# %%
df_column_names = [
    'vacancy_id',
    'vacancy_name',
    'company_name',
    'company_dept',
    'area',
    'address',
    'latitude',
    'longitude',
    'salary_from',
    'salary_to',
    'salary_currency',
    'salary_gross',
    'publication_time',
    'last_changed',
    'schedule',
    'req',
    'resp',
    'cond',
    'skills'
]

# %%
def get_record_data(rec):
    result = dict()
    result['vacancy_id'] = rec['vacancyId']
    result['vacancy_name'] = rec['name']
    result['company_name'] = rec['company']['visibleName']
    if rec['company'].get('department', np.NAN) is np.NAN:
        result['company_dept'] = np.NAN
    else:
        result['company_dept'] = rec['company']['department'].get('@name', np.NAN)
    result['area'] = rec['area']['@id']
    if rec.get('address', None) is None:
        result['address'] = np.NAN
    else:
        result['address'] = rec['address'].get('displayName', np.NAN)
        if rec['address'].get('marker', None) is None:
            result['latitude'] = np.NAN
            result['longitude'] = np.NAN
        else:
            result['latitude'] = rec['address']['marker'].get('@lat', np.NAN)
            result['longitude'] = rec['address']['marker'].get('@lng', np.NAN)
    if rec['compensation'].get('noCompensation', None) is None:
        result['salary_from'] = rec['compensation'].get('from', np.NAN)
        result['salary_to'] = rec['compensation'].get('to', np.NAN)
        result['salary_currency'] = rec['compensation'].get('currencyCode', np.NAN)
        result['salary_gross'] = rec['compensation'].get('gross', np.NAN)
    else:
        result['salary_from'] = np.NAN
        result['salary_to'] = np.NAN
        result['salary_currency'] = np.NAN
        result['salary_gross'] = np.NAN
    result['publication_time'] = rec['publicationTime']['@timestamp']
    result['last_changed'] = rec['lastChangeTime']['@timestamp']
    result['schedule'] = rec['workSchedule']
    result['req'] = rec['snippet'].get('req', np.NAN)
    result['resp'] = rec['snippet'].get('resp', np.NAN)
    result['cond'] = rec['snippet'].get('cond', np.NAN)
    result['skills'] = rec['snippet'].get('skills', np.NAN)

    return result

# %%
raw_parsed_data = {name: [] for name in df_column_names}
for rec in vacancies_info:
    parsed = get_record_data(rec)
    for key in df_column_names:
        raw_parsed_data[key].append(parsed.get(key, np.NAN))
print('Control of num of records created:', len(raw_parsed_data['vacancy_id']))
print('Vacancies ID sample: ', raw_parsed_data['vacancy_id'][:10])
# Out:
# Control of num of records created: 191
# Vacancies ID sample:  [71426958, 71757739, 71908944, 72819441, 71523297, 72323871, 71492524, 71484836, 72787688, 70673604]

# %% [markdown]
# Converting data structures created to pandas DataFrame. Then making readable data in 'publication_time' and 'last_changed' columns. And finally assigning 'vacancy_id' as primary index (it's unique for each record). It will be useful later if I'll decide to update data so I'll be able to filter out existing data or update existing records

# %%
df = pd.DataFrame(raw_parsed_data)
df['publication_time'] = df['publication_time'].apply(pd.to_datetime, unit='s')
df['last_changed'] = df['last_changed'].apply(pd.to_datetime, unit='s')
df.set_index('vacancy_id', inplace=True)
df.head()
# Out:
#                                                  vacancy_name  \
# vacancy_id
# 71426958                      Data Scientist (команда Поиска)
# 71757739                                Аналитик/data science
# 71908944    Ведущий специалист отдела математического моде...
# 72819441               Data Scientist / Аналитик Data Science
# 71523297                              Data Scientist (Senior)
#
#                                   company_name  \
# vacancy_id
# 71426958    HeadHunter::Analytics/Data Science
# 71757739                             Смартсофт
# 71908944                               Eqvanta
# 72819441                          ПроКомплаенс
# 71523297             билайн: ИТ, Data, Digital
#
#                                   company_dept  area  \
# vacancy_id
# 71426958    HeadHunter::Analytics/Data Science     1
# 71757739                                   NaN     1
# 71908944                                   NaN     1
# 72819441                                   NaN     1
# 71523297             билайн: ИТ, Data, Digital     1
#
#                                           address   latitude  longitude  \
# vacancy_id
# 71426958           Москва, улица Годовикова, 9с10  55.809343  37.628505
# 71757739        Москва, Нижний Сусальный переулок  55.761355  37.662659
# 71908944                                      NaN        NaN        NaN
# 72819441    Москва, 1-й переулок Тружеников, 14с8  55.737938  37.571516
# 71523297                                      NaN        NaN        NaN
#
#             salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 71426958       350000.0        NaN             RUR         True
# 71757739            NaN        NaN             NaN          NaN
# 71908944            NaN        NaN             NaN          NaN
# 72819441            NaN        NaN             NaN          NaN
# 71523297            NaN        NaN             NaN          NaN
#
#               publication_time        last_changed  schedule  \
# vacancy_id
# 71426958   2022-11-22 10:01:59 2022-11-22 13:59:41  FULL_DAY
# 71757739   2022-11-27 07:31:08 2022-11-27 08:19:38  FULL_DAY
# 71908944   2022-11-27 07:57:44 2022-11-27 08:20:14    REMOTE
# 72819441   2022-11-26 15:14:05 2022-11-26 15:20:30  FULL_DAY
# 71523297   2022-11-26 16:04:20 2022-11-26 16:19:13    REMOTE
#
#                                                           req  \
# vacancy_id
# 71426958    Опыт реализации и применения моделей машинного...
# 71757739    Высшее техническое образование (IT или физмат)...
# 71908944    Опыт работы в data science от 2х лет. Высшее м...
# 72819441    Опыт работы над прикладными задачами или решен...
# 71523297    Мы рассчитываем, что у тебя есть опыт и знания...
#
#                                                          resp  \
# vacancy_id
# 71426958    Развитие моделей поискового ранжирования и рек...
# 71757739    Участие в задачах, связанных с анализом больши...
# 71908944    Работу над актуальными финтех-продуктами. Полн...
# 72819441    Выявление и связывание ключевой информации в к...
# 71523297    Решать бизнес-задачи с помощью анализа данных ...
#
#                                                          cond  skills
# vacancy_id
# 71426958    Возможность выбора места работы: удаленно или ...     NaN
# 71757739    Работу в центре Москвы возле метро "Курская", ...     NaN
# 71908944    Продуктивную и вдохновляющую атмосферу. Понятн...     NaN
# 72819441    Оформление по ТК РФ (оплата отпуска, больничны...     NaN
# 71523297                                                 None     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 71426958 to 71923183
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vacancy_name      191 non-null    object
#  1   company_name      191 non-null    object
#  2   company_dept      75 non-null     object
#  3   area              191 non-null    int64
#  4   address           84 non-null     object
#  5   latitude          82 non-null     float64
#  6   longitude         82 non-null     float64
#  7   salary_from       18 non-null     float64
#  8   salary_to         17 non-null     float64
#  9   salary_currency   23 non-null     object
#  10  salary_gross      23 non-null     object
#  11  publication_time  191 non-null    datetime64[ns]
#  12  last_changed      191 non-null    datetime64[ns]
#  13  schedule          191 non-null    object
#  14  req               190 non-null    object
#  15  resp              190 non-null    object
#  16  cond              172 non-null    object
#  17  skills            0 non-null      float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(10)
# memory usage: 28.4+ KB

# %%
df.to_csv('datasets/'+filename+'.csv')
