# %% [markdown]
# ### Data scraping from hh.ru and preparation

# %% [markdown]
# [EN] The main goal of this file is to understand how one can get data about vacancies from the biggest Russian job site - hh.ru.<br>
# Here I'll analyze the search results about DS vacancies. Transformed data will be saved in .csv for further processing<br>
# [RU] Основная задача файла - разобраться, каким образом получить данные о вакансиях с hh.ru.<br>
# Для этого я проанализирую результат поисковой выдачи по направлению DS. Данные, которые я смогу получить, сохраню затем в .csv для дальнейшей обработки

# %%
#import requests
import urllib.request
#import datetime
#import re
from bs4 import BeautifulSoup
import json
import numpy as np
import pandas as pd

from time import sleep

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium import webdriver

# %% [markdown]
# [EN] Preparing browser under selenium control to collect data<br>
# [RU] Подготовка браузера под контролем библиотеки selenium к сбору данных

# %%
chrome_mode = 'headed' #'headless' # for debug purposes we can change this value to any but 'headless' to run Chrome in standard mode
chrome_options = Options()
if chrome_mode == 'headless':
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--disable-gpu')
    chrome_options.add_argument('--headless')
service = Service(executable_path="c:\\Applications\\WebDriver\\chromedriver-x32.exe")
browser = webdriver.Chrome(service=service, options=chrome_options)

# %%
# urls to search vacancies by words "аналитик данных" / "data scien*" in Russia
#https://hh.ru/search/vacancy?text=data+scien*&search_field=name&search_field=description&area=1&salary=150000&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100&no_magic=true&L_save_area=true
#https://hh.ru/search/vacancy?text=data+scien*&search_field=name&search_field=description&area=1&salary=150000&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100&no_magic=true&L_save_area=true&page=1&hhtmFrom=vacancy_search_list
#https://hh.ru/search/vacancy?text=data+scien*&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100&no_magic=true&L_save_area=true
search_url_template = "https://hh.ru/search/vacancy?text={}&search_field=name&search_field=description&{}salary={}&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page={}"
items_on_page = 100
salary_level = '' #'150000'
search_texts = [
    "data+scien*",
    "%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85",
]
areas = {
    'All': '',
    'Moscow': 'area=1&',
    'SPb': 'area=2&',
    'Ekaterinburg': 'area=3&',
    'Novosib': 'area=4&',
    'Austria': 'area=7&',
    'Erevan': 'area=13&',
    'NNovgorod': 'area=66&',
    'RostovND': 'area=76&',
    'Samara': 'area=78&',
    'Saratov': 'area=79&',
    'Kazan': 'area=88&',
    'Chelyabinsk': 'area=104&',
    '???': 'area=159&',
    'Almaty': 'area=160&',
    'Minsk': 'area=1002&',
    'Nur-Sultan': 'area=159&',
    'Tbilisi': 'area=2758&',
    'Tashkent': 'area=2759&',
}
url_tail = '&page={}&hhtmFrom=vacancy_search_list'

# %%
def combine_base_url(template=None, search_text='', area_keys=[], salary='', items_per_page=100):
    if template is None:
        return None
    areas_str = ''
    for key in area_keys:
        areas_str += areas[key]
    return template.format(search_text, areas_str, salary, items_per_page)

# %%
base_url = combine_base_url(template = search_url_template, search_text=search_texts[0])
base_url
# Out:
# 'https://hh.ru/search/vacancy?text=data+scien*&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100'

# %%
output_filename = 'vacancies_data_scientist'

# %%
browser.get(base_url)

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')
# Page source code showed us there is only 1 'template' tag on page.
# It contains a huge amount of data including vacancies list in dictionary-like format (possibly for JS parsing).
# So here I'll use json library to convert html text to dictionaries/lists
json_parsed = json.loads(soup.find_all('template')[0].text)
print('"Template" tag contains {} keys'.format(len(json_parsed)))
# Out:
# "Template" tag contains 496 keys

# %%
json_parsed
# Out:
# {'authPhone': None,
#  'authNewEmployerAreaIdsToRedirect': [],
#  'authNewEmployerCategories': [],
#  'authNewEmployerFields': [],
#  'authNewEmployerInitialValues': {},
#  'authNewEmployerPhoneMask': None,
#  'activeResumeAccessType': None,
#  'accountTemporarilyLocked': {},
#  'accountPhoneVerification': None,
#  'applicantSignup': {'fields': [], 'hideLogin': False},
#  'applicantVacancyResponseStatuses': {},
#  'applicantResumes': [],
#  'applicantResponseStreaks': {},
#  'applicantPackageType': 'basic',
#  'applicantServiceType': '',
#  'applicantPaymentBackUrl': '',
#  'applicantAnalyticsAction': '',
#  'applicantPaymentTypes': [],
#  'applicantAvailableResumeServices': [],
#  'applicantPackageContent': [],
#  'applicantAvailableQuantities': [],
#  'applicantServicesPrices': {},
#  'applicantPaymentSource': 'desktop',
#  'applicantFindJobRecommendedQuantity': None,
#  'applicantSuitableVacancyByResume': {},
#  'account': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountConnect': {},
#  'accountConnectOAuth': {},
#  'accountConnectResponse': {},
#  'actualAccount': None,
#  'accountHistoryServices': {'employerActiveTemporalServices': [],
#   'employerTemporalServices': [],
#   'employerActiveSingleServices': [],
#   'employerFreeServices': []},
#  'accountHistoryReplenishments': {'bills': [],
#   'documentLinksVisibility': False,
#   'currency': 'RUR'},
#  'accountHistoryExpenditures': {'services': [], 'currency': ''},
#  'artifactRules': None,
#  'hhidAccount': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountDelete': {'applicantName': '',
#   'resumesList': {'resumes': {'published': [], 'unpublished': []},
#    'count': 0}},
#  'adsSearchParams': {'puid11': 'searchVacancy',
#   'puid23': '',
#   'puid14': 'data scien*',
#   'puid29': '',
#   'puid30': '',
#   'puid12': '',
#   'puid13': ''},
#  'adsVacancyParams': {},
#  'alreadyRegisteredEmployer': None,
#  'anonymousUserType': None,
#  'advancedSearch': {'showSearchConditions': False,
#   'hideSuggest': False,
#   'vacancy': None,
#   'resume': None,
#   'experience': [],
#   'keySkills': [],
#   'university': [],
#   'citizenship': [],
#   'work_ticket': [],
#   'employment': [],
#   'schedule': [],
#   'driver_license_types': [],
#   'job_search_status': [],
#   'language': [],
#   'exclusion': []},
#  'anonymousEmployer': {'suggestedProfessions': [],
#   'applicantCount': None,
#   'publicationPrice': None,
#   'averageEmployersOnline': None},
#  'allowedSMSCountries': None,
#  'appleBusinessChat': {'isEnabled': False, 'href': ''},
#  'abortPageContent': False,
#  'applicantEmployersNegotiationStats': {'employer-negotiation-stats': []},
#  'applicantEmployerManagersActivity': [],
#  'applicantNews': [],
#  'applicantArticles': [],
#  'applicantLatestResume': None,
#  'applicantFaq': [],
#  'addressesSuggestRemoteMode': False,
#  'analyticsParams': {'hhtmSource': 'vacancy_search_list',
#   'hhtmFrom': '',
#   'hhtmSourceLabel': '',
#   'hhtmFromLabel': '',
#   'screenType': 'SIMPLE'},
#  'applicantInfo': {'total': 0, 'finished': 0, 'visible': 0, 'searchable': 0},
#  'applicantNegotiations': {'topicList': [], 'filterInUse': 'all'},
#  'applicantNegotiationsActionsData': {'deleteAction': {},
#   'filters': [],
#   'filterByStatus': [],
#   'backUrl': '',
#   'order': {}},
#  'applicantPaymentServices': [],
#  'applicantResumesStatistics': {},
#  'applicantSettingsMenu': [],
#  'applicantSubscriptions': {'formItems': {},
#   'initialValues': {},
#   'email': None,
#   'emailVerified': None},
#  'applicantUseful': [],
#  'applicantUserStatuses': None,
#  'authUrl': {'login-url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-form': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-field-value': '',
#   'backurl-field-name': 'backUrl',
#   'remember-field-name': 'remember',
#   'remember-field-value': 'yes',
#   'backurl': 'https://lipetsk.hh.ru/search/vacancy?text=data+scien%2A&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#   'failurl': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'signup-form': '/account/signup?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'auth-employer-url': '/auth/employer/?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'remember-password': '/account/remember_password?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'agreement-form': '/account/agreement?backurl=%2Faccount%2Fsignup%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100',
#   'employer-agreement': '/auth/employer/agreement?backurl=%2Fauth%2Femployer%2F%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100'},
#  'availableVacancyActions': {},
#  'analyticsConversionPromo': None,
#  'brandedVacancyTemplates': [],
#  'employerSubscriptions': {'initialValues': {}, 'employerId': ''},
#  'emailVerification': {'email': '', 'needVerification': False, 'mailURL': ''},
#  'employerTests': [],
#  'employerResumesNegotiationLinks': {},
#  'employerRegistrationPresentsByCountryId': {},
#  'applicantResumesIdentifiers': [],
#  'areaTree': [],
#  'assessments': {'assessments': []},
#  'availableCallOptions': [],
#  'loginForm': {'passwordRecovery': {'trl': 'Получить пароль'},
#   'registration': [{'trl': 'Соискателя',
#     'code': 'REG_APPLICANT',
#     'translationKey': 'account.login.registration.applicant.capitalized'},
#    {'trl': 'Работодателя',
#     'code': 'REG_EMPLOYER',
#     'translationKey': 'account.login.registration.employer.capitalized'}],
#   'socialNetworks': [{'trl': 'Мой Мир@mail.ru',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list',
#     'code': 'MAIL',
#     'translationKey': 'socialNetworkTitle.mail'},
#    {'trl': 'Одноклассники',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list',
#     'code': 'OK',
#     'translationKey': 'socialNetworkTitle.ok'},
#    {'trl': 'ВКонтакте',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list',
#     'code': 'VK',
#     'translationKey': 'socialNetworkTitle.vk'},
#    {'trl': 'Google',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list',
#     'code': 'GPLUS',
#     'translationKey': 'socialNetworkTitle.gplus'},
#    {'trl': 'Доктор на работе',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list',
#     'code': 'DNR',
#     'translationKey': 'socialNetworkTitle.dnr'}]},
#  'backofficeCanEditTemplate': True,
#  'backUrl': None,
#  'banners': {'under-pagination-search-results-l': [{'id': '293',
#     'cId': 'e8c99b6f-dbc1-4549-a28c-157953ce98a7',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'under-pagination-search-results-m': [{'id': '294',
#     'cId': 'be8f9cc1-b220-4f42-9cb2-7a55ada30c59',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'under-pagination-search-results-s': [{'id': '292',
#     'cId': '000c8edb-8f6f-4687-9c32-5fb2ffa5db85',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'under-pagination-search-results-xs': [{'id': '521',
#     'cId': '416bcd7d-4c4f-45b4-81ad-8b75a92f12a1',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-rotate': [{'id': '654',
#     'cId': '31ea43f6-a1ee-4c18-87cb-edaf862656d0'},
#    {'id': '655', 'cId': '13067e37-686b-4634-a9b3-80141043be51'}],
#   'serp-first-l': [{'id': '221',
#     'cId': '0b4d8b85-b2f8-46c2-81d0-c8bf5391954a',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-first-m': [{'id': '637',
#     'cId': '76e5b995-e364-4a44-9fe0-1be3b6a04dc9',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-first-s': [{'id': '613',
#     'cId': '25629b6b-f449-4919-95ba-ebc2f6eb0bca',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-first-xs': [{'id': '630',
#     'cId': 'aae29aad-b2bd-49d3-b1be-9c1502270e97',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-second-l': [{'id': '175',
#     'cId': 'ce6a6af6-6972-49fb-b9f4-6aefc352bf4e',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-second-m': [{'id': '347',
#     'cId': 'c7528f59-5e8c-426f-ae58-30ef64daca0e',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-second-s': [{'id': '638',
#     'cId': '53b272bf-9762-4ea0-bdee-1ed162dc2282',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-second-xs': [{'id': '505',
#     'cId': '6bfa1bf0-1a23-4d52-9a5d-e025044f9063',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-xs': [{'id': '661',
#     'cId': '14420844-6603-499e-befd-60e87d19850e'},
#    {'id': '662', 'cId': 'f66a26dd-6abc-4864-843a-5b35b247b0f6'},
#    {'id': '663', 'cId': 'ee857b49-9254-45f4-9524-4a044449377a'}],
#   'serp-third-l': [{'id': '72',
#     'cId': 'be00fc26-378f-46cf-9bbc-2f186e37e4bf',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-third-m': [{'id': '261',
#     'cId': '9891e62f-7807-445a-a427-331bcd2e7eb4',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-third-s': [{'id': '261',
#     'cId': '31bd129a-360c-4331-9c8e-6e1f0c62b8b6',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-third-xs': [{'id': '60',
#     'cId': '25e55970-4da6-494f-8783-b96b82b9328b',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fourth-l': [{'id': '69',
#     'cId': '76a71501-4276-4e67-8f9d-3528b5a5df80',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fourth-m': [{'id': '91',
#     'cId': '7a93e795-79b4-4de2-9ede-452127d7397e',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fourth-s': [{'id': '91',
#     'cId': '36a2de74-345a-4753-ab0b-e2438c1b9d44',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fourth-xs': [{'id': '59',
#     'cId': '49d61f19-7570-42d5-a4fb-3760c46fcd23',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fifth-l': [{'id': '158',
#     'cId': 'e4573ee5-7f84-43a9-aa5e-8071226cd178',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fifth-m': [{'id': '87',
#     'cId': '3e35b3bc-6e3d-48b6-a8d1-3cefb9d73091',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fifth-s': [{'id': '87',
#     'cId': '64a47f91-f699-459a-89e3-7b9697e808a0',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fifth-xs': [{'id': '19',
#     'cId': '0f87e290-b42a-4a41-9e4b-fc31faf57cc8',
#     'pp': 'g',
#     'p2': 'hoyc'}]},
#  'bannersImage': {},
#  'cancelFetchBanners': False,
#  'candidates': {'collection': {'actions': [], 'filters': []},
#   'onlyAssessments': False},
#  'candidatesList': None,
#  'captchaAccountState': {'state': '', 'backurl': '', 'failurl': ''},
#  'catalogLinks': [],
#  'chatBot': {'messengers': [{'type': 'vk',
#     'icon': 'vk',
#     'href': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'},
#    {'type': 'telegram',
#     'icon': 'telegram',
#     'href': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'},
#    {'type': 'viber',
#     'icon': 'viber-mini',
#     'href': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'}],
#   'page': 'vacancysearch',
#   'genericUserType': 'anonymous',
#   'source': 'hhru'},
#  'chatik': None,
#  'chatikIntegration': False,
#  'chatikUnreadCount': 0,
#  'checkedTopics': [],
#  'checkedEmployerFAQLink': 'https://feedback.hh.ru/article/details/id/5951',
#  'clickmeInfo': None,
#  'commentsByUserId': {},
#  'companiesOfTheDay': [],
#  'config': {'staticHost': 'https://i.hh.ru',
#   'hhcdnHost': 'https://hhcdn.ru',
#   'imageResizingCdnHost': 'https://img.hhcdn.ru'},
#  'countryPhoneCode': '',
#  'contactPhones': [{'country': '+7',
#    'city': '495',
#    'number': '974-64-27',
#    'postfix': 'msk'},
#   {'country': '+7', 'city': '812', 'number': '458-45-45', 'postfix': 'spb'},
#   {'country': '8',
#    'city': '800',
#    'number': '100-64-27',
#    'postfix': 'regions'}],
#  'companiesOfTheDayTrls': {'area': ''},
#  'currencies': {'default': 'RUR',
#   'list': [{'code': 'RUR',
#     'name': 'руб.',
#     'gender': 'MASCULINE',
#     'rate': 1,
#     'defaultCurrency': True,
#     'site': True},
#    {'code': 'USD',
#     'name': 'USD',
#     'gender': 'MASCULINE',
#     'rate': 0.018739,
#     'defaultCurrency': False,
#     'site': True},
#    {'code': 'EUR',
#     'name': 'EUR',
#     'gender': 'MASCULINE',
#     'rate': 0.01784,
#     'defaultCurrency': False,
#     'site': True}]},
#  'complaintReasonTypes': [],
#  'competitorAnalysisBanner': {},
#  'chatWritePossibilities': [],
#  'criteriaCurrencyCode': 'RUR',
#  'crosslinks': None,
#  'currentManagerId': '',
#  'countryId': '1',
#  'defaultCountryCompanySearchId': '113',
#  'driverLicenseTypes': [],
#  'detectedVacancySearchAreaIds': ['58'],
#  'discriminationWarning': False,
#  'chatResponseId': None,
#  'displayType': 'DESKTOP',
#  'distances': None,
#  'domainRegionTrl': '',
#  'domainAreaId': '58',
#  'draftsPurchaseInfo': {},
#  'employerAddresses': [],
#  'employerAddressesCount': None,
#  'employerAddressesPage': {'addresses': [],
#   'addressesCount': 0,
#   'isFetching': False,
#   'loadingComponent': ''},
#  'employerArticles': [],
#  'employerBillingInfo': None,
#  'employerCarts': None,
#  'employerChecks': {},
#  'employerAdvice': None,
#  'employerAdvices': [],
#  'employerButtons': {},
#  'employerNegotiationsChangeTopic': None,
#  'employerCompanyMenu': [],
#  'employerConstructorWebViewMode': False,
#  'employerConstructorAutoAddWidget': None,
#  'employerConstructorSettings': {'pictureSettings': {}},
#  'employerConstructor': {'editMode': False,
#   'previewModeWithBranding': True,
#   'version': None,
#   'canEdit': False,
#   'modalError': None,
#   'widgets': [],
#   'widgetsOrder': [],
#   'saveStatus': 'DIRTY',
#   'hasUnsavedChanges': False,
#   'pictureId': None,
#   'resizeStatus': 'DIRTY',
#   'images': [],
#   'tabPrices': [],
#   'hasConstructor': False,
#   'hasService': False,
#   'readyToActivateCartId': None,
#   'sidebarColors': {}},
#  'employerDocuments': [],
#  'employerPageIsViewMode': False,
#  'employerCurrentDivision': None,
#  'employerDocumentsSettings': {},
#  'employerEdoList': [],
#  'employerDocumentsMenu': [],
#  'employerDepartments': [],
#  'employerDivisions': {},
#  'employerFaq': [],
#  'employerHasDivisions': False,
#  'employerId': '',
#  'employerImplants': None,
#  'employerName': '',
#  'employerIndexPage': {},
#  'employerLogo': {'logoUrl': None, 'logoStatus': 'Dirty'},
#  'edoDictionary': None,
#  'employerInfo': {'id': None,
#   'name': None,
#   'category': None,
#   'address': None,
#   'site': None,
#   'industries': None,
#   'hrBrand': None,
#   'description': None,
#   'saveDescriptionStatus': 'DIRTY',
#   'organizationFormId': None,
#   'isTrusted': False,
#   'canEditDescription': False,
#   'hasUnsavedChanges': False},
#  'employments': [],
#  'employerInsiders': [],
#  'employerInvoicePurchase': {'cart': {'cartId': None, 'services': []},
#   'activations': {'services': {}, 'currentActivationType': None}},
#  'employerReviewsModal': {'visible': False, 'reviewsEnabled': False},
#  'employerLastSearches': [],
#  'employersListQuery': None,
#  'employerSeoCities': [],
#  'employerSettingsVacancyPublication': {},
#  'employerInsiderInterview': None,
#  'employerManager': None,
#  'employerNoAdviceArticles': [],
#  'employerManagersPage': {'managersViewMeta': {'ableToCreateManager': False,
#    'canEditEmployerManagerQuotas': False,
#    'managersCreationLimitReached': True,
#    'onlyOneManagerEnabled': False,
#    'MCPSGroup': False,
#    'resumeViewsAccessDenied': True,
#    'ResumeViewHistory': False,
#    'showResumeViewsNumbers': False,
#    'giveMCPAllowed': False,
#    'userEmail': ''},
#   'managersShown': [],
#   'negotiationStats': {'politeness-index': {},
#    'responses-read-percent': {},
#    'responses-read-percent-change': {},
#    'responses-received': {},
#    'responses-replied-percent': {},
#    'responses-replied-percent-change': {},
#    'responses-reply-time-days': {}},
#   'resumeViews': {},
#   'filter': '',
#   'loading': False},
#  'employerManagersList': [],
#  'employerManagers': [],
#  'employerMarketSegmentType': None,
#  'employerConsumptionSegmentType': None,
#  'employersList': {'totalEmployersFound': 0, 'employers': [], 'paging': None},
#  'employersListOnReactEnabled': False,
#  'employerNews': [],
#  'employerExperiences': {'experience': []},
#  'employerReviewsApplicantProfileBadge': False,
#  'employerReviewsApplicantShowIndexWidget': False,
#  'employerReviewRating': {'ids': [], 'ratings': []},
#  'employerSearchSettings': {},
#  'employerSettingsMenu': {'employerManagersLink': '/employer/managers',
#   'menuItems': [],
#   'employerManagerName': ''},
#  'employerNegotiations': {'total': None,
#   'maximumTopicsPerUser': None,
#   'topicList': [],
#   'responseLetters': {}},
#  'employerStatus': {'category': '',
#   'state': '',
#   'countryId': '',
#   'suspiciousState': 'NOT_SUSPICIOUS'},
#  'employerViewSelectedAreas': [],
#  'enableSimilarSavedSearch': False,
#  'enableJobSearchStatus': False,
#  'experiments': {'enabled': {'tempexp_15905_linking_vacancies': 'experiment',
#    'vacancy_partial_redesign_b': 'experiment',
#    'yenisei_bert_tdi': 'experiment',
#    'tempexp_16177_v2': 'experiment',
#    'tempexp_14535_b': 'experiment'},
#   'checked': []},
#  'educationLevels': [],
#  'errorCode': None,
#  'excludedVacancyPublicationAreas': [],
#  'favoriteVacancies': {},
#  'fastVacanciesSubscriptionSettings': {},
#  'favoriteVacanciesCount': None,
#  'features': {'new_vacancy_suggest': True,
#   'delayed_cart_activation_article_id': '30085',
#   'max_vacancies_rendered_on_server': 20},
#  'filteredVacancyResponsesCount': None,
#  'floodlightGtagEnabled': False,
#  'floodlightUtm': {},
#  'financialDocumentDeeds': [],
#  'financialDocumentDeedsFilters': None,
#  'financialDocumentDeedsPaging': None,
#  'financialDocumentDeedsTotalRows': None,
#  'fetchingData': False,
#  'folderContent': None,
#  'footer': [{'name': 'footerNav',
#    'translations': {'name': '[RU:15:supernova.navi.footerNav]'},
#    'subItems': [{'name': 'site',
#      'translations': {'name': 'HeadHunter'},
#      'subItems': [{'name': 'copyright',
#        'translations': {'name': 'О компании'},
#        'url': '/article/28?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'hhCompanyInfo',
#        'translations': {'name': 'Наши вакансии'},
#        'url': '/employer/1455?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advertisingDescription',
#        'translations': {'name': 'Реклама на сайте'},
#        'url': 'https://ads.hh.ru/?from=footer_new&hhtmFromLabel=footer_new',
#        'external': True},
#       {'name': 'hardwareRequirements',
#        'translations': {'name': 'Требования к ПО'},
#        'url': '/article/176?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'dataProtection',
#        'translations': {'name': 'Защита персональных данных'},
#        'url': '/article/personal_data?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'safety',
#        'translations': {'name': 'Безопасный HeadHunter'},
#        'url': '/safety?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'compliance',
#        'translations': {'name': 'Этика и\xa0комплаенс'},
#        'url': '/article/compliance?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'api',
#        'translations': {'name': 'HeadHunter API'},
#        'url': 'https://dev.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'partners',
#        'translations': {'name': 'Партнерам'},
#        'url': '/partners?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'investor',
#        'translations': {'name': 'Инвесторам'},
#        'url': 'https://investor.hh.ru',
#        'external': True},
#       {'name': 'conditions',
#        'translations': {'name': 'Условия оказания услуг'},
#        'url': '/conditions?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'terms',
#        'translations': {'name': 'Условия использования сайтов'},
#        'url': '/terms?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'articles',
#      'translations': {'name': 'Новости и статьи'},
#      'url': '/articles',
#      'subItems': [{'name': 'hrNews',
#        'translations': {'name': 'Новости рынка HR'},
#        'url': '/articles/market-news/hr-news?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'articlesInsider',
#        'translations': {'name': 'Жизнь в компании'},
#        'url': '/articles/insider?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'itproject',
#        'translations': {'name': 'ИТ-проекты'},
#        'url': '/articles/applicants/it-projects?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'employersRating',
#        'translations': {'name': 'Рейтинг работодателей России'},
#        'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'applicantServices',
#      'translations': {'name': 'Сервисы для соискателей'},
#      'subItems': [{'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advancementServices',
#        'translations': {'name': 'Все сервисы'},
#        'url': '/applicant-services/services/all?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'proforientation',
#        'translations': {'name': 'Профориентация'},
#        'url': '/article/proforientation_promo?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'ka',
#        'translations': {'name': 'Форум карьеристов'},
#        'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'findjob',
#        'translations': {'name': 'Продвижение резюме'},
#        'url': '/applicant/services/findjob?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'wantwork',
#        'translations': {'name': 'Хочу у вас работать'},
#        'url': '/article/98?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'calendar',
#        'translations': {'name': 'Производственный календарь'},
#        'url': '/calendar?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'forTeens',
#      'translations': {'name': 'Молодым специалистам'},
#      'subItems': [{'name': 'career',
#        'translations': {'name': 'Карьера для молодых специалистов'},
#        'url': '/students?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'school',
#        'translations': {'name': 'Школа программистов'},
#        'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'schoolProduct',
#        'translations': {'name': 'Школа продактов'},
#        'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'additional',
#      'translations': {'name': '[RU:15:supernova.navi.additional]'},
#      'subItems': [{'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'anonymousCreateVacancy',
#          'translations': {'name': 'Поиск сотрудников'},
#          'url': '/employer?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'copiny',
#          'translations': {'name': 'Помощь'},
#          'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#          'external': True},
#         {'name': 'agreement',
#          'translations': {'name': 'Пользовательское соглашение'},
#          'url': '/account/agreement?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'employersSearch',
#          'translations': {'name': 'Каталог компаний'},
#          'url': '/employers_company?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'catalog',
#          'translations': {'name': 'Работа по профессиям'},
#          'url': '/catalog?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'chatBot',
#          'translations': {'name': 'Уведомления в\xa0мессенджер'},
#          'subItems': [{'name': 'chatBotTelegram',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotTelegram]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotViber',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotViber]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotVk',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotVk]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True}]}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.additionalSection]'},
#        'subItems': [{'name': 'lang',
#          'translations': {'name': '[RU:15:supernova.navi.lang]'}}]}]}]}],
#  'forbidden': False,
#  'globalInvitations': 3103214,
#  'getPageHtmlEnabled': False,
#  'globalStatistics': {'vacancies': 881382,
#   'employers': 1803338,
#   'resumes': 59932749},
#  'hasBrandedTemplates': False,
#  'hasEditSidebarButton': False,
#  'hasForceReloadDreamJob': False,
#  'hasListOfVacanciesByRoles': False,
#  'hasVacancyResponsesSummaryService': False,
#  'hasVideoInterview': False,
#  'hasChameleon': False,
#  'headerMenu': [{'name': 'menuLvl1',
#    'translations': {'name': '[RU:15:supernova.navi.menuLvl1]'},
#    'subItems': [{'name': 'mainContent',
#      'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#      'subItems': [{'name': 'switchers',
#        'translations': {'name': '[RU:15:supernova.navi.switchers]'},
#        'subItems': [{'name': 'areaSwitcher',
#          'translations': {'name': 'Липецк'}},
#         {'name': 'applicant',
#          'translations': {'name': 'Соискателям'},
#          'url': '/set_user_type?user_type=applicant&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'active': True},
#         {'name': 'employer',
#          'translations': {'name': 'Работодателям'},
#          'url': '/set_user_type?user_type=employer&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'trackClicks': True}]},
#       {'name': 'fill',
#        'translations': {'name': '[RU:15:supernova.navi.fill]'}},
#       {'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#       {'name': 'interviewpractice',
#        'translations': {'name': 'Репетиция собеседования'},
#        'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#     {'name': 'applicantServices', 'translations': {'name': 'Все сервисы'}}]},
#   {'name': 'menuLvl2',
#    'translations': {'name': '[RU:15:supernova.navi.menuLvl2]'},
#    'subItems': [{'name': 'logo',
#      'translations': {'name': '[RU:15:supernova.navi.logo]'}},
#     {'name': 'help',
#      'translations': {'name': 'Помощь'},
#      'dropdown': True,
#      'subItems': [{'name': 'mainContent',
#        'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'vishnu',
#          'translations': {'name': 'Виртуальный консультант'}},
#         {'name': 'applicantHelp',
#          'translations': {'name': 'Вопросы и ответы'},
#          'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#          'external': True},
#         {'name': 'copiny',
#          'translations': {'name': 'Сообщество поддержки'},
#          'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#          'external': True},
#         {'name': 'writeToUs',
#          'translations': {'name': 'Пишите нам'},
#          'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#          'external': True}]},
#       {'name': 'supportChat',
#        'translations': {'name': 'Техподдержка онлайн'}}]},
#     {'name': 'userTypeSwitcher',
#      'translations': {'name': '[RU:15:supernova.navi.userTypeSwitcher]'},
#      'trackClicks': True,
#      'dropdown': True,
#      'subItems': [{'name': 'userTypeSwitcherApplicant',
#        'translations': {'name': 'Ищу работу'},
#        'url': '/set_user_type?user_type=applicant&backurl=%2F',
#        'trackClicks': True,
#        'active': True},
#       {'name': 'userTypeSwitcherEmployer',
#        'translations': {'name': 'Ищу сотрудника'},
#        'url': '/employer',
#        'trackClicks': True}]},
#     {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}},
#     {'name': 'searchVacancy',
#      'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'},
#      'url': '/search/vacancy/advanced'},
#     {'name': 'signup',
#      'translations': {'name': 'Создать резюме'},
#      'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#     {'name': 'login',
#      'translations': {'name': 'Войти'},
#      'url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100'},
#     {'name': 'mobile',
#      'translations': {'name': '[RU:15:supernova.navi.mobile]'},
#      'url': '/mobile',
#      'dropdown': True,
#      'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Липецк'}},
#       {'name': 'mainContent',
#        'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'help',
#          'translations': {'name': 'Помощь'},
#          'dropdown': True,
#          'subItems': [{'name': 'mainContent',
#            'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#            'subItems': [{'name': 'applicantHelp',
#              'translations': {'name': 'Вопросы и ответы'},
#              'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#              'external': True},
#             {'name': 'copiny',
#              'translations': {'name': 'Сообщество поддержки'},
#              'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#              'external': True},
#             {'name': 'writeToUs',
#              'translations': {'name': 'Пишите нам'},
#              'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#              'external': True}]},
#           {'name': 'supportChat',
#            'translations': {'name': 'Техподдержка онлайн'}}]},
#         {'name': 'signup',
#          'translations': {'name': 'Создать резюме'},
#          'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#       {'name': 'applicantServices',
#        'translations': {'name': 'Все сервисы'},
#        'subItems': [{'name': 'advancementServices',
#          'translations': {'name': 'Продвижение резюме'},
#          'url': '/applicant-services/services/all',
#          'subItems': [{'name': 'expertresume',
#            'translations': {'name': 'Готовое резюме',
#             'description': 'Доверьте составление резюме профессионалам!'},
#            'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'careerconsult',
#            'translations': {'name': 'Карьерная консультация',
#             'description': 'Обсудите с\xa0экспертом, как эффективно искать работу'},
#            'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'interviewpractice',
#            'translations': {'name': 'Репетиция собеседования',
#             'description': 'Подготовьтесь к\xa0интервью вместе с\xa0карьерным экспертом'},
#            'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu',
#            'badge': 'new'},
#           {'name': 'applicantVacancyResponsesSummary',
#            'translations': {'name': 'Статистика по\xa0вакансии',
#             'description': 'Сравните себя с\xa0другими кандидатами, откликнувшимися на\xa0вакансию'},
#            'url': '/article/vacancy_summary?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'proforientation',
#            'translations': {'name': 'Профориентация',
#             'description': 'Узнайте, какой вы специалист и добейтесь большего'},
#            'url': '/article/proforientation_promo?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'findjob',
#            'translations': {'name': 'Продвижение резюме',
#             'description': 'Автоматическое поднятие резюме в\xa0результатах поиска'},
#            'url': '/applicant/services/findjob?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'wantwork',
#            'translations': {'name': 'Хочу у вас работать',
#             'description': 'Отправьте свое резюме в компанию мечты'},
#            'url': '/article/98?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#         {'name': 'educationServices',
#          'translations': {'name': 'Образование и консультации'},
#          'subItems': [{'name': 'applicantEduCenter',
#            'translations': {'name': 'Бесплатные вебинары'},
#            'url': '/article/applicant-free-webinars?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'articles',
#            'translations': {'name': 'Статьи'},
#            'url': '/articles?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'ka',
#            'translations': {'name': 'Форум карьеристов'},
#            'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'school',
#            'translations': {'name': 'Школа программистов'},
#            'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'itproject',
#            'translations': {'name': 'ИТ-проекты'},
#            'url': '/articles/applicants/it-projects?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'articlesInsider',
#            'translations': {'name': 'Жизнь в компании'},
#            'url': '/articles/insider?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'hhRatingAll',
#            'translations': {'name': 'Рейтинг работодателей России'},
#            'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'schoolProduct',
#            'translations': {'name': 'Школа продактов'},
#            'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True}]},
#         {'name': 'beginnerServices',
#          'translations': {'name': 'Студентам и начинающим специалистам'},
#          'subItems': [{'name': 'career',
#            'translations': {'name': 'Карьера для молодых специалистов'},
#            'url': '/students?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'rating',
#            'translations': {'name': 'Рейтинг факультетов и вузов'},
#            'url': '/rating?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#         {'name': 'beta',
#          'translations': {'name': 'Сервисы в\xa0разработке'},
#          'subItems': [{'name': 'betaApplicant',
#            'translations': {'name': 'Песочница',
#             'description': 'Попробуйте новые сервисы, которые, возможно, появятся на\xa0hh.ru в\xa0будущем'},
#            'url': '/article/beta_applicant?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]}]}]}]},
#   {'name': 'searchForm',
#    'translations': {'name': '[RU:15:supernova.navi.searchForm]'},
#    'subItems': [{'name': 'searchVacancy',
#      'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'},
#      'url': '/search/vacancy/advanced',
#      'action': '/search/vacancy'},
#     {'name': 'resumeSearch',
#      'translations': {'name': '[RU:15:supernova.navi.resumeSearch]'},
#      'url': '/search/resume/advanced',
#      'action': '/search/resume'},
#     {'name': 'employersList',
#      'translations': {'name': '[RU:15:supernova.navi.employersList]'},
#      'url': '/employers_list?areaId=113',
#      'action': '/employers_list'}]},
#   {'name': 'applicantServices',
#    'translations': {'name': 'Все сервисы'},
#    'subItems': [{'name': 'advancementServices',
#      'translations': {'name': 'Продвижение резюме'},
#      'url': '/applicant-services/services/all',
#      'subItems': [{'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме',
#         'description': 'Доверьте составление резюме профессионалам!'},
#        'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'careerconsult',
#        'translations': {'name': 'Карьерная консультация',
#         'description': 'Обсудите с\xa0экспертом, как эффективно искать работу'},
#        'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'interviewpractice',
#        'translations': {'name': 'Репетиция собеседования',
#         'description': 'Подготовьтесь к\xa0интервью вместе с\xa0карьерным экспертом'},
#        'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu',
#        'badge': 'new'},
#       {'name': 'applicantVacancyResponsesSummary',
#        'translations': {'name': 'Статистика по\xa0вакансии',
#         'description': 'Сравните себя с\xa0другими кандидатами, откликнувшимися на\xa0вакансию'},
#        'url': '/article/vacancy_summary?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'proforientation',
#        'translations': {'name': 'Профориентация',
#         'description': 'Узнайте, какой вы специалист и добейтесь большего'},
#        'url': '/article/proforientation_promo?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'findjob',
#        'translations': {'name': 'Продвижение резюме',
#         'description': 'Автоматическое поднятие резюме в\xa0результатах поиска'},
#        'url': '/applicant/services/findjob?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'wantwork',
#        'translations': {'name': 'Хочу у вас работать',
#         'description': 'Отправьте свое резюме в компанию мечты'},
#        'url': '/article/98?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#     {'name': 'educationServices',
#      'translations': {'name': 'Образование и консультации'},
#      'subItems': [{'name': 'applicantEduCenter',
#        'translations': {'name': 'Бесплатные вебинары'},
#        'url': '/article/applicant-free-webinars?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'articles',
#        'translations': {'name': 'Статьи'},
#        'url': '/articles?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'ka',
#        'translations': {'name': 'Форум карьеристов'},
#        'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'school',
#        'translations': {'name': 'Школа программистов'},
#        'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'itproject',
#        'translations': {'name': 'ИТ-проекты'},
#        'url': '/articles/applicants/it-projects?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'articlesInsider',
#        'translations': {'name': 'Жизнь в компании'},
#        'url': '/articles/insider?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'hhRatingAll',
#        'translations': {'name': 'Рейтинг работодателей России'},
#        'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'schoolProduct',
#        'translations': {'name': 'Школа продактов'},
#        'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True}]},
#     {'name': 'beginnerServices',
#      'translations': {'name': 'Студентам и начинающим специалистам'},
#      'subItems': [{'name': 'career',
#        'translations': {'name': 'Карьера для молодых специалистов'},
#        'url': '/students?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'rating',
#        'translations': {'name': 'Рейтинг факультетов и вузов'},
#        'url': '/rating?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#     {'name': 'beta',
#      'translations': {'name': 'Сервисы в\xa0разработке'},
#      'subItems': [{'name': 'betaApplicant',
#        'translations': {'name': 'Песочница',
#         'description': 'Попробуйте новые сервисы, которые, возможно, появятся на\xa0hh.ru в\xa0будущем'},
#        'url': '/article/beta_applicant?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]}]}],
#  'hideFooterServices': False,
#  'hhid': None,
#  'industriesTree': [],
#  'infoMoreResponsesBlock17168': {},
#  'infoTip': {},
#  'isLightPage': False,
#  'isMapVacancySearch': False,
#  'isNewEmployer': False,
#  'isNewVacancy': False,
#  'isWebView': False,
#  'isIFrame': False,
#  'isProfessionalRolesModeInResume': False,
#  'langs': ['RU'],
#  'languages': {'language': []},
#  'languageLevels': {'level': []},
#  'lastUpdatedSearchQueryText': '',
#  'loyaltySurvey': {'showNotification': False,
#   'removeFromUserNotifications': False,
#   'showBanner': False,
#   'runSurvey': False},
#  'locale': {'areaId': '113',
#   'domainAreaId': '58',
#   'host': 'voronezh.hh.ru',
#   'protocolHost': 'https://lipetsk.hh.ru',
#   'isSeoDomain': True,
#   'platform': 'HEADHUNTER',
#   'availableLanguages': ['RU', 'EN'],
#   'siteLanguage': 'RU'},
#  'logos': {'logoDomain': 'hh-ru', 'smallLogoDomain': 'hh.ru'},
#  'loginError': None,
#  'loginTileType': None,
#  'mainContentVisible': True,
#  'managerAnnouncementBanner': None,
#  'managersList': [],
#  'managersListLoaded': False,
#  'managerNegotiationStats': {},
#  'managerCluster': {},
#  'messengers': [{'country': '7',
#    'city': '916',
#    'number': '5514067',
#    'messengerType': 'WHATSAPP',
#    'accountName': None},
#   {'country': '7',
#    'city': '916',
#    'number': '5515747',
#    'messengerType': 'VIBER',
#    'accountName': 'hh_welcome'},
#   {'country': None,
#    'city': None,
#    'number': None,
#    'messengerType': 'TELEGRAM',
#    'accountName': 'reg_hh_bot'}],
#  'metaRole': None,
#  'metroCatalog': {'currentStation': '',
#   'cityMetro': '',
#   'currentLine': '',
#   'currentLineTranslation': ''},
#  'managerActiveCount': None,
#  'metroCities': [],
#  'microFrontends': {},
#  'mobileAppPromotionVisible': False,
#  'newEmployerDashboardVacancy': {'employerRegionResumesCount': 0,
#   'employerRegion': 0,
#   'giftsCount': 0},
#  'newTargetEmployerResumes': [],
#  'notifications': [],
#  'noMenu': False,
#  'numOfOpenVacancies': None,
#  'negotiationsHistory': [],
#  'novaSorts': {'orderBy': 'relevance',
#   'searchPeriod': '0',
#   'workType': {'value': 'fullTime', 'changed': False}},
#  'oldEmployerLastSearches': [],
#  'oldEmployerUpdates': [],
#  'orderedCalls': {'canRequestMore': False, 'calls': []},
#  'otp': {},
#  'overlayMenu': False,
#  'pageError': {},
#  'pageMetaData': {'header': '',
#   'title': '',
#   'keywords': '',
#   'description': '',
#   'rssHref': '',
#   'rssTitle': '',
#   'canonical': ''},
#  'permissions': [],
#  'personalManager': {'available': False,
#   'smallPhoto': '',
#   'yearsInCompany': None,
#   'firstName': '',
#   'lastName': '',
#   'phonesWithComments': []},
#  'personalManagerMenu': {'isAssigned': False},
#  'postponedActions': {},
#  'platform': 'XHH',
#  'previousEmployerTargets': [],
#  'priceCart': None,
#  'priceData': None,
#  'priceCartOptions': {'removable': True, 'activation': False},
#  'priceDBAccess': None,
#  'priceEmployerBrand': None,
#  'priceNewCartEnabled': False,
#  'pricePageMetaInfo': {'description': '', 'pageTitle': ''},
#  'priceRecommended': None,
#  'priceRegionalPublications': None,
#  'priceClickmeProducts': {},
#  'pricePublications': {},
#  'priceAddContacts': {'tabName': '',
#   'purchaseUrl': '',
#   'dbAccessUrl': '',
#   'activeAccesses': [],
#   'products': {}},
#  'priceResumeSelections': None,
#  'priceZp': None,
#  'printVersion': {},
#  'priceBranding': {'items': [],
#   'employerId': None,
#   'defaultPriceRegions': [],
#   'employerConstructorExpirationTime': None},
#  'probationCatalog': {'probationCatalog': []},
#  'partTimeTypes': None,
#  'profareasCatalog': {'catalog': [], 'popularCatalog': [], 'profareaName': ''},
#  'profareaTree': [],
#  'professionsList': None,
#  'professionalAreaList': {},
#  'professionalAreaListCounted': [],
#  'professionalRolesFromSearch': [],
# ...
#      'cond': 'Официальное оформление. График работы 5/2. ДМС и социальный пакет. Возможность профессионального роста и развития в рамках Компании.',
#      'skill': 'Python',
#      'desc': None},
#     'responsesCount': 11,
#     'online_users_count': 0},
#    {'@responseLetterRequired': False,
#     '@showContact': False,
#     'vacancyId': 67501000,
#     'name': 'Face recognition data scientist',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'AGENCY',
#      '@countryId': 1,
#      '@state': 'APPROVED',
#      'id': 3142130,
#      'name': 'Рекрутинговое Агентство ДЕЛО',
#      'visibleName': 'Рекрутинговое Агентство ДЕЛО',
#      'logos': {'logo': [{'@type': 'searchResultsPage',
#         '@url': '/employer-logo/2600285.jpeg'},
#        {'@type': 'small', '@url': '/employer-logo/2600285.jpeg'},
#        {'@type': 'vacancyPage', '@url': '/employer-logo/2600286.jpeg'},
#        {'@type': 'medium', '@url': '/employer-logo/2600286.jpeg'},
#        {'@type': 'ORIGINAL', '@url': '/employer-logo-original/539703.jpg'},
#        {'@type': 'employerPage', '@url': '/employer-logo/2600284.jpeg'}]},
#      'employerOrganizationFormId': 0,
#      'companySiteUrl': ''},
#     'compensation': {'from': 100000,
#      'to': 150000,
#      'currencyCode': 'RUR',
#      'gross': False},
#     'publicationTime': {'@timestamp': 1657076365,
#      '$': '2022-07-06T05:59:25.460+03:00'},
#     'type': 'open',
#     'area': {'@id': 11, 'name': 'Барнаул', 'path': '.113.222.1217.11.'},
#     'acceptTemporary': False,
#     'metallic': 'standard',
#     'creationSite': 'novosibirsk.hh.ru',
#     'creationSiteId': 14,
#     'displayHost': 'lipetsk.hh.ru',
#     'lastChangeTime': {'@timestamp': 1657076365,
#      '$': '2022-07-06T05:59:25.483+03:00'},
#     'creationTime': '2022-07-05T13:39:21.307+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 62476655,
#      '@managerId': 3908841,
#      '@userId': 40387601,
#      'latestActivity': None},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': True,
#     'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67501000',
#      'mobile': 'https://m.hh.ru/vacancy/67501000'},
#     'workSchedule': 'REMOTE',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 5910058,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_5910058'},
#     'vacancyProperties': {'properties': [{}]},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'contactInfo': None,
#     'userLabels': [],
#     'snippet': {'req': 'Образование и опыт работы: программирование и анализ данных в сфере распознавания лиц.',
#      'resp': 'Консультирование в области программирования нейросетей. Программирование нейросетей. создание проекта по подключению к нейросети около 10 камер для логирования.',
#      'cond': 'Условия договорные, будем исходить из компетенций успешных соискателей и взаимной заинтересованности. Проектная удаленная работа, поэтому индивидуальные договоренности по итогам собеседования.',
#      'skill': 'MS PowerPoint, Анализ данных, MS Access, Data Analysis',
#      'desc': None},
#     'responsesCount': 38,
#     'online_users_count': 0},
#    {'@responseLetterRequired': False,
#     '@showContact': True,
#     'vacancyId': 67546327,
#     'name': 'ML Engineer/Data Scientist (to Georgia)',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'COMPANY',
#      '@countryId': 1,
#      '@structureName': '208902',
#      '@state': 'APPROVED',
#      'id': 208902,
#      'name': 'Аркадия',
#      'visibleName': 'Аркадия',
#      'structureName': '208902',
#      'logos': {'logo': [{'@type': 'searchResultsPage',
#         '@url': '/employer-logo/1262601.png'},
#        {'@type': 'small', '@url': '/employer-logo/1262601.png'},
#        {'@type': 'vacancyPage', '@url': '/employer-logo/1262602.png'},
#        {'@type': 'medium', '@url': '/employer-logo/1262602.png'},
#        {'@type': 'ORIGINAL', '@url': '/employer-logo-original/120053.png'},
#        {'@type': 'employerPage', '@url': '/employer-logo/1262600.png'}]},
#      'employerOrganizationFormId': 15,
#      'mainEmployerId': 208902,
#      'companySiteUrl': 'https://softwarecountry.com'},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1657112757,
#      '$': '2022-07-06T16:05:57.975+03:00'},
#     'type': 'open',
#     'area': {'@id': 2, 'name': 'Санкт-Петербург', 'path': '.113.231.2.'},
#     'acceptTemporary': False,
#     'contactInfo': None,
#     'metallic': 'standard',
#     'code': 'JNJ',
#     'creationSite': 'spb.hh.ru',
#     'creationSiteId': 7,
#     'displayHost': 'lipetsk.hh.ru',
#     'lastChangeTime': {'@timestamp': 1657126364,
#      '$': '2022-07-06T19:52:44.465+03:00'},
#     'creationTime': '2022-07-06T16:05:57.975+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 95379648,
#      '@managerId': 6146446,
#      '@userId': 73235790,
#      'latestActivity': None},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': True,
#     'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67546327',
#      'mobile': 'https://m.hh.ru/vacancy/67546327'},
#     'workSchedule': 'FULL_DAY',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{'language': [{'id': 57, 'degree': 'b2'}]}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 5994564,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_5994564'},
#     'vacancyProperties': {'properties': [{}]},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'userLabels': [],
#     'snippet': {'req': 'Python and its data stack (pandas, numpy, scikit-learn, etc.). PyTorch. Jupyter Notebooks. Experience with NLP: text representation, NLP tasks...',
#      'resp': 'Maintain and extend data preprocessing pipelines. Maintain and extend feature extraction pipelines. Work with stakeholders to clarify requirements and identify...',
#      'cond': None,
#      'skill': 'Python, Git, Linux, Английский язык',
#      'desc': None},
#     'responsesCount': 6,
#     'online_users_count': 0},
#    {'@responseLetterRequired': False,
#     '@showContact': False,
#     'vacancyId': 67079125,
#     'name': 'Middle Data Scientist',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'COMPANY',
#      '@countryId': 1,
#      '@state': 'APPROVED',
#      'id': 3060884,
#      'name': 'Ridex GmbH',
#      'visibleName': 'Ridex GmbH',
#      'logos': {'logo': [{'@type': 'ORIGINAL',
#         '@url': '/employer-logo-original/767611.png'},
#        {'@type': 'employerPage', '@url': '/employer-logo/3511400.png'},
#        {'@type': 'searchResultsPage', '@url': '/employer-logo/3511401.png'},
#        {'@type': 'small', '@url': '/employer-logo/3511401.png'},
#        {'@type': 'vacancyPage', '@url': '/employer-logo/3511402.png'},
#        {'@type': 'medium', '@url': '/employer-logo/3511402.png'}]},
#      'companySiteUrl': 'http://ridex.eu'},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1657028742,
#      '$': '2022-07-05T16:45:42.984+03:00'},
#     'type': 'open',
#     'area': {'@id': 4, 'name': 'Новосибирск', 'path': '.113.222.1202.4.'},
#     'acceptTemporary': False,
#     'address': {'@id': 4272926,
#      '@disabled': False,
#      'metroStations': {'@lat': 55.029941,
#       '@lng': 82.92069,
#       'metro': [{'@isAlias': False,
#         '@cityId': 4,
#         '@id': 297,
#         '@name': 'metro.297',
#         '@order': 3,
#         '@translit': 'ploschad_lenina',
#         'id': 297,
#         'lat': 55.029941,
#         'line': {'@id': 52,
#          '@name': 'metroline.52',
#          '@translit': 'leninskaya',
#          '@cityId': 4,
#          'id': 52,
#          'name': 'Ленинская',
#          'color': '#CD0505'},
#         'lng': 82.92069,
#         'name': 'Площадь Ленина'}]},
#      'city': 'Новосибирск',
#      'street': 'Красный проспект',
#      'building': '17',
#      'displayName': 'Новосибирск, Красный проспект, 17',
#      'mapData': '{"points":{"center":{"lat":55.028266535115414,"lng":82.9207169999999,"zoom":16},"marker":{"lat":55.026592,"lng":82.920744}}}',
#      'marker': {'@lat': 55.026592, '@lng': 82.920744},
#      'manager': {'@id': 4822663}},
#     'metallic': 'standard',
#     'creationSite': 'hh.ru',
#     'creationSiteId': 1,
#     'displayHost': 'lipetsk.hh.ru',
#     'lastChangeTime': {'@timestamp': 1657102155,
#      '$': '2022-07-06T13:09:15.389+03:00'},
#     'creationTime': '2022-06-22T12:17:16.631+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 103807574,
#      '@managerId': 6975220,
#      '@userId': 81638613,
#      'latestActivity': None},
#     'inboxPossibility': False,
#     'chatWritePossibility': 'DISABLED',
#     'notify': False,
#     'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67079125',
#      'mobile': 'https://m.hh.ru/vacancy/67079125'},
#     'workSchedule': 'FULL_DAY',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 5268564,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_5268564'},
#     'vacancyProperties': {'properties': [{}]},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'contactInfo': None,
#     'userLabels': [],
#     'snippet': {'req': 'Думать о конечной бизнес-задаче, мыслить логически, уделять внимание деталям. Пройденные курсы по Data Science/ML. Знание Spark. ',
#      'resp': 'Прогнозирование спроса и планирование доставки. Разработка и улучшение динамического ценообразование. Кластеризация ассортимента. Дизайн экспериментов и запуск A/B тестов. ',
#      'cond': 'Позитивная и дружелюбная команда. Приятная рабочая атмосфера, общение на "ты". Заработная плата обсуждается индивидуально в зависимости от Вашего опыта и...',
#      'skill': 'Python, SQL, Git, PostgreSQL, Linux',
#      'desc': None},
#     'responsesCount': 5,
#     'online_users_count': 0}],
#   'vacanciesCounts': 100,
#   'hasVacanciesWithAddress': True,
#   'isClustersEnabled': True,
#   'clustersCount': 0,
#   'paging': {'previous': {'page': -1, 'disabled': True},
#    'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#     {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True},
#     {'text': '3', 'page': 2, 'selected': False, 'inShortRange': True},
#     {'text': '4', 'page': 3, 'selected': False, 'inShortRange': False},
#     {'text': '5', 'page': 4, 'selected': False, 'inShortRange': False},
#     {'text': '...', 'page': 5, 'selected': False, 'inShortRange': False}],
#    'lastPage': {'page': 10, 'selected': False},
#    'next': {'page': 1, 'disabled': False},
#    'os': 'Win'},
#   'queries': {'effective': 'clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'currentAndInternalParams': 'clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'enableSnippets': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'disableSnippets': 'clusters=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'legacy': 'clusters=true&itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=data+scien%2A',
#    'currentParams': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'rss': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'map': 'clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'dynamicMap': 'clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'legacyRss': 'clusters=true&itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=data+scien%2A',
#    'autosearch': 'enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'legacyAutosearch': 'itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=data+scien%2A',
#    'pagingBase': 'L_is_autosearch=false&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'orderByBase': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'searchPeriodBase': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'itemsOnPageBase': 'clusters=true&enable_snippets=true&ored_clusters=true&search_field=name&search_field=description&text=data+scien%2A',
#    'searchWizardBase': 'L_is_autosearch=false&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true'},
#   'queryRanks': [],
#   'totalResults': 1030,
#   'enableNovaFilters': True,
#   'enableSimilarSavedSearch': False,
#   'fixes': {},
#   'suggests': {},
#   'catalogLinks': []},
#  'vacancyStat': None,
#  'vacancyTests': {},
#  'vacancyView': {'company': {}, 'features': []},
#  'vacancyWizard': {'totalEmployersFound': 0,
#   'employerHits': [],
#   'rootAreaId': 0},
#  'vacancyTemplates': [],
#  'vacancyTemplateForEdit': None,
#  'vacancyClickmeLanding': None,
#  'vacancyViewsCount': None,
#  'vacancyConstructor': {'vacancyBrandedTemplates': [], 'expirationTime': None},
#  'vacancyConstructorBackOfficeView': None,
#  'vacancyConstructorTemplateMode': None,
#  'vacancyConstructorMobilePreview': {'templateId': None},
#  'vacancyConstructorSettings': None,
#  'vacation': None,
#  'vacancyResponsePopup': {},
#  'vacancyMessages': [],
#  'vacancyFeedback': None,
#  'vrSignupLogin': {},
#  'vrVacancies': None,
#  'wantWorkEmployer': {'employerInfo': {'id': None, 'name': ''},
#   'employerLogo': {'logoUrl': None}},
#  'wheelOfFortuneDataUrl': None,
#  'workInOtherCity': None,
#  'xsrfToken': '26da5bc147ce935f1497e6937497f5df',
#  'employerDivisionChangelog': {'changes': []},
#  'serviceAdditional': {'serviceNames': {}},
#  'supernovaAnonymousDashboard': {'backgroundScope': '',
#   'backgroundIndex': '',
#   'bigPromoEmployerId': '',
#   'bigPromoSlogan': '',
#   'bigPromoLinkText': '',
#   'bigPromoLinkUrl': '',
#   'bigPromoFootnote': None},
#  'pinnedChatMessages': {'hasMore': False, 'items': []},
#  'preparedVacancyTemplates': [],
#  'snippetAccessResume': {'productList': [],
#   'area': '',
#   'isShowSnippetResume': False},
#  'zpEmployerOnboarding': {'showOnboardingModal': False},
#  'zpCrossPostInfo': None,
#  'accountHistoryActionsData': None,
#  'accountHistoryMoney': {'hasPersonalManager': False,
#   'state': '',
#   'email': '',
#   'agreements': {},
#   'currency': '',
#   'hrs': {'orders': []},
#   'balances': {},
#   'employerCountry': '',
#   'availableWithoutBlockedMoney': 0},
#  'scheduleInterviewRemindInfo': None,
#  'router': {'location': {'pathname': '/search/vacancy',
#    'search': '?text=data+scien*&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#    'hash': '',
#    'key': '964d1v',
#    'query': {'text': 'data+scien*',
#     'search_field': 'description',
#     'salary': '',
#     'currency_code': 'RUR',
#     'experience': 'doesNotMatter',
#     'order_by': 'relevance',
#     'search_period': '0',
#     'items_on_page': '100'}},
#   'action': 'POP'}}

# %%
# Total number of search results
print(json_parsed['searchCounts'])
# or
print(json_parsed['vacancySearchResult']['totalResults'])
# ?
# Out:
# {'isLoad': False, 'value': 1030}
# 1030

# %%
json_parsed['searchClustersBasic'].keys()
# Out:
# dict_keys(['label', 'industry', 'experience', 'schedule', 'professionalArea', 'professional_role', 'area', 'employment', 'compensation', 'part_time', 'search_field', 'excluded_text'])

# %% [markdown]
# [EN] In case total search results number exceeds 2000 (seems to be hardcoded limitation) it is possible to use 'searchClustersBasic'->'area' to implement partial searches
# [RU] Если итоговое количество записей превысит 2000 (а это, похоже, "жестко" прописанное ограничение), можно пропарсить ключ 'searchClustersBasic'->'area', чтобы организовать частичные выборки и затем объединить результаты

# %%
json_parsed['searchClustersBasic']['area']['groups'].keys()
# Out:
# dict_keys(['1', '2', '7', '9', '13', '16', '21', '27', '28', '37', '40', '48', '74', '85', '94', '97', '113', '146', '150', '152', '153', '159', '160', '172', '177', '180', '181', '188', '194', '199', '200', '205', '208', '236', '1001', '1002', '1146', '1202', '1217', '1255', '1261', '1317', '1384', '1438', '1511', '1530', '1586', '1596', '1624', '1646', '1652', '1661', '1679', '1704', '1716', '1844', '1880', '1898', '1913', '1948', '2237', '2492', '2758', '2759', '2760', '2814', '5046'])

# %%
json_parsed['searchClustersBasic']['area']['groups']['1']
# Out:
# {'count': 527, 'seoDomain': 'hh.ru', 'order': 2, 'title': 'Москва', 'id': '1'}

# %% [markdown]
# 'count' - vacancies found in area, 'id' - area id (we can add records to _areas_ dictionary using 'id' and 'title' keys to make it possible to search in more regions)

# %% [markdown]
# [EN] We've got a huge amount of 'empty' data structures after transforming. There are empty dictionaries and dictionaries which contain 'empty' data structures. So I'll clean these artifacts out to make the search of data more efficient.<br>
# [RU] В полученном ответе много "пустых" данных - пустые словари, а также словари, содержащие "пустые" структуры. Очистим результат от этих артефактов, чтобы было легче искать значимую информацию

# %%
# Function to check if dictionary is 'empty' / Функция, проверяющая словарь на "пустоту"
def is_dict_empty(input_dict):
    result = True
    for key in input_dict.keys():
        if (type(input_dict[key]) is type(dict())) and (len(input_dict[key]) > 0):
            # Рекуррентная проверка словарей
            result = result and is_dict_empty(input_dict[key])
        else:
            # "Пустыми" считать структуры, длина которых равна 0, имеющие значение None или являющиеся пустым словарем или списком
            checks_empty = (input_dict[key] is None) or (str(input_dict[key]) in ['{}', '[]']) or (len(str(input_dict[key])) == 0)
            result = result and checks_empty
        if not result:
            break
    return result

# %%
clean_dict = {}
for key in json_parsed.keys():
    if (type(json_parsed[key]) is type(dict())):
        if not is_dict_empty(json_parsed[key]):
            clean_dict[key] = json_parsed[key]
    else:
        checks_empty = (json_parsed[key] is None) or (str(json_parsed[key]) in ['{}', '[]']) or (len(str(json_parsed[key])) == 0)
        if not checks_empty:
            clean_dict[key] = json_parsed[key]
print('{} non-empty keys in result'.format(len(clean_dict)))
print('====================================================')
for key in clean_dict.keys():
    print('{} ====> {}'.format(key, clean_dict[key]))
# Out:
# 181 non-empty keys in result
# ====================================================
# applicantSignup ====> {'fields': [], 'hideLogin': False}
# applicantPackageType ====> basic
# applicantPaymentSource ====> desktop
# accountHistoryReplenishments ====> {'bills': [], 'documentLinksVisibility': False, 'currency': 'RUR'}
# accountDelete ====> {'applicantName': '', 'resumesList': {'resumes': {'published': [], 'unpublished': []}, 'count': 0}}
# adsSearchParams ====> {'puid11': 'searchVacancy', 'puid23': '', 'puid14': 'data scien*', 'puid29': '', 'puid30': '', 'puid12': '', 'puid13': ''}
# advancedSearch ====> {'showSearchConditions': False, 'hideSuggest': False, 'vacancy': None, 'resume': None, 'experience': [], 'keySkills': [], 'university': [], 'citizenship': [], 'work_ticket': [], 'employment': [], 'schedule': [], 'driver_license_types': [], 'job_search_status': [], 'language': [], 'exclusion': []}
# appleBusinessChat ====> {'isEnabled': False, 'href': ''}
# abortPageContent ====> False
# addressesSuggestRemoteMode ====> False
# analyticsParams ====> {'hhtmSource': 'vacancy_search_list', 'hhtmFrom': '', 'hhtmSourceLabel': '', 'hhtmFromLabel': '', 'screenType': 'SIMPLE'}
# applicantInfo ====> {'total': 0, 'finished': 0, 'visible': 0, 'searchable': 0}
# applicantNegotiations ====> {'topicList': [], 'filterInUse': 'all'}
# authUrl ====> {'login-url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'login-form': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'login-field-value': '', 'backurl-field-name': 'backUrl', 'remember-field-name': 'remember', 'remember-field-value': 'yes', 'backurl': 'https://lipetsk.hh.ru/search/vacancy?text=data+scien%2A&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'failurl': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'signup-form': '/account/signup?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'auth-employer-url': '/auth/employer/?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'remember-password': '/account/remember_password?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'agreement-form': '/account/agreement?backurl=%2Faccount%2Fsignup%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100', 'employer-agreement': '/auth/employer/agreement?backurl=%2Fauth%2Femployer%2F%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253Ddata%252Bscien%25252A%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100'}
# emailVerification ====> {'email': '', 'needVerification': False, 'mailURL': ''}
# loginForm ====> {'passwordRecovery': {'trl': 'Получить пароль'}, 'registration': [{'trl': 'Соискателя', 'code': 'REG_APPLICANT', 'translationKey': 'account.login.registration.applicant.capitalized'}, {'trl': 'Работодателя', 'code': 'REG_EMPLOYER', 'translationKey': 'account.login.registration.employer.capitalized'}], 'socialNetworks': [{'trl': 'Мой Мир@mail.ru', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list', 'code': 'MAIL', 'translationKey': 'socialNetworkTitle.mail'}, {'trl': 'Одноклассники', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list', 'code': 'OK', 'translationKey': 'socialNetworkTitle.ok'}, {'trl': 'ВКонтакте', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list', 'code': 'VK', 'translationKey': 'socialNetworkTitle.vk'}, {'trl': 'Google', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list', 'code': 'GPLUS', 'translationKey': 'socialNetworkTitle.gplus'}, {'trl': 'Доктор на работе', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=26da5bc147ce935f1497e6937497f5df&hhtmSource=vacancy_search_list', 'code': 'DNR', 'translationKey': 'socialNetworkTitle.dnr'}]}
# backofficeCanEditTemplate ====> True
# banners ====> {'under-pagination-search-results-l': [{'id': '293', 'cId': 'e8c99b6f-dbc1-4549-a28c-157953ce98a7', 'pp': 'g', 'p2': 'houd'}], 'under-pagination-search-results-m': [{'id': '294', 'cId': 'be8f9cc1-b220-4f42-9cb2-7a55ada30c59', 'pp': 'g', 'p2': 'hoxr'}], 'under-pagination-search-results-s': [{'id': '292', 'cId': '000c8edb-8f6f-4687-9c32-5fb2ffa5db85', 'pp': 'g', 'p2': 'hoxs'}], 'under-pagination-search-results-xs': [{'id': '521', 'cId': '416bcd7d-4c4f-45b4-81ad-8b75a92f12a1', 'pp': 'g', 'p2': 'hoyc'}], 'under-search-results-rotate': [{'id': '654', 'cId': '31ea43f6-a1ee-4c18-87cb-edaf862656d0'}, {'id': '655', 'cId': '13067e37-686b-4634-a9b3-80141043be51'}], 'serp-first-l': [{'id': '221', 'cId': '0b4d8b85-b2f8-46c2-81d0-c8bf5391954a', 'pp': 'g', 'p2': 'houd'}], 'serp-first-m': [{'id': '637', 'cId': '76e5b995-e364-4a44-9fe0-1be3b6a04dc9', 'pp': 'g', 'p2': 'hoxr'}], 'serp-first-s': [{'id': '613', 'cId': '25629b6b-f449-4919-95ba-ebc2f6eb0bca', 'pp': 'g', 'p2': 'hoxs'}], 'serp-first-xs': [{'id': '630', 'cId': 'aae29aad-b2bd-49d3-b1be-9c1502270e97', 'pp': 'g', 'p2': 'hoyc'}], 'serp-second-l': [{'id': '175', 'cId': 'ce6a6af6-6972-49fb-b9f4-6aefc352bf4e', 'pp': 'g', 'p2': 'houd'}], 'serp-second-m': [{'id': '347', 'cId': 'c7528f59-5e8c-426f-ae58-30ef64daca0e', 'pp': 'g', 'p2': 'hoxr'}], 'serp-second-s': [{'id': '638', 'cId': '53b272bf-9762-4ea0-bdee-1ed162dc2282', 'pp': 'g', 'p2': 'hoxs'}], 'serp-second-xs': [{'id': '505', 'cId': '6bfa1bf0-1a23-4d52-9a5d-e025044f9063', 'pp': 'g', 'p2': 'hoyc'}], 'under-search-results-xs': [{'id': '661', 'cId': '14420844-6603-499e-befd-60e87d19850e'}, {'id': '662', 'cId': 'f66a26dd-6abc-4864-843a-5b35b247b0f6'}, {'id': '663', 'cId': 'ee857b49-9254-45f4-9524-4a044449377a'}], 'serp-third-l': [{'id': '72', 'cId': 'be00fc26-378f-46cf-9bbc-2f186e37e4bf', 'pp': 'g', 'p2': 'houd'}], 'serp-third-m': [{'id': '261', 'cId': '9891e62f-7807-445a-a427-331bcd2e7eb4', 'pp': 'g', 'p2': 'hoxr'}], 'serp-third-s': [{'id': '261', 'cId': '31bd129a-360c-4331-9c8e-6e1f0c62b8b6', 'pp': 'g', 'p2': 'hoxs'}], 'serp-third-xs': [{'id': '60', 'cId': '25e55970-4da6-494f-8783-b96b82b9328b', 'pp': 'g', 'p2': 'hoyc'}], 'serp-fourth-l': [{'id': '69', 'cId': '76a71501-4276-4e67-8f9d-3528b5a5df80', 'pp': 'g', 'p2': 'houd'}], 'serp-fourth-m': [{'id': '91', 'cId': '7a93e795-79b4-4de2-9ede-452127d7397e', 'pp': 'g', 'p2': 'hoxr'}], 'serp-fourth-s': [{'id': '91', 'cId': '36a2de74-345a-4753-ab0b-e2438c1b9d44', 'pp': 'g', 'p2': 'hoxs'}], 'serp-fourth-xs': [{'id': '59', 'cId': '49d61f19-7570-42d5-a4fb-3760c46fcd23', 'pp': 'g', 'p2': 'hoyc'}], 'serp-fifth-l': [{'id': '158', 'cId': 'e4573ee5-7f84-43a9-aa5e-8071226cd178', 'pp': 'g', 'p2': 'houd'}], 'serp-fifth-m': [{'id': '87', 'cId': '3e35b3bc-6e3d-48b6-a8d1-3cefb9d73091', 'pp': 'g', 'p2': 'hoxr'}], 'serp-fifth-s': [{'id': '87', 'cId': '64a47f91-f699-459a-89e3-7b9697e808a0', 'pp': 'g', 'p2': 'hoxs'}], 'serp-fifth-xs': [{'id': '19', 'cId': '0f87e290-b42a-4a41-9e4b-fc31faf57cc8', 'pp': 'g', 'p2': 'hoyc'}]}
# cancelFetchBanners ====> False
# candidates ====> {'collection': {'actions': [], 'filters': []}, 'onlyAssessments': False}
# chatBot ====> {'messengers': [{'type': 'vk', 'icon': 'vk', 'href': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'}, {'type': 'telegram', 'icon': 'telegram', 'href': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'}, {'type': 'viber', 'icon': 'viber-mini', 'href': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3Ddata%2Bscien%252A'}], 'page': 'vacancysearch', 'genericUserType': 'anonymous', 'source': 'hhru'}
# chatikIntegration ====> False
# chatikUnreadCount ====> 0
# checkedEmployerFAQLink ====> https://feedback.hh.ru/article/details/id/5951
# config ====> {'staticHost': 'https://i.hh.ru', 'hhcdnHost': 'https://hhcdn.ru', 'imageResizingCdnHost': 'https://img.hhcdn.ru'}
# contactPhones ====> [{'country': '+7', 'city': '495', 'number': '974-64-27', 'postfix': 'msk'}, {'country': '+7', 'city': '812', 'number': '458-45-45', 'postfix': 'spb'}, {'country': '8', 'city': '800', 'number': '100-64-27', 'postfix': 'regions'}]
# currencies ====> {'default': 'RUR', 'list': [{'code': 'RUR', 'name': 'руб.', 'gender': 'MASCULINE', 'rate': 1, 'defaultCurrency': True, 'site': True}, {'code': 'USD', 'name': 'USD', 'gender': 'MASCULINE', 'rate': 0.018739, 'defaultCurrency': False, 'site': True}, {'code': 'EUR', 'name': 'EUR', 'gender': 'MASCULINE', 'rate': 0.01784, 'defaultCurrency': False, 'site': True}]}
# criteriaCurrencyCode ====> RUR
# countryId ====> 1
# defaultCountryCompanySearchId ====> 113
# detectedVacancySearchAreaIds ====> ['58']
# discriminationWarning ====> False
# displayType ====> DESKTOP
# domainAreaId ====> 58
# employerAddressesPage ====> {'addresses': [], 'addressesCount': 0, 'isFetching': False, 'loadingComponent': ''}
# employerConstructorWebViewMode ====> False
# employerConstructor ====> {'editMode': False, 'previewModeWithBranding': True, 'version': None, 'canEdit': False, 'modalError': None, 'widgets': [], 'widgetsOrder': [], 'saveStatus': 'DIRTY', 'hasUnsavedChanges': False, 'pictureId': None, 'resizeStatus': 'DIRTY', 'images': [], 'tabPrices': [], 'hasConstructor': False, 'hasService': False, 'readyToActivateCartId': None, 'sidebarColors': {}}
# employerPageIsViewMode ====> False
# employerHasDivisions ====> False
# employerLogo ====> {'logoUrl': None, 'logoStatus': 'Dirty'}
# employerInfo ====> {'id': None, 'name': None, 'category': None, 'address': None, 'site': None, 'industries': None, 'hrBrand': None, 'description': None, 'saveDescriptionStatus': 'DIRTY', 'organizationFormId': None, 'isTrusted': False, 'canEditDescription': False, 'hasUnsavedChanges': False}
# employerReviewsModal ====> {'visible': False, 'reviewsEnabled': False}
# employerManagersPage ====> {'managersViewMeta': {'ableToCreateManager': False, 'canEditEmployerManagerQuotas': False, 'managersCreationLimitReached': True, 'onlyOneManagerEnabled': False, 'MCPSGroup': False, 'resumeViewsAccessDenied': True, 'ResumeViewHistory': False, 'showResumeViewsNumbers': False, 'giveMCPAllowed': False, 'userEmail': ''}, 'managersShown': [], 'negotiationStats': {'politeness-index': {}, 'responses-read-percent': {}, 'responses-read-percent-change': {}, 'responses-received': {}, 'responses-replied-percent': {}, 'responses-replied-percent-change': {}, 'responses-reply-time-days': {}}, 'resumeViews': {}, 'filter': '', 'loading': False}
# employersList ====> {'totalEmployersFound': 0, 'employers': [], 'paging': None}
# employersListOnReactEnabled ====> False
# employerReviewsApplicantProfileBadge ====> False
# employerReviewsApplicantShowIndexWidget ====> False
# employerSettingsMenu ====> {'employerManagersLink': '/employer/managers', 'menuItems': [], 'employerManagerName': ''}
# employerStatus ====> {'category': '', 'state': '', 'countryId': '', 'suspiciousState': 'NOT_SUSPICIOUS'}
# enableSimilarSavedSearch ====> False
# enableJobSearchStatus ====> False
# experiments ====> {'enabled': {'tempexp_15905_linking_vacancies': 'experiment', 'vacancy_partial_redesign_b': 'experiment', 'yenisei_bert_tdi': 'experiment', 'tempexp_16177_v2': 'experiment', 'tempexp_14535_b': 'experiment'}, 'checked': []}
# features ====> {'new_vacancy_suggest': True, 'delayed_cart_activation_article_id': '30085', 'max_vacancies_rendered_on_server': 20}
# floodlightGtagEnabled ====> False
# fetchingData ====> False
# footer ====> [{'name': 'footerNav', 'translations': {'name': '[RU:15:supernova.navi.footerNav]'}, 'subItems': [{'name': 'site', 'translations': {'name': 'HeadHunter'}, 'subItems': [{'name': 'copyright', 'translations': {'name': 'О компании'}, 'url': '/article/28?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'hhCompanyInfo', 'translations': {'name': 'Наши вакансии'}, 'url': '/employer/1455?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'advertisingDescription', 'translations': {'name': 'Реклама на сайте'}, 'url': 'https://ads.hh.ru/?from=footer_new&hhtmFromLabel=footer_new', 'external': True}, {'name': 'hardwareRequirements', 'translations': {'name': 'Требования к ПО'}, 'url': '/article/176?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'dataProtection', 'translations': {'name': 'Защита персональных данных'}, 'url': '/article/personal_data?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'safety', 'translations': {'name': 'Безопасный HeadHunter'}, 'url': '/safety?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'compliance', 'translations': {'name': 'Этика и\xa0комплаенс'}, 'url': '/article/compliance?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'api', 'translations': {'name': 'HeadHunter API'}, 'url': 'https://dev.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}, {'name': 'partners', 'translations': {'name': 'Партнерам'}, 'url': '/partners?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'investor', 'translations': {'name': 'Инвесторам'}, 'url': 'https://investor.hh.ru', 'external': True}, {'name': 'conditions', 'translations': {'name': 'Условия оказания услуг'}, 'url': '/conditions?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'terms', 'translations': {'name': 'Условия использования сайтов'}, 'url': '/terms?from=footer_new&hhtmFromLabel=footer_new'}]}, {'name': 'articles', 'translations': {'name': 'Новости и статьи'}, 'url': '/articles', 'subItems': [{'name': 'hrNews', 'translations': {'name': 'Новости рынка HR'}, 'url': '/articles/market-news/hr-news?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'articlesInsider', 'translations': {'name': 'Жизнь в компании'}, 'url': '/articles/insider?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'itproject', 'translations': {'name': 'ИТ-проекты'}, 'url': '/articles/applicants/it-projects?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'employersRating', 'translations': {'name': 'Рейтинг работодателей России'}, 'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}]}, {'name': 'applicantServices', 'translations': {'name': 'Сервисы для соискателей'}, 'subItems': [{'name': 'expertresume', 'translations': {'name': 'Готовое резюме'}, 'url': '/article/expert_resume?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'advancementServices', 'translations': {'name': 'Все сервисы'}, 'url': '/applicant-services/services/all?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'proforientation', 'translations': {'name': 'Профориентация'}, 'url': '/article/proforientation_promo?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'ka', 'translations': {'name': 'Форум карьеристов'}, 'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}, {'name': 'findjob', 'translations': {'name': 'Продвижение резюме'}, 'url': '/applicant/services/findjob?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'wantwork', 'translations': {'name': 'Хочу у вас работать'}, 'url': '/article/98?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'calendar', 'translations': {'name': 'Производственный календарь'}, 'url': '/calendar?from=footer_new&hhtmFromLabel=footer_new'}]}, {'name': 'forTeens', 'translations': {'name': 'Молодым специалистам'}, 'subItems': [{'name': 'career', 'translations': {'name': 'Карьера для молодых специалистов'}, 'url': '/students?from=footer_new&hhtmFromLa ...
# forbidden ====> False
# globalInvitations ====> 3103214
# getPageHtmlEnabled ====> False
# globalStatistics ====> {'vacancies': 881382, 'employers': 1803338, 'resumes': 59932749}
# hasBrandedTemplates ====> False
# hasEditSidebarButton ====> False
# hasForceReloadDreamJob ====> False
# hasListOfVacanciesByRoles ====> False
# hasVacancyResponsesSummaryService ====> False
# hasVideoInterview ====> False
# hasChameleon ====> False
# headerMenu ====> [{'name': 'menuLvl1', 'translations': {'name': '[RU:15:supernova.navi.menuLvl1]'}, 'subItems': [{'name': 'mainContent', 'translations': {'name': '[RU:15:supernova.navi.mainContent]'}, 'subItems': [{'name': 'switchers', 'translations': {'name': '[RU:15:supernova.navi.switchers]'}, 'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Липецк'}}, {'name': 'applicant', 'translations': {'name': 'Соискателям'}, 'url': '/set_user_type?user_type=applicant&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'active': True}, {'name': 'employer', 'translations': {'name': 'Работодателям'}, 'url': '/set_user_type?user_type=employer&backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%2A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'trackClicks': True}]}, {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}}, {'name': 'expertresume', 'translations': {'name': 'Готовое резюме'}, 'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}, {'name': 'interviewpractice', 'translations': {'name': 'Репетиция собеседования'}, 'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]}, {'name': 'applicantServices', 'translations': {'name': 'Все сервисы'}}]}, {'name': 'menuLvl2', 'translations': {'name': '[RU:15:supernova.navi.menuLvl2]'}, 'subItems': [{'name': 'logo', 'translations': {'name': '[RU:15:supernova.navi.logo]'}}, {'name': 'help', 'translations': {'name': 'Помощь'}, 'dropdown': True, 'subItems': [{'name': 'mainContent', 'translations': {'name': '[RU:15:supernova.navi.mainContent]'}, 'subItems': [{'name': 'vishnu', 'translations': {'name': 'Виртуальный консультант'}}, {'name': 'applicantHelp', 'translations': {'name': 'Вопросы и ответы'}, 'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new', 'external': True}, {'name': 'copiny', 'translations': {'name': 'Сообщество поддержки'}, 'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new', 'external': True}, {'name': 'writeToUs', 'translations': {'name': 'Пишите нам'}, 'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header', 'external': True}]}, {'name': 'supportChat', 'translations': {'name': 'Техподдержка онлайн'}}]}, {'name': 'userTypeSwitcher', 'translations': {'name': '[RU:15:supernova.navi.userTypeSwitcher]'}, 'trackClicks': True, 'dropdown': True, 'subItems': [{'name': 'userTypeSwitcherApplicant', 'translations': {'name': 'Ищу работу'}, 'url': '/set_user_type?user_type=applicant&backurl=%2F', 'trackClicks': True, 'active': True}, {'name': 'userTypeSwitcherEmployer', 'translations': {'name': 'Ищу сотрудника'}, 'url': '/employer', 'trackClicks': True}]}, {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}}, {'name': 'searchVacancy', 'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'}, 'url': '/search/vacancy/advanced'}, {'name': 'signup', 'translations': {'name': 'Создать резюме'}, 'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}, {'name': 'login', 'translations': {'name': 'Войти'}, 'url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3Ddata%2Bscien%252A%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100'}, {'name': 'mobile', 'translations': {'name': '[RU:15:supernova.navi.mobile]'}, 'url': '/mobile', 'dropdown': True, 'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Липецк'}}, {'name': 'mainCo ...
# hideFooterServices ====> False
# isLightPage ====> False
# isMapVacancySearch ====> False
# isNewEmployer ====> False
# isNewVacancy ====> False
# isWebView ====> False
# isIFrame ====> False
# isProfessionalRolesModeInResume ====> False
# langs ====> ['RU']
# loyaltySurvey ====> {'showNotification': False, 'removeFromUserNotifications': False, 'showBanner': False, 'runSurvey': False}
# locale ====> {'areaId': '113', 'domainAreaId': '58', 'host': 'voronezh.hh.ru', 'protocolHost': 'https://lipetsk.hh.ru', 'isSeoDomain': True, 'platform': 'HEADHUNTER', 'availableLanguages': ['RU', 'EN'], 'siteLanguage': 'RU'}
# logos ====> {'logoDomain': 'hh-ru', 'smallLogoDomain': 'hh.ru'}
# mainContentVisible ====> True
# managersListLoaded ====> False
# messengers ====> [{'country': '7', 'city': '916', 'number': '5514067', 'messengerType': 'WHATSAPP', 'accountName': None}, {'country': '7', 'city': '916', 'number': '5515747', 'messengerType': 'VIBER', 'accountName': 'hh_welcome'}, {'country': None, 'city': None, 'number': None, 'messengerType': 'TELEGRAM', 'accountName': 'reg_hh_bot'}]
# mobileAppPromotionVisible ====> False
# newEmployerDashboardVacancy ====> {'employerRegionResumesCount': 0, 'employerRegion': 0, 'giftsCount': 0}
# noMenu ====> False
# novaSorts ====> {'orderBy': 'relevance', 'searchPeriod': '0', 'workType': {'value': 'fullTime', 'changed': False}}
# orderedCalls ====> {'canRequestMore': False, 'calls': []}
# overlayMenu ====> False
# personalManager ====> {'available': False, 'smallPhoto': '', 'yearsInCompany': None, 'firstName': '', 'lastName': '', 'phonesWithComments': []}
# personalManagerMenu ====> {'isAssigned': False}
# platform ====> XHH
# priceCartOptions ====> {'removable': True, 'activation': False}
# priceNewCartEnabled ====> False
# professionalRolesSerpEnable ====> True
# readOnlyBanner ====> {'days': 0, 'isReadOnly': False}
# resolutionRenderRestriction ====> All
# request ====> {'protocol': 'https', 'host': 'lipetsk.hh.ru', 'origin': 'https://lipetsk.hh.ru', 'url': '/search/vacancy?text=data+scien*&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'id': '16572877146629c5016e7f5700ea1b21', 'luxPageName': 'VacancySearch'}
# recaptcha ====> {'isBot': False, 'siteKey': None}
# regionClarification ====> {'host': 'lipetsk.hh.ru', 'translations': {'area': 'Липецк'}}
# resumeViewHistory ====> {'showResumeFallbackWarning': False}
# resumeVisibilityEmployerBlacklist ====> {'items': [], 'total': 0, 'page': 0, 'perPage': 10, 'isFetching': False, 'canAdd': 0, 'limit': 0, 'pager': None}
# resumeVisibilityEmployerWhitelist ====> {'items': [], 'total': 0, 'page': 0, 'perPage': 10, 'isFetching': False, 'canAdd': 0, 'limit': 0, 'pager': None}
# resumeVisibilityEmployerSearchResultsBlacklist ====> {'items': [], 'total': 0, 'isFetching': False}
# resumeVisibilityEmployerSearchResultsWhitelist ====> {'items': [], 'total': 0, 'isFetching': False}
# resumeFormFields ====> {'title': [{'string': ''}]}
# resumeComments ====> {'status': 'FETCH', 'items': {}}
# resumeSearchResult ====> {'criteria': {'search_period': '0', 'order_by': 'relevance', 'items_on_page': '20', 'date_from': '', 'date_to': ''}, 'paging': None, 'catalogLinks': [], 'resumes': [], 'settings': {'activeSettings': [], 'availableSettings': []}, 'clusters': {}, 'hidden': 0, 'total': 0, 'applicantUserStatuses': {}, 'vacancySimilarBuyContacts': {}, 'stats': {'totalResults': 0, 'totalUngroupedResults': 0, 'normalSearchResults': 0, 'normalGroupedSearchResults': 0}}
# resumeSearchQuery ====> {'itemsOnPage': [50], 'pageNumber': ['0'], 'collection': []}
# relocationWarning ====> {'show': False, 'confirmed': False}
# searchAjax ====> True
# searchMetroRedirect ====> {'enable': False, 'path': ''}
# searchCatalogRedirect ====> False
# searchXSControls ====> False
# searchVacancyLoading ====> False
# searchPreference ====> {'isShown': False}
# searchCounts ====> {'isLoad': False, 'value': 1030}
# searchClusters ====> {'label': {'groups': {'not_from_agency': {'count': 984, 'order': 1, 'title': 'Без вакансий агентств', 'id': 'not_from_agency'}, 'with_address': {'count': 410, 'order': 2, 'title': 'Только с адресом', 'id': 'with_address'}, 'accept_handicapped': {'count': 19, 'order': 3, 'title': 'Только доступные для людей с\xa0инвалидностью', 'id': 'accept_handicapped'}}, 'selectedValues': [], 'disableQueries': [], 'order': 14}, 'industry': {'groups': {'5': {'count': 20, 'order': 8, 'title': 'Перевозки, логистика, склад, ВЭД', 'id': '5'}, '7': {'count': 485, 'order': 1, 'title': 'Информационные технологии, системная интеграция, интернет', 'id': '7'}, '8': {'count': 15, 'order': 10, 'title': 'Электроника, приборостроение, бытовая техника, компьютеры и оргтехника', 'id': '8'}, '9': {'count': 38, 'order': 6, 'title': 'Телекоммуникации, связь', 'id': '9'}, '11': {'count': 29, 'order': 7, 'title': 'СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование', 'id': '11'}, '13': {'count': 6, 'order': 19, 'title': 'Строительство, недвижимость, эксплуатация, проектирование', 'id': '13'}, '15': {'count': 9, 'order': 16, 'title': 'Автомобильный бизнес', 'id': '15'}, '24': {'count': 13, 'order': 12, 'title': 'Металлургия, металлообработка', 'id': '24'}, '27': {'count': 8, 'order': 18, 'title': 'Продукты питания', 'id': '27'}, '29': {'count': 5, 'order': 20, 'title': 'Сельское хозяйство', 'id': '29'}, '33': {'count': 4, 'order': 22, 'title': 'Тяжелое машиностроение', 'id': '33'}, '34': {'count': 3, 'order': 25, 'title': 'Химическое производство, удобрения', 'id': '34'}, '36': {'count': 13, 'order': 13, 'title': 'Государственные организации', 'id': '36'}, '37': {'count': 1, 'order': 27, 'title': 'Общественная деятельность, партии, благотворительность, НКО', 'id': '37'}, '39': {'count': 51, 'order': 4, 'title': 'Образовательные учреждения', 'id': '39'}, '41': {'count': 50, 'order': 5, 'title': 'Розничная торговля', 'id': '41'}, '42': {'count': 9, 'order': 17, 'title': 'Товары народного потребления (непищевые)', 'id': '42'}, '43': {'count': 246, 'order': 2, 'title': 'Финансовый сектор', 'id': '43'}, '44': {'count': 62, 'order': 3, 'title': 'Услуги для бизнеса', 'id': '44'}, '45': {'count': 12, 'order': 14, 'title': 'Добывающая отрасль', 'id': '45'}, '46': {'count': 1, 'order': 28, 'title': 'Энергетика', 'id': '46'}, '47': {'count': 10, 'order': 15, 'title': 'Нефть и газ', 'id': '47'}, '48': {'count': 20, 'order': 9, 'title': 'Медицина, фармацевтика, аптеки', 'id': '48'}, '49': {'count': 15, 'order': 11, 'title': 'Услуги для населения', 'id': '49'}, '50': {'count': 4, 'order': 23, 'title': 'Гостиницы, рестораны, общепит, кейтеринг', 'id': '50'}, '52': {'count': 4, 'order': 24, 'title': 'Искусство, культура', 'id': '52'}, '388': {'count': 4, 'order': 21, 'title': 'Промышленное оборудование, техника, станки и комплектующие', 'id': '388'}, '389': {'count': 1, 'order': 26, 'title': 'Управление многопрофильными активами', 'id': '389'}}, 'selectedValues': [], 'disableQueries': [], 'order': 9}, 'experience': {'groups': {'between3And6': {'count': 464, 'order': 1, 'title': 'От\xa03\xa0до\xa06\xa0лет', 'id': 'between3And6'}, 'between1And3': {'count': 429, 'order': 2, 'title': 'От\xa01\xa0года до\xa03\xa0лет', 'id': 'between1And3'}, 'moreThan6': {'count': 72, 'order': 3, 'title': 'Более 6\xa0лет', 'id': 'moreThan6'}, 'noExperience': {'count': 65, 'order': 4, 'title': 'Нет опыта', 'id': 'noExperience'}}, 'selectedValues': None, 'disableQueries': [], 'order': 11}, 'schedule': {'groups': {'fullDay': {'count': 771, 'order': 1, 'title': 'Полный день', 'id': 'fullDay'}, 'remote': {'count': 191, 'order': 2, 'title': 'Удаленная работа', 'id': 'remote'}, 'flexible': {'count': 64, 'order': 3, 'title': 'Гибкий график', 'id': 'flexible'}, 'shift': {'count': 4, 'order': 4, 'title': 'Сменный график', 'id': 'shift'}}, 'selectedValues': [], 'disableQueries': [], 'order': 13}, 'professionalArea': {'groups': {'1': {'count': 824, 'order': 1, 'title': 'Информационные тех ...
# searchClustersInitialValues ====> {'label': [], 'industry': [], 'experience': None, 'schedule': [], 'professionalArea': [], 'professional_role': [], 'area': [], 'employment': [], 'compensation': {'onlyWithSalary': False, 'salary': None}, 'part_time': None, 'search_field': ['name', 'description'], 'excluded_text': [], 'neighbours': [], 'metro': [], 'specialization': [], 'subIndustry': []}
# searchClustersBasic ====> {'label': {'groups': {'not_from_agency': {'count': 825675, 'order': 1, 'title': 'Без вакансий агентств', 'id': 'not_from_agency'}, 'with_address': {'count': 502614, 'order': 2, 'title': 'Только с адресом', 'id': 'with_address'}, 'accept_handicapped': {'count': 19729, 'order': 3, 'title': 'Только доступные для людей с\xa0инвалидностью', 'id': 'accept_handicapped'}, 'accept_kids': {'count': 727, 'order': 4, 'title': 'Только доступные для соискателей от 14 лет', 'id': 'accept_kids'}}, 'selectedValues': [], 'disableQueries': [], 'order': 14}, 'industry': {'groups': {'5': {'count': 32377, 'order': 9, 'title': 'Перевозки, логистика, склад, ВЭД', 'id': '5'}, '7': {'count': 64799, 'order': 2, 'title': 'Информационные технологии, системная интеграция, интернет', 'id': '7'}, '8': {'count': 22271, 'order': 14, 'title': 'Электроника, приборостроение, бытовая техника, компьютеры и оргтехника', 'id': '8'}, '9': {'count': 15485, 'order': 18, 'title': 'Телекоммуникации, связь', 'id': '9'}, '11': {'count': 15495, 'order': 17, 'title': 'СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование', 'id': '11'}, '13': {'count': 61953, 'order': 3, 'title': 'Строительство, недвижимость, эксплуатация, проектирование', 'id': '13'}, '15': {'count': 23622, 'order': 11, 'title': 'Автомобильный бизнес', 'id': '15'}, '19': {'count': 3943, 'order': 27, 'title': 'Лесная промышленность, деревообработка', 'id': '19'}, '24': {'count': 22311, 'order': 13, 'title': 'Металлургия, металлообработка', 'id': '24'}, '27': {'count': 40885, 'order': 6, 'title': 'Продукты питания', 'id': '27'}, '29': {'count': 10488, 'order': 24, 'title': 'Сельское хозяйство', 'id': '29'}, '33': {'count': 15483, 'order': 19, 'title': 'Тяжелое машиностроение', 'id': '33'}, '34': {'count': 11094, 'order': 23, 'title': 'Химическое производство, удобрения', 'id': '34'}, '36': {'count': 12298, 'order': 22, 'title': 'Государственные организации', 'id': '36'}, '37': {'count': 904, 'order': 29, 'title': 'Общественная деятельность, партии, благотворительность, НКО', 'id': '37'}, '39': {'count': 14255, 'order': 20, 'title': 'Образовательные учреждения', 'id': '39'}, '41': {'count': 133817, 'order': 1, 'title': 'Розничная торговля', 'id': '41'}, '42': {'count': 50748, 'order': 4, 'title': 'Товары народного потребления (непищевые)', 'id': '42'}, '43': {'count': 40167, 'order': 7, 'title': 'Финансовый сектор', 'id': '43'}, '44': {'count': 43360, 'order': 5, 'title': 'Услуги для бизнеса', 'id': '44'}, '45': {'count': 13542, 'order': 21, 'title': 'Добывающая отрасль', 'id': '45'}, '46': {'count': 9434, 'order': 25, 'title': 'Энергетика', 'id': '46'}, '47': {'count': 16173, 'order': 15, 'title': 'Нефть и газ', 'id': '47'}, '48': {'count': 38389, 'order': 8, 'title': 'Медицина, фармацевтика, аптеки', 'id': '48'}, '49': {'count': 15937, 'order': 16, 'title': 'Услуги для населения', 'id': '49'}, '50': {'count': 29482, 'order': 10, 'title': 'Гостиницы, рестораны, общепит, кейтеринг', 'id': '50'}, '51': {'count': 6937, 'order': 26, 'title': 'ЖКХ', 'id': '51'}, '52': {'count': 628, 'order': 30, 'title': 'Искусство, культура', 'id': '52'}, '388': {'count': 23108, 'order': 12, 'title': 'Промышленное оборудование, техника, станки и комплектующие', 'id': '388'}, '389': {'count': 2370, 'order': 28, 'title': 'Управление многопрофильными активами', 'id': '389'}}, 'selectedValues': [], 'disableQueries': [], 'order': 9}, 'experience': {'groups': {'between1And3': {'count': 405993, 'order': 1, 'title': 'От\xa01\xa0года до\xa03\xa0лет', 'id': 'between1And3'}, 'noExperience': {'count': 287279, 'order': 2, 'title': 'Нет опыта', 'id': 'noExperience'}, 'between3And6': {'count': 166792, 'order': 3, 'title': 'От\xa03\xa0до\xa06\xa0лет', 'id': 'between3And6'}, 'moreThan6': {'count': 21359, 'order': 4, 'title': 'Более 6\xa0лет', 'id': 'moreThan6'}}, 'selectedValues': None, 'disableQueries': [], 'order': 11}, 'schedule': {'groups': {'fullDay': {'count': 634398, 'order': 1, 'title': 'Полный день', 'id': 'ful ...
# searchClustersChanged ====> False
# searchClustersTip ====> {'show': False, 'totalResults': 0}
# searchClustersSettings ====> {'type': 'vacancy', 'actionPath': '/search/vacancy'}
# searchResumeSeoCatalog ====> {'active': False}
# similarSavedSearchEnabled ====> False
# socialNetworksLinks ====> [{'name': 'vk', 'url': 'https://vk.com/headhunter'}, {'name': 'ok', 'url': 'http://www.odnoklassniki.ru/headhunter'}, {'name': 'twitter', 'url': 'https://twitter.com/hh_ru'}]
# session ====> {'isFallback': False, 'securityCheckFailed': False, 'hasExtraAccounts': False}
# smilesShoudBeShown ====> False
# showSkillSurveyOnVacancyEditPage ====> False
# showJobSearchStatusNotification ====> False
# showVacancyConstructorExample ====> False
# showVacancyConstructorExampleState ====> False
# showManagerContactsVacancyInfotip ====> False
# showWebimButtonOnLogin ====> False
# showResumeSearchConditions ====> False
# showEmployerStatisticsLinks ====> False
# supernovaSearchView ====> {'large': False, 'largeXS': False, 'expanded': False}
# supernovaSearchName ====> searchVacancy
# supernovaSearchArea ====> {'translations': {'area': 'Липецке'}}
# supernovaUserType ====> applicant
# supportChat ====> {'available': True, 'workday': None, 'weekend': None}
# syncAreaWithNeighboursArea ====> False
# stayInTouch ====> {'apps': [{'name': 'ios', 'href': 'https://redirect.appmetrica.yandex.com/serve/672819448956069558?main_page=lipetsk.hh.ru'}, {'name': 'android', 'href': 'https://redirect.appmetrica.yandex.com/serve/1033107423658825167?main_page=lipetsk.hh.ru'}, {'name': 'huawei', 'href': 'https://redirect.appmetrica.yandex.com/serve/819411740142879951?main_page=lipetsk.hh.ru'}], 'mobilePage': '/mobile'}
# topLevelDomain ====> hh.ru
# topLevelSite ====> hh.ru
# templatePreviewModal ====> {'visible': False, 'currentType': 'constructor', 'currentCompanyType': 'pticefabrika', 'logos': {'constructor': ['pticefabrika', 'zenno', 'lifefitnes', 'intiled'], 'typical': ['pp', 'technoavia', 'kedr', 'fintech'], 'individual': ['twogis', 'fresh', 'bank', 'rb']}}
# trl ====> {'RU': {'novafilters.similarSavedSearch.explanation': 'Мы\xa0запоминаем фильтры, которые вы\xa0применили к\xa0подходящим вакансиям', 'error.400.message': 'Плохой запрос', 'error.403.message': 'Пожалуйста, авторизуйтесь на сайте', 'error.404.message': 'Такой страницы не существует', 'error.500.tryagain': 'Извините, сервис временно недоступен. Попробуйте чуть позже.', 'error.599.tryagain': 'Извините, сервис временно недоступен. Попробуйте чуть позже.', 'emailVerificationInfo.notVerified': 'Ваш почтовый адрес {0} не\xa0подтвержден.', 'emailVerificationInfo.send': 'Отправить письмо для подтверждения', 'emailVerificationInfo.success': 'Письмо успешно отправлено, ', 'emailVerificationInfo.check': 'проверьте\xa0почту', 'emailVerificationInfo.cantGet': 'Не приходит письмо', 'emailVerificationInfo.error': 'Произошла ошибка.', 'emailVerificationInfo.tryAgain': 'Попробовать еще раз', 'inform.employer.restricted.1': 'Доступ к возможностям hh.ru ограничен.', 'inform.employer.restricted.2': 'Загрузите подтверждающие документы и дождитесь звонка менеджера.', 'inform.button.load': 'Загрузить', 'inform.employer.pending.1': 'На время проверки загруженных документов доступ к hh.ru ограничен.', 'inform.employer.pending.2': 'Ожидайте звонка от менеджера в ближайшее время.', 'employer.zpOnboardingModal.nextBtnStart': 'Начать экскурсию', 'employer.zpOnboardingModal.nextBtnContinue': 'Продолжить', 'employer.zpOnboardingModal.nextBtnEnd': 'Приступить к\xa0работе', 'employer.zpOnboardingModal.backBtn': 'Назад', 'employer.zpOnboardingModal.start.header': 'Посмотрите, как обновился личный кабинет', 'employer.zpOnboardingModal.start.text': 'Впереди\xa0— минутная экскурсия о\xa0том, где\xa0находятся ваши вакансии, заказы, подписки на\xa0резюме и\xa0избранное', 'employer.zpOnboardingModal.activeVacancies.header': 'Начнём с\xa0опубликованных вакансий: они\xa0— в\xa0«Вакансиях»', 'employer.zpOnboardingModal.activeVacancies.text': 'В\xa0разделе «Мои\xa0вакансии», если быть точными', 'employer.zpOnboardingModal.activeVacanciesMore.header': 'Не\xa0нашли публикаций на\xa0странице «Мои\xa0вакансии»?', 'employer.zpOnboardingModal.activeVacanciesMore.text': 'Они чуть ниже, под\xa0вашими черновиками\xa0— неопубликованными вакансиями', 'employer.zpOnboardingModal.archivedVacancies.header': 'Архивные вакансии\xa0— тоже в\xa0«Вакансиях»', 'employer.zpOnboardingModal.archivedVacancies.text': 'Раздел: «Архив»', 'employer.zpOnboardingModal.orders.header': 'Ваши заказы\xa0— в\xa0меню «Счёт»', 'employer.zpOnboardingModal.orders.text': 'Раздел: «Состояние и\xa0история»', 'employer.zpOnboardingModal.closingDocs.header': 'Закрывающие документы\xa0— там\xa0же, в\xa0меню «Счёт»', 'employer.zpOnboardingModal.closingDocs.text': 'Раздел: «Документы»', 'employer.zpOnboardingModal.subscriptions.header': 'Подписки на\xa0резюме\xa0— в\xa0«Кандидатах»', 'employer.zpOnboardingModal.subscriptions.text': 'Раздел: «Автопоиск»\xa0— теперь подписки называются именно так', 'employer.zpOnboardingModal.favourites.header': 'Избранные резюме\xa0—\xa0тоже в\xa0«Кандидатах»', 'employer.zpOnboardingModal.favourites.text': 'Кстати, теперь их\xa0можно сортировать по\xa0папкам', 'employer.zpOnboardingModal.end.header': 'И\xa0последнее: появилось больше возможностей ускорить наём сотрудников', 'employer.zpOnboardingModal.end.text': 'Например, рекомендации резюме стали ещё точнее\xa0— система опирается на\xa0ваши действия, лучше понимает, кто вам нужен, и\xa0предлагает больше подходящих людей.', 'employer.zpOnboardingModal.end.additionalInfoText': 'Узнать обо\xa0всех возможностях', 'employer.zpOnboardingModal.fromSteps': '{0}\xa0из\xa0{1}', 'supernova.footer.mobile.banner.header': 'Скачайте приложение', 'supernova.footer.mobile.banner.description.qr': 'Свежие вакансии, ответы на\xa0отклики и\xa0доступ к\xa0резюме\xa0— всегда у\xa0вас под рукой.', 'supernova.footer.mobile.banner.description.additional': 'Просто\xa0наведите камеру телефона на\xa0QR-код.', 'supernova.footer.mobile.banner.appButton': ...
# trudvsemEnabled ====> False
# userType ====> anonymous
# appLink ====> {'detected': False, 'href': '', 'type': '', 'name': ''}
# criteriaTextUpdated ====> data scien*
# userTargeting ====> {'puid42': None, 'puid48': None, 'puid49': None, 'puid44': None, 'puid53': None, 'puid63': None, 'puid45': None, 'puid41': None, 'puid56': None, 'puid57': None, 'puid46': None, 'puid43': '113:230:1890:58', 'puid1': '113:230:1890:58', 'puid47': None, 'puid54': None, 'puid50': None, 'puid51': None, 'puid52': None, 'puid55': None, 'puid2': '01aaJL10AEw57mLINCI2pg--', 'puid3': 'ru_RU', 'puid10': 'tempexp_15905_linking_vacancies:vacancy_partial_redesign_b:yenisei_bert_tdi:tempexp_16177_v2:tempexp_14535_b', 'puid58': 'null'}
# vacanciesOfTheDay ====> {'isLoading': True, 'success': True, 'vacancies': [], 'compensation': {'from': 0, 'to': 0, 'currencyCode': 'RUR'}}
# vacancyConstructorTemplate ====> {'pictures': {'VACANCY_CONSTRUCTOR_TOP': {}, 'VACANCY_CONSTRUCTOR_BOTTOM': {}, 'ZARPLATA_VACANCY_CONSTRUCTOR_TOP': {}, 'ZARPLATA_VACANCY_CONSTRUCTOR_BOTTOM': {}}, 'visibleCropImagePopup': False, 'imageCropSettings': {}}
# availablePublicationTypes ====> {'loading': False, 'params': {'areaIds': [], 'professionalRoleIds': [], 'withClickme': False, 'withZpCrossPost': True}, 'data': None}
# auctionPromo ====> {'auctionPromoAvailable': False, 'auctionPromoThankYouModal': False, 'auctionPromoChecked': False}
# vacancyCreateDraftSaveEnabled ====> True
# vacancyDiscountPromoControlsInfo ====> {'visibility': False}
# vacancyCreateSavedToDraft ====> False
# vacancyCreateAllowRegions ====> False
# isPromoVacancy ====> False
# isVacancyCreationAllowed ====> True
# isVacancyEditAllowed ====> True
# isAddressAddAllowed ====> True
# isAbortVacancyPollEnabled ====> False
# vacancyCreateSelectPublicationType ====> False
# otherRoleWarning ====> False
# isZpEmployer ====> False
# vacancyResponses ====> {'totalResumesCount': 0, 'collection': {'name': ''}, 'collections': [], 'resumes': {'total': 0, 'elementsJson': []}, 'phoneCalls': {'calls': []}, 'callsToResume': {}}
# hhcaptcha ====> {'isBot': False}
# vacancyResponsePopupVisible ====> False
# vacancySavedSearches ====> {'isAllSelected': False, 'selectedItems': [], 'error': False, 'isFullPageReactEnabled': False, 'email': '', 'emailVerified': True, 'savedSearch': [], 'filterValue': 'all', 'isLoading': ''}
# vacancySearchDictionaries ====> {'schedule': ['fullDay', 'shift', 'flexible', 'remote', 'flyInFlyOut'], 'experience': ['noExperience', 'between1And3', 'between3And6', 'moreThan6'], 'employment': ['full', 'part', 'project', 'volunteer', 'probation'], 'labels': ['with_address', 'accept_handicapped', 'not_from_agency', 'accept_kids'], 'orderBy': ['relevance', 'publication_time', 'salary_desc', 'salary_asc'], 'searchPeriod': ['0', '30', '7', '3', '1'], 'prioritySortCommon': ['metallic', 'none'], 'searchFields': ['name', 'company_name', 'description'], 'minItemsOnPage': 0, 'maxItemsOnPage': 100, 'maxSearchResult': 2000, 'privateParamPrefix': 'L_'}
# vacancySearchResult ====> {'vacancyAdditionalParams': ['position', 'requestId', 'totalVacancies'], 'proxiedSearchFormParams': {'clusters': True, 'ored_clusters': True, 'text': 'data scien*', 'items_on_page': 100, 'search_field': ['name', 'description'], 'enable_snippets': True}, 'savedSearches': {'isSavedSearch': False, 'email': None, 'selectedClusters': [{'name': 'search_field', 'title': 'Ключевые слова в названии вакансии и\xa0в описании вакансии'}], 'position': 2}, 'criteria': {'employment': [], 'schedule': [], 'page': 0, 'limit': -1, 'offset': -1, 'clusters': True, 'area': [], 'currency_code': 'RUR', 'metro': [], 'specialization': [], 'professional_role': [], 'search_debug': False, 'control_flag': ['vacancyBlacklistJoinEnabled:True'], 'saved_search_id': None, 'vacancy_id': None, 'resume': None, 'no_magic': False, 'ored_clusters': True, 'cache_ttl_sec': 0, 'text': 'data scien*', 'date_from': None, 'date_to': None, 'items_on_page': 100, 'order_by': 'relevance', 'label': [], 'search_field': ['name', 'description'], 'experience': None, 'enable_snippets': True, 'only_with_salary': False, 'part_time': None, 'is_part_time_clusters_enabled': False, 'exclude_archived': True, 'exclude_closed': True, 'search_period': None, 'salary': None, 'bottom_left_lat': None, 'bottom_left_lng': None, 'top_right_lat': None, 'top_right_lng': None, 'sort_point_lat': None, 'sort_point_lng': None, 'employer_id': None, 'employer_manager_id': None, 'industry': [], 'precision': None, 'geocode_type': None, 'geohash': None, 'recommended_by_uid': False, 'excluded_text': None}, 'totalUsedFilters': 2, 'vacancies': [{'@responseLetterRequired': False, '@showContact': False, 'vacancyId': 67570281, 'name': 'Data engineer (RnD)', 'company': {'@showSimilarVacancies': True, '@trusted': True, '@category': 'COMPANY', '@countryId': 4, '@state': 'APPROVED', 'id': 672796, 'name': 'SOFTSWISS', 'visibleName': 'SOFTSWISS', 'logos': {'logo': [{'@type': 'searchResultsPage', '@url': '/employer-logo/3921983.png'}, {'@type': 'small', '@url': '/employer-logo/3921983.png'}, {'@type': 'vacancyPage', '@url': '/employer-logo/3921984.png'}, {'@type': 'medium', '@url': '/employer-logo/3921984.png'}, {'@type': 'ORIGINAL', '@url': '/employer-logo-original/870277.png'}, {'@type': 'employerPage', '@url': '/employer-logo/3921982.png'}]}, 'companySiteUrl': 'https://careers.softswiss.com/'}, 'compensation': {'noCompensation': {}}, 'publicationTime': {'@timestamp': 1657183767, '$': '2022-07-07T11:49:27.850+03:00'}, 'type': 'open', 'area': {'@id': 2758, 'name': 'Тбилиси', 'path': '.28.2758.'}, 'acceptTemporary': False, 'metallic': 'premium', 'creationSite': 'hh.ru', 'creationSiteId': 1, 'displayHost': 'lipetsk.hh.ru', 'lastChangeTime': {'@timestamp': 1657205780, '$': '2022-07-07T17:56:20.563+03:00'}, 'creationTime': '2022-07-07T11:49:27.850+03:00', 'canBeShared': True, 'employerManager': {'@hhid': 100374019, '@managerId': 6593851, '@userId': 78216945}, 'inboxPossibility': True, 'chatWritePossibility': 'ENABLED_AFTER_INVITATION', 'notify': True, 'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67570281', 'mobile': 'https://m.hh.ru/vacancy/67570281'}, 'workSchedule': 'FULL_DAY', 'acceptIncompleteResumes': False, 'driverLicenseTypes': [{}], 'languages': [{'language': [{'id': 57, 'degree': 'b2'}]}], 'workingDays': [{}], 'workingTimeIntervals': [{}], 'workingTimeModes': [{}], 'hrBotScenario': {'hrBotScenarioId': 6038521, 'enabled': False, 'scenarioCode': 'vacancy_scenario_6038521'}, 'vacancyProperties': {'properties': [{}]}, 'publicationType': 'PREMIUM', 'vacancyPlatforms': ['HH'], 'contactInfo': None, 'userLabels': [], 'snippet': {'req': 'Experience in data environments, such as Data Lakes, Data Warehouses, Data Marts, Data transformation concepts and working with large data...', 'resp': '...Big Data technology landscape to build business-critical, scalable and robust data pipelines and intuitive data products that power data...', 'cond': None, 'skill': 'Big Data, Python, Spark, SCALA, Английски ...
# vacancyWizard ====> {'totalEmployersFound': 0, 'employerHits': [], 'rootAreaId': 0}
# xsrfToken ====> 26da5bc147ce935f1497e6937497f5df
# pinnedChatMessages ====> {'hasMore': False, 'items': []}
# snippetAccessResume ====> {'productList': [], 'area': '', 'isShowSnippetResume': False}
# zpEmployerOnboarding ====> {'showOnboardingModal': False}
# accountHistoryMoney ====> {'hasPersonalManager': False, 'state': '', 'email': '', 'agreements': {}, 'currency': '', 'hrs': {'orders': []}, 'balances': {}, 'employerCountry': '', 'availableWithoutBlockedMoney': 0}
# router ====> {'location': {'pathname': '/search/vacancy', 'search': '?text=data+scien*&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'hash': '', 'key': '964d1v', 'query': {'text': 'data+scien*', 'search_field': 'description', 'salary': '', 'currency_code': 'RUR', 'experience': 'doesNotMatter', 'order_by': 'relevance', 'search_period': '0', 'items_on_page': '100'}}, 'action': 'POP'}

# %% [markdown]
# [EN] Keys analysis show search results are under 'vacancySearchResult'->'vacancies' keys
# Another useful keys are:
# 'searchClusters' contains grouping characteristics
# - 'industry'
# - 'groups'
#
# [RU] Визуальный анализ ключей показывает, что результаты поиска хранятся в ключе 'vacancySearchResult'->'vacancies'
# Другие полезные ключи:
# 'searchClusters' - содержит группировочные характеристики
# - 'industry' - список отраслей/направлений, в которых были найдены вакансии (возможно, с указанием количества?)
# - 'groups' - список населенных пунктов

# %%
vacancies_info = clean_dict['vacancySearchResult']['vacancies']
print('Vacancies data type: {}'.format(type(vacancies_info)))
print('Num of vacancies: {}'.format(len(vacancies_info)))
# Out:
# Vacancies data type: <class 'list'>
# Num of vacancies: 100

# %% [markdown]
# [EN] We have 100 records containing vacancies info from the 1st search page. Now we have to find total number of pages to get all of them. So we go to 'paging' key
# [RU] У нас имеются данные о вакансиях с 1 страницы, содержащие 100 записей, как мы и просили в запросе.
# Теперь нужно найти информацию о том, сколько страниц всего сформировано, чтобы организовать получение информации с остальных страниц.
# Для этого служит ключ 'paging'

# %%
clean_dict['vacancySearchResult']['paging']
# Out:
# {'previous': {'page': -1, 'disabled': True},
#  'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#   {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True},
#   {'text': '3', 'page': 2, 'selected': False, 'inShortRange': True},
#   {'text': '4', 'page': 3, 'selected': False, 'inShortRange': False},
#   {'text': '5', 'page': 4, 'selected': False, 'inShortRange': False},
#   {'text': '...', 'page': 5, 'selected': False, 'inShortRange': False}],
#  'lastPage': {'page': 10, 'selected': False},
#  'next': {'page': 1, 'disabled': False},
#  'os': 'Win'}

# %% [markdown]
# [EN] Here is pagination data. Last page number contains in 'lastPage'->'page' key. So we have N+1 pages as they are 0-indexed.
# [RU] Здесь приводятся данные разметки по страницам. Номер последней страницы содержится в ключе 'lastPage'->'page'. Таким образом, всего в результатах поиска N+1 страниц, поскольку страница, которую мы получили, и анализируем сейчас, имеет индекс 0

# %%
last_page = clean_dict['vacancySearchResult']['paging']['lastPage']['page']
for page in range(1, last_page+1):
    browser.get(base_url+url_tail.format(page))
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    json_parsed = json.loads(soup.find_all('template')[0].text)
    vacancies_info += json_parsed['vacancySearchResult']['vacancies']

print('Final vacancies info contains {} record(s)'.format(len(vacancies_info)))
# Out:
# Final vacancies info contains 1028 record(s)

# %% [markdown]
# [EN] We've got info from all pages and now can close browser

# %%
browser.quit()

# %% [markdown]
# [EN] Dumping data to have an opportunity to restore raw data later...

# %%
with open('datasets/'+output_filename+'.json', 'w') as f:
    json.dump(vacancies_info, f)

# %% [markdown]
# [EN] And now it's time to select fields to fill in DataFrame
# [RU] Сейчас нужно понять, какие поля из описаний вакансий нам понадобятся, чтобы использовать их в анализе

# %%
for key in vacancies_info[0].keys():
    print('{} =======> {}'.format(key, vacancies_info[0][key]))
# Out:
# @responseLetterRequired =======> False
# @showContact =======> False
# vacancyId =======> 67570281
# name =======> Data engineer (RnD)
# company =======> {'@showSimilarVacancies': True, '@trusted': True, '@category': 'COMPANY', '@countryId': 4, '@state': 'APPROVED', 'id': 672796, 'name': 'SOFTSWISS', 'visibleName': 'SOFTSWISS', 'logos': {'logo': [{'@type': 'searchResultsPage', '@url': '/employer-logo/3921983.png'}, {'@type': 'small', '@url': '/employer-logo/3921983.png'}, {'@type': 'vacancyPage', '@url': '/employer-logo/3921984.png'}, {'@type': 'medium', '@url': '/employer-logo/3921984.png'}, {'@type': 'ORIGINAL', '@url': '/employer-logo-original/870277.png'}, {'@type': 'employerPage', '@url': '/employer-logo/3921982.png'}]}, 'companySiteUrl': 'https://careers.softswiss.com/'}
# compensation =======> {'noCompensation': {}}
# publicationTime =======> {'@timestamp': 1657183767, '$': '2022-07-07T11:49:27.850+03:00'}
# type =======> open
# area =======> {'@id': 2758, 'name': 'Тбилиси', 'path': '.28.2758.'}
# acceptTemporary =======> False
# metallic =======> premium
# creationSite =======> hh.ru
# creationSiteId =======> 1
# displayHost =======> lipetsk.hh.ru
# lastChangeTime =======> {'@timestamp': 1657205780, '$': '2022-07-07T17:56:20.563+03:00'}
# creationTime =======> 2022-07-07T11:49:27.850+03:00
# canBeShared =======> True
# employerManager =======> {'@hhid': 100374019, '@managerId': 6593851, '@userId': 78216945}
# inboxPossibility =======> True
# chatWritePossibility =======> ENABLED_AFTER_INVITATION
# notify =======> True
# links =======> {'desktop': 'https://lipetsk.hh.ru/vacancy/67570281', 'mobile': 'https://m.hh.ru/vacancy/67570281'}
# workSchedule =======> FULL_DAY
# acceptIncompleteResumes =======> False
# driverLicenseTypes =======> [{}]
# languages =======> [{'language': [{'id': 57, 'degree': 'b2'}]}]
# workingDays =======> [{}]
# workingTimeIntervals =======> [{}]
# workingTimeModes =======> [{}]
# hrBotScenario =======> {'hrBotScenarioId': 6038521, 'enabled': False, 'scenarioCode': 'vacancy_scenario_6038521'}
# vacancyProperties =======> {'properties': [{}]}
# publicationType =======> PREMIUM
# vacancyPlatforms =======> ['HH']
# contactInfo =======> None
# userLabels =======> []
# snippet =======> {'req': 'Experience in data environments, such as Data Lakes, Data Warehouses, Data Marts, Data transformation concepts and working with large data...', 'resp': '...Big Data technology landscape to build business-critical, scalable and robust data pipelines and intuitive data products that power data...', 'cond': None, 'skill': 'Big Data, Python, Spark, SCALA, Английский язык', 'desc': None}
# responsesCount =======> 1
# online_users_count =======> 0

# %% [markdown]
# Полезную информацию несут / Useful info keys:
# - 'vacancyId' - уникальный идентификатор вакансии, по которому потом можно перейти на страницу с подробным описанием вакансии
# - 'name' - наименование вакансии (предполагаемая должность)
# - 'company'->'visibleName' + 'company'->'department'->'@name'
# - 'area'->'@id', 'area'->'name' - код и название условной географической области поиска
# - 'address'->'displayName', 'address'->'marker'->('@lat', '@lng') - показываемый адрес и координаты для карты
# - 'compensation'->{'from', 'to', 'currencyCode', 'gross'=(True=до вычета налогов, False=на руки)} (или 'compensation'->'noCompensation', если данных нет) - размер з/п
# - 'workSchedule' - график занятости (полный / сменный / гибкий / удаленный...)
# - 'snippet' - отрывки из описания вакансии dict('req' - требования, 'resp' - функции/задачи, 'cond' - условия, 'skill' - ?требуемые навыки?, 'desc' - ?)
# - 'publicationTime'
# - 'lastChangeTime'

# %% [markdown]
# Lets define function to get necessary data from json:

# %%
df_column_names = [
    'vacancy_id',
    'vacancy_name',
    'company_name',
    'company_dept',
    'area',
    'address',
    'latitude',
    'longitude',
    'salary_from',
    'salary_to',
    'salary_currency',
    'salary_gross',
    'publication_time',
    'last_changed',
    'schedule',
    'req',
    'resp',
    'cond',
    'skills'
]

# %%
def get_record_data(rec):
    result = dict()
    result['vacancy_id'] = rec['vacancyId']
    result['vacancy_name'] = rec['name']
    result['company_name'] = rec['company']['visibleName']
    if rec['company'].get('department', np.NAN) is np.NAN:
        result['company_dept'] = np.NAN
    else:
        result['company_dept'] = rec['company']['department'].get('@name', np.NAN)
    result['area'] = rec['area']['@id']
    if rec.get('address', None) is None:
        result['address'] = np.NAN
    else:
        result['address'] = rec['address'].get('displayName', np.NAN)
        if rec['address'].get('marker', None) is None:
            result['latitude'] = np.NAN
            result['longitude'] = np.NAN
        else:
            result['latitude'] = rec['address']['marker'].get('@lat', np.NAN)
            result['longitude'] = rec['address']['marker'].get('@lng', np.NAN)
    if rec['compensation'].get('noCompensation', None) is None:
        result['salary_from'] = rec['compensation'].get('from', np.NAN)
        result['salary_to'] = rec['compensation'].get('to', np.NAN)
        result['salary_currency'] = rec['compensation'].get('currencyCode', np.NAN)
        result['salary_gross'] = rec['compensation'].get('gross', np.NAN)
    else:
        result['salary_from'] = np.NAN
        result['salary_to'] = np.NAN
        result['salary_currency'] = np.NAN
        result['salary_gross'] = np.NAN
    result['publication_time'] = rec['publicationTime']['@timestamp']
    result['last_changed'] = rec['lastChangeTime']['@timestamp']
    result['schedule'] = rec['workSchedule']
    result['req'] = rec['snippet'].get('req', np.NAN)
    result['resp'] = rec['snippet'].get('resp', np.NAN)
    result['cond'] = rec['snippet'].get('cond', np.NAN)
    result['skills'] = rec['snippet'].get('skills', np.NAN)

    return result

# %%
raw_parsed_data = {name: [] for name in df_column_names}
for rec in vacancies_info:
    parsed = get_record_data(rec)
    for key in df_column_names:
        raw_parsed_data[key].append(parsed.get(key, np.NAN))
print('Control of num of records created:', len(raw_parsed_data['vacancy_id']))
print('Vacancies ID sample: ', raw_parsed_data['vacancy_id'][:10])
# Out:
# Control of num of records created: 1028
# Vacancies ID sample:  [67570281, 54418768, 54168093, 66986986, 66198333, 66933586, 67613430, 67609341, 67617590, 67114858]

# %% [markdown]
# Converting data structures created to pandas DataFrame. Then making readable data in 'publication_time' and 'last_changed' columns. And finally assigning 'vacancy_id' as primary index (it's unique for each record). It will be useful later if I'll decide to update data so I'll be able to filter out existing data or update existing records

# %%
df = pd.DataFrame(raw_parsed_data)
df['publication_time'] = df['publication_time'].apply(pd.to_datetime, unit='s')
df['last_changed'] = df['last_changed'].apply(pd.to_datetime, unit='s')
df.set_index('vacancy_id', inplace=True)
df.head()
# Out:
#                                            vacancy_name        company_name  \
# vacancy_id
# 67570281                            Data engineer (RnD)           SOFTSWISS
# 54418768                          Senior data scientist         Банк ДОМ.РФ
# 54168093    Middle / Senior QA-инженер в команду Поиска      HeadHunter::QA
# 66986986                                 Data Scientist             ImagiON
# 66198333                                 Data Scientist  БиАйЭй-Технолоджиз
#
#               company_dept  area  \
# vacancy_id
# 67570281               NaN  2758
# 54418768               NaN     1
# 54168093    HeadHunter::QA     1
# 66986986               NaN     1
# 66198333               NaN     2
#
#                                                       address   latitude  \
# vacancy_id
# 67570281                                                  NaN        NaN
# 54418768                        Москва, улица Воздвиженка, 10  55.753301
# 54168093                       Москва, улица Годовикова, 9с10  55.809343
# 66986986    Москва, Центральный административный округ, Пр...  55.749451
# 66198333                                                  NaN        NaN
#
#             longitude  salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 67570281          NaN          NaN        NaN             NaN          NaN
# 54418768    37.606263          NaN        NaN             NaN          NaN
# 54168093    37.628505     200000.0        NaN             RUR         True
# 66986986    37.542824          NaN        NaN             NaN          NaN
# 66198333          NaN          NaN        NaN             NaN          NaN
#
#               publication_time        last_changed  schedule  \
# vacancy_id
# 67570281   2022-07-07 08:49:27 2022-07-07 14:56:20  FULL_DAY
# 54418768   2022-07-05 06:04:39 2022-07-05 06:04:39  FULL_DAY
# 54168093   2022-07-02 18:44:56 2022-07-02 18:44:56  FULL_DAY
# 66986986   2022-07-08 08:46:42 2022-07-08 08:59:43  FULL_DAY
# 66198333   2022-07-08 07:46:57 2022-07-08 07:46:57  FULL_DAY
#
#                                                           req  \
# vacancy_id
# 67570281    Experience in data environments, such as Data ...
# 54418768    Опыт от 1 года в банковской сфере. Знание стат...
# 54168093    Знание методов и методик тестирования. Опыт те...
# 66986986    Опыт работы от 1 года. Опыт работы по анализу ...
# 66198333    Знание SQL. Знание математической статистики. ...
#
#                                                          resp  \
# vacancy_id
# 67570281    ...Big Data technology landscape to build busi...
# 54418768    Построение моделей вероятности дефолта (PD) и ...
# 54168093    Обнаружение, документирование и отслеживание д...
# 66986986                                                 None
# 66198333    Прогнозирование спроса, эластичность спроса по...
#
#                                                          cond  skills
# vacancy_id
# 67570281                                                 None     NaN
# 54418768    Конкурентный уровень заработной платы + премии...     NaN
# 54168093    Возможность выбора места работы: удаленно или ...     NaN
# 66986986    Комфортный офис в Москва Сити, м. Деловой цент...     NaN
# 66198333    Бесценный опыт работы над интересными проектам...     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 67570281 to 66733561
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vacancy_name      1028 non-null   object
#  1   company_name      1028 non-null   object
#  2   company_dept      206 non-null    object
#  3   area              1028 non-null   int64
#  4   address           405 non-null    object
#  5   latitude          404 non-null    float64
#  6   longitude         404 non-null    float64
#  7   salary_from       195 non-null    float64
#  8   salary_to         118 non-null    float64
#  9   salary_currency   221 non-null    object
#  10  salary_gross      220 non-null    object
#  11  publication_time  1028 non-null   datetime64[ns]
#  12  last_changed      1028 non-null   datetime64[ns]
#  13  schedule          1028 non-null   object
#  14  req               1022 non-null   object
#  15  resp              1017 non-null   object
#  16  cond              767 non-null    object
#  17  skills            0 non-null      float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(10)
# memory usage: 152.6+ KB

# %%
df.to_csv('datasets/'+output_filename+'.csv')
