# %% [markdown]
# ## Data scraping from hh.ru and preparation

# %% [markdown]
# The main goal of this file is to understand how one can get data about vacancies from the biggest Russian job site - hh.ru.
# Here I'll analyze the search results about DS vacancies. Transformed data will be saved in .csv for further processing.

# %%
#import requests
#import urllib.request
#import datetime
#import re
from bs4 import BeautifulSoup
import json
import numpy as np
import pandas as pd

from time import sleep

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium import webdriver

import sys
import logging

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

handler = logging.StreamHandler(stream=sys.stdout)
handler.setFormatter(logging.Formatter(fmt='[%(asctime)s: %(funcName)s: %(levelname)s] %(message)s'))
logger.addHandler(handler)

# %% [markdown]
# Preparing browser under selenium control to collect data

# %%
chrome_mode = 'headed' #'headless' # for debug purposes we can change this value to any but 'headless' to run Chrome in standard mode
chrome_options = Options()
if chrome_mode == 'headless':
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--disable-gpu')
    chrome_options.add_argument('--headless')
service = Service(executable_path="c:\\Applications\\WebDriver\\chromedriver-x32.exe")
browser = webdriver.Chrome(service=service, options=chrome_options)

# %%
"""
urls to search vacancies by words "аналитик данных" / "data scien*" in Russia looks like:
(1) https://hh.ru/search/vacancy?
                        text=data+scien*&                   # will be format parameter
                        search_field=name&search_field=description&
                        area=1&                             # will be format parameter
                        salary=150000&currency_code=RUR&    # will be format parameter
                        experience=doesNotMatter&
                        order_by=relevance&
                        search_period=0&
                        items_on_page=100&
                        no_magic=true&
                        L_save_area=true
(2) https://hh.ru/search/vacancy?
                        text=data+scien*&
                        search_field=name&search_field=description&
                        area=1&
                        salary=150000&currency_code=RUR&
                        experience=doesNotMatter&
                        order_by=relevance&
                        search_period=0&
                        items_on_page=100&
                        no_magic=true&
                        L_save_area=true&
                        page=1&                         # these 2 parameters are used when navigating to different pages
                        hhtmFrom=vacancy_search_list
(3) https://hh.ru/search/vacancy?
                        text=data+scien*&
                        search_field=name&search_field=description&
                                                        # 'area' parameter is missing => search in all areas
                        salary=&currency_code=RUR&      # 'salary' parameter set to '' => search for all salary amounts
                        experience=doesNotMatter&
                        order_by=relevance&
                        search_period=0&
                        items_on_page=100&
                        no_magic=true&
                        L_save_area=true
"""
# Out:
# '\nurls to search vacancies by words "аналитик данных" / "data scien*" in Russia looks like:\n(1) https://hh.ru/search/vacancy?\n                        text=data+scien*&                   # will be format parameter\n                        search_field=name&search_field=description&\n                        area=1&                             # will be format parameter\n                        salary=150000&currency_code=RUR&    # will be format parameter\n                        experience=doesNotMatter&\n                        order_by=relevance&\n                        search_period=0&\n                        items_on_page=100&\n                        no_magic=true&\n                        L_save_area=true\n(2) https://hh.ru/search/vacancy?\n                        text=data+scien*&\n                        search_field=name&search_field=description&\n                        area=1&\n                        salary=150000&currency_code=RUR&\n                        experience=doesNotMatter&\n                        order_by=relevance&\n                        search_period=0&\n                        items_on_page=100&\n                        no_magic=true&\n                        L_save_area=true&\n                        page=1&                         # these 2 parameters are used when navigating to different pages\n                        hhtmFrom=vacancy_search_list\n(3) https://hh.ru/search/vacancy?\n                        text=data+scien*&\n                        search_field=name&search_field=description&\n                                                        # \'area\' parameter is missing => search in all areas\n                        salary=&currency_code=RUR&      # \'salary\' parameter set to \'\' => search for all salary amounts\n                        experience=doesNotMatter&\n                        order_by=relevance&\n                        search_period=0&\n                        items_on_page=100&\n                        no_magic=true&\n                        L_save_area=true\n'

# %%
search_url_template = "https://hh.ru/search/vacancy?text={}&search_field=name&search_field=description&{}salary={}&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100"
#items_on_page = 100
salary_level = '' #'150000'
search_texts = [
    "data+scien*",
    "%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85",
    "data analy*",
    "{}",
]
areas = {
    '#later': '{}', # left to configure later
    'All': '',
    'Moscow': 'area=1&',
    'SPb': 'area=2&',
    'Ekaterinburg': 'area=3&',
    'Novosib': 'area=4&',
    'Austria': 'area=7&',
    'Erevan': 'area=13&',
    'NNovgorod': 'area=66&',
    'RostovND': 'area=76&',
    'Samara': 'area=78&',
    'Saratov': 'area=79&',
    'Kazan': 'area=88&',
    'Chelyabinsk': 'area=104&',
    '???': 'area=159&',
    'Almaty': 'area=160&',
    'Minsk': 'area=1002&',
    'Nur-Sultan': 'area=159&',
    'Tbilisi': 'area=2758&',
    'Tashkent': 'area=2759&',
}
url_tail = '&page={}&hhtmFrom=vacancy_search_list'
output_filename = 'vacancies_data_analyst'

# %%
def combine_base_url(template=None, search_text='', area_keys=[], salary=''): #, items_per_page=100
    if template is None:
        return None
    areas_str = ''
    for key in area_keys:
        areas_str += areas[key]
    if salary == '' or salary is None:
        salary_str = ''
    else:
        salary_str = str(salary) + '&only_with_salary=true&'
    return template.format(search_text, areas_str, salary_str) #, items_per_page

# %% [markdown]
# The baseline url to start search with:

# %%
base_url = combine_base_url(template = search_url_template, search_text=search_texts[1], area_keys=['All'], salary=salary_level)
base_url
# Out:
# 'https://hh.ru/search/vacancy?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100'

# %%
browser.get(base_url)

# %% [markdown]
# The page source code analysis shows that all info about vacancies is located under 'template' key. This 1-row data looks like json-parseable multilevel structure. So I'm going to feed it to json module and the analyse more deeply.

# %%
soup = BeautifulSoup(browser.page_source, 'html.parser')
# Page source code showed us there is only 1 'template' tag on page.
# It contains a huge amount of data including vacancies list in dictionary-like format (possibly for JS parsing).
# So here I'll use json library to convert html text to dictionaries/lists
json_parsed = json.loads(soup.find_all('template')[0].text)
print('"Template" tag contains {} keys'.format(len(json_parsed)))
# Out:
# "Template" tag contains 498 keys

# %%
json_parsed
# Out:
# {'authPhone': None,
#  'authNewEmployerAreaIdsToRedirect': [],
#  'authNewEmployerCategories': [],
#  'authNewEmployerFields': [],
#  'authNewEmployerInitialValues': {},
#  'authNewEmployerPhoneMask': None,
#  'activeResumeAccessType': None,
#  'accountTemporarilyLocked': {},
#  'accountPhoneVerification': None,
#  'applicantSignup': {'fields': [], 'hideLogin': False},
#  'applicantVacancyResponseStatuses': {},
#  'applicantResumes': [],
#  'applicantResponseStreaks': {},
#  'applicantPackageType': 'basic',
#  'applicantServiceType': '',
#  'applicantPaymentBackUrl': '',
#  'applicantAnalyticsAction': '',
#  'applicantPaymentTypes': [],
#  'applicantAvailableResumeServices': [],
#  'applicantPackageContent': [],
#  'applicantAvailableQuantities': [],
#  'applicantServicesPrices': {},
#  'applicantPaymentSource': 'desktop',
#  'applicantFindJobRecommendedQuantity': None,
#  'applicantSuitableVacancyByResume': {},
#  'account': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountConnect': {},
#  'accountConnectOAuth': {},
#  'accountConnectResponse': {},
#  'actualAccount': None,
#  'accountHistoryServices': {'employerActiveTemporalServices': [],
#   'employerTemporalServices': [],
#   'employerActiveSingleServices': [],
#   'employerFreeServices': []},
#  'accountHistoryReplenishments': {'bills': [],
#   'documentLinksVisibility': False,
#   'currency': 'RUR'},
#  'accountHistoryExpenditures': {'services': [], 'currency': ''},
#  'artifactRules': None,
#  'hhidAccount': {'firstName': None, 'middleName': None, 'lastName': None},
#  'accountDelete': {'applicantName': '',
#   'resumesList': {'resumes': {'published': [], 'unpublished': []},
#    'count': 0}},
#  'adsSearchParams': {'puid11': 'searchVacancy',
#   'puid23': '',
#   'puid14': 'аналитик данных',
#   'puid29': '',
#   'puid30': '',
#   'puid12': '',
#   'puid13': ''},
#  'adsVacancyParams': {},
#  'alreadyRegisteredEmployer': None,
#  'anonymousUserType': None,
#  'advancedSearch': {'showSearchConditions': False,
#   'hideSuggest': False,
#   'vacancy': None,
#   'resume': None,
#   'experience': [],
#   'keySkills': [],
#   'university': [],
#   'citizenship': [],
#   'work_ticket': [],
#   'employment': [],
#   'schedule': [],
#   'driver_license_types': [],
#   'job_search_status': [],
#   'language': [],
#   'exclusion': []},
#  'anonymousEmployer': {'suggestedProfessions': [],
#   'applicantCount': None,
#   'publicationPrice': None,
#   'averageEmployersOnline': None},
#  'allowedSMSCountries': None,
#  'appleBusinessChat': {'isEnabled': False, 'href': ''},
#  'abortPageContent': False,
#  'applicantEmployersNegotiationStats': {'employer-negotiation-stats': []},
#  'applicantEmployerManagersActivity': [],
#  'applicantNews': [],
#  'applicantArticles': [],
#  'applicantLatestResume': None,
#  'applicantFaq': [],
#  'addressesSuggestRemoteMode': False,
#  'analyticsParams': {'hhtmSource': 'vacancy_search_list',
#   'hhtmFrom': '',
#   'hhtmSourceLabel': '',
#   'hhtmFromLabel': '',
#   'screenType': 'SIMPLE'},
#  'applicantInfo': {'total': 0, 'finished': 0, 'visible': 0, 'searchable': 0},
#  'applicantNegotiations': {'topicList': [], 'filterInUse': 'all'},
#  'applicantNegotiationsActionsData': {'deleteAction': {},
#   'filters': [],
#   'filterByStatus': [],
#   'backUrl': '',
#   'order': {}},
#  'applicantPaymentServices': [],
#  'applicantResumesStatistics': {},
#  'applicantSettingsMenu': [],
#  'applicantSubscriptions': {'formItems': {},
#   'initialValues': {},
#   'email': None,
#   'emailVerified': None},
#  'applicantUseful': [],
#  'applicantUserStatuses': None,
#  'authUrl': {'login-url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-form': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'login-field-value': '',
#   'backurl-field-name': 'backUrl',
#   'remember-field-name': 'remember',
#   'remember-field-value': 'yes',
#   'backurl': 'https://lipetsk.hh.ru/search/vacancy?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#   'failurl': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'signup-form': '/account/signup?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'auth-employer-url': '/auth/employer/?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'remember-password': '/account/remember_password?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#   'agreement-form': '/account/agreement?backurl=%2Faccount%2Fsignup%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253D%2525D0%2525B0%2525D0%2525BD%2525D0%2525B0%2525D0%2525BB%2525D0%2525B8%2525D1%252582%2525D0%2525B8%2525D0%2525BA%252B%2525D0%2525B4%2525D0%2525B0%2525D0%2525BD%2525D0%2525BD%2525D1%25258B%2525D1%252585%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100',
#   'employer-agreement': '/auth/employer/agreement?backurl=%2Fauth%2Femployer%2F%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253D%2525D0%2525B0%2525D0%2525BD%2525D0%2525B0%2525D0%2525BB%2525D0%2525B8%2525D1%252582%2525D0%2525B8%2525D0%2525BA%252B%2525D0%2525B4%2525D0%2525B0%2525D0%2525BD%2525D0%2525BD%2525D1%25258B%2525D1%252585%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100'},
#  'availableVacancyActions': {},
#  'analyticsConversionPromo': None,
#  'brandedVacancyTemplates': [],
#  'employerSubscriptions': {'initialValues': {}, 'employerId': ''},
#  'emailVerification': {'email': '', 'needVerification': False, 'mailURL': ''},
#  'employerTests': [],
#  'employerResumesNegotiationLinks': {},
#  'employerRegistrationPresentsByCountryId': {},
#  'applicantResumesIdentifiers': [],
#  'areaTree': [],
#  'assessments': {'assessments': []},
#  'availableCallOptions': [],
#  'loginForm': {'passwordRecovery': {'trl': 'Получить пароль'},
#   'registration': [{'trl': 'Соискателя',
#     'code': 'REG_APPLICANT',
#     'translationKey': 'account.login.registration.applicant.capitalized'},
#    {'trl': 'Работодателя',
#     'code': 'REG_EMPLOYER',
#     'translationKey': 'account.login.registration.employer.capitalized'}],
#   'socialNetworks': [{'trl': 'Мой Мир@mail.ru',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list',
#     'code': 'MAIL',
#     'translationKey': 'socialNetworkTitle.mail'},
#    {'trl': 'Одноклассники',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list',
#     'code': 'OK',
#     'translationKey': 'socialNetworkTitle.ok'},
#    {'trl': 'ВКонтакте',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list',
#     'code': 'VK',
#     'translationKey': 'socialNetworkTitle.vk'},
#    {'trl': 'Google',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list',
#     'code': 'GPLUS',
#     'translationKey': 'socialNetworkTitle.gplus'},
#    {'trl': 'Доктор на работе',
#     'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list',
#     'code': 'DNR',
#     'translationKey': 'socialNetworkTitle.dnr'}]},
#  'backofficeCanEditTemplate': True,
#  'backUrl': None,
#  'banners': {'under-pagination-search-results-l': [{'id': '293',
#     'cId': '05145823-bd1f-4820-8401-993236eda193',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'under-pagination-search-results-m': [{'id': '294',
#     'cId': 'a7f0d630-8462-461e-b1db-76512f798ca3',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'under-pagination-search-results-s': [{'id': '292',
#     'cId': '4faf8bef-0c4f-4498-850a-e0ea7860fe08',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'under-pagination-search-results-xs': [{'id': '521',
#     'cId': '3daed3f9-441b-4816-ab7b-d271bd6f8680',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-rotate': [{'id': '654',
#     'cId': '5bf1d6f9-0dc0-4a07-863b-dc4fe410921d'},
#    {'id': '655', 'cId': 'b443c3fc-f65e-4d4c-9045-cdeb13756315'}],
#   'serp-first-l': [{'id': '221',
#     'cId': 'b21e020b-61c4-4490-b16e-a9db4dc1e865',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-first-m': [{'id': '637',
#     'cId': '4eaf2fd0-1686-4d62-963a-2523c39b0718',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-first-s': [{'id': '613',
#     'cId': 'a1167275-28a2-4db1-942b-ba7333d82d77',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-first-xs': [{'id': '630',
#     'cId': 'b2c13c21-e012-4d5a-8cba-51a3f347b417',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-second-l': [{'id': '175',
#     'cId': '8e0c2279-587b-4374-9b19-a1680b126698',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-second-m': [{'id': '347',
#     'cId': '496e576c-47af-479d-bab0-9b2f9d5310aa',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-second-s': [{'id': '638',
#     'cId': 'd84ca539-5483-47ed-aa3e-cafd82e2cac0',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-second-xs': [{'id': '505',
#     'cId': 'e2788b88-1f8d-45d3-a164-a9d96283a7a8',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'under-search-results-xs': [{'id': '661',
#     'cId': '9fad8592-a619-46b3-82fa-8f17a3942387'},
#    {'id': '662', 'cId': 'a3ab7451-fc5b-45f5-9b44-dd320cee4d59'},
#    {'id': '663', 'cId': '45f7566c-c8d5-46c2-9434-75b9e31f5d13'}],
#   'serp-third-l': [{'id': '72',
#     'cId': '22ef04a6-5637-4f62-bc53-06cdbda57c81',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-third-m': [{'id': '261',
#     'cId': '61fa6a70-c567-4282-b996-7b4ea0c409cc',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-third-s': [{'id': '261',
#     'cId': 'f915cbf0-2671-439b-9f1d-1177304d2d6b',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-third-xs': [{'id': '60',
#     'cId': '00205123-89b1-4aec-94f5-7ebe0d0bccb6',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fourth-l': [{'id': '69',
#     'cId': '7edb40e9-33df-4f78-9dee-b648b8adc16e',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fourth-m': [{'id': '91',
#     'cId': 'b7e8d18a-8ce2-4db5-98c1-36c0d772b102',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fourth-s': [{'id': '91',
#     'cId': '392a4f23-4339-4f81-864d-9731e40e7a92',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fourth-xs': [{'id': '59',
#     'cId': '130b87ec-4225-454d-96ed-c11a8f61f94d',
#     'pp': 'g',
#     'p2': 'hoyc'}],
#   'serp-fifth-l': [{'id': '158',
#     'cId': '5ef6bec6-78ae-40d7-aa6c-74df920c9a23',
#     'pp': 'g',
#     'p2': 'houd'}],
#   'serp-fifth-m': [{'id': '87',
#     'cId': '6f103d06-643b-43c1-b63f-5969a500f85b',
#     'pp': 'g',
#     'p2': 'hoxr'}],
#   'serp-fifth-s': [{'id': '87',
#     'cId': '16b2f952-7a7d-4f25-a17b-aef5d8dda70a',
#     'pp': 'g',
#     'p2': 'hoxs'}],
#   'serp-fifth-xs': [{'id': '19',
#     'cId': 'bc8ee17d-9031-4699-909b-300fe11b2fd3',
#     'pp': 'g',
#     'p2': 'hoyc'}]},
#  'bannersImage': {},
#  'cancelFetchBanners': False,
#  'candidates': {'collection': {'actions': [], 'filters': []},
#   'onlyAssessments': False},
#  'candidatesList': None,
#  'captchaAccountState': {'state': '', 'backurl': '', 'failurl': ''},
#  'catalogLinks': [],
#  'chatBot': {'messengers': [{'type': 'vk',
#     'icon': 'vk',
#     'href': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'},
#    {'type': 'telegram',
#     'icon': 'telegram',
#     'href': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'},
#    {'type': 'viber',
#     'icon': 'viber-mini',
#     'href': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'}],
#   'page': 'vacancysearch',
#   'genericUserType': 'anonymous',
#   'source': 'hhru'},
#  'chatik': None,
#  'chatikIntegration': False,
#  'chatikUnreadCount': 0,
#  'checkedTopics': [],
#  'checkedEmployerFAQLink': 'https://feedback.hh.ru/article/details/id/5951',
#  'clickmeInfo': None,
#  'commentsByUserId': {},
#  'companiesOfTheDay': [],
#  'config': {'staticHost': 'https://i.hh.ru',
#   'hhcdnHost': 'https://hhcdn.ru',
#   'imageResizingCdnHost': 'https://img.hhcdn.ru'},
#  'countryPhoneCode': '',
#  'contactPhones': [{'country': '+7',
#    'city': '495',
#    'number': '974-64-27',
#    'postfix': 'msk'},
#   {'country': '+7', 'city': '812', 'number': '458-45-45', 'postfix': 'spb'},
#   {'country': '8',
#    'city': '800',
#    'number': '100-64-27',
#    'postfix': 'regions'}],
#  'companiesOfTheDayTrls': {'area': ''},
#  'currencies': {'default': 'RUR',
#   'list': [{'code': 'RUR',
#     'name': 'руб.',
#     'gender': 'MASCULINE',
#     'rate': 1,
#     'defaultCurrency': True,
#     'site': True},
#    {'code': 'USD',
#     'name': 'USD',
#     'gender': 'MASCULINE',
#     'rate': 0.016312,
#     'defaultCurrency': False,
#     'site': True},
#    {'code': 'EUR',
#     'name': 'EUR',
#     'gender': 'MASCULINE',
#     'rate': 0.01618,
#     'defaultCurrency': False,
#     'site': True}]},
#  'complaintReasonTypes': [],
#  'competitorAnalysisBanner': {},
#  'chatWritePossibilities': [],
#  'criteriaCurrencyCode': 'RUR',
#  'crosslinks': None,
#  'currentManagerId': '',
#  'countryId': '1',
#  'defaultCountryCompanySearchId': '113',
#  'driverLicenseTypes': [],
#  'detectedVacancySearchAreaIds': ['58'],
#  'discriminationWarning': False,
#  'chatResponseId': None,
#  'displayType': 'DESKTOP',
#  'distances': None,
#  'domainRegionTrl': '',
#  'domainAreaId': '58',
#  'draftsPurchaseInfo': {},
#  'employerAddresses': [],
#  'employerAddressesCount': None,
#  'employerAddressesPage': {'addresses': [],
#   'addressesCount': 0,
#   'isFetching': False,
#   'loadingComponent': ''},
#  'employerArticles': [],
#  'employerBillingInfo': None,
#  'employerCarts': None,
#  'employerChecks': {},
#  'employerAdvice': None,
#  'employerAdvices': [],
#  'employerButtons': {},
#  'employerNegotiationsChangeTopic': None,
#  'employerCompanyMenu': [],
#  'employerConstructorWebViewMode': False,
#  'employerConstructorAutoAddWidget': None,
#  'employerConstructorSettings': {'pictureSettings': {}},
#  'employerConstructor': {'editMode': False,
#   'previewModeWithBranding': True,
#   'version': None,
#   'canEdit': False,
#   'modalError': None,
#   'widgets': [],
#   'widgetsOrder': [],
#   'saveStatus': 'DIRTY',
#   'hasUnsavedChanges': False,
#   'pictureId': None,
#   'resizeStatus': 'DIRTY',
#   'images': [],
#   'tabPrices': [],
#   'hasConstructor': False,
#   'hasService': False,
#   'readyToActivateCartId': None,
#   'sidebarColors': {}},
#  'employerDocuments': [],
#  'employerPageIsViewMode': False,
#  'employerCurrentDivision': None,
#  'employerDocumentsSettings': {},
#  'employerEdoList': [],
#  'employerDocumentsMenu': [],
#  'employerDepartments': [],
#  'employerDivisions': {},
#  'employerFaq': [],
#  'employerHasDivisions': False,
#  'employerId': '',
#  'employerImplants': None,
#  'employerName': '',
#  'employerIndexPage': {},
#  'employerLogo': {'logoUrl': None, 'logoStatus': 'Dirty'},
#  'edoDictionary': None,
#  'employerInfo': {'id': None,
#   'name': None,
#   'category': None,
#   'address': None,
#   'site': None,
#   'industries': None,
#   'hrBrand': None,
#   'description': None,
#   'saveDescriptionStatus': 'DIRTY',
#   'organizationFormId': None,
#   'isTrusted': False,
#   'canEditDescription': False,
#   'hasUnsavedChanges': False},
#  'employments': [],
#  'employerInsiders': [],
#  'employerInvoicePurchase': {'cart': {'cartId': None, 'services': []},
#   'activations': {'services': {}, 'currentActivationType': None}},
#  'employerReviewsModal': {'visible': False, 'reviewsEnabled': False},
#  'employerLastSearches': [],
#  'employersListQuery': None,
#  'employerSeoCities': [],
#  'employerSettingsVacancyPublication': {},
#  'employerInsiderInterview': None,
#  'employerManager': None,
#  'employerNoAdviceArticles': [],
#  'employerManagersPage': {'managersViewMeta': {'ableToCreateManager': False,
#    'canEditEmployerManagerQuotas': False,
#    'managersCreationLimitReached': True,
#    'onlyOneManagerEnabled': False,
#    'MCPSGroup': False,
#    'resumeViewsAccessDenied': True,
#    'ResumeViewHistory': False,
#    'showResumeViewsNumbers': False,
#    'giveMCPAllowed': False,
#    'userEmail': ''},
#   'managersShown': [],
#   'negotiationStats': {'politeness-index': {},
#    'responses-read-percent': {},
#    'responses-read-percent-change': {},
#    'responses-received': {},
#    'responses-replied-percent': {},
#    'responses-replied-percent-change': {},
#    'responses-reply-time-days': {}},
#   'resumeViews': {},
#   'filter': '',
#   'loading': False},
#  'employerManagersList': [],
#  'employerManagers': [],
#  'employerMarketSegmentType': None,
#  'employerConsumptionSegmentType': None,
#  'employersList': {'totalEmployersFound': 0, 'employers': [], 'paging': None},
#  'employersListOnReactEnabled': False,
#  'employerNews': [],
#  'employerExperiences': {'experience': []},
#  'employerReviewsApplicantProfileBadge': False,
#  'employerReviewsApplicantShowIndexWidget': False,
#  'employerReviewRating': {'ids': [], 'ratings': []},
#  'employerSearchSettings': {},
#  'employerSettingsMenu': {'employerManagersLink': '/employer/managers',
#   'menuItems': [],
#   'employerManagerName': ''},
#  'employerNegotiations': {'total': None,
#   'maximumTopicsPerUser': None,
#   'topicList': [],
#   'responseLetters': {}},
#  'employerStatus': {'category': '',
#   'state': '',
#   'countryId': '',
#   'suspiciousState': 'NOT_SUSPICIOUS'},
#  'employerViewSelectedAreas': [],
#  'enableSimilarSavedSearch': False,
#  'enableJobSearchStatus': False,
#  'experiments': {'enabled': {'tempexp_16565_b': 'control',
#    'tempexp_16927': 'control',
#    'tempexp_16565_c': 'control',
#    'tempexp_15905_linking_vacancies': 'control',
#    'tempexp_16565_a': 'control',
#    'tempexp_14535_b': 'experiment',
#    'tempexp_16177_v2': 'experiment',
#    'tempexp_16916_a': 'experiment',
#    'vacancy_partial_redesign_b': 'experiment'},
#   'checked': []},
#  'educationLevels': [],
#  'errorCode': None,
#  'excludedVacancyPublicationAreas': [],
#  'favoriteVacancies': {},
#  'fastVacanciesSubscriptionSettings': {},
#  'favoriteVacanciesCount': None,
#  'features': {'new_vacancy_suggest': True,
#   'delayed_cart_activation_article_id': '30085',
#   'max_vacancies_rendered_on_server': 20},
#  'filteredVacancyResponsesCount': None,
#  'floodlightGtagEnabled': False,
#  'floodlightUtm': {},
#  'financialDocumentDeeds': [],
#  'financialDocumentDeedsFilters': None,
#  'financialDocumentDeedsPaging': None,
#  'financialDocumentDeedsTotalRows': None,
#  'fetchingData': False,
#  'folderContent': None,
#  'footer': [{'name': 'footerNav',
#    'translations': {'name': '[RU:15:supernova.navi.footerNav]'},
#    'subItems': [{'name': 'site',
#      'translations': {'name': 'HeadHunter'},
#      'subItems': [{'name': 'copyright',
#        'translations': {'name': 'О компании'},
#        'url': '/article/28?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'hhCompanyInfo',
#        'translations': {'name': 'Наши вакансии'},
#        'url': '/employer/1455?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advertisingDescription',
#        'translations': {'name': 'Реклама на сайте'},
#        'url': 'https://ads.hh.ru/?from=footer_new&hhtmFromLabel=footer_new',
#        'external': True},
#       {'name': 'hardwareRequirements',
#        'translations': {'name': 'Требования к ПО'},
#        'url': '/article/176?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'dataProtection',
#        'translations': {'name': 'Защита персональных данных'},
#        'url': '/article/personal_data?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'safety',
#        'translations': {'name': 'Безопасный HeadHunter'},
#        'url': '/safety?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'compliance',
#        'translations': {'name': 'Этика и\xa0комплаенс'},
#        'url': '/article/compliance?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'api',
#        'translations': {'name': 'HeadHunter API'},
#        'url': 'https://dev.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'partners',
#        'translations': {'name': 'Партнерам'},
#        'url': '/partners?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'investor',
#        'translations': {'name': 'Инвесторам'},
#        'url': 'https://investor.hh.ru',
#        'external': True},
#       {'name': 'conditions',
#        'translations': {'name': 'Условия оказания услуг'},
#        'url': '/conditions?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'terms',
#        'translations': {'name': 'Условия использования сайтов'},
#        'url': '/terms?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'articles',
#      'translations': {'name': 'Новости и статьи'},
#      'url': '/articles',
#      'subItems': [{'name': 'hrNews',
#        'translations': {'name': 'Новости рынка HR'},
#        'url': '/articles/market-news/hr-news?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'articlesInsider',
#        'translations': {'name': 'Жизнь в компании'},
#        'url': '/articles/insider?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'itproject',
#        'translations': {'name': 'ИТ-проекты'},
#        'url': '/articles/applicants/it-projects?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'employersRating',
#        'translations': {'name': 'Рейтинг работодателей России'},
#        'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'applicantServices',
#      'translations': {'name': 'Сервисы для соискателей'},
#      'subItems': [{'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'advancementServices',
#        'translations': {'name': 'Все сервисы'},
#        'url': '/applicant-services/services/all?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'proforientation',
#        'translations': {'name': 'Профориентация'},
#        'url': '/article/proforientation_promo?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'ka',
#        'translations': {'name': 'Форум карьеристов'},
#        'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'findjob',
#        'translations': {'name': 'Продвижение резюме'},
#        'url': '/applicant/services/findjob?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'wantwork',
#        'translations': {'name': 'Хочу у вас работать'},
#        'url': '/article/98?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'calendar',
#        'translations': {'name': 'Производственный календарь'},
#        'url': '/calendar?from=footer_new&hhtmFromLabel=footer_new'}]},
#     {'name': 'forTeens',
#      'translations': {'name': 'Молодым специалистам'},
#      'subItems': [{'name': 'career',
#        'translations': {'name': 'Карьера для молодых специалистов'},
#        'url': '/students?from=footer_new&hhtmFromLabel=footer_new'},
#       {'name': 'school',
#        'translations': {'name': 'Школа программистов'},
#        'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True},
#       {'name': 'schoolProduct',
#        'translations': {'name': 'Школа продактов'},
#        'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#        'external': True}]},
#     {'name': 'additional',
#      'translations': {'name': '[RU:15:supernova.navi.additional]'},
#      'subItems': [{'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'anonymousCreateVacancy',
#          'translations': {'name': 'Поиск сотрудников'},
#          'url': '/employer?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'copiny',
#          'translations': {'name': 'Помощь'},
#          'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new',
#          'external': True},
#         {'name': 'agreement',
#          'translations': {'name': 'Пользовательское соглашение'},
#          'url': '/account/agreement?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'employersSearch',
#          'translations': {'name': 'Каталог компаний'},
#          'url': '/employers_company?from=footer_new&hhtmFromLabel=footer_new'},
#         {'name': 'catalog',
#          'translations': {'name': 'Работа по профессиям'},
#          'url': '/catalog?from=footer_new&hhtmFromLabel=footer_new'}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.footer.header.additionalSection]'},
#        'subItems': [{'name': 'chatBot',
#          'translations': {'name': 'Уведомления в\xa0мессенджер'},
#          'subItems': [{'name': 'chatBotTelegram',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotTelegram]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotViber',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotViber]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True},
#           {'name': 'chatBotVk',
#            'translations': {'name': '[RU:15:supernova.navi.chatBotVk]'},
#            'url': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=footer_anonymous',
#            'external': True}]}]},
#       {'name': 'additionalSection',
#        'translations': {'name': '[RU:15:supernova.navi.additionalSection]'},
#        'subItems': [{'name': 'lang',
#          'translations': {'name': '[RU:15:supernova.navi.lang]'}}]}]}]}],
#  'forbidden': False,
#  'globalInvitations': 2768561,
#  'getPageHtmlEnabled': False,
#  'globalStatistics': {'vacancies': 889338,
#   'employers': 1805265,
#   'resumes': 60030803},
#  'hasBrandedTemplates': False,
#  'hasEditSidebarButton': False,
#  'hasForceReloadDreamJob': False,
#  'hasListOfVacanciesByRoles': False,
#  'hasVacancyResponsesSummaryService': False,
#  'hasVideoInterview': False,
#  'hasChameleon': False,
#  'headerMenu': [{'name': 'menuLvl1',
#    'translations': {'name': '[RU:15:supernova.navi.menuLvl1]'},
#    'subItems': [{'name': 'mainContent',
#      'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#      'subItems': [{'name': 'switchers',
#        'translations': {'name': '[RU:15:supernova.navi.switchers]'},
#        'subItems': [{'name': 'areaSwitcher',
#          'translations': {'name': 'Липецк'}},
#         {'name': 'applicant',
#          'translations': {'name': 'Соискателям'},
#          'url': '/set_user_type?user_type=applicant&backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'active': True},
#         {'name': 'employer',
#          'translations': {'name': 'Работодателям'},
#          'url': '/set_user_type?user_type=employer&backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100',
#          'trackClicks': True}]},
#       {'name': 'fill',
#        'translations': {'name': '[RU:15:supernova.navi.fill]'}},
#       {'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме'},
#        'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#       {'name': 'careerconsult',
#        'translations': {'name': 'Карьерная консультация'},
#        'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#     {'name': 'applicantServices', 'translations': {'name': 'Все сервисы'}}]},
#   {'name': 'menuLvl2',
#    'translations': {'name': '[RU:15:supernova.navi.menuLvl2]'},
#    'subItems': [{'name': 'logo',
#      'translations': {'name': '[RU:15:supernova.navi.logo]'}},
#     {'name': 'help',
#      'translations': {'name': 'Помощь'},
#      'dropdown': True,
#      'subItems': [{'name': 'mainContent',
#        'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'vishnu',
#          'translations': {'name': 'Виртуальный консультант'}},
#         {'name': 'applicantHelp',
#          'translations': {'name': 'Вопросы и ответы'},
#          'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#          'external': True},
#         {'name': 'copiny',
#          'translations': {'name': 'Сообщество поддержки'},
#          'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#          'external': True},
#         {'name': 'writeToUs',
#          'translations': {'name': 'Пишите нам'},
#          'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#          'external': True}]},
#       {'name': 'supportChat',
#        'translations': {'name': 'Техподдержка онлайн'}}]},
#     {'name': 'userTypeSwitcher',
#      'translations': {'name': '[RU:15:supernova.navi.userTypeSwitcher]'},
#      'trackClicks': True,
#      'dropdown': True,
#      'subItems': [{'name': 'userTypeSwitcherApplicant',
#        'translations': {'name': 'Ищу работу'},
#        'url': '/set_user_type?user_type=applicant&backurl=%2F',
#        'trackClicks': True,
#        'active': True},
#       {'name': 'userTypeSwitcherEmployer',
#        'translations': {'name': 'Ищу сотрудника'},
#        'url': '/employer',
#        'trackClicks': True}]},
#     {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}},
#     {'name': 'searchVacancy',
#      'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'},
#      'url': '/search/vacancy/advanced'},
#     {'name': 'signup',
#      'translations': {'name': 'Создать резюме'},
#      'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'},
#     {'name': 'login',
#      'translations': {'name': 'Войти'},
#      'url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100'},
#     {'name': 'mobile',
#      'translations': {'name': '[RU:15:supernova.navi.mobile]'},
#      'url': '/mobile',
#      'dropdown': True,
#      'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Липецк'}},
#       {'name': 'mainContent',
#        'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#        'subItems': [{'name': 'help',
#          'translations': {'name': 'Помощь'},
#          'dropdown': True,
#          'subItems': [{'name': 'mainContent',
#            'translations': {'name': '[RU:15:supernova.navi.mainContent]'},
#            'subItems': [{'name': 'applicantHelp',
#              'translations': {'name': 'Вопросы и ответы'},
#              'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#              'external': True},
#             {'name': 'copiny',
#              'translations': {'name': 'Сообщество поддержки'},
#              'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new',
#              'external': True},
#             {'name': 'writeToUs',
#              'translations': {'name': 'Пишите нам'},
#              'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header',
#              'external': True}]},
#           {'name': 'supportChat',
#            'translations': {'name': 'Техподдержка онлайн'}}]},
#         {'name': 'signup',
#          'translations': {'name': 'Создать резюме'},
#          'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]},
#       {'name': 'applicantServices',
#        'translations': {'name': 'Все сервисы'},
#        'subItems': [{'name': 'advancementServices',
#          'translations': {'name': 'Продвижение резюме'},
#          'url': '/applicant-services/services/all',
#          'subItems': [{'name': 'expertresume',
#            'translations': {'name': 'Готовое резюме',
#             'description': 'Доверьте составление резюме профессионалам!'},
#            'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'careerconsult',
#            'translations': {'name': 'Карьерная консультация',
#             'description': 'Обсудите с\xa0экспертом, как эффективно искать работу'},
#            'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'interviewpractice',
#            'translations': {'name': 'Репетиция собеседования',
#             'description': 'Подготовьтесь к\xa0интервью вместе с\xa0карьерным экспертом'},
#            'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu',
#            'badge': 'new'},
#           {'name': 'applicantVacancyResponsesSummary',
#            'translations': {'name': 'Статистика по\xa0вакансии',
#             'description': 'Сравните себя с\xa0другими кандидатами, откликнувшимися на\xa0вакансию'},
#            'url': '/article/vacancy_summary?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'proforientation',
#            'translations': {'name': 'Профориентация',
#             'description': 'Узнайте, какой вы специалист и добейтесь большего'},
#            'url': '/article/proforientation_promo?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'findjob',
#            'translations': {'name': 'Продвижение резюме',
#             'description': 'Автоматическое поднятие резюме в\xa0результатах поиска'},
#            'url': '/applicant/services/findjob?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'wantwork',
#            'translations': {'name': 'Хочу у вас работать',
#             'description': 'Отправьте свое резюме в компанию мечты'},
#            'url': '/article/98?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#         {'name': 'educationServices',
#          'translations': {'name': 'Образование и консультации'},
#          'subItems': [{'name': 'applicantEduCenter',
#            'translations': {'name': 'Бесплатные вебинары'},
#            'url': '/article/applicant-free-webinars?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'articles',
#            'translations': {'name': 'Статьи'},
#            'url': '/articles?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'ka',
#            'translations': {'name': 'Форум карьеристов'},
#            'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'school',
#            'translations': {'name': 'Школа программистов'},
#            'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'itproject',
#            'translations': {'name': 'ИТ-проекты'},
#            'url': '/articles/applicants/it-projects?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'articlesInsider',
#            'translations': {'name': 'Жизнь в компании'},
#            'url': '/articles/insider?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'hhRatingAll',
#            'translations': {'name': 'Рейтинг работодателей России'},
#            'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True},
#           {'name': 'schoolProduct',
#            'translations': {'name': 'Школа продактов'},
#            'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#            'external': True}]},
#         {'name': 'beginnerServices',
#          'translations': {'name': 'Студентам и начинающим специалистам'},
#          'subItems': [{'name': 'career',
#            'translations': {'name': 'Карьера для молодых специалистов'},
#            'url': '/students?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#           {'name': 'rating',
#            'translations': {'name': 'Рейтинг факультетов и вузов'},
#            'url': '/rating?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#         {'name': 'beta',
#          'translations': {'name': 'Сервисы в\xa0разработке'},
#          'subItems': [{'name': 'betaApplicant',
#            'translations': {'name': 'Песочница',
#             'description': 'Попробуйте новые сервисы, которые, возможно, появятся на\xa0hh.ru в\xa0будущем'},
#            'url': '/article/beta_applicant?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]}]}]}]},
#   {'name': 'searchForm',
#    'translations': {'name': '[RU:15:supernova.navi.searchForm]'},
#    'subItems': [{'name': 'searchVacancy',
#      'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'},
#      'url': '/search/vacancy/advanced',
#      'action': '/search/vacancy'},
#     {'name': 'resumeSearch',
#      'translations': {'name': '[RU:15:supernova.navi.resumeSearch]'},
#      'url': '/search/resume/advanced',
#      'action': '/search/resume'},
#     {'name': 'employersList',
#      'translations': {'name': '[RU:15:supernova.navi.employersList]'},
#      'url': '/employers_list?areaId=113',
#      'action': '/employers_list'}]},
#   {'name': 'applicantServices',
#    'translations': {'name': 'Все сервисы'},
#    'subItems': [{'name': 'advancementServices',
#      'translations': {'name': 'Продвижение резюме'},
#      'url': '/applicant-services/services/all',
#      'subItems': [{'name': 'expertresume',
#        'translations': {'name': 'Готовое резюме',
#         'description': 'Доверьте составление резюме профессионалам!'},
#        'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'careerconsult',
#        'translations': {'name': 'Карьерная консультация',
#         'description': 'Обсудите с\xa0экспертом, как эффективно искать работу'},
#        'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'interviewpractice',
#        'translations': {'name': 'Репетиция собеседования',
#         'description': 'Подготовьтесь к\xa0интервью вместе с\xa0карьерным экспертом'},
#        'url': '/interview_practice?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu',
#        'badge': 'new'},
#       {'name': 'applicantVacancyResponsesSummary',
#        'translations': {'name': 'Статистика по\xa0вакансии',
#         'description': 'Сравните себя с\xa0другими кандидатами, откликнувшимися на\xa0вакансию'},
#        'url': '/article/vacancy_summary?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'proforientation',
#        'translations': {'name': 'Профориентация',
#         'description': 'Узнайте, какой вы специалист и добейтесь большего'},
#        'url': '/article/proforientation_promo?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'findjob',
#        'translations': {'name': 'Продвижение резюме',
#         'description': 'Автоматическое поднятие резюме в\xa0результатах поиска'},
#        'url': '/applicant/services/findjob?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'wantwork',
#        'translations': {'name': 'Хочу у вас работать',
#         'description': 'Отправьте свое резюме в компанию мечты'},
#        'url': '/article/98?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#     {'name': 'educationServices',
#      'translations': {'name': 'Образование и консультации'},
#      'subItems': [{'name': 'applicantEduCenter',
#        'translations': {'name': 'Бесплатные вебинары'},
#        'url': '/article/applicant-free-webinars?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'articles',
#        'translations': {'name': 'Статьи'},
#        'url': '/articles?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'ka',
#        'translations': {'name': 'Форум карьеристов'},
#        'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'school',
#        'translations': {'name': 'Школа программистов'},
#        'url': 'http://school.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'itproject',
#        'translations': {'name': 'ИТ-проекты'},
#        'url': '/articles/applicants/it-projects?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'articlesInsider',
#        'translations': {'name': 'Жизнь в компании'},
#        'url': '/articles/insider?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'hhRatingAll',
#        'translations': {'name': 'Рейтинг работодателей России'},
#        'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True},
#       {'name': 'schoolProduct',
#        'translations': {'name': 'Школа продактов'},
#        'url': 'https://productschool.hh.ru/?utm_source=hh.ru&utm_medium=referral&utm_campaign=menu_new',
#        'external': True}]},
#     {'name': 'beginnerServices',
#      'translations': {'name': 'Студентам и начинающим специалистам'},
#      'subItems': [{'name': 'career',
#        'translations': {'name': 'Карьера для молодых специалистов'},
#        'url': '/students?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'},
#       {'name': 'rating',
#        'translations': {'name': 'Рейтинг факультетов и вузов'},
#        'url': '/rating?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]},
#     {'name': 'beta',
#      'translations': {'name': 'Сервисы в\xa0разработке'},
#      'subItems': [{'name': 'betaApplicant',
#        'translations': {'name': 'Песочница',
#         'description': 'Попробуйте новые сервисы, которые, возможно, появятся на\xa0hh.ru в\xa0будущем'},
#        'url': '/article/beta_applicant?hhtmFrom=vacancy_search_list&hhtmFromLabel=menu'}]}]}],
#  'hideFooterServices': False,
#  'hhid': None,
#  'industriesTree': [],
#  'infoMoreResponsesBlock17168': {},
#  'infoTip': {'name': 'vacancy_search_rating_exp'},
#  'isLightPage': False,
#  'isMapVacancySearch': False,
#  'isNewEmployer': False,
#  'isNewVacancy': False,
#  'isWebView': False,
#  'isIFrame': False,
#  'isProfessionalRolesModeInResume': False,
#  'langs': ['RU'],
#  'languages': {'language': []},
#  'languageLevels': {'level': []},
#  'lastUpdatedSearchQueryText': '',
#  'loyaltySurvey': {'showNotification': False,
#   'removeFromUserNotifications': False,
#   'showBanner': False,
#   'runSurvey': False},
#  'locale': {'areaId': '113',
#   'domainAreaId': '58',
#   'host': 'voronezh.hh.ru',
#   'protocolHost': 'https://lipetsk.hh.ru',
#   'isSeoDomain': True,
#   'platform': 'HEADHUNTER',
#   'availableLanguages': ['EN', 'RU'],
#   'siteLanguage': 'RU'},
#  'logos': {'logoDomain': 'hh-ru', 'smallLogoDomain': 'hh.ru'},
#  'loginError': None,
#  'loginTileType': None,
# ...
#     'lastChangeTime': {'@timestamp': 1657631541,
#      '$': '2022-07-12T16:12:21.929+03:00'},
#     'creationTime': '2022-07-12T11:28:05.835+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 140703040,
#      '@managerId': 10820471,
#      '@userId': 118497695,
#      'latestActivity': 'online'},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': True,
#     'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67691101',
#      'mobile': 'https://m.hh.ru/vacancy/67691101'},
#     'workSchedule': 'FULL_DAY',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 6253113,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_6253113'},
#     'vacancyProperties': {'properties': [{}]},
#     'publicationType': 'STANDARD',
#     'vacancyPlatforms': ['HH'],
#     'userLabels': [],
#     'snippet': {'req': 'Уверенное знание баз данных, MS Visual Studio. Владение SQL (для разработки хранилища данных), DAX, Power Query (M), Excel. ',
#      'resp': 'Разработка и поддержка отчетности на OLAP-кубах - получение ТЗ, импорт данных, агрегирование, формирование куба и его настройка. Умение и готовность...',
#      'cond': '32 года успешной истории. Собственное российское производство. Широкий ассортиментный портфель 500 SKU: собственные бренды жевательный мармелад «Фру-Фру», воздушный зефир...',
#      'skill': 'MS SQL, MS Visual Studio, MS SQL Server, Transact-SQL',
#      'desc': None},
#     'responsesCount': 9,
#     'online_users_count': 5},
#    {'@responseLetterRequired': False,
#     '@showContact': False,
#     'vacancyId': 67107178,
#     'name': 'Аналитик данных',
#     'company': {'@showSimilarVacancies': True,
#      '@trusted': True,
#      '@category': 'COMPANY',
#      '@countryId': 1,
#      '@state': 'APPROVED',
#      'id': 4482374,
#      'name': 'Медиапоинт',
#      'visibleName': 'Медиапоинт',
#      'logos': {'logo': [{'@type': 'searchResultsPage',
#         '@url': '/employer-logo/3310392.png'},
#        {'@type': 'small', '@url': '/employer-logo/3310392.png'},
#        {'@type': 'employerPage', '@url': '/employer-logo/3310391.png'},
#        {'@type': 'vacancyPage', '@url': '/employer-logo/3310393.png'},
#        {'@type': 'medium', '@url': '/employer-logo/3310393.png'},
#        {'@type': 'ORIGINAL', '@url': '/employer-logo-original/717319.png'}]},
#      'employerOrganizationFormId': 0,
#      'companySiteUrl': ''},
#     'compensation': {'noCompensation': {}},
#     'publicationTime': {'@timestamp': 1657522219,
#      '$': '2022-07-11T09:50:19.068+03:00'},
#     'type': 'open',
#     'area': {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'},
#     'acceptTemporary': False,
#     'address': {'@id': 7589118,
#      '@disabled': False,
#      'city': 'Москва',
#      'street': 'Замоскворецкая линия',
#      'building': 'метро Технопарк',
#      'displayName': 'Москва, Замоскворецкая линия, метро Технопарк',
#      'mapData': '{"points":{"center":{"lat":55.69407835366061,"lng":37.66337178647499,"zoom":17},"marker":{"lat":55.69448244302192,"lng":37.66331220104883}}}',
#      'marker': {'@lat': 55.69448244302192, '@lng': 37.66331220104883},
#      'manager': {'@id': 7315317}},
#     'metallic': 'standard_plus',
#     'creationSite': 'hh.ru',
#     'creationSiteId': 1,
#     'displayHost': 'lipetsk.hh.ru',
#     'lastChangeTime': {'@timestamp': 1657615577,
#      '$': '2022-07-12T11:46:17.567+03:00'},
#     'creationTime': '2022-06-23T09:50:19.068+03:00',
#     'canBeShared': True,
#     'employerManager': {'@hhid': 141416960,
#      '@managerId': 10897548,
#      '@userId': 119208376},
#     'inboxPossibility': True,
#     'chatWritePossibility': 'ENABLED_AFTER_INVITATION',
#     'notify': False,
#     'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/67107178',
#      'mobile': 'https://m.hh.ru/vacancy/67107178'},
#     'workSchedule': 'FLEXIBLE',
#     'acceptIncompleteResumes': False,
#     'driverLicenseTypes': [{}],
#     'languages': [{'language': [{'id': 57, 'degree': 'b1'}]}],
#     'workingDays': [{}],
#     'workingTimeIntervals': [{}],
#     'workingTimeModes': [{}],
#     'hrBotScenario': {'hrBotScenarioId': 5320731,
#      'enabled': False,
#      'scenarioCode': 'vacancy_scenario_5320731'},
#     'vacancyProperties': {'properties': [{}]},
#     'publicationType': 'STANDARD_PLUS',
#     'vacancyPlatforms': ['HH'],
#     'contactInfo': None,
#     'userLabels': [],
#     'snippet': {'req': 'Опыт работы с данными. Знание основ математической статистики, теории вероятности и методов машинного обучения. Опыт в работе с PowerBI или...',
#      'resp': 'Строить скоринговые модели. Участвовать в развитии инфраструктуры. Разработка ML-сервисов. Статистический анализ данных. Строить дашборды.',
#      'cond': 'Динамичный и быстроразвивающийся бизнес, ресурсы, возможность сделать вместе лучший продукт на рынке. Свободу действий в принятии решений. Достойный уровень заработной...',
#      'skill': 'Python, SQL, Git, Математическая статистика, Статистический анализ',
#      'desc': None},
#     'responsesCount': 281,
#     'online_users_count': 1}],
#   'vacanciesCounts': 101,
#   'hasVacanciesWithAddress': True,
#   'isClustersEnabled': True,
#   'clustersCount': 0,
#   'paging': {'previous': {'page': -1, 'disabled': True},
#    'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#     {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True},
#     {'text': '3', 'page': 2, 'selected': False, 'inShortRange': True},
#     {'text': '4', 'page': 3, 'selected': False, 'inShortRange': False},
#     {'text': '5', 'page': 4, 'selected': False, 'inShortRange': False},
#     {'text': '...', 'page': 5, 'selected': False, 'inShortRange': False}],
#    'lastPage': {'page': 19, 'selected': False},
#    'next': {'page': 1, 'disabled': False},
#    'os': 'Win'},
#   'queries': {'effective': 'clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'currentAndInternalParams': 'clusters=true&control_flag=vacancyBlacklistJoinEnabled%3ATrue&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'enableSnippets': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'disableSnippets': 'clusters=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'legacy': 'clusters=true&itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'currentParams': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'rss': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'map': 'clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'dynamicMap': 'clusters=true&enable_snippets=true&items_on_page=100&label=with_address&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'legacyRss': 'clusters=true&itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'autosearch': 'enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'legacyAutosearch': 'itemsOnPage=100&searchfield=vacancyname&searchfield=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'pagingBase': 'L_is_autosearch=false&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'orderByBase': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'searchPeriodBase': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'itemsOnPageBase': 'clusters=true&enable_snippets=true&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#    'searchWizardBase': 'L_is_autosearch=false&clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true'},
#   'queryRanks': [{'q1': 'аналитик данных',
#     'q2': 'анализ данных',
#     'cfRank': 0.6047485761861048,
#     'overlapRank': 0.7653477049958979,
#     'qrqRank': 0.8865696694545233,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85'},
#    {'q1': 'аналитик данных',
#     'q2': 'аналитик',
#     'cfRank': 0.2732704374931112,
#     'overlapRank': 0.4875271222850728,
#     'qrqRank': 0.9101740077943576,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA'},
#    {'q1': 'аналитик данных',
#     'q2': 'обработка данных',
#     'cfRank': 0,
#     'overlapRank': 0.7860996264950991,
#     'qrqRank': 0.8709223209142322,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%BE%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85'},
#    {'q1': 'аналитик данных',
#     'q2': 'специалист по обработке данных',
#     'cfRank': 0,
#     'overlapRank': 0.7282137883760094,
#     'qrqRank': 0.8642197382307852,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D1%81%D0%BF%D0%B5%D1%86%D0%B8%D0%B0%D0%BB%D0%B8%D1%81%D1%82+%D0%BF%D0%BE+%D0%BE%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B5+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85'},
#    {'q1': 'аналитик данных',
#     'q2': 'хранилища данных',
#     'cfRank': 0,
#     'overlapRank': 0.6980601494019604,
#     'qrqRank': 0.8920614989030893,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D1%85%D1%80%D0%B0%D0%BD%D0%B8%D0%BB%D0%B8%D1%89%D0%B0+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85'},
#    {'q1': 'аналитик данных',
#     'q2': 'data analyst',
#     'cfRank': 0.7167307333657004,
#     'overlapRank': 0,
#     'qrqRank': 0.868801683841473,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=data+analyst'},
#    {'q1': 'аналитик данных',
#     'q2': 'spss',
#     'cfRank': 0.6493525760991484,
#     'overlapRank': 0,
#     'qrqRank': 0.9354513169348813,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=spss'},
#    {'q1': 'аналитик данных',
#     'q2': 'аналитик bi',
#     'cfRank': 0.5135501163803148,
#     'overlapRank': 0,
#     'qrqRank': 0.9213036076081011,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+bi'},
#    {'q1': 'аналитик данных',
#     'q2': 'sas',
#     'cfRank': 0.2835251774690151,
#     'overlapRank': 0,
#     'qrqRank': 0.865822520438148,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=sas'},
#    {'q1': 'аналитик данных',
#     'q2': 'аналитик отчетность',
#     'cfRank': 0,
#     'overlapRank': 0,
#     'qrqRank': 0.9593479650871666,
#     'q2DocumentCount': 0,
#     'href': 'clusters=true&enable_snippets=true&items_on_page=100&ored_clusters=true&search_field=name&search_field=description&text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%BE%D1%82%D1%87%D0%B5%D1%82%D0%BD%D0%BE%D1%81%D1%82%D1%8C'}],
#   'totalResults': 10627,
#   'enableNovaFilters': True,
#   'enableSimilarSavedSearch': False,
#   'fixes': {},
#   'suggests': {},
#   'catalogLinks': []},
#  'vacancyStat': None,
#  'vacancyTests': {},
#  'vacancyView': {'company': {}, 'features': []},
#  'vacancyWizard': {'totalEmployersFound': 0,
#   'employerHits': [],
#   'rootAreaId': 0},
#  'vacancyTemplates': [],
#  'vacancyTemplateForEdit': None,
#  'vacancyClickmeLanding': None,
#  'vacancyViewsCount': None,
#  'vacancyConstructor': {'vacancyBrandedTemplates': [], 'expirationTime': None},
#  'vacancyConstructorBackOfficeView': None,
#  'vacancyConstructorTemplateMode': None,
#  'vacancyConstructorMobilePreview': {'templateId': None},
#  'vacancyConstructorSettings': None,
#  'vacation': None,
#  'vacancyResponsePopup': {},
#  'vacancyResponseSummary': None,
#  'vacancyMessages': [],
#  'vacancyFeedback': None,
#  'vrSignupLogin': {},
#  'vrVacancies': None,
#  'wantWorkEmployer': {'employerInfo': {'id': None, 'name': ''},
#   'employerLogo': {'logoUrl': None}},
#  'wheelOfFortuneDataUrl': None,
#  'workInOtherCity': None,
#  'xsrfToken': 'fe1ada2697af8ee0c22481e316ea8664',
#  'employerDivisionChangelog': {'changes': []},
#  'serviceAdditional': {'serviceNames': {}},
#  'supernovaAnonymousDashboard': {'backgroundScope': '',
#   'backgroundIndex': '',
#   'bigPromoEmployerId': '',
#   'bigPromoSlogan': '',
#   'bigPromoLinkText': '',
#   'bigPromoLinkUrl': '',
#   'bigPromoFootnote': None},
#  'pinnedChatMessages': {'hasMore': False, 'items': []},
#  'preparedVacancyTemplates': [],
#  'snippetAccessResume': {'productList': [],
#   'area': '',
#   'isShowSnippetResume': False},
#  'zpEmployerOnboarding': {'showOnboardingModal': False},
#  'zpCrossPostInfo': None,
#  'accountHistoryActionsData': None,
#  'accountHistoryMoney': {'hasPersonalManager': False,
#   'state': '',
#   'email': '',
#   'agreements': {},
#   'currency': '',
#   'hrs': {'orders': []},
#   'balances': {},
#   'employerCountry': '',
#   'availableWithoutBlockedMoney': 0},
#  'scheduleInterviewRemindInfo': None,
#  'router': {'location': {'pathname': '/search/vacancy',
#    'search': '?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100',
#    'hash': '',
#    'key': 'xlri6q',
#    'query': {'text': '%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#     'search_field': 'description',
#     'salary': '',
#     'currency_code': 'RUR',
#     'experience': 'doesNotMatter',
#     'order_by': 'relevance',
#     'search_period': '0',
#     'items_on_page': '100'}},
#   'action': 'POP'}}

# %% [markdown]
# #### Analyzing page structure

# %% [markdown]
# We've got a huge amount of 'empty' data structures after translating page to json format. There are empty dictionaries and dictionaries containing 'empty' data structures. So I'll clean out these artifacts to make the visual analysis of data more efficient.

# %%
# Function to check if dictionary is 'empty'
def is_dict_empty(input_dict):
    result = True
    for key in input_dict.keys():
        if (type(input_dict[key]) is type(dict())) and (len(input_dict[key]) > 0):
            # Рекуррентная проверка словарей
            result = result and is_dict_empty(input_dict[key])
        else:
            # "Пустыми" считать структуры, длина которых равна 0, имеющие значение None или являющиеся пустым словарем или списком
            checks_empty = (input_dict[key] is None) or (str(input_dict[key]) in ['{}', '[]']) or (len(str(input_dict[key])) == 0)
            result = result and checks_empty
        if not result:
            break
    return result

# %%
clean_dict = {}
for key in json_parsed.keys():
    if (type(json_parsed[key]) is type(dict())):
        if not is_dict_empty(json_parsed[key]):
            clean_dict[key] = json_parsed[key]
    else:
        checks_empty = (json_parsed[key] is None) or (str(json_parsed[key]) in ['{}', '[]']) or (len(str(json_parsed[key])) == 0)
        if not checks_empty:
            clean_dict[key] = json_parsed[key]
print('{} non-empty keys in result'.format(len(clean_dict)))
print('====================================================')
for key in clean_dict.keys():
    print('{} ====> {}'.format(key, clean_dict[key]))
# Out:
# 183 non-empty keys in result
# ====================================================
# applicantSignup ====> {'fields': [], 'hideLogin': False}
# applicantPackageType ====> basic
# applicantPaymentSource ====> desktop
# accountHistoryReplenishments ====> {'bills': [], 'documentLinksVisibility': False, 'currency': 'RUR'}
# accountDelete ====> {'applicantName': '', 'resumesList': {'resumes': {'published': [], 'unpublished': []}, 'count': 0}}
# adsSearchParams ====> {'puid11': 'searchVacancy', 'puid23': '', 'puid14': 'аналитик данных', 'puid29': '', 'puid30': '', 'puid12': '', 'puid13': ''}
# advancedSearch ====> {'showSearchConditions': False, 'hideSuggest': False, 'vacancy': None, 'resume': None, 'experience': [], 'keySkills': [], 'university': [], 'citizenship': [], 'work_ticket': [], 'employment': [], 'schedule': [], 'driver_license_types': [], 'job_search_status': [], 'language': [], 'exclusion': []}
# appleBusinessChat ====> {'isEnabled': False, 'href': ''}
# abortPageContent ====> False
# addressesSuggestRemoteMode ====> False
# analyticsParams ====> {'hhtmSource': 'vacancy_search_list', 'hhtmFrom': '', 'hhtmSourceLabel': '', 'hhtmFromLabel': '', 'screenType': 'SIMPLE'}
# applicantInfo ====> {'total': 0, 'finished': 0, 'visible': 0, 'searchable': 0}
# applicantNegotiations ====> {'topicList': [], 'filterInUse': 'all'}
# authUrl ====> {'login-url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'login-form': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'login-field-value': '', 'backurl-field-name': 'backUrl', 'remember-field-name': 'remember', 'remember-field-value': 'yes', 'backurl': 'https://lipetsk.hh.ru/search/vacancy?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'failurl': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'signup-form': '/account/signup?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'auth-employer-url': '/auth/employer/?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'remember-password': '/account/remember_password?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'agreement-form': '/account/agreement?backurl=%2Faccount%2Fsignup%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253D%2525D0%2525B0%2525D0%2525BD%2525D0%2525B0%2525D0%2525BB%2525D0%2525B8%2525D1%252582%2525D0%2525B8%2525D0%2525BA%252B%2525D0%2525B4%2525D0%2525B0%2525D0%2525BD%2525D0%2525BD%2525D1%25258B%2525D1%252585%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100', 'employer-agreement': '/auth/employer/agreement?backurl=%2Fauth%2Femployer%2F%3Fbackurl%3D%252Fsearch%252Fvacancy%253Ftext%253D%2525D0%2525B0%2525D0%2525BD%2525D0%2525B0%2525D0%2525BB%2525D0%2525B8%2525D1%252582%2525D0%2525B8%2525D0%2525BA%252B%2525D0%2525B4%2525D0%2525B0%2525D0%2525BD%2525D0%2525BD%2525D1%25258B%2525D1%252585%2526search_field%253Dname%2526search_field%253Ddescription%2526salary%253D%2526currency_code%253DRUR%2526experience%253DdoesNotMatter%2526order_by%253Drelevance%2526search_period%253D0%2526items_on_page%253D100'}
# emailVerification ====> {'email': '', 'needVerification': False, 'mailURL': ''}
# loginForm ====> {'passwordRecovery': {'trl': 'Получить пароль'}, 'registration': [{'trl': 'Соискателя', 'code': 'REG_APPLICANT', 'translationKey': 'account.login.registration.applicant.capitalized'}, {'trl': 'Работодателя', 'code': 'REG_EMPLOYER', 'translationKey': 'account.login.registration.employer.capitalized'}], 'socialNetworks': [{'trl': 'Мой Мир@mail.ru', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=MAIL&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list', 'code': 'MAIL', 'translationKey': 'socialNetworkTitle.mail'}, {'trl': 'Одноклассники', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=OK&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list', 'code': 'OK', 'translationKey': 'socialNetworkTitle.ok'}, {'trl': 'ВКонтакте', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=VK&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list', 'code': 'VK', 'translationKey': 'socialNetworkTitle.vk'}, {'trl': 'Google', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=GPLUS&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list', 'code': 'GPLUS', 'translationKey': 'socialNetworkTitle.gplus'}, {'trl': 'Доктор на работе', 'url': '/account/connect?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100&site=DNR&_xsrf=fe1ada2697af8ee0c22481e316ea8664&hhtmSource=vacancy_search_list', 'code': 'DNR', 'translationKey': 'socialNetworkTitle.dnr'}]}
# backofficeCanEditTemplate ====> True
# banners ====> {'under-pagination-search-results-l': [{'id': '293', 'cId': '05145823-bd1f-4820-8401-993236eda193', 'pp': 'g', 'p2': 'houd'}], 'under-pagination-search-results-m': [{'id': '294', 'cId': 'a7f0d630-8462-461e-b1db-76512f798ca3', 'pp': 'g', 'p2': 'hoxr'}], 'under-pagination-search-results-s': [{'id': '292', 'cId': '4faf8bef-0c4f-4498-850a-e0ea7860fe08', 'pp': 'g', 'p2': 'hoxs'}], 'under-pagination-search-results-xs': [{'id': '521', 'cId': '3daed3f9-441b-4816-ab7b-d271bd6f8680', 'pp': 'g', 'p2': 'hoyc'}], 'under-search-results-rotate': [{'id': '654', 'cId': '5bf1d6f9-0dc0-4a07-863b-dc4fe410921d'}, {'id': '655', 'cId': 'b443c3fc-f65e-4d4c-9045-cdeb13756315'}], 'serp-first-l': [{'id': '221', 'cId': 'b21e020b-61c4-4490-b16e-a9db4dc1e865', 'pp': 'g', 'p2': 'houd'}], 'serp-first-m': [{'id': '637', 'cId': '4eaf2fd0-1686-4d62-963a-2523c39b0718', 'pp': 'g', 'p2': 'hoxr'}], 'serp-first-s': [{'id': '613', 'cId': 'a1167275-28a2-4db1-942b-ba7333d82d77', 'pp': 'g', 'p2': 'hoxs'}], 'serp-first-xs': [{'id': '630', 'cId': 'b2c13c21-e012-4d5a-8cba-51a3f347b417', 'pp': 'g', 'p2': 'hoyc'}], 'serp-second-l': [{'id': '175', 'cId': '8e0c2279-587b-4374-9b19-a1680b126698', 'pp': 'g', 'p2': 'houd'}], 'serp-second-m': [{'id': '347', 'cId': '496e576c-47af-479d-bab0-9b2f9d5310aa', 'pp': 'g', 'p2': 'hoxr'}], 'serp-second-s': [{'id': '638', 'cId': 'd84ca539-5483-47ed-aa3e-cafd82e2cac0', 'pp': 'g', 'p2': 'hoxs'}], 'serp-second-xs': [{'id': '505', 'cId': 'e2788b88-1f8d-45d3-a164-a9d96283a7a8', 'pp': 'g', 'p2': 'hoyc'}], 'under-search-results-xs': [{'id': '661', 'cId': '9fad8592-a619-46b3-82fa-8f17a3942387'}, {'id': '662', 'cId': 'a3ab7451-fc5b-45f5-9b44-dd320cee4d59'}, {'id': '663', 'cId': '45f7566c-c8d5-46c2-9434-75b9e31f5d13'}], 'serp-third-l': [{'id': '72', 'cId': '22ef04a6-5637-4f62-bc53-06cdbda57c81', 'pp': 'g', 'p2': 'houd'}], 'serp-third-m': [{'id': '261', 'cId': '61fa6a70-c567-4282-b996-7b4ea0c409cc', 'pp': 'g', 'p2': 'hoxr'}], 'serp-third-s': [{'id': '261', 'cId': 'f915cbf0-2671-439b-9f1d-1177304d2d6b', 'pp': 'g', 'p2': 'hoxs'}], 'serp-third-xs': [{'id': '60', 'cId': '00205123-89b1-4aec-94f5-7ebe0d0bccb6', 'pp': 'g', 'p2': 'hoyc'}], 'serp-fourth-l': [{'id': '69', 'cId': '7edb40e9-33df-4f78-9dee-b648b8adc16e', 'pp': 'g', 'p2': 'houd'}], 'serp-fourth-m': [{'id': '91', 'cId': 'b7e8d18a-8ce2-4db5-98c1-36c0d772b102', 'pp': 'g', 'p2': 'hoxr'}], 'serp-fourth-s': [{'id': '91', 'cId': '392a4f23-4339-4f81-864d-9731e40e7a92', 'pp': 'g', 'p2': 'hoxs'}], 'serp-fourth-xs': [{'id': '59', 'cId': '130b87ec-4225-454d-96ed-c11a8f61f94d', 'pp': 'g', 'p2': 'hoyc'}], 'serp-fifth-l': [{'id': '158', 'cId': '5ef6bec6-78ae-40d7-aa6c-74df920c9a23', 'pp': 'g', 'p2': 'houd'}], 'serp-fifth-m': [{'id': '87', 'cId': '6f103d06-643b-43c1-b63f-5969a500f85b', 'pp': 'g', 'p2': 'hoxr'}], 'serp-fifth-s': [{'id': '87', 'cId': '16b2f952-7a7d-4f25-a17b-aef5d8dda70a', 'pp': 'g', 'p2': 'hoxs'}], 'serp-fifth-xs': [{'id': '19', 'cId': 'bc8ee17d-9031-4699-909b-300fe11b2fd3', 'pp': 'g', 'p2': 'hoyc'}]}
# cancelFetchBanners ====> False
# candidates ====> {'collection': {'actions': [], 'filters': []}, 'onlyAssessments': False}
# chatBot ====> {'messengers': [{'type': 'vk', 'icon': 'vk', 'href': 'https://chatbot.hh.ru/hh-bot/vk?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'}, {'type': 'telegram', 'icon': 'telegram', 'href': 'https://chatbot.hh.ru/hh-bot/telegram?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'}, {'type': 'viber', 'icon': 'viber-mini', 'href': 'https://chatbot.hh.ru/hh-bot/viber?utm_source=hhru&utm_medium=referral&utm_campaign=search_vacancy_page_autosearch_bot_anonymous&command=save_search&search_url=https%3A//lipetsk.hh.ru/search/vacancy%3Fenable_snippets%3Dtrue%26items_on_page%3D100%26ored_clusters%3Dtrue%26search_field%3Dname%26search_field%3Ddescription%26text%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585'}], 'page': 'vacancysearch', 'genericUserType': 'anonymous', 'source': 'hhru'}
# chatikIntegration ====> False
# chatikUnreadCount ====> 0
# checkedEmployerFAQLink ====> https://feedback.hh.ru/article/details/id/5951
# config ====> {'staticHost': 'https://i.hh.ru', 'hhcdnHost': 'https://hhcdn.ru', 'imageResizingCdnHost': 'https://img.hhcdn.ru'}
# contactPhones ====> [{'country': '+7', 'city': '495', 'number': '974-64-27', 'postfix': 'msk'}, {'country': '+7', 'city': '812', 'number': '458-45-45', 'postfix': 'spb'}, {'country': '8', 'city': '800', 'number': '100-64-27', 'postfix': 'regions'}]
# currencies ====> {'default': 'RUR', 'list': [{'code': 'RUR', 'name': 'руб.', 'gender': 'MASCULINE', 'rate': 1, 'defaultCurrency': True, 'site': True}, {'code': 'USD', 'name': 'USD', 'gender': 'MASCULINE', 'rate': 0.016312, 'defaultCurrency': False, 'site': True}, {'code': 'EUR', 'name': 'EUR', 'gender': 'MASCULINE', 'rate': 0.01618, 'defaultCurrency': False, 'site': True}]}
# criteriaCurrencyCode ====> RUR
# countryId ====> 1
# defaultCountryCompanySearchId ====> 113
# detectedVacancySearchAreaIds ====> ['58']
# discriminationWarning ====> False
# displayType ====> DESKTOP
# domainAreaId ====> 58
# employerAddressesPage ====> {'addresses': [], 'addressesCount': 0, 'isFetching': False, 'loadingComponent': ''}
# employerConstructorWebViewMode ====> False
# employerConstructor ====> {'editMode': False, 'previewModeWithBranding': True, 'version': None, 'canEdit': False, 'modalError': None, 'widgets': [], 'widgetsOrder': [], 'saveStatus': 'DIRTY', 'hasUnsavedChanges': False, 'pictureId': None, 'resizeStatus': 'DIRTY', 'images': [], 'tabPrices': [], 'hasConstructor': False, 'hasService': False, 'readyToActivateCartId': None, 'sidebarColors': {}}
# employerPageIsViewMode ====> False
# employerHasDivisions ====> False
# employerLogo ====> {'logoUrl': None, 'logoStatus': 'Dirty'}
# employerInfo ====> {'id': None, 'name': None, 'category': None, 'address': None, 'site': None, 'industries': None, 'hrBrand': None, 'description': None, 'saveDescriptionStatus': 'DIRTY', 'organizationFormId': None, 'isTrusted': False, 'canEditDescription': False, 'hasUnsavedChanges': False}
# employerReviewsModal ====> {'visible': False, 'reviewsEnabled': False}
# employerManagersPage ====> {'managersViewMeta': {'ableToCreateManager': False, 'canEditEmployerManagerQuotas': False, 'managersCreationLimitReached': True, 'onlyOneManagerEnabled': False, 'MCPSGroup': False, 'resumeViewsAccessDenied': True, 'ResumeViewHistory': False, 'showResumeViewsNumbers': False, 'giveMCPAllowed': False, 'userEmail': ''}, 'managersShown': [], 'negotiationStats': {'politeness-index': {}, 'responses-read-percent': {}, 'responses-read-percent-change': {}, 'responses-received': {}, 'responses-replied-percent': {}, 'responses-replied-percent-change': {}, 'responses-reply-time-days': {}}, 'resumeViews': {}, 'filter': '', 'loading': False}
# employersList ====> {'totalEmployersFound': 0, 'employers': [], 'paging': None}
# employersListOnReactEnabled ====> False
# employerReviewsApplicantProfileBadge ====> False
# employerReviewsApplicantShowIndexWidget ====> False
# employerSettingsMenu ====> {'employerManagersLink': '/employer/managers', 'menuItems': [], 'employerManagerName': ''}
# employerStatus ====> {'category': '', 'state': '', 'countryId': '', 'suspiciousState': 'NOT_SUSPICIOUS'}
# enableSimilarSavedSearch ====> False
# enableJobSearchStatus ====> False
# experiments ====> {'enabled': {'tempexp_16565_b': 'control', 'tempexp_16927': 'control', 'tempexp_16565_c': 'control', 'tempexp_15905_linking_vacancies': 'control', 'tempexp_16565_a': 'control', 'tempexp_14535_b': 'experiment', 'tempexp_16177_v2': 'experiment', 'tempexp_16916_a': 'experiment', 'vacancy_partial_redesign_b': 'experiment'}, 'checked': []}
# features ====> {'new_vacancy_suggest': True, 'delayed_cart_activation_article_id': '30085', 'max_vacancies_rendered_on_server': 20}
# floodlightGtagEnabled ====> False
# fetchingData ====> False
# footer ====> [{'name': 'footerNav', 'translations': {'name': '[RU:15:supernova.navi.footerNav]'}, 'subItems': [{'name': 'site', 'translations': {'name': 'HeadHunter'}, 'subItems': [{'name': 'copyright', 'translations': {'name': 'О компании'}, 'url': '/article/28?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'hhCompanyInfo', 'translations': {'name': 'Наши вакансии'}, 'url': '/employer/1455?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'advertisingDescription', 'translations': {'name': 'Реклама на сайте'}, 'url': 'https://ads.hh.ru/?from=footer_new&hhtmFromLabel=footer_new', 'external': True}, {'name': 'hardwareRequirements', 'translations': {'name': 'Требования к ПО'}, 'url': '/article/176?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'dataProtection', 'translations': {'name': 'Защита персональных данных'}, 'url': '/article/personal_data?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'safety', 'translations': {'name': 'Безопасный HeadHunter'}, 'url': '/safety?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'compliance', 'translations': {'name': 'Этика и\xa0комплаенс'}, 'url': '/article/compliance?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'api', 'translations': {'name': 'HeadHunter API'}, 'url': 'https://dev.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}, {'name': 'partners', 'translations': {'name': 'Партнерам'}, 'url': '/partners?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'investor', 'translations': {'name': 'Инвесторам'}, 'url': 'https://investor.hh.ru', 'external': True}, {'name': 'conditions', 'translations': {'name': 'Условия оказания услуг'}, 'url': '/conditions?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'terms', 'translations': {'name': 'Условия использования сайтов'}, 'url': '/terms?from=footer_new&hhtmFromLabel=footer_new'}]}, {'name': 'articles', 'translations': {'name': 'Новости и статьи'}, 'url': '/articles', 'subItems': [{'name': 'hrNews', 'translations': {'name': 'Новости рынка HR'}, 'url': '/articles/market-news/hr-news?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'articlesInsider', 'translations': {'name': 'Жизнь в компании'}, 'url': '/articles/insider?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'itproject', 'translations': {'name': 'ИТ-проекты'}, 'url': '/articles/applicants/it-projects?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'employersRating', 'translations': {'name': 'Рейтинг работодателей России'}, 'url': 'https://rating.hh.ru/poll?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}]}, {'name': 'applicantServices', 'translations': {'name': 'Сервисы для соискателей'}, 'subItems': [{'name': 'expertresume', 'translations': {'name': 'Готовое резюме'}, 'url': '/article/expert_resume?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'advancementServices', 'translations': {'name': 'Все сервисы'}, 'url': '/applicant-services/services/all?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'proforientation', 'translations': {'name': 'Профориентация'}, 'url': '/article/proforientation_promo?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'ka', 'translations': {'name': 'Форум карьеристов'}, 'url': 'https://feedback.hh.ru/filter/301/304?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_footer_new', 'external': True}, {'name': 'findjob', 'translations': {'name': 'Продвижение резюме'}, 'url': '/applicant/services/findjob?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'wantwork', 'translations': {'name': 'Хочу у вас работать'}, 'url': '/article/98?from=footer_new&hhtmFromLabel=footer_new'}, {'name': 'calendar', 'translations': {'name': 'Производственный календарь'}, 'url': '/calendar?from=footer_new&hhtmFromLabel=footer_new'}]}, {'name': 'forTeens', 'translations': {'name': 'Молодым специалистам'}, 'subItems': [{'name': 'career', 'translations': {'name': 'Карьера для молодых специалистов'}, 'url': '/students?from=footer_new&hhtmFromLa ...
# forbidden ====> False
# globalInvitations ====> 2768561
# getPageHtmlEnabled ====> False
# globalStatistics ====> {'vacancies': 889338, 'employers': 1805265, 'resumes': 60030803}
# hasBrandedTemplates ====> False
# hasEditSidebarButton ====> False
# hasForceReloadDreamJob ====> False
# hasListOfVacanciesByRoles ====> False
# hasVacancyResponsesSummaryService ====> False
# hasVideoInterview ====> False
# hasChameleon ====> False
# headerMenu ====> [{'name': 'menuLvl1', 'translations': {'name': '[RU:15:supernova.navi.menuLvl1]'}, 'subItems': [{'name': 'mainContent', 'translations': {'name': '[RU:15:supernova.navi.mainContent]'}, 'subItems': [{'name': 'switchers', 'translations': {'name': '[RU:15:supernova.navi.switchers]'}, 'subItems': [{'name': 'areaSwitcher', 'translations': {'name': 'Липецк'}}, {'name': 'applicant', 'translations': {'name': 'Соискателям'}, 'url': '/set_user_type?user_type=applicant&backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'active': True}, {'name': 'employer', 'translations': {'name': 'Работодателям'}, 'url': '/set_user_type?user_type=employer&backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field%3Dname%26search_field%3Ddescription%26salary%3D%26currency_code%3DRUR%26experience%3DdoesNotMatter%26order_by%3Drelevance%26search_period%3D0%26items_on_page%3D100', 'trackClicks': True}]}, {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}}, {'name': 'expertresume', 'translations': {'name': 'Готовое резюме'}, 'url': '/article/expert_resume?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}, {'name': 'careerconsult', 'translations': {'name': 'Карьерная консультация'}, 'url': '/career_consult?hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}]}, {'name': 'applicantServices', 'translations': {'name': 'Все сервисы'}}]}, {'name': 'menuLvl2', 'translations': {'name': '[RU:15:supernova.navi.menuLvl2]'}, 'subItems': [{'name': 'logo', 'translations': {'name': '[RU:15:supernova.navi.logo]'}}, {'name': 'help', 'translations': {'name': 'Помощь'}, 'dropdown': True, 'subItems': [{'name': 'mainContent', 'translations': {'name': '[RU:15:supernova.navi.mainContent]'}, 'subItems': [{'name': 'vishnu', 'translations': {'name': 'Виртуальный консультант'}}, {'name': 'applicantHelp', 'translations': {'name': 'Вопросы и ответы'}, 'url': 'https://feedback.hh.ru/knowledge-base/articles/applicant?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new', 'external': True}, {'name': 'copiny', 'translations': {'name': 'Сообщество поддержки'}, 'url': 'https://feedback.hh.ru?utm_source=hh.ru&utm_medium=referral&utm_campaign=from_header_new', 'external': True}, {'name': 'writeToUs', 'translations': {'name': 'Пишите нам'}, 'url': 'https://feedback.hh.ru/ticket/add?hhtmFrom=vacancy_search_list&hhtmFromLabel=header', 'external': True}]}, {'name': 'supportChat', 'translations': {'name': 'Техподдержка онлайн'}}]}, {'name': 'userTypeSwitcher', 'translations': {'name': '[RU:15:supernova.navi.userTypeSwitcher]'}, 'trackClicks': True, 'dropdown': True, 'subItems': [{'name': 'userTypeSwitcherApplicant', 'translations': {'name': 'Ищу работу'}, 'url': '/set_user_type?user_type=applicant&backurl=%2F', 'trackClicks': True, 'active': True}, {'name': 'userTypeSwitcherEmployer', 'translations': {'name': 'Ищу сотрудника'}, 'url': '/employer', 'trackClicks': True}]}, {'name': 'fill', 'translations': {'name': '[RU:15:supernova.navi.fill]'}}, {'name': 'searchVacancy', 'translations': {'name': '[RU:15:supernova.navi.searchVacancy]'}, 'url': '/search/vacancy/advanced'}, {'name': 'signup', 'translations': {'name': 'Создать резюме'}, 'url': '/account/signup?backurl=%2Fapplicant%2Fresumes%2Fnew&hhtmFrom=vacancy_search_list&hhtmFromLabel=header'}, {'name': 'login', 'translations': {'name': 'Войти'}, 'url': '/account/login?backurl=%2Fsearch%2Fvacancy%3Ftext%3D%25D0%25B0%25D0%25BD%25D0%25B0%25D0%25BB%25D0%25B8%25D1%2582%25D0%25B8%25D0%25BA%2B%25D0%25B4%25D0%25B0%25D0%25BD%25D0%25BD%25D1%258B%25D1%2585%26search_field ...
# hideFooterServices ====> False
# infoTip ====> {'name': 'vacancy_search_rating_exp'}
# isLightPage ====> False
# isMapVacancySearch ====> False
# isNewEmployer ====> False
# isNewVacancy ====> False
# isWebView ====> False
# isIFrame ====> False
# isProfessionalRolesModeInResume ====> False
# langs ====> ['RU']
# loyaltySurvey ====> {'showNotification': False, 'removeFromUserNotifications': False, 'showBanner': False, 'runSurvey': False}
# locale ====> {'areaId': '113', 'domainAreaId': '58', 'host': 'voronezh.hh.ru', 'protocolHost': 'https://lipetsk.hh.ru', 'isSeoDomain': True, 'platform': 'HEADHUNTER', 'availableLanguages': ['EN', 'RU'], 'siteLanguage': 'RU'}
# logos ====> {'logoDomain': 'hh-ru', 'smallLogoDomain': 'hh.ru'}
# mainContentVisible ====> True
# managersListLoaded ====> False
# messengers ====> [{'country': '7', 'city': '916', 'number': '5514067', 'messengerType': 'WHATSAPP', 'accountName': None}, {'country': '7', 'city': '916', 'number': '5515747', 'messengerType': 'VIBER', 'accountName': 'hh_welcome'}, {'country': None, 'city': None, 'number': None, 'messengerType': 'TELEGRAM', 'accountName': 'reg_hh_bot'}]
# mobileAppPromotionVisible ====> False
# newEmployerDashboardVacancy ====> {'employerRegionResumesCount': 0, 'employerRegion': 0, 'giftsCount': 0}
# noMenu ====> False
# novaSorts ====> {'orderBy': 'relevance', 'searchPeriod': '0', 'workType': {'value': 'fullTime', 'changed': False}}
# orderedCalls ====> {'canRequestMore': False, 'calls': []}
# overlayMenu ====> False
# personalManager ====> {'available': False, 'smallPhoto': '', 'yearsInCompany': None, 'firstName': '', 'lastName': '', 'phonesWithComments': []}
# personalManagerMenu ====> {'isAssigned': False}
# platform ====> XHH
# priceCartOptions ====> {'removable': True, 'activation': False}
# priceNewCartEnabled ====> False
# professionalRolesSerpEnable ====> True
# readOnlyBanner ====> {'days': 0, 'isReadOnly': False}
# resolutionRenderRestriction ====> All
# request ====> {'protocol': 'https', 'host': 'lipetsk.hh.ru', 'origin': 'https://lipetsk.hh.ru', 'url': '/search/vacancy?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'id': '1657633923719f0698d65e99bb7e00d8', 'luxPageName': 'VacancySearch'}
# recaptcha ====> {'isBot': False, 'siteKey': None}
# regionClarification ====> {'host': 'lipetsk.hh.ru', 'translations': {'area': 'Липецк'}}
# resumeViewHistory ====> {'showResumeFallbackWarning': False}
# resumeVisibilityEmployerBlacklist ====> {'items': [], 'total': 0, 'page': 0, 'perPage': 10, 'isFetching': False, 'canAdd': 0, 'limit': 0, 'pager': None}
# resumeVisibilityEmployerWhitelist ====> {'items': [], 'total': 0, 'page': 0, 'perPage': 10, 'isFetching': False, 'canAdd': 0, 'limit': 0, 'pager': None}
# resumeVisibilityEmployerSearchResultsBlacklist ====> {'items': [], 'total': 0, 'isFetching': False}
# resumeVisibilityEmployerSearchResultsWhitelist ====> {'items': [], 'total': 0, 'isFetching': False}
# resumeFormFields ====> {'title': [{'string': ''}]}
# resumeComments ====> {'status': 'FETCH', 'items': {}}
# resumeSearchResult ====> {'criteria': {'search_period': '0', 'order_by': 'relevance', 'items_on_page': '20', 'date_from': '', 'date_to': ''}, 'paging': None, 'catalogLinks': [], 'resumes': [], 'settings': {'activeSettings': [], 'availableSettings': []}, 'clusters': {}, 'hidden': 0, 'total': 0, 'applicantUserStatuses': {}, 'vacancySimilarBuyContacts': {}, 'stats': {'totalResults': 0, 'totalUngroupedResults': 0, 'normalSearchResults': 0, 'normalGroupedSearchResults': 0}}
# resumeSearchQuery ====> {'itemsOnPage': [50], 'pageNumber': ['0'], 'collection': []}
# relocationWarning ====> {'show': False, 'confirmed': False}
# searchAjax ====> True
# searchMetroRedirect ====> {'enable': False, 'path': ''}
# searchCatalogRedirect ====> False
# searchXSControls ====> False
# searchVacancyLoading ====> False
# searchPreference ====> {'isShown': False}
# searchCounts ====> {'isLoad': False, 'value': 10627}
# searchClusters ====> {'label': {'groups': {'not_from_agency': {'count': 10285, 'order': 1, 'title': 'Без вакансий агентств', 'id': 'not_from_agency'}, 'with_address': {'count': 5550, 'order': 2, 'title': 'Только с адресом', 'id': 'with_address'}, 'accept_handicapped': {'count': 249, 'order': 3, 'title': 'Только доступные для людей с\xa0инвалидностью', 'id': 'accept_handicapped'}}, 'selectedValues': [], 'disableQueries': [], 'order': 14}, 'industry': {'groups': {'5': {'count': 270, 'order': 10, 'title': 'Перевозки, логистика, склад, ВЭД', 'id': '5'}, '7': {'count': 3452, 'order': 1, 'title': 'Информационные технологии, системная интеграция, интернет', 'id': '7'}, '8': {'count': 268, 'order': 11, 'title': 'Электроника, приборостроение, бытовая техника, компьютеры и оргтехника', 'id': '8'}, '9': {'count': 434, 'order': 8, 'title': 'Телекоммуникации, связь', 'id': '9'}, '11': {'count': 480, 'order': 7, 'title': 'СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование', 'id': '11'}, '13': {'count': 425, 'order': 9, 'title': 'Строительство, недвижимость, эксплуатация, проектирование', 'id': '13'}, '15': {'count': 180, 'order': 15, 'title': 'Автомобильный бизнес', 'id': '15'}, '19': {'count': 75, 'order': 24, 'title': 'Лесная промышленность, деревообработка', 'id': '19'}, '24': {'count': 166, 'order': 16, 'title': 'Металлургия, металлообработка', 'id': '24'}, '27': {'count': 483, 'order': 6, 'title': 'Продукты питания', 'id': '27'}, '29': {'count': 113, 'order': 22, 'title': 'Сельское хозяйство', 'id': '29'}, '33': {'count': 46, 'order': 26, 'title': 'Тяжелое машиностроение', 'id': '33'}, '34': {'count': 103, 'order': 23, 'title': 'Химическое производство, удобрения', 'id': '34'}, '36': {'count': 128, 'order': 20, 'title': 'Государственные организации', 'id': '36'}, '37': {'count': 15, 'order': 29, 'title': 'Общественная деятельность, партии, благотворительность, НКО', 'id': '37'}, '39': {'count': 203, 'order': 13, 'title': 'Образовательные учреждения', 'id': '39'}, '41': {'count': 1064, 'order': 3, 'title': 'Розничная торговля', 'id': '41'}, '42': {'count': 488, 'order': 5, 'title': 'Товары народного потребления (непищевые)', 'id': '42'}, '43': {'count': 1546, 'order': 2, 'title': 'Финансовый сектор', 'id': '43'}, '44': {'count': 575, 'order': 4, 'title': 'Услуги для бизнеса', 'id': '44'}, '45': {'count': 161, 'order': 17, 'title': 'Добывающая отрасль', 'id': '45'}, '46': {'count': 69, 'order': 25, 'title': 'Энергетика', 'id': '46'}, '47': {'count': 194, 'order': 14, 'title': 'Нефть и газ', 'id': '47'}, '48': {'count': 238, 'order': 12, 'title': 'Медицина, фармацевтика, аптеки', 'id': '48'}, '49': {'count': 151, 'order': 18, 'title': 'Услуги для населения', 'id': '49'}, '50': {'count': 116, 'order': 21, 'title': 'Гостиницы, рестораны, общепит, кейтеринг', 'id': '50'}, '51': {'count': 37, 'order': 28, 'title': 'ЖКХ', 'id': '51'}, '52': {'count': 4, 'order': 30, 'title': 'Искусство, культура', 'id': '52'}, '388': {'count': 148, 'order': 19, 'title': 'Промышленное оборудование, техника, станки и комплектующие', 'id': '388'}, '389': {'count': 41, 'order': 27, 'title': 'Управление многопрофильными активами', 'id': '389'}}, 'selectedValues': [], 'disableQueries': [], 'order': 9}, 'experience': {'groups': {'between1And3': {'count': 5736, 'order': 1, 'title': 'От\xa01\xa0года до\xa03\xa0лет', 'id': 'between1And3'}, 'between3And6': {'count': 3882, 'order': 2, 'title': 'От\xa03\xa0до\xa06\xa0лет', 'id': 'between3And6'}, 'noExperience': {'count': 708, 'order': 3, 'title': 'Нет опыта', 'id': 'noExperience'}, 'moreThan6': {'count': 301, 'order': 4, 'title': 'Более 6\xa0лет', 'id': 'moreThan6'}}, 'selectedValues': None, 'disableQueries': [], 'order': 11}, 'schedule': {'groups': {'fullDay': {'count': 8649, 'order': 1, 'title': 'Полный день', 'id': 'fullDay'}, 'remote': {'count': 1615, 'order': 2, 'title': 'Удаленная работа', 'id': 'remote'}, 'flexible': {'count': 298, 'order': 3, 'title': 'Гибкий график', 'id': 'flexible'}, 'shift': {'count': 53, ...
# searchClustersInitialValues ====> {'label': [], 'industry': [], 'experience': None, 'schedule': [], 'professionalArea': [], 'professional_role': [], 'area': [], 'employment': [], 'compensation': {'onlyWithSalary': False, 'salary': None}, 'part_time': None, 'search_field': ['name', 'description'], 'excluded_text': [], 'neighbours': [], 'metro': [], 'specialization': [], 'subIndustry': []}
# searchClustersBasic ====> {'label': {'groups': {'not_from_agency': {'count': 817716, 'order': 1, 'title': 'Без вакансий агентств', 'id': 'not_from_agency'}, 'with_address': {'count': 498732, 'order': 2, 'title': 'Только с адресом', 'id': 'with_address'}, 'accept_handicapped': {'count': 19442, 'order': 3, 'title': 'Только доступные для людей с\xa0инвалидностью', 'id': 'accept_handicapped'}, 'accept_kids': {'count': 735, 'order': 4, 'title': 'Только доступные для соискателей от 14 лет', 'id': 'accept_kids'}}, 'selectedValues': [], 'disableQueries': [], 'order': 14}, 'industry': {'groups': {'5': {'count': 32509, 'order': 9, 'title': 'Перевозки, логистика, склад, ВЭД', 'id': '5'}, '7': {'count': 63049, 'order': 2, 'title': 'Информационные технологии, системная интеграция, интернет', 'id': '7'}, '8': {'count': 22098, 'order': 13, 'title': 'Электроника, приборостроение, бытовая техника, компьютеры и оргтехника', 'id': '8'}, '9': {'count': 15275, 'order': 18, 'title': 'Телекоммуникации, связь', 'id': '9'}, '11': {'count': 15285, 'order': 17, 'title': 'СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование', 'id': '11'}, '13': {'count': 61571, 'order': 3, 'title': 'Строительство, недвижимость, эксплуатация, проектирование', 'id': '13'}, '15': {'count': 23242, 'order': 11, 'title': 'Автомобильный бизнес', 'id': '15'}, '19': {'count': 3898, 'order': 27, 'title': 'Лесная промышленность, деревообработка', 'id': '19'}, '24': {'count': 21724, 'order': 14, 'title': 'Металлургия, металлообработка', 'id': '24'}, '27': {'count': 40479, 'order': 6, 'title': 'Продукты питания', 'id': '27'}, '29': {'count': 10407, 'order': 24, 'title': 'Сельское хозяйство', 'id': '29'}, '33': {'count': 14786, 'order': 19, 'title': 'Тяжелое машиностроение', 'id': '33'}, '34': {'count': 10999, 'order': 23, 'title': 'Химическое производство, удобрения', 'id': '34'}, '36': {'count': 12038, 'order': 22, 'title': 'Государственные организации', 'id': '36'}, '37': {'count': 878, 'order': 29, 'title': 'Общественная деятельность, партии, благотворительность, НКО', 'id': '37'}, '39': {'count': 14164, 'order': 20, 'title': 'Образовательные учреждения', 'id': '39'}, '41': {'count': 134145, 'order': 1, 'title': 'Розничная торговля', 'id': '41'}, '42': {'count': 50050, 'order': 4, 'title': 'Товары народного потребления (непищевые)', 'id': '42'}, '43': {'count': 39134, 'order': 7, 'title': 'Финансовый сектор', 'id': '43'}, '44': {'count': 42420, 'order': 5, 'title': 'Услуги для бизнеса', 'id': '44'}, '45': {'count': 13151, 'order': 21, 'title': 'Добывающая отрасль', 'id': '45'}, '46': {'count': 9339, 'order': 25, 'title': 'Энергетика', 'id': '46'}, '47': {'count': 16072, 'order': 15, 'title': 'Нефть и газ', 'id': '47'}, '48': {'count': 38457, 'order': 8, 'title': 'Медицина, фармацевтика, аптеки', 'id': '48'}, '49': {'count': 15732, 'order': 16, 'title': 'Услуги для населения', 'id': '49'}, '50': {'count': 29086, 'order': 10, 'title': 'Гостиницы, рестораны, общепит, кейтеринг', 'id': '50'}, '51': {'count': 6895, 'order': 26, 'title': 'ЖКХ', 'id': '51'}, '52': {'count': 647, 'order': 30, 'title': 'Искусство, культура', 'id': '52'}, '388': {'count': 22787, 'order': 12, 'title': 'Промышленное оборудование, техника, станки и комплектующие', 'id': '388'}, '389': {'count': 2316, 'order': 28, 'title': 'Управление многопрофильными активами', 'id': '389'}}, 'selectedValues': [], 'disableQueries': [], 'order': 9}, 'experience': {'groups': {'between1And3': {'count': 401195, 'order': 1, 'title': 'От\xa01\xa0года до\xa03\xa0лет', 'id': 'between1And3'}, 'noExperience': {'count': 285163, 'order': 2, 'title': 'Нет опыта', 'id': 'noExperience'}, 'between3And6': {'count': 164564, 'order': 3, 'title': 'От\xa03\xa0до\xa06\xa0лет', 'id': 'between3And6'}, 'moreThan6': {'count': 21181, 'order': 4, 'title': 'Более 6\xa0лет', 'id': 'moreThan6'}}, 'selectedValues': None, 'disableQueries': [], 'order': 11}, 'schedule': {'groups': {'fullDay': {'count': 627506, 'order': 1, 'title': 'Полный день', 'id': 'ful ...
# searchClustersChanged ====> False
# searchClustersTip ====> {'show': False, 'totalResults': 0}
# searchClustersSettings ====> {'type': 'vacancy', 'actionPath': '/search/vacancy'}
# searchQuickFilters ====> [{'novafilter': 'schedule', 'option': 'shift'}, {'novafilter': 'schedule', 'option': 'remote'}, {'novafilter': 'experience', 'option': 'noExperience'}]
# searchResumeSeoCatalog ====> {'active': False}
# similarSavedSearchEnabled ====> False
# socialNetworksLinks ====> [{'name': 'vk', 'url': 'https://vk.com/headhunter'}, {'name': 'ok', 'url': 'http://www.odnoklassniki.ru/headhunter'}, {'name': 'twitter', 'url': 'https://twitter.com/hh_ru'}]
# session ====> {'isFallback': False, 'securityCheckFailed': False, 'hasExtraAccounts': False}
# smilesShoudBeShown ====> False
# showSkillSurveyOnVacancyEditPage ====> False
# showJobSearchStatusNotification ====> False
# showVacancyConstructorExample ====> False
# showVacancyConstructorExampleState ====> False
# showManagerContactsVacancyInfotip ====> False
# showWebimButtonOnLogin ====> False
# showResumeSearchConditions ====> False
# showEmployerStatisticsLinks ====> False
# supernovaSearchView ====> {'large': False, 'largeXS': False, 'expanded': False}
# supernovaSearchName ====> searchVacancy
# supernovaSearchArea ====> {'translations': {'area': 'Липецке'}}
# supernovaUserType ====> applicant
# supportChat ====> {'available': True, 'workday': None, 'weekend': None}
# syncAreaWithNeighboursArea ====> False
# stayInTouch ====> {'apps': [{'name': 'ios', 'href': 'https://redirect.appmetrica.yandex.com/serve/672819448956069558?main_page=lipetsk.hh.ru'}, {'name': 'android', 'href': 'https://redirect.appmetrica.yandex.com/serve/1033107423658825167?main_page=lipetsk.hh.ru'}, {'name': 'huawei', 'href': 'https://redirect.appmetrica.yandex.com/serve/819411740142879951?main_page=lipetsk.hh.ru'}], 'mobilePage': '/mobile'}
# topLevelDomain ====> hh.ru
# topLevelSite ====> hh.ru
# templatePreviewModal ====> {'visible': False, 'currentType': 'constructor', 'currentCompanyType': 'pticefabrika', 'logos': {'constructor': ['pticefabrika', 'zenno', 'lifefitnes', 'intiled'], 'typical': ['pp', 'technoavia', 'kedr', 'fintech'], 'individual': ['twogis', 'fresh', 'bank', 'rb']}}
# trl ====> {'RU': {'novafilters.similarSavedSearch.explanation': 'Мы\xa0запоминаем фильтры, которые вы\xa0применили к\xa0подходящим вакансиям', 'error.400.message': 'Плохой запрос', 'error.403.message': 'Пожалуйста, авторизуйтесь на сайте', 'error.404.message': 'Такой страницы не существует', 'error.500.tryagain': 'Извините, сервис временно недоступен. Попробуйте чуть позже.', 'error.599.tryagain': 'Извините, сервис временно недоступен. Попробуйте чуть позже.', 'emailVerificationInfo.notVerified': 'Ваш почтовый адрес {0} не\xa0подтвержден.', 'emailVerificationInfo.send': 'Отправить письмо для подтверждения', 'emailVerificationInfo.success': 'Письмо успешно отправлено, ', 'emailVerificationInfo.check': 'проверьте\xa0почту', 'emailVerificationInfo.cantGet': 'Не приходит письмо', 'emailVerificationInfo.error': 'Произошла ошибка.', 'emailVerificationInfo.tryAgain': 'Попробовать еще раз', 'inform.employer.restricted.1': 'Доступ к возможностям hh.ru ограничен.', 'inform.employer.restricted.2': 'Загрузите подтверждающие документы и дождитесь звонка менеджера.', 'inform.button.load': 'Загрузить', 'inform.employer.pending.1': 'На время проверки загруженных документов доступ к hh.ru ограничен.', 'inform.employer.pending.2': 'Ожидайте звонка от менеджера в ближайшее время.', 'employer.zpOnboardingModal.nextBtnStart': 'Начать экскурсию', 'employer.zpOnboardingModal.nextBtnContinue': 'Продолжить', 'employer.zpOnboardingModal.nextBtnEnd': 'Приступить к\xa0работе', 'employer.zpOnboardingModal.backBtn': 'Назад', 'employer.zpOnboardingModal.start.header': 'Посмотрите, как обновился личный кабинет', 'employer.zpOnboardingModal.start.text': 'Впереди\xa0— минутная экскурсия о\xa0том, где\xa0находятся ваши вакансии, заказы, подписки на\xa0резюме и\xa0избранное', 'employer.zpOnboardingModal.activeVacancies.header': 'Начнём с\xa0опубликованных вакансий: они\xa0— в\xa0«Вакансиях»', 'employer.zpOnboardingModal.activeVacancies.text': 'В\xa0разделе «Мои\xa0вакансии», если быть точными', 'employer.zpOnboardingModal.activeVacanciesMore.header': 'Не\xa0нашли публикаций на\xa0странице «Мои\xa0вакансии»?', 'employer.zpOnboardingModal.activeVacanciesMore.text': 'Они чуть ниже, под\xa0вашими черновиками\xa0— неопубликованными вакансиями', 'employer.zpOnboardingModal.archivedVacancies.header': 'Архивные вакансии\xa0— тоже в\xa0«Вакансиях»', 'employer.zpOnboardingModal.archivedVacancies.text': 'Раздел: «Архив»', 'employer.zpOnboardingModal.orders.header': 'Ваши заказы\xa0— в\xa0меню «Счёт»', 'employer.zpOnboardingModal.orders.text': 'Раздел: «Состояние и\xa0история»', 'employer.zpOnboardingModal.closingDocs.header': 'Закрывающие документы\xa0— там\xa0же, в\xa0меню «Счёт»', 'employer.zpOnboardingModal.closingDocs.text': 'Раздел: «Документы»', 'employer.zpOnboardingModal.subscriptions.header': 'Подписки на\xa0резюме\xa0— в\xa0«Кандидатах»', 'employer.zpOnboardingModal.subscriptions.text': 'Раздел: «Автопоиск»\xa0— теперь подписки называются именно так', 'employer.zpOnboardingModal.favourites.header': 'Избранные резюме\xa0—\xa0тоже в\xa0«Кандидатах»', 'employer.zpOnboardingModal.favourites.text': 'Кстати, теперь их\xa0можно сортировать по\xa0папкам', 'employer.zpOnboardingModal.end.header': 'И\xa0последнее: появилось больше возможностей ускорить наём сотрудников', 'employer.zpOnboardingModal.end.text': 'Например, рекомендации резюме стали ещё точнее\xa0— система опирается на\xa0ваши действия, лучше понимает, кто вам нужен, и\xa0предлагает больше подходящих людей.', 'employer.zpOnboardingModal.end.additionalInfoText': 'Узнать обо\xa0всех возможностях', 'employer.zpOnboardingModal.fromSteps': '{0}\xa0из\xa0{1}', 'supernova.footer.mobile.banner.header': 'Скачайте приложение', 'supernova.footer.mobile.banner.description.qr': 'Свежие вакансии, ответы на\xa0отклики и\xa0доступ к\xa0резюме\xa0— всегда у\xa0вас под рукой.', 'supernova.footer.mobile.banner.description.additional': 'Просто\xa0наведите камеру телефона на\xa0QR-код.', 'supernova.footer.mobile.banner.appButton': ...
# trudvsemEnabled ====> False
# userType ====> anonymous
# appLink ====> {'detected': False, 'href': '', 'type': '', 'name': ''}
# criteriaTextUpdated ====> аналитик данных
# userTargeting ====> {'puid42': None, 'puid48': None, 'puid49': None, 'puid44': None, 'puid53': None, 'puid63': None, 'puid45': None, 'puid41': None, 'puid56': None, 'puid57': None, 'puid43': '113:230:1890:58', 'puid1': '113:230:1890:58', 'puid47': None, 'puid54': None, 'puid50': None, 'puid51': None, 'puid52': None, 'puid55': None, 'puid46': None, 'puid2': 'X7WzrwjHeSUzqmLNfIMyjQ--', 'puid3': 'ru_RU', 'puid10': 'tempexp_14535_b:tempexp_16177_v2:tempexp_16916_a:vacancy_partial_redesign_b', 'puid58': 'null'}
# vacanciesOfTheDay ====> {'isLoading': True, 'success': True, 'vacancies': [], 'compensation': {'from': 0, 'to': 0, 'currencyCode': 'RUR'}}
# vacancyConstructorTemplate ====> {'pictures': {'VACANCY_CONSTRUCTOR_TOP': {}, 'VACANCY_CONSTRUCTOR_BOTTOM': {}, 'ZARPLATA_VACANCY_CONSTRUCTOR_TOP': {}, 'ZARPLATA_VACANCY_CONSTRUCTOR_BOTTOM': {}}, 'visibleCropImagePopup': False, 'imageCropSettings': {}}
# availablePublicationTypes ====> {'loading': False, 'params': {'areaIds': [], 'professionalRoleIds': [], 'withClickme': False, 'withZpCrossPost': True}, 'data': None}
# auctionPromo ====> {'auctionPromoAvailable': False, 'auctionPromoThankYouModal': False, 'auctionPromoChecked': False}
# vacancyCreateDraftSaveEnabled ====> True
# vacancyDiscountPromoControlsInfo ====> {'visibility': False}
# vacancyCreateSavedToDraft ====> False
# vacancyCreateAllowRegions ====> False
# isPromoVacancy ====> False
# isVacancyCreationAllowed ====> True
# isVacancyEditAllowed ====> True
# isAddressAddAllowed ====> True
# isAbortVacancyPollEnabled ====> False
# vacancyCreateSelectPublicationType ====> False
# otherRoleWarning ====> False
# isZpEmployer ====> False
# vacancyResponses ====> {'totalResumesCount': 0, 'collection': {'name': ''}, 'collections': [], 'resumes': {'total': 0, 'elementsJson': []}, 'phoneCalls': {'calls': []}, 'callsToResume': {}}
# hhcaptcha ====> {'isBot': False}
# vacancyResponsePopupVisible ====> False
# vacancySavedSearches ====> {'isAllSelected': False, 'selectedItems': [], 'error': False, 'isFullPageReactEnabled': False, 'email': '', 'emailVerified': True, 'savedSearch': [], 'filterValue': 'all', 'isLoading': ''}
# vacancySearchDictionaries ====> {'schedule': ['fullDay', 'shift', 'flexible', 'remote', 'flyInFlyOut'], 'experience': ['noExperience', 'between1And3', 'between3And6', 'moreThan6'], 'employment': ['full', 'part', 'project', 'volunteer', 'probation'], 'labels': ['with_address', 'accept_handicapped', 'not_from_agency', 'accept_kids'], 'orderBy': ['relevance', 'publication_time', 'salary_desc', 'salary_asc'], 'searchPeriod': ['0', '30', '7', '3', '1'], 'prioritySortCommon': ['metallic', 'none'], 'searchFields': ['name', 'company_name', 'description'], 'minItemsOnPage': 0, 'maxItemsOnPage': 100, 'maxSearchResult': 2000, 'privateParamPrefix': 'L_'}
# vacancySearchResult ====> {'vacancyAdditionalParams': ['position', 'requestId', 'totalVacancies'], 'proxiedSearchFormParams': {'clusters': True, 'ored_clusters': True, 'text': 'аналитик данных', 'items_on_page': 100, 'search_field': ['name', 'description'], 'enable_snippets': True}, 'savedSearches': {'isSavedSearch': False, 'email': None, 'selectedClusters': [{'name': 'search_field', 'title': 'Ключевые слова в названии вакансии и\xa0в описании вакансии'}], 'position': 2}, 'criteria': {'employment': [], 'schedule': [], 'page': 0, 'limit': -1, 'offset': -1, 'clusters': True, 'area': [], 'currency_code': 'RUR', 'metro': [], 'specialization': [], 'professional_role': [], 'search_debug': False, 'control_flag': ['vacancyBlacklistJoinEnabled:True'], 'saved_search_id': None, 'vacancy_id': None, 'resume': None, 'no_magic': False, 'ored_clusters': True, 'cache_ttl_sec': 0, 'district': [], 'text': 'аналитик данных', 'date_from': None, 'date_to': None, 'items_on_page': 100, 'order_by': 'relevance', 'label': [], 'search_field': ['name', 'description'], 'experience': None, 'enable_snippets': True, 'only_with_salary': False, 'part_time': None, 'is_part_time_clusters_enabled': False, 'exclude_archived': True, 'exclude_closed': True, 'search_period': None, 'salary': None, 'bottom_left_lat': None, 'bottom_left_lng': None, 'top_right_lat': None, 'top_right_lng': None, 'sort_point_lat': None, 'sort_point_lng': None, 'employer_id': None, 'employer_manager_id': None, 'industry': [], 'precision': None, 'geocode_type': None, 'geohash': None, 'recommended_by_uid': False, 'excluded_text': None}, 'totalUsedFilters': 2, 'vacancies': [{'@responseLetterRequired': False, '@showContact': True, 'vacancyId': 54958158, 'name': 'Аналитик CRM', 'company': {'@showSimilarVacancies': True, '@trusted': True, '@category': 'COMPANY', '@countryId': 1, '@structureName': '44534', '@state': 'APPROVED', 'id': 44534, 'name': 'Аптеки ВИТА', 'visibleName': 'Аптеки ВИТА', 'structureName': '44534', 'logos': {'logo': [{'@type': 'searchResultsPage', '@url': '/employer-logo/2123334.jpeg'}, {'@type': 'small', '@url': '/employer-logo/2123334.jpeg'}, {'@type': 'employerPage', '@url': '/employer-logo/2123333.jpeg'}, {'@type': 'ORIGINAL', '@url': '/employer-logo-original/420315.jpg'}, {'@type': 'vacancyPage', '@url': '/employer-logo/2123335.jpeg'}, {'@type': 'medium', '@url': '/employer-logo/2123335.jpeg'}], '@showInSearch': True}, 'mainEmployerId': 44534, 'companySiteUrl': 'http://www.vitaexpress.ru'}, 'compensation': {'noCompensation': {}}, 'publicationTime': {'@timestamp': 1657005792, '$': '2022-07-05T10:23:12.424+03:00'}, 'type': 'open', 'area': {'@id': 78, 'name': 'Самара', 'path': '.113.226.1586.78.'}, 'acceptTemporary': False, 'address': {'@id': 3237507, '@disabled': False, 'city': 'Самара', 'street': 'улица Куйбышева', 'building': '110', 'displayName': 'Самара, улица Куйбышева, 110', 'mapData': '{"points":{"center":{"lat":53.191766999991025,"lng":50.09097700000001,"zoom":19},"marker":{"lat":53.191767,"lng":50.090977}}}', 'marker': {'@lat': 53.191767, '@lng': 50.090977}, 'manager': {'@id': 6223420}}, 'contactInfo': None, 'metallic': 'standard', 'template': 'makeup:25752', 'creationSite': 'samara.hh.ru', 'creationSiteId': 8, 'displayHost': 'lipetsk.hh.ru', 'lastChangeTime': {'@timestamp': 1657614661, '$': '2022-07-12T11:31:01.896+03:00'}, 'creationTime': '2022-04-20T16:39:40.911+03:00', 'canBeShared': True, 'employerManager': {'@hhid': 141144416, '@managerId': 10866736, '@userId': 118937496}, 'inboxPossibility': True, 'chatWritePossibility': 'ENABLED_AFTER_INVITATION', 'notify': False, 'links': {'desktop': 'https://lipetsk.hh.ru/vacancy/54958158', 'mobile': 'https://m.hh.ru/vacancy/54958158'}, 'workSchedule': 'FULL_DAY', 'acceptIncompleteResumes': False, 'driverLicenseTypes': [{}], 'languages': [{}], 'workingDays': [{}], 'workingTimeIntervals': [{}], 'workingTimeModes': [{}], 'hrBotScenario': {'hrBotScenarioId': 2349606, 'enabled': False, 'scenarioCode': 'vacancy_scenario_2349606' ...
# vacancyWizard ====> {'totalEmployersFound': 0, 'employerHits': [], 'rootAreaId': 0}
# xsrfToken ====> fe1ada2697af8ee0c22481e316ea8664
# pinnedChatMessages ====> {'hasMore': False, 'items': []}
# snippetAccessResume ====> {'productList': [], 'area': '', 'isShowSnippetResume': False}
# zpEmployerOnboarding ====> {'showOnboardingModal': False}
# accountHistoryMoney ====> {'hasPersonalManager': False, 'state': '', 'email': '', 'agreements': {}, 'currency': '', 'hrs': {'orders': []}, 'balances': {}, 'employerCountry': '', 'availableWithoutBlockedMoney': 0}
# router ====> {'location': {'pathname': '/search/vacancy', 'search': '?text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&search_field=name&search_field=description&salary=&currency_code=RUR&experience=doesNotMatter&order_by=relevance&search_period=0&items_on_page=100', 'hash': '', 'key': 'xlri6q', 'query': {'text': '%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85', 'search_field': 'description', 'salary': '', 'currency_code': 'RUR', 'experience': 'doesNotMatter', 'order_by': 'relevance', 'search_period': '0', 'items_on_page': '100'}}, 'action': 'POP'}

# %% [markdown]
# Now the *clean_dict* variable contains key with not-empty data bound to them.
# Keys analysis shows main search results are under _'vacancySearchResult'->'vacancies'_ keys.
# Another useful keys are:
# _'searchClusters'_ contains grouping characteristics ('industry', 'groups')
# _'searchClustersBasic'_ contains options to split data further ('area', 'compensation', etc.)

# %%
# Total number of search results
print(clean_dict['searchCounts'])
# or
print(clean_dict['vacancySearchResult']['totalResults'])
# ?
# Out:
# {'isLoad': False, 'value': 10627}
# 10627

# %%
clean_dict['searchClustersBasic'].keys()
# Out:
# dict_keys(['label', 'industry', 'experience', 'schedule', 'professionalArea', 'professional_role', 'area', 'employment', 'compensation', 'part_time', 'search_field', 'excluded_text'])

# %% [markdown]
# In case total search results number exceeds 2000 (seems to be hardcoded limit) it is possible to use 'searchClustersBasic'->'area' to implement partial searches

# %%
clean_dict['searchClustersBasic']['area']['groups']['113']
# Out:
# {'count': 10002,
#  'seoDomain': 'hh.ru',
#  'order': 1,
#  'title': 'Россия',
#  'id': '113'}

# %% [markdown]
# The key _'count'_ contains number of vacancies found in area, _'id'_ - area id. I can parse _'area'->'groups'_ keys to search in regions separately. It gives me a way to bypass the max vacancies limitation mentioned above

# %%
areas_to_crawl = []
area_ids_excluded = ['113'] # grouping ids: 113 = Russia
if json_parsed['vacancySearchResult']['totalResults'] > 2000:
    search_json_obj = json_parsed['searchClustersBasic']['area']['groups']
    for key in search_json_obj.keys():
        if (key not in area_ids_excluded) and (search_json_obj[key]['count'] > 0):
            areas_to_crawl.append(key)
print('Total areas with vacancies num: {}'.format(len(areas_to_crawl)))
print("First 10 values of areas' ids: ", areas_to_crawl[:10])
# Out:
# Total areas with vacancies num: 128
# First 10 values of areas' ids:  ['1', '2', '9', '13', '16', '28', '40', '48', '94', '97']

# %% [markdown]
# Let's check vacancies number per page to ensure _'items_on_page'_ parameter works fine

# %%
vacancies_info = clean_dict['vacancySearchResult']['vacancies']
print('Vacancies data type: {}'.format(type(vacancies_info)))
print('Num of vacancies: {}'.format(len(vacancies_info)))
# Out:
# Vacancies data type: <class 'list'>
# Num of vacancies: 101

# %% [markdown]
# There is 100 records containing vacancies info from the 1st search page. So this parameter is OK. And now I want to find total number of pages to get all of them.
# The _'paging'_ key seems a right place for this info

# %%
clean_dict['vacancySearchResult']['paging']
# Out:
# {'previous': {'page': -1, 'disabled': True},
#  'pages': [{'text': '1', 'page': 0, 'selected': True, 'inShortRange': True},
#   {'text': '2', 'page': 1, 'selected': False, 'inShortRange': True},
#   {'text': '3', 'page': 2, 'selected': False, 'inShortRange': True},
#   {'text': '4', 'page': 3, 'selected': False, 'inShortRange': False},
#   {'text': '5', 'page': 4, 'selected': False, 'inShortRange': False},
#   {'text': '...', 'page': 5, 'selected': False, 'inShortRange': False}],
#  'lastPage': {'page': 19, 'selected': False},
#  'next': {'page': 1, 'disabled': False},
#  'os': 'Win'}

# %% [markdown]
# Indeed here is pagination data. Last page number contains in _'lastPage'->'page'_ key. And total search results is splitted on N+1 pages as they are 0-indexed.
# Now I have all the necessary info to get all vacancies into 1 place.
# > [!!!] In case of only 1 page the key _'paging'_ will contain _null_ value
# In case there are 2 or 3 pages the key _'lastPage'_ is absent

# %% [markdown]
# #### Harvesting vacancies info from hh.ru

# %% [markdown]
# It's time to combine all informations about harvesting procedure to make it correct:
# (1) if total number of results exceeds 2000 I have to get info partially from different areas (which are in *areas_to_crawl* variable). In this case there will possibly be duplicates as I don't know display algorithm in details. If *areas_to_crawl* has length == 0 then there are less than 2000 vacancies found;
# (1.5) if it's not enough I should go to split further by underground lines or stations (parameter _metro=9&_ or _metro=9.37&_ in address line);
# (2) I don't need to clean json results as I know all the necessary keys;
# (3) I need to loop through all the pages.

# %%
# returns num of pages to parse
def get_num_pages(json_dump, logger=logger):
    result = None
    div_paging = json_dump['vacancySearchResult'].get('paging', None)
    if div_paging is not None:
        if div_paging.get('lastPage', None) is None:
            result = max([x['page'] for x in div_paging['pages']])
        else:
            result = div_paging['lastPage']['page']
    return result

# %%
# parse all pages from first
def parse_pages(browser, first_page_url, tail_url, logger=logger):
    logger.debug('Flow control received')
    result = []
    browser.get(first_page_url)
    max_available_records = 2000
    if json_parsed['vacancySearchResult']['totalResults'] > max_available_records:
        logger.debug('More than {} records detected => passing flow control to "parse_pages_by_undeground"'.format(max_available_records))
        result += parse_pages_by_underground(browser, first_page_url, tail_url)
    else:
        logger.debug('Less than {} records detected => beginning parsing pages'.format(max_available_records))
        json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
        result += json_dump['vacancySearchResult']['vacancies']
        num_pages = get_num_pages(json_dump)
        logger.debug('Page 1 / {} parsed'.format(num_pages+1))
        if num_pages is not None:
            for page in range(1, num_pages+1):
                browser.get(first_page_url+tail_url.format(page))
                div_list = BeautifulSoup(browser.page_source, 'html.parser').find_all('template')
                json_dump = json.loads(div_list[0].text)
                result += json_dump['vacancySearchResult']['vacancies']
                logger.debug('Page {} / {} parsed'.format(page+1, num_pages+1))
    return result

# %%
# page address to filter search results by underground lines/stations
"""
https://hh.ru/search/vacancy?
                            area=1&
                            metro=9.37&
                            search_field=name&search_field=description&
                            text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&
                            from=suggest_post&
                            clusters=true&
                            no_magic=true&
                            ored_clusters=true&
                            items_on_page=100&
                            enable_snippets=true
"""
# Out:
# '\nhttps://hh.ru/search/vacancy?\n                            area=1&\n                            metro=9.37&\n                            search_field=name&search_field=description&\n                            text=%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA+%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85&\n                            from=suggest_post&\n                            clusters=true&\n                            no_magic=true&\n                            ored_clusters=true&\n                            items_on_page=100&\n                            enable_snippets=true\n'

# %%
def parse_pages_by_underground(browser, start_page_url, tail_url, logger=logger):
    # at the moment function is called browser has already opened start_page_url
    # start_page_url doesn't contain 'page=' parameter
    #browser.get(start_page_url)
    logger.debug('Flow control received')
    json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
    # get all underground lines with search result > 0
    underground_dump = json_dump['searchClustersBasic']['metro']['groups']
    underground_lines = {key: underground_dump[key]['title'] for key in underground_dump.keys() if underground_dump[key]['type'] == 'line'}
    new_url_template = start_page_url + '&metro={}'
    logger.debug('Got {} underground lines. Begin parsing'.format(len(underground_lines)))
    
    result = []
    for line in underground_lines:
        logger.debug('Underground line: {}'.format(underground_lines[line]))
        url = new_url_template.format(line)
        browser.get(url)
        json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
        result += json_dump['vacancySearchResult']['vacancies']
        num_pages = get_num_pages(json_dump)
        logger.debug('Page 1 / {} parsed'.format(num_pages+1))
        if num_pages is not None:
            for page in range(1, num_pages+1):
                browser.get(url+tail_url.format(page))
                json_dump = json.loads(BeautifulSoup(browser.page_source, 'html.parser').find_all('template')[0].text)
                result += json_dump['vacancySearchResult']['vacancies']
                logger.debug('Page {} / {} parsed'.format(page+1, num_pages+1))
    return result

# %%
vacancies_info = []
if len(areas_to_crawl) > 0:
    url_by_area = combine_base_url(template = search_url_template, search_text=search_texts[1], area_keys=['#later'], salary=salary_level)
    for area in areas_to_crawl:
        vacancies_info += parse_pages(browser, url_by_area.format('area={}&'.format(area)), url_tail)

print('Final vacancies info contains {} record(s)'.format(len(vacancies_info)))
# Out:
# Final vacancies info contains 4467 record(s)

# %%
len(vacancies_info)
# Out:
# 4467

# %% [markdown]
# We've got info from all pages and now can close browser

# %%
browser.quit()

# %% [markdown]
# Dumping data to have an opportunity to restore raw data later...

# %%
with open('datasets/'+output_filename+'.json', 'w') as f:
    json.dump(vacancies_info, f)

# %% [markdown]
# And now it's time to select fields to fill in DataFrame

# %%
for key in vacancies_info[0].keys():
    print('{} =======> {}'.format(key, vacancies_info[0][key]))
# Out:
# @responseLetterRequired =======> False
# @showContact =======> False
# vacancyId =======> 67551709
# name =======> Backend developer (Python, PostgreSQL)
# company =======> {'@showSimilarVacancies': True, '@trusted': True, '@category': 'COMPANY', '@countryId': 1, '@state': 'APPROVED', 'id': 9001909, 'name': 'Шамсуллин Рустам Радикович', 'visibleName': 'Шамсуллин Рустам Радикович', 'employerOrganizationFormId': 9, 'companySiteUrl': ''}
# compensation =======> {'to': 350000, 'currencyCode': 'RUR', 'gross': False}
# publicationTime =======> {'@timestamp': 1657122199, '$': '2022-07-06T18:43:19.351+03:00'}
# type =======> open
# area =======> {'@id': 1, 'name': 'Москва', 'path': '.113.232.1.'}
# acceptTemporary =======> True
# address =======> {'@id': 11250202, '@disabled': False, 'metroStations': {'@lat': 55.70678, '@lng': 37.58499, 'metro': [{'@isAlias': False, '@cityId': 1, '@id': 74, '@name': 'metro.74', '@order': 14, '@translit': 'leninskiy_prospekt', 'id': 74, 'lat': 55.70678, 'line': {'@id': 6, '@name': 'metroline.6', '@translit': 'kaluzhsko_rizhskaya', '@cityId': 1, 'id': 6, 'name': 'Калужско-Рижская', 'color': '#F07E24'}, 'lng': 37.58499, 'name': 'Ленинский проспект'}, {'@isAlias': False, '@cityId': 1, '@id': 535, '@name': 'metro.535', '@order': 20, '@translit': 'luzhniki', 'id': 535, 'lat': 55.720278, 'line': {'@id': 95, '@name': 'metroline.95', '@translit': 'mck', '@cityId': 1, 'id': 95, 'name': 'МЦК', 'color': '#CC4C6E'}, 'lng': 37.563056, 'name': 'Лужники'}]}, 'city': 'Москва', 'street': 'Лужнецкая набережная', 'building': '2/4с4', 'displayName': 'Москва, Лужнецкая набережная, 2/4с4', 'mapData': '{"points":{"center":{"lat":55.7135295854577,"lng":37.57402300000001,"zoom":14},"marker":{"lat":55.715489,"lng":37.573627}}}', 'marker': {'@lat': 55.715489, '@lng': 37.573627}, 'manager': {'@id': 11010455}}
# metallic =======> premium
# creationSite =======> hh.ru
# creationSiteId =======> 1
# displayHost =======> lipetsk.hh.ru
# lastChangeTime =======> {'@timestamp': 1657566948, '$': '2022-07-11T22:15:48.489+03:00'}
# creationTime =======> 2022-07-06T18:43:19.351+03:00
# canBeShared =======> True
# employerManager =======> {'@hhid': 142393470, '@managerId': 11010455, '@userId': 120177246}
# inboxPossibility =======> True
# chatWritePossibility =======> ENABLED_AFTER_INVITATION
# notify =======> False
# links =======> {'desktop': 'https://lipetsk.hh.ru/vacancy/67551709', 'mobile': 'https://m.hh.ru/vacancy/67551709'}
# workSchedule =======> FULL_DAY
# acceptIncompleteResumes =======> False
# driverLicenseTypes =======> [{}]
# languages =======> [{}]
# workingDays =======> [{}]
# workingTimeIntervals =======> [{}]
# workingTimeModes =======> [{}]
# hrBotScenario =======> {'hrBotScenarioId': 6005377, 'enabled': True, 'scenarioCode': 'vacancy_scenario_6005377'}
# vacancyProperties =======> {'properties': [{}]}
# publicationType =======> PREMIUM
# vacancyPlatforms =======> ['HH', 'ZP']
# contactInfo =======> None
# userLabels =======> []
# snippet =======> {'req': None, 'resp': 'Обработку спортивных он-лайн видео-трансляции. HTTP API. Веб-админку с разными пользовательскими ролями. Сбор и обработку данных. ', 'cond': 'Вторым этапом будет оплачиваемое тестовое задание, максимально приближенное к реальным задачам. Плюсы работы у нас: Официальное трудоустройство, зарплата, премии +...', 'skill': 'Python, PostgreSQL, SQL, HTTP', 'desc': None}
# responsesCount =======> 105
# online_users_count =======> 28

# %% [markdown]
# Useful info keys:
# - 'vacancyId' - unique vacancy id which can be used to see description on https://hh.ru/vacancy/[vacancyId]
# - 'name' - no comments )
# - 'company'->'visibleName' + 'company'->'department'->'@name' - department info (if exists)
# - 'area'->'@id', 'area'->'name' - код и название условной географической области поиска
# - 'address'->'displayName', 'address'->'marker'->('@lat', '@lng') - показываемый адрес и координаты для карты
# - 'compensation'->{'from', 'to', 'currencyCode', 'gross'=(True="before taxes", False="clean amount")} (или 'compensation'->'noCompensation', if no data) - salary info
# - 'workSchedule' - full / shift / remote...
# - 'snippet' - vacancy's description pieces: dict('req' - requirements, 'resp' - responsibilities, 'cond' - conditions, 'skill' - ?not used?, 'desc' - ?)
# - 'publicationTime'
# - 'lastChangeTime'

# %% [markdown]
# Lets define function to get necessary data from json:

# %%
df_column_names = [
    'vacancy_id',
    'vacancy_name',
    'company_name',
    'company_dept',
    'area',
    'address',
    'latitude',
    'longitude',
    'salary_from',
    'salary_to',
    'salary_currency',
    'salary_gross',
    'publication_time',
    'last_changed',
    'schedule',
    'req',
    'resp',
    'cond',
    'skills'
]

# %%
def get_record_data(rec):
    result = dict()
    result['vacancy_id'] = rec['vacancyId']
    result['vacancy_name'] = rec['name']
    result['company_name'] = rec['company']['visibleName']
    if rec['company'].get('department', np.NAN) is np.NAN:
        result['company_dept'] = np.NAN
    else:
        result['company_dept'] = rec['company']['department'].get('@name', np.NAN)
    result['area'] = rec['area']['@id']
    if rec.get('address', None) is None:
        result['address'] = np.NAN
    else:
        result['address'] = rec['address'].get('displayName', np.NAN)
        if rec['address'].get('marker', None) is None:
            result['latitude'] = np.NAN
            result['longitude'] = np.NAN
        else:
            result['latitude'] = rec['address']['marker'].get('@lat', np.NAN)
            result['longitude'] = rec['address']['marker'].get('@lng', np.NAN)
    if rec['compensation'].get('noCompensation', None) is None:
        result['salary_from'] = rec['compensation'].get('from', np.NAN)
        result['salary_to'] = rec['compensation'].get('to', np.NAN)
        result['salary_currency'] = rec['compensation'].get('currencyCode', np.NAN)
        result['salary_gross'] = rec['compensation'].get('gross', np.NAN)
    else:
        result['salary_from'] = np.NAN
        result['salary_to'] = np.NAN
        result['salary_currency'] = np.NAN
        result['salary_gross'] = np.NAN
    result['publication_time'] = rec['publicationTime']['@timestamp']
    result['last_changed'] = rec['lastChangeTime']['@timestamp']
    result['schedule'] = rec['workSchedule']
    result['req'] = rec['snippet'].get('req', np.NAN)
    result['resp'] = rec['snippet'].get('resp', np.NAN)
    result['cond'] = rec['snippet'].get('cond', np.NAN)
    result['skills'] = rec['snippet'].get('skills', np.NAN)

    return result

# %%
raw_parsed_data = {name: [] for name in df_column_names}
for rec in vacancies_info:
    parsed = get_record_data(rec)
    for key in df_column_names:
        raw_parsed_data[key].append(parsed.get(key, np.NAN))
print('Control of num of records created:', len(raw_parsed_data['vacancy_id']))
print('Vacancies ID sample: ', raw_parsed_data['vacancy_id'][:10])
# Out:
# Control of num of records created: 4467
# Vacancies ID sample:  [67551709, 67119378, 67547530, 67627301, 67302297, 67583082, 54571452, 67583022, 66891845, 67579748]

# %% [markdown]
# Converting data structures created to pandas DataFrame. Then making readable data in 'publication_time' and 'last_changed' columns. And finally assigning 'vacancy_id' as primary index (it's unique for each record). It will be useful later if I'll decide to update data so I'll be able to filter out existing data or update existing records

# %%
df = pd.DataFrame(raw_parsed_data)
df['publication_time'] = df['publication_time'].apply(pd.to_datetime, unit='s')
df['last_changed'] = df['last_changed'].apply(pd.to_datetime, unit='s')
df.set_index('vacancy_id', inplace=True)
df.head()
# Out:
#                                       vacancy_name  \
# vacancy_id
# 67551709    Backend developer (Python, PostgreSQL)
# 67119378    Product Analyst (продуктовый аналитик)
# 67547530                                  Аналитик
# 67627301                               Аналитик BI
# 67302297                          Ведущий аналитик
#
#                           company_name company_dept  area  \
# vacancy_id
# 67551709    Шамсуллин Рустам Радикович          NaN     1
# 67119378           Мидлэнд Ритейл Груп          NaN     1
# 67547530                         МСУ-1          NaN     1
# 67627301                          А101          NaN     1
# 67302297                      Триафлай          NaN     1
#
#                                         address   latitude  longitude  \
# vacancy_id
# 67551709    Москва, Лужнецкая набережная, 2/4с4  55.715489  37.573627
# 67119378        Москва, улица Льва Толстого, 20  55.735439  37.584981
# 67547530           Москва, Ольховская улица, 49  55.778644  37.674418
# 67627301                     посёлок Коммунарка  55.570395  37.475495
# 67302297       Москва, Турчанинов переулок, 6с2  55.737101  37.597199
#
#             salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 67551709            NaN   350000.0             RUR        False
# 67119378            NaN   180000.0             RUR        False
# 67547530       120000.0        NaN             RUR        False
# 67627301            NaN        NaN             NaN          NaN
# 67302297       200000.0        NaN             RUR        False
#
#               publication_time        last_changed  schedule  \
# vacancy_id
# 67551709   2022-07-06 15:43:19 2022-07-11 19:15:48  FULL_DAY
# 67119378   2022-07-11 09:50:12 2022-07-11 10:00:13  FULL_DAY
# 67547530   2022-07-11 06:42:04 2022-07-11 06:42:05  FULL_DAY
# 67627301   2022-07-10 08:05:10 2022-07-11 06:31:47  FULL_DAY
# 67302297   2022-07-10 14:12:28 2022-07-10 14:59:19  FULL_DAY
#
#                                                           req  \
# vacancy_id
# 67551709                                                 None
# 67119378    Умение выбирать нужный способ оценки данных – ...
# 67547530    Опыт работы в строительстве и знание технологи...
# 67627301    Высшее физико-математическое или экономическое...
# 67302297    ...3х лет на позиции аналитика, включая опыт с...
#
#                                                          resp  \
# vacancy_id
# 67551709    Обработку спортивных он-лайн видео-трансляции....
# 67119378    Взаимодействие со всеми продуктовыми командами...
# 67547530    Нормирование строительно-монтажных работ. Ресу...
# 67627301    Сбор данных из различных источников (1С, SQL, ...
# 67302297    Внедрение продукта конечному заказчику. Вендор...
#
#                                                          cond  skills
# vacancy_id
# 67551709    Вторым этапом будет оплачиваемое тестовое зада...     NaN
# 67119378    Удаленку или офис в пешей доступности от Метро...     NaN
# 67547530    Работа в крупной стабильной строительной компа...     NaN
# 67627301    Удаленный формат работы. График работы: 5/2, с...     NaN
# 67302297    Испытательный срок 3 месяца. Гибкий график (40...     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4467 entries, 67551709 to 66835012
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vacancy_name      4467 non-null   object
#  1   company_name      4467 non-null   object
#  2   company_dept      785 non-null    object
#  3   area              4467 non-null   int64
#  4   address           4090 non-null   object
#  5   latitude          4090 non-null   float64
#  6   longitude         4090 non-null   float64
#  7   salary_from       853 non-null    float64
#  8   salary_to         544 non-null    float64
#  9   salary_currency   988 non-null    object
#  10  salary_gross      988 non-null    object
#  11  publication_time  4467 non-null   datetime64[ns]
#  12  last_changed      4467 non-null   datetime64[ns]
#  13  schedule          4467 non-null   object
#  14  req               4439 non-null   object
#  15  resp              4463 non-null   object
#  16  cond              4315 non-null   object
#  17  skills            0 non-null      float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(10)
# memory usage: 663.1+ KB

# %%
df.to_csv('datasets/'+output_filename+'.csv')
