# %% [markdown]
# # Enriching dataset by scraping additional info about vacancies

# %%
#from datetime import datetime as dt

import numpy as np
print('Numpy version:', np.__version__)
import pandas as pd
print('Pandas version:', pd.__version__)
import matplotlib as mpl
print('Matplotlib version:', mpl.__version__)
import matplotlib.pyplot as plt
import seaborn as sns
print('Seaborn version:', sns.__version__)

from bs4 import BeautifulSoup
import json

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium import webdriver

import sys

from tqdm import tqdm
# Out:
# Numpy version: 1.23.5
# Pandas version: 1.5.2
# Matplotlib version: 3.6.2
# Seaborn version: 0.12.1

# %%
import logging

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

handler = logging.StreamHandler(stream=sys.stdout)
handler.setFormatter(logging.Formatter(fmt='[%(asctime)s: %(funcName)s: %(levelname)s] %(message)s'))
logger.addHandler(handler)

# %% [markdown]
# #### Loading dataset to enrich

# %%
df_filename = 'datasets/vacancies-no-duplicates-2022-11-27.csv'

# %%
df = pd.read_csv(df_filename, index_col=0)
df.head()
# Out:
#                                                vacancy_name  \
# vacancy_id
# 72750262    Ведущий аналитик (качество данных\Data quality)
# 72674818                                    Аналитик данных
# 72527010                               Аналитик базы данных
# 70839955                      Аналитик данных (Data Office)
# 72943931                                Аналитик ГЕО данных
#
#                                 company_name  \
# vacancy_id
# 72750262                      Банк ВТБ (ПАО)
# 72674818    Городские информационные системы
# 72527010                              Вектор
# 70839955                       VK, ВКонтакте
# 72943931        ГАУ ИНСТИТУТ ГЕНПЛАНА МОСКВЫ
#
#                                          address   latitude  longitude  \
# vacancy_id
# 72750262    Москва, Пресненская набережная, 10с1  55.748914  37.535466
# 72674818                                     NaN        NaN        NaN
# 72527010    Красногорск, бульвар Строителей, 4к1  55.814462  37.385412
# 70839955                                     NaN        NaN        NaN
# 72943931       Москва, 2-я Брестская улица, 2/14  55.769641  37.593121
#
#             salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 72750262            NaN        NaN             NaN          NaN
# 72674818       120000.0   180000.0             RUR        False
# 72527010        70000.0        NaN             RUR        False
# 70839955            NaN        NaN             NaN          NaN
# 72943931            NaN        NaN             NaN          NaN
#
#                publication_time         last_changed  schedule  \
# vacancy_id
# 72750262    2022-11-23 07:08:44  2022-11-23 07:08:44  FULL_DAY
# 72674818    2022-11-27 09:36:56  2022-11-27 10:21:43  FULL_DAY
# 72527010    2022-11-27 08:32:14  2022-11-27 09:21:16  FULL_DAY
# 70839955    2022-11-27 07:02:13  2022-11-27 07:02:13  FULL_DAY
# 72943931    2022-11-25 13:00:40  2022-11-26 19:50:13  FULL_DAY
#
#                                                           req  \
# vacancy_id
# 72750262    Высшее образование. Опыт работы в качестве ана...
# 72674818    ...заданий, валидация данных. Особенности OLAP...
# 72527010    Умение обрабатывать большие объемы данных и ви...
# 70839955    Понимаете основные продуктовые и бизнес-метрик...
# 72943931    Хорошее знание инструментов WEB-картографии и ...
#
#                                                          resp  \
# vacancy_id
# 72750262    Мониторинг качества данных, организация процес...
# 72674818    ...SQL-запросы, хранимые процедуры, вьюшки. Ви...
# 72527010    ...данных и подготовка информации для расчетов...
# 70839955    Плотно взаимодействовать на ежедневной основе ...
# 72943931    Интеграция данных из различных источников в ед...
#
#                                                          cond
# vacancy_id
# 72750262    Трудоустройство согласно Законодательству. Кон...
# 72674818    Удалённая работа. Уютный коллектив. Минимум бю...
# 72527010    График: 5/2 , с 8:00 до 17:00,выходные: суббот...
# 70839955                                                  NaN
# 72943931    Стабильная заработная плата, включающая оклад,...

# %% [markdown]
# #### Setting up browser

# %%
chrome_mode = 'headed' #'headless' # for debug purposes we can change this value to any but 'headless' to run Chrome in standard mode
chrome_options = Options()
if chrome_mode == 'headless':
    chrome_options.add_argument('--disable-extensions')
    chrome_options.add_argument('--disable-gpu')
    chrome_options.add_argument('--headless')
service = Service(executable_path="d:\\Applications\\WebDriver\\chromedriver-107-x32.exe")
browser = webdriver.Chrome(service=service, options=chrome_options)

# %%
base_url = 'https://hh.ru/vacancy/{}'

# %% [markdown]
# #### Analyzing single vacancy webpage structure

# %%
browser.get(base_url.format(df.index[0]))
soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
#<span class="bloko-tag__section bloko-tag__section_text" data-qa="bloko-tag__text">Английский язык</span>
for item in soup.find_all(attrs={'data-qa': 'bloko-tag__text'}):
    print(item.text)
# Out:
# Анализ данных
# Аналитическое мышление
# Data quality

# %%
soup.find_all(attrs={'data-qa': 'vacancy-description'})[0]
# Out:
# <div class="vacancy-branded-user-content" data-qa="vacancy-description" itemprop="description"><strong>Обязанности:</strong> <ul> <li>участие в проектах по внедрению и развитию инструментов и процессов управления данными;</li> <li>разработка нормативной документации в части управления данными (качеством, доступностью, актуальностью, полнотой, стоимостью и т.д.);</li> <li>выстраивание взаимоотношений с внутренними клиентами в рамках функционально – ролевой модели управления данными;</li> <li>мониторинг качества данных, организация процессов управления инцидентами и проблемами качества данных, реализация мероприятий по повышению качества данных;</li> <li>участие в разработке бизнес - глоссария терминов Банка;</li> </ul> <strong>Требования:</strong> <ul> <li>высшее образование;</li> <li>опыт работы в качестве аналитика не менее 3-х лет;</li> <li>з​нания в области управленческого, бухгалтерского учета, МСФО, риск - отчетности;</li> <li>опыт руководства проектами или участия в проектах по внедрению аналитических систем, DWH, BI;</li> <li>опыт работы по направлению Data quality будет преимуществом;</li> <li>предметные знания промышленных инструментов управления данными (Informatica, IBM, SAS, Oracle);</li> <li>опыт проектирования моделей данных в промышленных CASE инструментах (Sybase PowerDesigner, IBM Data Architect и т.д.);</li> <li>опыт подготовки презентационных материалов, проведения рабочих встреч, ведения деловой переписки;</li> <li>высокие коммуникативные навыки, стрессоустойчивость, усидчивость.</li> </ul> <strong>Условия:</strong> <ul> <li>трудоустройство согласно Законодательству;</li> <li>конкурентная заработная плата;</li> <li>профессиональное обучение и развитие;</li> <li>добровольное медицинское страхование, льготные условия кредитования;</li> <li>корпоративная пенсионная программа, материальная помощь;</li> <li>спортивная жизнь и корпоративные мероприятия;</li> <li>возможность построить карьеру в ведущем банке России.</li> </ul></div>

# %% [markdown]
# Page code analysis shows that we can take key skills from tags where `data-qa="bloko-tag__text"` and vacancy description from tags where `data-qa="vacancy-description"` and vacancy experience needed from tags where `data-qa="vacancy-experience"`.
# We can get cleaned text using _.text_ property

# %%
df['full_description'] = ''
df['key_skills'] = ''
df['experience_needed'] = ''
df.head()
# Out:
#                                                vacancy_name  \
# vacancy_id
# 72750262    Ведущий аналитик (качество данных\Data quality)
# 72674818                                    Аналитик данных
# 72527010                               Аналитик базы данных
# 70839955                      Аналитик данных (Data Office)
# 72943931                                Аналитик ГЕО данных
#
#                                 company_name  \
# vacancy_id
# 72750262                      Банк ВТБ (ПАО)
# 72674818    Городские информационные системы
# 72527010                              Вектор
# 70839955                       VK, ВКонтакте
# 72943931        ГАУ ИНСТИТУТ ГЕНПЛАНА МОСКВЫ
#
#                                          address   latitude  longitude  \
# vacancy_id
# 72750262    Москва, Пресненская набережная, 10с1  55.748914  37.535466
# 72674818                                     NaN        NaN        NaN
# 72527010    Красногорск, бульвар Строителей, 4к1  55.814462  37.385412
# 70839955                                     NaN        NaN        NaN
# 72943931       Москва, 2-я Брестская улица, 2/14  55.769641  37.593121
#
#             salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 72750262            NaN        NaN             NaN          NaN
# 72674818       120000.0   180000.0             RUR        False
# 72527010        70000.0        NaN             RUR        False
# 70839955            NaN        NaN             NaN          NaN
# 72943931            NaN        NaN             NaN          NaN
#
#                publication_time         last_changed  schedule  \
# vacancy_id
# 72750262    2022-11-23 07:08:44  2022-11-23 07:08:44  FULL_DAY
# 72674818    2022-11-27 09:36:56  2022-11-27 10:21:43  FULL_DAY
# 72527010    2022-11-27 08:32:14  2022-11-27 09:21:16  FULL_DAY
# 70839955    2022-11-27 07:02:13  2022-11-27 07:02:13  FULL_DAY
# 72943931    2022-11-25 13:00:40  2022-11-26 19:50:13  FULL_DAY
#
#                                                           req  \
# vacancy_id
# 72750262    Высшее образование. Опыт работы в качестве ана...
# 72674818    ...заданий, валидация данных. Особенности OLAP...
# 72527010    Умение обрабатывать большие объемы данных и ви...
# 70839955    Понимаете основные продуктовые и бизнес-метрик...
# 72943931    Хорошее знание инструментов WEB-картографии и ...
#
#                                                          resp  \
# vacancy_id
# 72750262    Мониторинг качества данных, организация процес...
# 72674818    ...SQL-запросы, хранимые процедуры, вьюшки. Ви...
# 72527010    ...данных и подготовка информации для расчетов...
# 70839955    Плотно взаимодействовать на ежедневной основе ...
# 72943931    Интеграция данных из различных источников в ед...
#
#                                                          cond  \
# vacancy_id
# 72750262    Трудоустройство согласно Законодательству. Кон...
# 72674818    Удалённая работа. Уютный коллектив. Минимум бю...
# 72527010    График: 5/2 , с 8:00 до 17:00,выходные: суббот...
# 70839955                                                  NaN
# 72943931    Стабильная заработная плата, включающая оклад,...
#
#            full_description key_skills experience_needed
# vacancy_id
# 72750262
# 72674818
# 72527010
# 70839955
# 72943931

# %% [markdown]
# Let's test and fill both new columns for first 3 rows of dataset => SUCCESSFUL
# Filling all rows...

# %%
logger.debug('Beginning parsing vacancies')
total_num = len(df.index)
for i, vac_id in enumerate(df.index):
    logger.debug('Parsing vacancy ID {} ({} / {}) parsing'.format(vac_id, i+1, total_num))
    browser.get(base_url.format(vac_id))
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    descr = soup.find_all(attrs={'data-qa': 'vacancy-description'})
    if len(descr) > 0:
        df.loc[vac_id, 'full_description'] = descr[0].text
    descr = soup.find_all(attrs={'data-qa': 'bloko-tag__text'})
    if len(descr) > 0:
        df.loc[vac_id, 'key_skills'] = ';'.join([i.text for i in descr])
    descr = soup.find_all(attrs={'data-qa': 'vacancy-experience'})
    if len(descr) > 0:
        df.loc[vac_id, 'experience_needed'] = descr[0].text
logger.debug('Parsing finished')
df.head()
# Out:
# [2022-11-27 20:06:22,727: <module>: DEBUG] Beginning parsing vacancies
# [2022-11-27 20:06:22,739: <module>: DEBUG] Parsing vacancy ID 72750262 (0 / 435) parsing
# [2022-11-27 20:06:25,359: <module>: DEBUG] Parsing vacancy ID 72674818 (1 / 435) parsing
# [2022-11-27 20:06:27,460: <module>: DEBUG] Parsing vacancy ID 72527010 (2 / 435) parsing
# [2022-11-27 20:06:30,323: <module>: DEBUG] Parsing vacancy ID 70839955 (3 / 435) parsing
# [2022-11-27 20:06:32,547: <module>: DEBUG] Parsing vacancy ID 72943931 (4 / 435) parsing
# [2022-11-27 20:06:34,729: <module>: DEBUG] Parsing vacancy ID 72677600 (5 / 435) parsing
# [2022-11-27 20:06:37,305: <module>: DEBUG] Parsing vacancy ID 72785935 (6 / 435) parsing
# [2022-11-27 20:06:39,518: <module>: DEBUG] Parsing vacancy ID 72681497 (7 / 435) parsing
# [2022-11-27 20:06:41,378: <module>: DEBUG] Parsing vacancy ID 71424469 (8 / 435) parsing
# [2022-11-27 20:06:43,674: <module>: DEBUG] Parsing vacancy ID 72432302 (9 / 435) parsing
# [2022-11-27 20:06:46,883: <module>: DEBUG] Parsing vacancy ID 72730952 (10 / 435) parsing
# [2022-11-27 20:06:51,643: <module>: DEBUG] Parsing vacancy ID 49495729 (11 / 435) parsing
# [2022-11-27 20:06:53,661: <module>: DEBUG] Parsing vacancy ID 72454638 (12 / 435) parsing
# [2022-11-27 20:06:56,189: <module>: DEBUG] Parsing vacancy ID 71811656 (13 / 435) parsing
# [2022-11-27 20:06:58,189: <module>: DEBUG] Parsing vacancy ID 72947996 (14 / 435) parsing
# [2022-11-27 20:07:00,825: <module>: DEBUG] Parsing vacancy ID 71696102 (15 / 435) parsing
# [2022-11-27 20:07:04,189: <module>: DEBUG] Parsing vacancy ID 72374586 (16 / 435) parsing
# [2022-11-27 20:07:06,909: <module>: DEBUG] Parsing vacancy ID 72753000 (17 / 435) parsing
# [2022-11-27 20:07:08,949: <module>: DEBUG] Parsing vacancy ID 72700550 (18 / 435) parsing
# [2022-11-27 20:07:12,707: <module>: DEBUG] Parsing vacancy ID 69166398 (19 / 435) parsing
# [2022-11-27 20:07:15,276: <module>: DEBUG] Parsing vacancy ID 72929553 (20 / 435) parsing
# [2022-11-27 20:07:17,818: <module>: DEBUG] Parsing vacancy ID 72932911 (21 / 435) parsing
# [2022-11-27 20:07:19,827: <module>: DEBUG] Parsing vacancy ID 72178984 (22 / 435) parsing
# [2022-11-27 20:07:22,700: <module>: DEBUG] Parsing vacancy ID 72931854 (23 / 435) parsing
# [2022-11-27 20:07:25,079: <module>: DEBUG] Parsing vacancy ID 68580282 (24 / 435) parsing
# [2022-11-27 20:07:27,724: <module>: DEBUG] Parsing vacancy ID 72177207 (25 / 435) parsing
# [2022-11-27 20:07:29,873: <module>: DEBUG] Parsing vacancy ID 33368305 (26 / 435) parsing
# [2022-11-27 20:07:31,947: <module>: DEBUG] Parsing vacancy ID 71053555 (27 / 435) parsing
# [2022-11-27 20:07:33,911: <module>: DEBUG] Parsing vacancy ID 69981940 (28 / 435) parsing
# [2022-11-27 20:07:36,072: <module>: DEBUG] Parsing vacancy ID 49898429 (29 / 435) parsing
# [2022-11-27 20:07:38,236: <module>: DEBUG] Parsing vacancy ID 72891556 (30 / 435) parsing
# [2022-11-27 20:07:40,408: <module>: DEBUG] Parsing vacancy ID 72859350 (31 / 435) parsing
# [2022-11-27 20:07:43,049: <module>: DEBUG] Parsing vacancy ID 71765299 (32 / 435) parsing
# [2022-11-27 20:07:45,720: <module>: DEBUG] Parsing vacancy ID 70331402 (33 / 435) parsing
# [2022-11-27 20:07:49,840: <module>: DEBUG] Parsing vacancy ID 71157906 (34 / 435) parsing
# [2022-11-27 20:07:53,128: <module>: DEBUG] Parsing vacancy ID 71822693 (35 / 435) parsing
# [2022-11-27 20:07:55,585: <module>: DEBUG] Parsing vacancy ID 72872759 (36 / 435) parsing
# [2022-11-27 20:07:57,685: <module>: DEBUG] Parsing vacancy ID 72401181 (37 / 435) parsing
# [2022-11-27 20:07:59,885: <module>: DEBUG] Parsing vacancy ID 72886096 (38 / 435) parsing
# [2022-11-27 20:08:01,883: <module>: DEBUG] Parsing vacancy ID 72803329 (39 / 435) parsing
# [2022-11-27 20:08:04,266: <module>: DEBUG] Parsing vacancy ID 72565713 (40 / 435) parsing
# [2022-11-27 20:08:06,755: <module>: DEBUG] Parsing vacancy ID 72868369 (41 / 435) parsing
# [2022-11-27 20:08:08,635: <module>: DEBUG] Parsing vacancy ID 72851580 (42 / 435) parsing
# [2022-11-27 20:08:10,666: <module>: DEBUG] Parsing vacancy ID 72858094 (43 / 435) parsing
# [2022-11-27 20:08:12,848: <module>: DEBUG] Parsing vacancy ID 72819761 (44 / 435) parsing
# [2022-11-27 20:08:15,135: <module>: DEBUG] Parsing vacancy ID 71278171 (45 / 435) parsing
# [2022-11-27 20:08:17,297: <module>: DEBUG] Parsing vacancy ID 68685601 (46 / 435) parsing
# [2022-11-27 20:08:19,155: <module>: DEBUG] Parsing vacancy ID 72815373 (47 / 435) parsing
# [2022-11-27 20:08:21,376: <module>: DEBUG] Parsing vacancy ID 71520097 (48 / 435) parsing
# [2022-11-27 20:08:23,553: <module>: DEBUG] Parsing vacancy ID 70167434 (49 / 435) parsing
# [2022-11-27 20:08:26,862: <module>: DEBUG] Parsing vacancy ID 72791375 (50 / 435) parsing
# [2022-11-27 20:08:28,998: <module>: DEBUG] Parsing vacancy ID 72172721 (51 / 435) parsing
# [2022-11-27 20:08:31,134: <module>: DEBUG] Parsing vacancy ID 70368551 (52 / 435) parsing
# [2022-11-27 20:08:33,177: <module>: DEBUG] Parsing vacancy ID 72743750 (53 / 435) parsing
# [2022-11-27 20:08:35,275: <module>: DEBUG] Parsing vacancy ID 72885814 (54 / 435) parsing
# [2022-11-27 20:08:38,506: <module>: DEBUG] Parsing vacancy ID 72756977 (55 / 435) parsing
# [2022-11-27 20:08:40,609: <module>: DEBUG] Parsing vacancy ID 70042203 (56 / 435) parsing
# [2022-11-27 20:08:42,592: <module>: DEBUG] Parsing vacancy ID 72816947 (57 / 435) parsing
# [2022-11-27 20:08:44,996: <module>: DEBUG] Parsing vacancy ID 72750012 (58 / 435) parsing
# [2022-11-27 20:08:47,048: <module>: DEBUG] Parsing vacancy ID 72792299 (59 / 435) parsing
# [2022-11-27 20:08:49,190: <module>: DEBUG] Parsing vacancy ID 71040857 (60 / 435) parsing
# [2022-11-27 20:08:51,148: <module>: DEBUG] Parsing vacancy ID 72673320 (61 / 435) parsing
# [2022-11-27 20:08:53,407: <module>: DEBUG] Parsing vacancy ID 72748002 (62 / 435) parsing
# [2022-11-27 20:08:55,566: <module>: DEBUG] Parsing vacancy ID 71063549 (63 / 435) parsing
# [2022-11-27 20:08:58,386: <module>: DEBUG] Parsing vacancy ID 72728137 (64 / 435) parsing
# [2022-11-27 20:09:00,627: <module>: DEBUG] Parsing vacancy ID 72759772 (65 / 435) parsing
# [2022-11-27 20:09:02,909: <module>: DEBUG] Parsing vacancy ID 72745842 (66 / 435) parsing
# [2022-11-27 20:09:05,100: <module>: DEBUG] Parsing vacancy ID 71020353 (67 / 435) parsing
# [2022-11-27 20:09:07,247: <module>: DEBUG] Parsing vacancy ID 72727660 (68 / 435) parsing
# [2022-11-27 20:09:09,633: <module>: DEBUG] Parsing vacancy ID 71574758 (69 / 435) parsing
# [2022-11-27 20:09:11,897: <module>: DEBUG] Parsing vacancy ID 70485345 (70 / 435) parsing
# [2022-11-27 20:09:14,288: <module>: DEBUG] Parsing vacancy ID 72678724 (71 / 435) parsing
# [2022-11-27 20:09:16,366: <module>: DEBUG] Parsing vacancy ID 71677969 (72 / 435) parsing
# [2022-11-27 20:09:18,454: <module>: DEBUG] Parsing vacancy ID 71564767 (73 / 435) parsing
# [2022-11-27 20:09:20,900: <module>: DEBUG] Parsing vacancy ID 71503885 (74 / 435) parsing
# [2022-11-27 20:09:23,370: <module>: DEBUG] Parsing vacancy ID 71644645 (75 / 435) parsing
# [2022-11-27 20:09:25,356: <module>: DEBUG] Parsing vacancy ID 72676930 (76 / 435) parsing
# [2022-11-27 20:09:27,736: <module>: DEBUG] Parsing vacancy ID 72321634 (77 / 435) parsing
# [2022-11-27 20:09:30,273: <module>: DEBUG] Parsing vacancy ID 72670953 (78 / 435) parsing
# [2022-11-27 20:09:32,667: <module>: DEBUG] Parsing vacancy ID 72363279 (79 / 435) parsing
# [2022-11-27 20:09:34,726: <module>: DEBUG] Parsing vacancy ID 72461633 (80 / 435) parsing
# [2022-11-27 20:09:37,617: <module>: DEBUG] Parsing vacancy ID 72671653 (81 / 435) parsing
# [2022-11-27 20:09:39,393: <module>: DEBUG] Parsing vacancy ID 67337786 (82 / 435) parsing
# [2022-11-27 20:09:41,803: <module>: DEBUG] Parsing vacancy ID 71575680 (83 / 435) parsing
# [2022-11-27 20:09:44,035: <module>: DEBUG] Parsing vacancy ID 70458752 (84 / 435) parsing
# [2022-11-27 20:09:46,307: <module>: DEBUG] Parsing vacancy ID 72693573 (85 / 435) parsing
# [2022-11-27 20:09:48,362: <module>: DEBUG] Parsing vacancy ID 72683785 (86 / 435) parsing
# [2022-11-27 20:09:50,350: <module>: DEBUG] Parsing vacancy ID 72077639 (87 / 435) parsing
# [2022-11-27 20:09:52,779: <module>: DEBUG] Parsing vacancy ID 70347957 (88 / 435) parsing
# [2022-11-27 20:09:55,079: <module>: DEBUG] Parsing vacancy ID 69301607 (89 / 435) parsing
# [2022-11-27 20:09:58,262: <module>: DEBUG] Parsing vacancy ID 69817436 (90 / 435) parsing
# [2022-11-27 20:10:02,004: <module>: DEBUG] Parsing vacancy ID 70110966 (91 / 435) parsing
# [2022-11-27 20:10:04,212: <module>: DEBUG] Parsing vacancy ID 69139141 (92 / 435) parsing
# [2022-11-27 20:10:06,604: <module>: DEBUG] Parsing vacancy ID 72483352 (93 / 435) parsing
# [2022-11-27 20:10:08,964: <module>: DEBUG] Parsing vacancy ID 71393741 (94 / 435) parsing
# [2022-11-27 20:10:11,226: <module>: DEBUG] Parsing vacancy ID 71286986 (95 / 435) parsing
# [2022-11-27 20:10:13,472: <module>: DEBUG] Parsing vacancy ID 72545533 (96 / 435) parsing
# [2022-11-27 20:10:15,569: <module>: DEBUG] Parsing vacancy ID 69058124 (97 / 435) parsing
# [2022-11-27 20:10:17,827: <module>: DEBUG] Parsing vacancy ID 71785472 (98 / 435) parsing
# [2022-11-27 20:10:20,925: <module>: DEBUG] Parsing vacancy ID 72483827 (99 / 435) parsing
# [2022-11-27 20:10:23,252: <module>: DEBUG] Parsing vacancy ID 72543609 (100 / 435) parsing
# [2022-11-27 20:10:25,401: <module>: DEBUG] Parsing vacancy ID 71343651 (101 / 435) parsing
# [2022-11-27 20:10:27,725: <module>: DEBUG] Parsing vacancy ID 72474440 (102 / 435) parsing
# [2022-11-27 20:10:29,929: <module>: DEBUG] Parsing vacancy ID 72531059 (103 / 435) parsing
# [2022-11-27 20:10:32,490: <module>: DEBUG] Parsing vacancy ID 70020940 (104 / 435) parsing
# [2022-11-27 20:10:34,698: <module>: DEBUG] Parsing vacancy ID 72531692 (105 / 435) parsing
# [2022-11-27 20:10:37,075: <module>: DEBUG] Parsing vacancy ID 72335867 (106 / 435) parsing
# [2022-11-27 20:10:39,167: <module>: DEBUG] Parsing vacancy ID 72083236 (107 / 435) parsing
# [2022-11-27 20:10:41,516: <module>: DEBUG] Parsing vacancy ID 72405936 (108 / 435) parsing
# [2022-11-27 20:10:43,686: <module>: DEBUG] Parsing vacancy ID 72402526 (109 / 435) parsing
# [2022-11-27 20:10:45,933: <module>: DEBUG] Parsing vacancy ID 72436370 (110 / 435) parsing
# [2022-11-27 20:10:48,208: <module>: DEBUG] Parsing vacancy ID 71824954 (111 / 435) parsing
# [2022-11-27 20:11:04,246: <module>: DEBUG] Parsing vacancy ID 68217245 (112 / 435) parsing
# [2022-11-27 20:11:07,394: <module>: DEBUG] Parsing vacancy ID 72402149 (113 / 435) parsing
# [2022-11-27 20:11:09,744: <module>: DEBUG] Parsing vacancy ID 72457596 (114 / 435) parsing
# [2022-11-27 20:11:13,640: <module>: DEBUG] Parsing vacancy ID 72028680 (115 / 435) parsing
# [2022-11-27 20:11:15,769: <module>: DEBUG] Parsing vacancy ID 71221332 (116 / 435) parsing
# [2022-11-27 20:11:18,185: <module>: DEBUG] Parsing vacancy ID 71504560 (117 / 435) parsing
# [2022-11-27 20:11:20,352: <module>: DEBUG] Parsing vacancy ID 67690935 (118 / 435) parsing
# [2022-11-27 20:11:22,520: <module>: DEBUG] Parsing vacancy ID 71204490 (119 / 435) parsing
# [2022-11-27 20:11:24,732: <module>: DEBUG] Parsing vacancy ID 71840083 (120 / 435) parsing
# [2022-11-27 20:11:27,031: <module>: DEBUG] Parsing vacancy ID 71385303 (121 / 435) parsing
# [2022-11-27 20:11:29,402: <module>: DEBUG] Parsing vacancy ID 72314401 (122 / 435) parsing
# [2022-11-27 20:11:31,924: <module>: DEBUG] Parsing vacancy ID 72309166 (123 / 435) parsing
# [2022-11-27 20:11:34,253: <module>: DEBUG] Parsing vacancy ID 72375543 (124 / 435) parsing
# [2022-11-27 20:11:36,612: <module>: DEBUG] Parsing vacancy ID 72430037 (125 / 435) parsing
# [2022-11-27 20:11:39,211: <module>: DEBUG] Parsing vacancy ID 72492020 (126 / 435) parsing
# [2022-11-27 20:11:41,359: <module>: DEBUG] Parsing vacancy ID 72336364 (127 / 435) parsing
# [2022-11-27 20:11:43,541: <module>: DEBUG] Parsing vacancy ID 69820273 (128 / 435) parsing
# [2022-11-27 20:11:45,859: <module>: DEBUG] Parsing vacancy ID 69026702 (129 / 435) parsing
# [2022-11-27 20:11:48,202: <module>: DEBUG] Parsing vacancy ID 71545541 (130 / 435) parsing
# [2022-11-27 20:11:50,246: <module>: DEBUG] Parsing vacancy ID 72291596 (131 / 435) parsing
# [2022-11-27 20:11:52,504: <module>: DEBUG] Parsing vacancy ID 72323790 (132 / 435) parsing
# [2022-11-27 20:11:56,180: <module>: DEBUG] Parsing vacancy ID 71502317 (133 / 435) parsing
# [2022-11-27 20:11:58,809: <module>: DEBUG] Parsing vacancy ID 72179862 (134 / 435) parsing
# [2022-11-27 20:12:01,090: <module>: DEBUG] Parsing vacancy ID 71703471 (135 / 435) parsing
# [2022-11-27 20:12:03,040: <module>: DEBUG] Parsing vacancy ID 72231657 (136 / 435) parsing
# [2022-11-27 20:12:05,684: <module>: DEBUG] Parsing vacancy ID 69975800 (137 / 435) parsing
# [2022-11-27 20:12:07,811: <module>: DEBUG] Parsing vacancy ID 68144682 (138 / 435) parsing
# [2022-11-27 20:12:10,832: <module>: DEBUG] Parsing vacancy ID 72310769 (139 / 435) parsing
# [2022-11-27 20:12:13,559: <module>: DEBUG] Parsing vacancy ID 71614468 (140 / 435) parsing
# [2022-11-27 20:12:16,456: <module>: DEBUG] Parsing vacancy ID 67697383 (141 / 435) parsing
# [2022-11-27 20:12:18,664: <module>: DEBUG] Parsing vacancy ID 68148509 (142 / 435) parsing
# [2022-11-27 20:12:21,599: <module>: DEBUG] Parsing vacancy ID 69343784 (143 / 435) parsing
# [2022-11-27 20:12:24,361: <module>: DEBUG] Parsing vacancy ID 72227204 (144 / 435) parsing
# [2022-11-27 20:12:26,276: <module>: DEBUG] Parsing vacancy ID 72126930 (145 / 435) parsing
# [2022-11-27 20:13:03,993: <module>: DEBUG] Parsing vacancy ID 72413000 (146 / 435) parsing
# [2022-11-27 20:13:06,591: <module>: DEBUG] Parsing vacancy ID 71710769 (147 / 435) parsing
# [2022-11-27 20:13:09,012: <module>: DEBUG] Parsing vacancy ID 71064340 (148 / 435) parsing
# [2022-11-27 20:13:11,201: <module>: DEBUG] Parsing vacancy ID 71188226 (149 / 435) parsing
# [2022-11-27 20:13:13,483: <module>: DEBUG] Parsing vacancy ID 72088508 (150 / 435) parsing
# [2022-11-27 20:13:15,563: <module>: DEBUG] Parsing vacancy ID 72030352 (151 / 435) parsing
# [2022-11-27 20:13:17,650: <module>: DEBUG] Parsing vacancy ID 72022495 (152 / 435) parsing
# [2022-11-27 20:13:20,130: <module>: DEBUG] Parsing vacancy ID 72373527 (153 / 435) parsing
# [2022-11-27 20:13:22,541: <module>: DEBUG] Parsing vacancy ID 72064201 (154 / 435) parsing
# [2022-11-27 20:13:24,653: <module>: DEBUG] Parsing vacancy ID 72028562 (155 / 435) parsing
# [2022-11-27 20:13:26,837: <module>: DEBUG] Parsing vacancy ID 71269931 (156 / 435) parsing
# [2022-11-27 20:14:25,882: <module>: DEBUG] Parsing vacancy ID 71095376 (157 / 435) parsing
# [2022-11-27 20:14:28,443: <module>: DEBUG] Parsing vacancy ID 72033782 (158 / 435) parsing
# [2022-11-27 20:14:30,687: <module>: DEBUG] Parsing vacancy ID 72227398 (159 / 435) parsing
# [2022-11-27 20:14:32,986: <module>: DEBUG] Parsing vacancy ID 72105864 (160 / 435) parsing
# [2022-11-27 20:14:35,783: <module>: DEBUG] Parsing vacancy ID 71950662 (161 / 435) parsing
# [2022-11-27 20:14:38,705: <module>: DEBUG] Parsing vacancy ID 71862774 (162 / 435) parsing
# [2022-11-27 20:14:41,456: <module>: DEBUG] Parsing vacancy ID 72050409 (163 / 435) parsing
# [2022-11-27 20:14:44,547: <module>: DEBUG] Parsing vacancy ID 66550927 (164 / 435) parsing
# [2022-11-27 20:14:47,169: <module>: DEBUG] Parsing vacancy ID 69898430 (165 / 435) parsing
# [2022-11-27 20:14:49,828: <module>: DEBUG] Parsing vacancy ID 71873472 (166 / 435) parsing
# [2022-11-27 20:14:52,387: <module>: DEBUG] Parsing vacancy ID 72268334 (167 / 435) parsing
# [2022-11-27 20:14:54,567: <module>: DEBUG] Parsing vacancy ID 71908454 (168 / 435) parsing
# [2022-11-27 20:14:56,785: <module>: DEBUG] Parsing vacancy ID 70852713 (169 / 435) parsing
# [2022-11-27 20:14:59,742: <module>: DEBUG] Parsing vacancy ID 70985142 (170 / 435) parsing
# [2022-11-27 20:15:03,293: <module>: DEBUG] Parsing vacancy ID 71833531 (171 / 435) parsing
# [2022-11-27 20:15:05,441: <module>: DEBUG] Parsing vacancy ID 71784459 (172 / 435) parsing
# [2022-11-27 20:15:08,240: <module>: DEBUG] Parsing vacancy ID 71611374 (173 / 435) parsing
# [2022-11-27 20:15:10,531: <module>: DEBUG] Parsing vacancy ID 71834309 (174 / 435) parsing
# [2022-11-27 20:15:13,037: <module>: DEBUG] Parsing vacancy ID 48276535 (175 / 435) parsing
# [2022-11-27 20:15:14,992: <module>: DEBUG] Parsing vacancy ID 69572448 (176 / 435) parsing
# [2022-11-27 20:15:17,096: <module>: DEBUG] Parsing vacancy ID 72002104 (177 / 435) parsing
# [2022-11-27 20:15:19,522: <module>: DEBUG] Parsing vacancy ID 71764233 (178 / 435) parsing
# [2022-11-27 20:15:21,837: <module>: DEBUG] Parsing vacancy ID 70994979 (179 / 435) parsing
# [2022-11-27 20:15:24,309: <module>: DEBUG] Parsing vacancy ID 71922694 (180 / 435) parsing
# [2022-11-27 20:15:26,595: <module>: DEBUG] Parsing vacancy ID 71919952 (181 / 435) parsing
# [2022-11-27 20:15:28,757: <module>: DEBUG] Parsing vacancy ID 71911135 (182 / 435) parsing
# [2022-11-27 20:15:31,014: <module>: DEBUG] Parsing vacancy ID 71862733 (183 / 435) parsing
# [2022-11-27 20:15:33,325: <module>: DEBUG] Parsing vacancy ID 71561867 (184 / 435) parsing
# [2022-11-27 20:15:35,644: <module>: DEBUG] Parsing vacancy ID 71779840 (185 / 435) parsing
# [2022-11-27 20:15:38,412: <module>: DEBUG] Parsing vacancy ID 69315730 (186 / 435) parsing
# [2022-11-27 20:15:41,157: <module>: DEBUG] Parsing vacancy ID 70821226 (187 / 435) parsing
# [2022-11-27 20:15:44,316: <module>: DEBUG] Parsing vacancy ID 71864456 (188 / 435) parsing
# [2022-11-27 20:15:46,849: <module>: DEBUG] Parsing vacancy ID 71706802 (189 / 435) parsing
# [2022-11-27 20:15:49,155: <module>: DEBUG] Parsing vacancy ID 71767705 (190 / 435) parsing
# [2022-11-27 20:15:52,277: <module>: DEBUG] Parsing vacancy ID 71817099 (191 / 435) parsing
# [2022-11-27 20:15:54,420: <module>: DEBUG] Parsing vacancy ID 71916303 (192 / 435) parsing
# [2022-11-27 20:15:56,798: <module>: DEBUG] Parsing vacancy ID 71785393 (193 / 435) parsing
# [2022-11-27 20:15:58,900: <module>: DEBUG] Parsing vacancy ID 71758879 (194 / 435) parsing
# [2022-11-27 20:16:01,048: <module>: DEBUG] Parsing vacancy ID 71775706 (195 / 435) parsing
# [2022-11-27 20:16:03,650: <module>: DEBUG] Parsing vacancy ID 71731624 (196 / 435) parsing
# [2022-11-27 20:16:07,761: <module>: DEBUG] Parsing vacancy ID 72057080 (197 / 435) parsing
# [2022-11-27 20:16:11,136: <module>: DEBUG] Parsing vacancy ID 69899632 (198 / 435) parsing
# [2022-11-27 20:16:14,236: <module>: DEBUG] Parsing vacancy ID 71882774 (199 / 435) parsing
# [2022-11-27 20:16:17,802: <module>: DEBUG] Parsing vacancy ID 71236171 (200 / 435) parsing
# [2022-11-27 20:16:20,082: <module>: DEBUG] Parsing vacancy ID 71879054 (201 / 435) parsing
# [2022-11-27 20:16:22,806: <module>: DEBUG] Parsing vacancy ID 72009804 (202 / 435) parsing
# [2022-11-27 20:16:24,701: <module>: DEBUG] Parsing vacancy ID 71881834 (203 / 435) parsing
# [2022-11-27 20:16:26,878: <module>: DEBUG] Parsing vacancy ID 67560361 (204 / 435) parsing
# [2022-11-27 20:16:29,452: <module>: DEBUG] Parsing vacancy ID 67497281 (205 / 435) parsing
# [2022-11-27 20:16:32,844: <module>: DEBUG] Parsing vacancy ID 69798669 (206 / 435) parsing
# [2022-11-27 20:16:34,922: <module>: DEBUG] Parsing vacancy ID 71757465 (207 / 435) parsing
# [2022-11-27 20:16:37,766: <module>: DEBUG] Parsing vacancy ID 71491903 (208 / 435) parsing
# [2022-11-27 20:16:41,461: <module>: DEBUG] Parsing vacancy ID 72462241 (209 / 435) parsing
# [2022-11-27 20:16:43,892: <module>: DEBUG] Parsing vacancy ID 72481614 (210 / 435) parsing
# [2022-11-27 20:16:47,028: <module>: DEBUG] Parsing vacancy ID 71550052 (211 / 435) parsing
# [2022-11-27 20:16:49,854: <module>: DEBUG] Parsing vacancy ID 72017561 (212 / 435) parsing
# [2022-11-27 20:16:52,745: <module>: DEBUG] Parsing vacancy ID 71186604 (213 / 435) parsing
# [2022-11-27 20:16:57,236: <module>: DEBUG] Parsing vacancy ID 70159029 (214 / 435) parsing
# [2022-11-27 20:17:00,453: <module>: DEBUG] Parsing vacancy ID 69761930 (215 / 435) parsing
# [2022-11-27 20:17:02,973: <module>: DEBUG] Parsing vacancy ID 71324989 (216 / 435) parsing
# [2022-11-27 20:17:05,358: <module>: DEBUG] Parsing vacancy ID 72136579 (217 / 435) parsing
# [2022-11-27 20:17:07,760: <module>: DEBUG] Parsing vacancy ID 72293408 (218 / 435) parsing
# [2022-11-27 20:17:10,044: <module>: DEBUG] Parsing vacancy ID 68958646 (219 / 435) parsing
# [2022-11-27 20:17:12,544: <module>: DEBUG] Parsing vacancy ID 72216020 (220 / 435) parsing
# [2022-11-27 20:17:14,483: <module>: DEBUG] Parsing vacancy ID 70761595 (221 / 435) parsing
# [2022-11-27 20:17:16,581: <module>: DEBUG] Parsing vacancy ID 72890279 (222 / 435) parsing
# [2022-11-27 20:17:19,142: <module>: DEBUG] Parsing vacancy ID 71647544 (223 / 435) parsing
# [2022-11-27 20:17:22,672: <module>: DEBUG] Parsing vacancy ID 67752294 (224 / 435) parsing
# [2022-11-27 20:17:24,758: <module>: DEBUG] Parsing vacancy ID 72937694 (225 / 435) parsing
# [2022-11-27 20:17:27,829: <module>: DEBUG] Parsing vacancy ID 72690491 (226 / 435) parsing
# [2022-11-27 20:17:31,015: <module>: DEBUG] Parsing vacancy ID 72800599 (227 / 435) parsing
# [2022-11-27 20:17:34,056: <module>: DEBUG] Parsing vacancy ID 72705264 (228 / 435) parsing
# [2022-11-27 20:17:36,415: <module>: DEBUG] Parsing vacancy ID 72655363 (229 / 435) parsing
# [2022-11-27 20:17:38,796: <module>: DEBUG] Parsing vacancy ID 72696252 (230 / 435) parsing
# [2022-11-27 20:17:41,950: <module>: DEBUG] Parsing vacancy ID 70649372 (231 / 435) parsing
# [2022-11-27 20:17:44,663: <module>: DEBUG] Parsing vacancy ID 72520219 (232 / 435) parsing
# [2022-11-27 20:17:47,455: <module>: DEBUG] Parsing vacancy ID 69277072 (233 / 435) parsing
# [2022-11-27 20:17:49,639: <module>: DEBUG] Parsing vacancy ID 72475780 (234 / 435) parsing
# [2022-11-27 20:17:51,951: <module>: DEBUG] Parsing vacancy ID 55133520 (235 / 435) parsing
# [2022-11-27 20:17:54,230: <module>: DEBUG] Parsing vacancy ID 72371872 (236 / 435) parsing
# [2022-11-27 20:17:56,201: <module>: DEBUG] Parsing vacancy ID 71883330 (237 / 435) parsing
# [2022-11-27 20:17:58,454: <module>: DEBUG] Parsing vacancy ID 71008487 (238 / 435) parsing
# [2022-11-27 20:18:00,641: <module>: DEBUG] Parsing vacancy ID 69710901 (239 / 435) parsing
# [2022-11-27 20:18:03,226: <module>: DEBUG] Parsing vacancy ID 72064606 (240 / 435) parsing
# [2022-11-27 20:18:05,417: <module>: DEBUG] Parsing vacancy ID 71781851 (241 / 435) parsing
# [2022-11-27 20:18:07,532: <module>: DEBUG] Parsing vacancy ID 71142123 (242 / 435) parsing
# [2022-11-27 20:18:09,584: <module>: DEBUG] Parsing vacancy ID 68605154 (243 / 435) parsing
# [2022-11-27 20:18:12,215: <module>: DEBUG] Parsing vacancy ID 69521844 (244 / 435) parsing
# [2022-11-27 20:18:14,832: <module>: DEBUG] Parsing vacancy ID 72350935 (245 / 435) parsing
# [2022-11-27 20:18:17,086: <module>: DEBUG] Parsing vacancy ID 71885162 (246 / 435) parsing
# [2022-11-27 20:18:20,189: <module>: DEBUG] Parsing vacancy ID 71145962 (247 / 435) parsing
# [2022-11-27 20:18:22,460: <module>: DEBUG] Parsing vacancy ID 72067498 (248 / 435) parsing
# [2022-11-27 20:18:24,610: <module>: DEBUG] Parsing vacancy ID 72069888 (249 / 435) parsing
# [2022-11-27 20:18:26,676: <module>: DEBUG] Parsing vacancy ID 71426958 (250 / 435) parsing
# [2022-11-27 20:18:28,995: <module>: DEBUG] Parsing vacancy ID 71757739 (251 / 435) parsing
# [2022-11-27 20:18:31,388: <module>: DEBUG] Parsing vacancy ID 71908944 (252 / 435) parsing
# [2022-11-27 20:18:34,365: <module>: DEBUG] Parsing vacancy ID 72819441 (253 / 435) parsing
# [2022-11-27 20:18:36,608: <module>: DEBUG] Parsing vacancy ID 71523297 (254 / 435) parsing
# [2022-11-27 20:18:38,806: <module>: DEBUG] Parsing vacancy ID 72323871 (255 / 435) parsing
# [2022-11-27 20:18:41,003: <module>: DEBUG] Parsing vacancy ID 71492524 (256 / 435) parsing
# [2022-11-27 20:18:43,156: <module>: DEBUG] Parsing vacancy ID 71484836 (257 / 435) parsing
# [2022-11-27 20:18:45,287: <module>: DEBUG] Parsing vacancy ID 72787688 (258 / 435) parsing
# [2022-11-27 20:18:47,532: <module>: DEBUG] Parsing vacancy ID 70673604 (259 / 435) parsing
# [2022-11-27 20:18:49,578: <module>: DEBUG] Parsing vacancy ID 67982032 (260 / 435) parsing
# [2022-11-27 20:18:51,905: <module>: DEBUG] Parsing vacancy ID 71582181 (261 / 435) parsing
# [2022-11-27 20:18:54,131: <module>: DEBUG] Parsing vacancy ID 72946864 (262 / 435) parsing
# [2022-11-27 20:18:56,408: <module>: DEBUG] Parsing vacancy ID 72012099 (263 / 435) parsing
# [2022-11-27 20:18:59,228: <module>: DEBUG] Parsing vacancy ID 72952363 (264 / 435) parsing
# [2022-11-27 20:19:02,056: <module>: DEBUG] Parsing vacancy ID 72747476 (265 / 435) parsing
# [2022-11-27 20:19:04,099: <module>: DEBUG] Parsing vacancy ID 70417563 (266 / 435) parsing
# [2022-11-27 20:19:06,554: <module>: DEBUG] Parsing vacancy ID 71890920 (267 / 435) parsing
# [2022-11-27 20:19:09,021: <module>: DEBUG] Parsing vacancy ID 67136583 (268 / 435) parsing
# [2022-11-27 20:19:23,832: <module>: DEBUG] Parsing vacancy ID 71836841 (269 / 435) parsing
# [2022-11-27 20:19:26,532: <module>: DEBUG] Parsing vacancy ID 70674007 (270 / 435) parsing
# [2022-11-27 20:19:29,655: <module>: DEBUG] Parsing vacancy ID 72230072 (271 / 435) parsing
# [2022-11-27 20:19:32,080: <module>: DEBUG] Parsing vacancy ID 71291372 (272 / 435) parsing
# [2022-11-27 20:19:34,266: <module>: DEBUG] Parsing vacancy ID 72878083 (273 / 435) parsing
# [2022-11-27 20:19:36,321: <module>: DEBUG] Parsing vacancy ID 72688089 (274 / 435) parsing
# [2022-11-27 20:19:38,740: <module>: DEBUG] Parsing vacancy ID 71883843 (275 / 435) parsing
# [2022-11-27 20:19:40,952: <module>: DEBUG] Parsing vacancy ID 69317605 (276 / 435) parsing
# [2022-11-27 20:19:43,654: <module>: DEBUG] Parsing vacancy ID 72948221 (277 / 435) parsing
# [2022-11-27 20:19:45,982: <module>: DEBUG] Parsing vacancy ID 72752133 (278 / 435) parsing
# [2022-11-27 20:19:47,886: <module>: DEBUG] Parsing vacancy ID 72415358 (279 / 435) parsing
# [2022-11-27 20:19:50,174: <module>: DEBUG] Parsing vacancy ID 72008668 (280 / 435) parsing
# [2022-11-27 20:19:52,473: <module>: DEBUG] Parsing vacancy ID 71575249 (281 / 435) parsing
# [2022-11-27 20:19:54,677: <module>: DEBUG] Parsing vacancy ID 72888902 (282 / 435) parsing
# [2022-11-27 20:19:57,885: <module>: DEBUG] Parsing vacancy ID 72946834 (283 / 435) parsing
# [2022-11-27 20:19:59,916: <module>: DEBUG] Parsing vacancy ID 71291375 (284 / 435) parsing
# [2022-11-27 20:20:02,397: <module>: DEBUG] Parsing vacancy ID 72546464 (285 / 435) parsing
# [2022-11-27 20:20:04,642: <module>: DEBUG] Parsing vacancy ID 69197357 (286 / 435) parsing
# [2022-11-27 20:20:06,685: <module>: DEBUG] Parsing vacancy ID 72944556 (287 / 435) parsing
# [2022-11-27 20:20:10,060: <module>: DEBUG] Parsing vacancy ID 72893549 (288 / 435) parsing
# [2022-11-27 20:20:12,212: <module>: DEBUG] Parsing vacancy ID 72924136 (289 / 435) parsing
# [2022-11-27 20:20:14,981: <module>: DEBUG] Parsing vacancy ID 72886108 (290 / 435) parsing
# [2022-11-27 20:20:17,158: <module>: DEBUG] Parsing vacancy ID 71714632 (291 / 435) parsing
# [2022-11-27 20:20:19,413: <module>: DEBUG] Parsing vacancy ID 72559915 (292 / 435) parsing
# [2022-11-27 20:20:21,752: <module>: DEBUG] Parsing vacancy ID 70979367 (293 / 435) parsing
# [2022-11-27 20:20:23,922: <module>: DEBUG] Parsing vacancy ID 72781802 (294 / 435) parsing
# [2022-11-27 20:20:26,986: <module>: DEBUG] Parsing vacancy ID 72038325 (295 / 435) parsing
# [2022-11-27 20:20:31,150: <module>: DEBUG] Parsing vacancy ID 72753967 (296 / 435) parsing
# [2022-11-27 20:20:33,332: <module>: DEBUG] Parsing vacancy ID 72752950 (297 / 435) parsing
# [2022-11-27 20:20:35,945: <module>: DEBUG] Parsing vacancy ID 72889287 (298 / 435) parsing
# [2022-11-27 20:20:38,360: <module>: DEBUG] Parsing vacancy ID 71958940 (299 / 435) parsing
# [2022-11-27 20:20:40,590: <module>: DEBUG] Parsing vacancy ID 72884368 (300 / 435) parsing
# [2022-11-27 20:20:43,103: <module>: DEBUG] Parsing vacancy ID 72821966 (301 / 435) parsing
# [2022-11-27 20:20:45,168: <module>: DEBUG] Parsing vacancy ID 72821352 (302 / 435) parsing
# [2022-11-27 20:20:47,257: <module>: DEBUG] Parsing vacancy ID 72820761 (303 / 435) parsing
# [2022-11-27 20:20:49,674: <module>: DEBUG] Parsing vacancy ID 72752515 (304 / 435) parsing
# [2022-11-27 20:20:52,321: <module>: DEBUG] Parsing vacancy ID 70243733 (305 / 435) parsing
# [2022-11-27 20:20:54,872: <module>: DEBUG] Parsing vacancy ID 71712459 (306 / 435) parsing
# [2022-11-27 20:20:57,241: <module>: DEBUG] Parsing vacancy ID 54829296 (307 / 435) parsing
# [2022-11-27 20:20:59,696: <module>: DEBUG] Parsing vacancy ID 72856413 (308 / 435) parsing
# [2022-11-27 20:21:02,019: <module>: DEBUG] Parsing vacancy ID 72788567 (309 / 435) parsing
# [2022-11-27 20:21:04,143: <module>: DEBUG] Parsing vacancy ID 69865413 (310 / 435) parsing
# [2022-11-27 20:21:06,257: <module>: DEBUG] Parsing vacancy ID 72788226 (311 / 435) parsing
# [2022-11-27 20:21:08,803: <module>: DEBUG] Parsing vacancy ID 71315683 (312 / 435) parsing
# [2022-11-27 20:21:11,007: <module>: DEBUG] Parsing vacancy ID 68621600 (313 / 435) parsing
# [2022-11-27 20:21:13,486: <module>: DEBUG] Parsing vacancy ID 69379894 (314 / 435) parsing
# [2022-11-27 20:21:16,818: <module>: DEBUG] Parsing vacancy ID 72141335 (315 / 435) parsing
# [2022-11-27 20:21:19,102: <module>: DEBUG] Parsing vacancy ID 72547109 (316 / 435) parsing
# [2022-11-27 20:21:22,030: <module>: DEBUG] Parsing vacancy ID 72736422 (317 / 435) parsing
# [2022-11-27 20:21:24,688: <module>: DEBUG] Parsing vacancy ID 72872678 (318 / 435) parsing
# [2022-11-27 20:21:26,928: <module>: DEBUG] Parsing vacancy ID 72800646 (319 / 435) parsing
# [2022-11-27 20:21:28,967: <module>: DEBUG] Parsing vacancy ID 72804111 (320 / 435) parsing
# [2022-11-27 20:21:31,082: <module>: DEBUG] Parsing vacancy ID 71614417 (321 / 435) parsing
# [2022-11-27 20:21:33,601: <module>: DEBUG] Parsing vacancy ID 70168410 (322 / 435) parsing
# [2022-11-27 20:21:35,913: <module>: DEBUG] Parsing vacancy ID 72725421 (323 / 435) parsing
# [2022-11-27 20:21:38,709: <module>: DEBUG] Parsing vacancy ID 72679805 (324 / 435) parsing
# [2022-11-27 20:21:41,964: <module>: DEBUG] Parsing vacancy ID 70345760 (325 / 435) parsing
# [2022-11-27 20:21:44,257: <module>: DEBUG] Parsing vacancy ID 72736408 (326 / 435) parsing
# [2022-11-27 20:21:46,841: <module>: DEBUG] Parsing vacancy ID 72229021 (327 / 435) parsing
# [2022-11-27 20:22:45,550: <module>: DEBUG] Parsing vacancy ID 71218959 (328 / 435) parsing
# [2022-11-27 20:23:45,637: <module>: DEBUG] Parsing vacancy ID 71393637 (329 / 435) parsing
# [2022-11-27 20:23:47,941: <module>: DEBUG] Parsing vacancy ID 70179582 (330 / 435) parsing
# [2022-11-27 20:24:46,793: <module>: DEBUG] Parsing vacancy ID 72702509 (331 / 435) parsing
# [2022-11-27 20:24:49,825: <module>: DEBUG] Parsing vacancy ID 72740316 (332 / 435) parsing
# [2022-11-27 20:24:52,459: <module>: DEBUG] Parsing vacancy ID 72015268 (333 / 435) parsing
# [2022-11-27 20:24:54,881: <module>: DEBUG] Parsing vacancy ID 72515207 (334 / 435) parsing
# [2022-11-27 20:25:18,282: <module>: DEBUG] Parsing vacancy ID 67411146 (335 / 435) parsing
# [2022-11-27 20:25:22,063: <module>: DEBUG] Parsing vacancy ID 55433924 (336 / 435) parsing
# [2022-11-27 20:25:24,497: <module>: DEBUG] Parsing vacancy ID 72663343 (337 / 435) parsing
# [2022-11-27 20:25:27,168: <module>: DEBUG] Parsing vacancy ID 70903553 (338 / 435) parsing
# [2022-11-27 20:25:29,354: <module>: DEBUG] Parsing vacancy ID 70903214 (339 / 435) parsing
# [2022-11-27 20:25:32,925: <module>: DEBUG] Parsing vacancy ID 72742677 (340 / 435) parsing
# [2022-11-27 20:25:35,096: <module>: DEBUG] Parsing vacancy ID 70895577 (341 / 435) parsing
# [2022-11-27 20:25:37,078: <module>: DEBUG] Parsing vacancy ID 54996943 (342 / 435) parsing
# [2022-11-27 20:25:40,345: <module>: DEBUG] Parsing vacancy ID 69293111 (343 / 435) parsing
# [2022-11-27 20:25:42,477: <module>: DEBUG] Parsing vacancy ID 72460074 (344 / 435) parsing
# [2022-11-27 20:25:45,440: <module>: DEBUG] Parsing vacancy ID 71133669 (345 / 435) parsing
# [2022-11-27 20:25:47,419: <module>: DEBUG] Parsing vacancy ID 70731531 (346 / 435) parsing
# [2022-11-27 20:25:49,621: <module>: DEBUG] Parsing vacancy ID 68115103 (347 / 435) parsing
# [2022-11-27 20:25:51,904: <module>: DEBUG] Parsing vacancy ID 72356204 (348 / 435) parsing
# [2022-11-27 20:25:54,443: <module>: DEBUG] Parsing vacancy ID 72495949 (349 / 435) parsing
# [2022-11-27 20:25:57,265: <module>: DEBUG] Parsing vacancy ID 71493755 (350 / 435) parsing
# [2022-11-27 20:25:59,576: <module>: DEBUG] Parsing vacancy ID 72422598 (351 / 435) parsing
# [2022-11-27 20:26:01,780: <module>: DEBUG] Parsing vacancy ID 72390089 (352 / 435) parsing
# [2022-11-27 20:26:03,784: <module>: DEBUG] Parsing vacancy ID 72567310 (353 / 435) parsing
# [2022-11-27 20:26:05,633: <module>: DEBUG] Parsing vacancy ID 72376925 (354 / 435) parsing
# [2022-11-27 20:26:07,818: <module>: DEBUG] Parsing vacancy ID 72559304 (355 / 435) parsing
# [2022-11-27 20:26:10,124: <module>: DEBUG] Parsing vacancy ID 72357549 (356 / 435) parsing
# [2022-11-27 20:26:12,293: <module>: DEBUG] Parsing vacancy ID 68148229 (357 / 435) parsing
# [2022-11-27 20:26:14,599: <module>: DEBUG] Parsing vacancy ID 72487579 (358 / 435) parsing
# [2022-11-27 20:26:16,677: <module>: DEBUG] Parsing vacancy ID 69404613 (359 / 435) parsing
# [2022-11-27 20:26:18,793: <module>: DEBUG] Parsing vacancy ID 72416209 (360 / 435) parsing
# [2022-11-27 20:26:21,577: <module>: DEBUG] Parsing vacancy ID 72304215 (361 / 435) parsing
# [2022-11-27 20:26:24,301: <module>: DEBUG] Parsing vacancy ID 71017285 (362 / 435) parsing
# [2022-11-27 20:26:26,950: <module>: DEBUG] Parsing vacancy ID 72487009 (363 / 435) parsing
# [2022-11-27 20:26:29,813: <module>: DEBUG] Parsing vacancy ID 72345450 (364 / 435) parsing
# [2022-11-27 20:26:32,294: <module>: DEBUG] Parsing vacancy ID 72460129 (365 / 435) parsing
# [2022-11-27 20:26:34,386: <module>: DEBUG] Parsing vacancy ID 70862418 (366 / 435) parsing
# [2022-11-27 20:26:37,010: <module>: DEBUG] Parsing vacancy ID 72164203 (367 / 435) parsing
# [2022-11-27 20:26:40,254: <module>: DEBUG] Parsing vacancy ID 72161998 (368 / 435) parsing
# [2022-11-27 20:26:42,425: <module>: DEBUG] Parsing vacancy ID 72338655 (369 / 435) parsing
# [2022-11-27 20:26:44,752: <module>: DEBUG] Parsing vacancy ID 72421904 (370 / 435) parsing
# [2022-11-27 20:26:47,356: <module>: DEBUG] Parsing vacancy ID 72421275 (371 / 435) parsing
# [2022-11-27 20:26:49,773: <module>: DEBUG] Parsing vacancy ID 69389255 (372 / 435) parsing
# [2022-11-27 20:26:51,963: <module>: DEBUG] Parsing vacancy ID 70163749 (373 / 435) parsing
# [2022-11-27 20:26:54,514: <module>: DEBUG] Parsing vacancy ID 72126864 (374 / 435) parsing
# [2022-11-27 20:26:56,475: <module>: DEBUG] Parsing vacancy ID 72088729 (375 / 435) parsing
# [2022-11-27 20:26:59,416: <module>: DEBUG] Parsing vacancy ID 70231803 (376 / 435) parsing
# [2022-11-27 20:27:01,896: <module>: DEBUG] Parsing vacancy ID 66725917 (377 / 435) parsing
# [2022-11-27 20:27:04,490: <module>: DEBUG] Parsing vacancy ID 71289566 (378 / 435) parsing
# [2022-11-27 20:27:06,398: <module>: DEBUG] Parsing vacancy ID 67924416 (379 / 435) parsing
# [2022-11-27 20:27:08,717: <module>: DEBUG] Parsing vacancy ID 72087568 (380 / 435) parsing
# [2022-11-27 20:27:11,824: <module>: DEBUG] Parsing vacancy ID 72297037 (381 / 435) parsing
# [2022-11-27 20:27:14,243: <module>: DEBUG] Parsing vacancy ID 72285842 (382 / 435) parsing
# [2022-11-27 20:27:16,316: <module>: DEBUG] Parsing vacancy ID 72421751 (383 / 435) parsing
# [2022-11-27 20:27:18,424: <module>: DEBUG] Parsing vacancy ID 72027147 (384 / 435) parsing
# [2022-11-27 20:27:20,644: <module>: DEBUG] Parsing vacancy ID 71080815 (385 / 435) parsing
# [2022-11-27 20:27:22,703: <module>: DEBUG] Parsing vacancy ID 72082373 (386 / 435) parsing
# [2022-11-27 20:27:24,734: <module>: DEBUG] Parsing vacancy ID 71322369 (387 / 435) parsing
# [2022-11-27 20:27:26,945: <module>: DEBUG] Parsing vacancy ID 72285658 (388 / 435) parsing
# [2022-11-27 20:27:29,893: <module>: DEBUG] Parsing vacancy ID 70011803 (389 / 435) parsing
# [2022-11-27 20:27:32,368: <module>: DEBUG] Parsing vacancy ID 69583138 (390 / 435) parsing
# [2022-11-27 20:27:34,480: <module>: DEBUG] Parsing vacancy ID 72221358 (391 / 435) parsing
# [2022-11-27 20:27:36,809: <module>: DEBUG] Parsing vacancy ID 69544850 (392 / 435) parsing
# [2022-11-27 20:27:39,149: <module>: DEBUG] Parsing vacancy ID 71772659 (393 / 435) parsing
# [2022-11-27 20:27:41,292: <module>: DEBUG] Parsing vacancy ID 67281498 (394 / 435) parsing
# [2022-11-27 20:27:44,284: <module>: DEBUG] Parsing vacancy ID 72167155 (395 / 435) parsing
# [2022-11-27 20:27:46,907: <module>: DEBUG] Parsing vacancy ID 69665417 (396 / 435) parsing
# [2022-11-27 20:27:49,075: <module>: DEBUG] Parsing vacancy ID 70742405 (397 / 435) parsing
# [2022-11-27 20:27:51,042: <module>: DEBUG] Parsing vacancy ID 69856866 (398 / 435) parsing
# [2022-11-27 20:27:53,548: <module>: DEBUG] Parsing vacancy ID 68330853 (399 / 435) parsing
# [2022-11-27 20:27:55,614: <module>: DEBUG] Parsing vacancy ID 70956260 (400 / 435) parsing
# [2022-11-27 20:28:07,413: <module>: DEBUG] Parsing vacancy ID 72084330 (401 / 435) parsing
# [2022-11-27 20:28:11,116: <module>: DEBUG] Parsing vacancy ID 72064609 (402 / 435) parsing
# [2022-11-27 20:28:13,298: <module>: DEBUG] Parsing vacancy ID 72209562 (403 / 435) parsing
# [2022-11-27 20:28:15,794: <module>: DEBUG] Parsing vacancy ID 71036467 (404 / 435) parsing
# [2022-11-27 20:28:17,715: <module>: DEBUG] Parsing vacancy ID 70862574 (405 / 435) parsing
# [2022-11-27 20:28:20,267: <module>: DEBUG] Parsing vacancy ID 71354549 (406 / 435) parsing
# [2022-11-27 20:28:22,457: <module>: DEBUG] Parsing vacancy ID 72028556 (407 / 435) parsing
# [2022-11-27 20:28:24,568: <module>: DEBUG] Parsing vacancy ID 70995598 (408 / 435) parsing
# [2022-11-27 20:28:26,882: <module>: DEBUG] Parsing vacancy ID 68357777 (409 / 435) parsing
# [2022-11-27 20:28:29,239: <module>: DEBUG] Parsing vacancy ID 69774676 (410 / 435) parsing
# [2022-11-27 20:28:31,314: <module>: DEBUG] Parsing vacancy ID 68023052 (411 / 435) parsing
# [2022-11-27 20:28:33,756: <module>: DEBUG] Parsing vacancy ID 72085848 (412 / 435) parsing
# [2022-11-27 20:28:35,975: <module>: DEBUG] Parsing vacancy ID 71136466 (413 / 435) parsing
# [2022-11-27 20:28:38,305: <module>: DEBUG] Parsing vacancy ID 71930796 (414 / 435) parsing
# [2022-11-27 20:28:41,599: <module>: DEBUG] Parsing vacancy ID 69972583 (415 / 435) parsing
# [2022-11-27 20:28:43,815: <module>: DEBUG] Parsing vacancy ID 72030849 (416 / 435) parsing
# [2022-11-27 20:28:46,137: <module>: DEBUG] Parsing vacancy ID 72006379 (417 / 435) parsing
# [2022-11-27 20:28:48,359: <module>: DEBUG] Parsing vacancy ID 70953440 (418 / 435) parsing
# [2022-11-27 20:28:50,508: <module>: DEBUG] Parsing vacancy ID 71933443 (419 / 435) parsing
# [2022-11-27 20:28:52,864: <module>: DEBUG] Parsing vacancy ID 72052750 (420 / 435) parsing
# [2022-11-27 20:28:54,894: <module>: DEBUG] Parsing vacancy ID 71889203 (421 / 435) parsing
# [2022-11-27 20:28:57,209: <module>: DEBUG] Parsing vacancy ID 71136980 (422 / 435) parsing
# [2022-11-27 20:28:59,435: <module>: DEBUG] Parsing vacancy ID 71833151 (423 / 435) parsing
# [2022-11-27 20:29:01,642: <module>: DEBUG] Parsing vacancy ID 72127423 (424 / 435) parsing
# [2022-11-27 20:29:04,184: <module>: DEBUG] Parsing vacancy ID 72072920 (425 / 435) parsing
# [2022-11-27 20:29:06,501: <module>: DEBUG] Parsing vacancy ID 71710949 (426 / 435) parsing
# [2022-11-27 20:29:08,814: <module>: DEBUG] Parsing vacancy ID 71709913 (427 / 435) parsing
# [2022-11-27 20:29:12,299: <module>: DEBUG] Parsing vacancy ID 71784128 (428 / 435) parsing
# [2022-11-27 20:29:14,759: <module>: DEBUG] Parsing vacancy ID 70871697 (429 / 435) parsing
# [2022-11-27 20:29:19,836: <module>: DEBUG] Parsing vacancy ID 71766550 (430 / 435) parsing
# [2022-11-27 20:29:42,895: <module>: DEBUG] Parsing vacancy ID 68650334 (431 / 435) parsing
# [2022-11-27 20:29:45,651: <module>: DEBUG] Parsing vacancy ID 71750170 (432 / 435) parsing
# [2022-11-27 20:29:47,671: <module>: DEBUG] Parsing vacancy ID 71864985 (433 / 435) parsing
# [2022-11-27 20:29:49,937: <module>: DEBUG] Parsing vacancy ID 71923183 (434 / 435) parsing
# [2022-11-27 20:29:52,688: <module>: DEBUG] Parsing finished
#                                                vacancy_name  \
# vacancy_id
# 72750262    Ведущий аналитик (качество данных\Data quality)
# 72674818                                    Аналитик данных
# 72527010                               Аналитик базы данных
# 70839955                      Аналитик данных (Data Office)
# 72943931                                Аналитик ГЕО данных
#
#                                 company_name  \
# vacancy_id
# 72750262                      Банк ВТБ (ПАО)
# 72674818    Городские информационные системы
# 72527010                              Вектор
# 70839955                       VK, ВКонтакте
# 72943931        ГАУ ИНСТИТУТ ГЕНПЛАНА МОСКВЫ
#
#                                          address   latitude  longitude  \
# vacancy_id
# 72750262    Москва, Пресненская набережная, 10с1  55.748914  37.535466
# 72674818                                     NaN        NaN        NaN
# 72527010    Красногорск, бульвар Строителей, 4к1  55.814462  37.385412
# 70839955                                     NaN        NaN        NaN
# 72943931       Москва, 2-я Брестская улица, 2/14  55.769641  37.593121
#
#             salary_from  salary_to salary_currency salary_gross  \
# vacancy_id
# 72750262            NaN        NaN             NaN          NaN
# 72674818       120000.0   180000.0             RUR        False
# 72527010        70000.0        NaN             RUR        False
# 70839955            NaN        NaN             NaN          NaN
# 72943931            NaN        NaN             NaN          NaN
#
#                publication_time         last_changed  schedule  \
# vacancy_id
# 72750262    2022-11-23 07:08:44  2022-11-23 07:08:44  FULL_DAY
# 72674818    2022-11-27 09:36:56  2022-11-27 10:21:43  FULL_DAY
# 72527010    2022-11-27 08:32:14  2022-11-27 09:21:16  FULL_DAY
# 70839955    2022-11-27 07:02:13  2022-11-27 07:02:13  FULL_DAY
# 72943931    2022-11-25 13:00:40  2022-11-26 19:50:13  FULL_DAY
#
#                                                           req  \
# vacancy_id
# 72750262    Высшее образование. Опыт работы в качестве ана...
# 72674818    ...заданий, валидация данных. Особенности OLAP...
# 72527010    Умение обрабатывать большие объемы данных и ви...
# 70839955    Понимаете основные продуктовые и бизнес-метрик...
# 72943931    Хорошее знание инструментов WEB-картографии и ...
#
#                                                          resp  \
# vacancy_id
# 72750262    Мониторинг качества данных, организация процес...
# 72674818    ...SQL-запросы, хранимые процедуры, вьюшки. Ви...
# 72527010    ...данных и подготовка информации для расчетов...
# 70839955    Плотно взаимодействовать на ежедневной основе ...
# 72943931    Интеграция данных из различных источников в ед...
#
#                                                          cond  \
# vacancy_id
# 72750262    Трудоустройство согласно Законодательству. Кон...
# 72674818    Удалённая работа. Уютный коллектив. Минимум бю...
# 72527010    График: 5/2 , с 8:00 до 17:00,выходные: суббот...
# 70839955                                                  NaN
# 72943931    Стабильная заработная плата, включающая оклад,...
#
#                                              full_description  \
# vacancy_id
# 72750262    Обязанности:  участие в проектах по внедрению ...
# 72674818    Мы сейчас переносим отчетность из SAP систем н...
# 72527010    Мы группа компаний "Truck Radar" - лидеры на р...
# 70839955    Мы занимаемся аналитикой экосистемных продукто...
# 72943931    Обязанности: • Создание и развитие корпоративн...
#
#                                                    key_skills  \
# vacancy_id
# 72750262    Анализ данных;Аналитическое мышление;Data quality
# 72674818    Английский язык;Работа в команде;SQL;PostgreSQ...
# 72527010    Базы данных;Работа с базами данных;Прогнозиров...
# 70839955    SQL;Python;Математическая статистика;BI;Аналитика
# 72943931                       QGIS;ArcGIS;ГИС;SQL;PostgreSQL
#
#            experience_needed
# vacancy_id
# 72750262             3–6 лет
# 72674818             3–6 лет
# 72527010            1–3 года
# 70839955            1–3 года
# 72943931            1–3 года

# %% [markdown]
# Saving intermediate dataset variant

# %%
df.to_csv('datasets/vacancies-no-duplicates-augm-2022-11-27.csv')

# %%
browser.quit()

# %%
df['experience_needed'].value_counts()
# Out:
# 1–3 года        237
# 3–6 лет         176
# более 6 лет      12
# не требуется     10
# Name: experience_needed, dtype: int64

# %% [markdown]
# Determining number of key skills mentioned

# %%
df['key_skills_num'] = df['key_skills'].apply(lambda x: len(x.split(';')))
df['key_skills_num'].max()
# Out:
# 29

# %% [markdown]
# Calculating key skills frequencies

# %%
key_skills_freq = {}
for vac_id in tqdm(df.index):
    if df.loc[vac_id, 'key_skills'] != '':
        for skill in df.loc[vac_id, 'key_skills'].split(';'):
            if key_skills_freq.get(skill, None) is None:
                key_skills_freq[skill] = 0
            key_skills_freq[skill] += 1
# Out:
# 100%|██████████| 435/435 [00:00<00:00, 22825.07it/s]

# %%
df_skills = pd.Series(key_skills_freq)
df_skills
# Out:
# Анализ данных             97
# Аналитическое мышление    60
# Data quality               2
# Английский язык           29
# Работа в команде          15
#                           ..
# Presto                     1
# Solr                       1
# Elasticsearch              1
# Credit Risk                1
# Lending                    1
# Length: 516, dtype: int64

# %% [markdown]
# First 10 most frequently skills

# %%
df_skills.sort_values(ascending=False).nlargest(20)
# Out:
# SQL                                    277
# Python                                 229
# Анализ данных                           97
# Аналитическое мышление                  60
# MS SQL                                  49
# MS PowerPoint                           45
# Математическая статистика               43
# Machine Learning                        34
# Power BI                                34
# Hadoop                                  31
# Английский язык                         29
# Статистический анализ                   27
# Работа с большим объемом информации     27
# Spark                                   27
# MS Excel                                25
# PostgreSQL                              24
# Big Data                                23
# ML                                      23
# Data Analysis                           23
# Аналитические исследования              23
# dtype: int64

# %%
df_skills = pd.DataFrame(df_skills, columns=['frequency']).reset_index().rename(columns={'index': 'skill'})
df_skills['skill_class'] = np.nan
df_skills.head()
# Out:
#                     skill  frequency  skill_class
# 0           Анализ данных         97          NaN
# 1  Аналитическое мышление         60          NaN
# 2            Data quality          2          NaN
# 3         Английский язык         29          NaN
# 4        Работа в команде         15          NaN

# %%
m = df_skills['skill'].str.contains('SQL')
df_skills.loc[m, 'skill_class'] = 'SQL'
df_skills.loc[m, ['skill', 'skill_class']]
# Out:
#                   skill skill_class
# 5                   SQL         SQL
# 6            PostgreSQL         SQL
# 30               MS SQL         SQL
# 39          SQL запросы         SQL
# 65               PL/SQL         SQL
# 139               NoSQL         SQL
# 142           PostgeSQL         SQL
# 204          Основы SQL         SQL
# 205  Базовые знания SQL         SQL
# 219       MS SQL Server         SQL
# 253       Oracle Pl/SQL         SQL
# 288               MySQL         SQL
# 381               PLSQL         SQL
# 382               T-SQL         SQL
# 458               MSSQL         SQL

# %%
df_skills.loc[[10, 16, 9, 31, 90], 'skill_class'] = 'SQL'

# %%
m = df_skills['skill'].str.contains('Python')
df_skills.loc[m, 'skill_class'] = 'Python'
df_skills.loc[m, ['skill', 'skill_class']]
# Out:
#            skill skill_class
# 7         Python      Python
# 143  Python 3.8+      Python

# %%
df_skills.loc[[0, 20, 68, 26, 161, 22], 'skill_class'] = 'Analysis & Statistics'

# %%
df_skills.loc[[189, 54, 349, 146, 460, 462, 475, 481], 'skill_class'] = 'Machine Learning'

# %%
df_skills.loc[[27, 34, 29, 55, 56, 46, 11], 'skill_class'] = 'BI & Presentations'

# %%
df_skills[df_skills['skill_class'].isna() & (df_skills['frequency'] > 1)].nlargest(30, columns=['frequency'])
# Out:
#                                    skill  frequency skill_class
# 1                 Аналитическое мышление         60         NaN
# 89                                Hadoop         31         NaN
# 3                        Английский язык         29         NaN
# 62   Работа с большим объемом информации         27         NaN
# 208                                Spark         27         NaN
# 93                              Big Data         23         NaN
# 53                                Pandas         20         NaN
# 154                                  Git         20         NaN
# 177                         Data Science         19         NaN
# 4                       Работа в команде         15         NaN
# 95          Математическое моделирование         14         NaN
# 71                         Бизнес-анализ         13         NaN
# 173                          Data Mining         13         NaN
# 369                                  NLP         13         NaN
# 17                       Прогнозирование         12         NaN
# 38                                   ETL         12         NaN
# 201                                  VBA         12         NaN
# 98                        Atlassian Jira         11         NaN
# 127            Английский — B1 — Средний         11         NaN
# 111                 Управление проектами         10         NaN
# 153                 Atlassian Confluence         10         NaN
# 84                                   DWH          9         NaN
# 94                                 Numpy          9         NaN
# 152                         data science          8         NaN
# 162                Математический анализ          8         NaN
# 83                      Системный анализ          7         NaN
# 87                                   Sas          7         NaN
# 181      Разработка поисковых технологий          7         NaN
# 233                        Моделирование          7         NaN
# 371                               Docker          7         NaN

# %%
print('Total number of mentions: ', df_skills['frequency'].sum())
print('Unclassified skills (multiple mentions): ', df_skills[df_skills['skill_class'].isna() & (df_skills['frequency'] > 1)]['frequency'].sum())
print('Unclassified skills (single mention): ', df_skills[df_skills['skill_class'].isna() & (df_skills['frequency'] == 1)]['frequency'].sum())
# Out:
# Total number of mentions:  2342
# Unclassified skills (multiple mentions):  907
# Unclassified skills (single mention):  307

# %%
df_skills.groupby(by='skill_class', dropna=False).agg({'frequency': 'sum'}).sort_values(by='frequency', ascending=False)
# Out:
#                        frequency
# skill_class
# NaN                         1214
# SQL                          435
# Python                       230
# Analysis & Statistics        229
# BI & Presentations           140
# Machine Learning              94
